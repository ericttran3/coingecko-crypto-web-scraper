# %% [markdown]
# # Crypto Trading Bot
#
# This notebook is designed to teach you how to obtain data from top Cryptocurrency exchanges and API sources to build a trading bot for price arbitrage strategies

# %% [markdown]
# ### Install Packages
#
# - CoinGecko: https://github.com/man-c/pycoingecko
# - CoinMarketCap:

# %%
# !pip install pycoingecko --quiet
# Out:
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/etran/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
from datetime import datetime
from IPython.core.display import HTML, display

from pycoingecko import CoinGeckoAPI

# %% [markdown]
# ### Configure Jupyter Notebook

# %%
# %matplotlib inline

pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_colwidth', 255)

display(HTML("<style>.container {width:85%} </style>"))
# Out:
# <style>.container {width:85%} </style>

# %% [markdown]
# ### Import Data

# %%
cg = CoinGeckoAPI()

# %%
# Check API Server status
cg.ping()
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
# Get list of support vs currencies
cg.get_supported_vs_currencies()[:10]
# Out:
# ['btc', 'eth', 'ltc', 'bch', 'bnb', 'eos', 'xrp', 'xlm', 'link', 'dot']

# %% [markdown]
# ### Coins

# %%
#` List all supported coin ids, name, and symbol
coins = cg.get_coins_list()
coins[:5]
# Out:
# [{'id': '01coin', 'symbol': 'zoc', 'name': '01coin'},
#  {'id': '0-5x-long-algorand-token',
#   'symbol': 'algohalf',
#   'name': '0.5X Long Algorand Token'},
#  {'id': '0-5x-long-altcoin-index-token',
#   'symbol': 'althalf',
#   'name': '0.5X Long Altcoin Index Token'},
#  {'id': '0-5x-long-balancer-token',
#   'symbol': 'balhalf',
#   'name': '0.5X Long Balancer Token'},
#  {'id': '0-5x-long-bitcoin-cash-token',
#   'symbol': 'bchhalf',
#   'name': '0.5X Long Bitcoin Cash Token'}]

# %%
coins_df = pd.DataFrame(data=coins, columns=['id', 'symbol', 'name'])
coins_df
# Out:
#                                  id    symbol                           name
# 0                            01coin       zoc                         01coin
# 1          0-5x-long-algorand-token  algohalf       0.5X Long Algorand Token
# 2     0-5x-long-altcoin-index-token   althalf  0.5X Long Altcoin Index Token
# 3          0-5x-long-balancer-token   balhalf       0.5X Long Balancer Token
# 4      0-5x-long-bitcoin-cash-token   bchhalf   0.5X Long Bitcoin Cash Token
# ...                             ...       ...                            ...
# 7113                           zyro      zyro                           Zyro
# 7114                  zytara-dollar      zusd                  Zytara Dollar
# 7115                            zyx       zyx                            ZYX
# 7116                    zzz-finance       zzz                    zzz.finance
# 7117                 zzz-finance-v2     zzzv2                 zzz.finance v2
#
# [7118 rows x 3 columns]

# %%
# List all supported coins price, market cap, volume, and market related data
coins_market = cg.get_coins_markets(vs_currency='usd')
coins_market
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 59453,
#   'market_cap': 1107036449279,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1242837118419,
#   'total_volume': 71795395430,
#   'high_24h': 59457,
#   'low_24h': 56637,
#   'price_change_24h': 442.62,
#   'price_change_percentage_24h': 0.75007,
#   'market_cap_change_24h': 5321199261,
#   'market_cap_change_percentage_24h': 0.48299,
#   'circulating_supply': 18705400.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 64805,
#   'ath_change_percentage': -8.57197,
#   'ath_date': '2021-04-14T11:54:46.763Z',
#   'atl': 67.81,
#   'atl_change_percentage': 87277.31004,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:32.553Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 4048.37,
#   'market_cap': 465059983465,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 63923144229,
#   'high_24h': 4033.3,
#   'low_24h': 3767.19,
#   'price_change_24h': 109.11,
#   'price_change_percentage_24h': 2.76975,
#   'market_cap_change_24h': 7842485424,
#   'market_cap_change_percentage_24h': 1.71526,
#   'circulating_supply': 115811061.5615,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4018.99,
#   'ath_change_percentage': 0.10921,
#   'ath_date': '2021-05-10T03:18:21.646Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 929132.98942,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 90.32183094261613,
#    'currency': 'btc',
#    'percentage': 9032.183094261612},
#   'last_updated': '2021-05-10T03:38:31.978Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 675.84,
#   'market_cap': 104544376774,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 115368621253,
#   'total_volume': 5914944621,
#   'high_24h': 683.09,
#   'low_24h': 633.13,
#   'price_change_24h': 25.86,
#   'price_change_percentage_24h': 3.97901,
#   'market_cap_change_24h': 3932036285,
#   'market_cap_change_percentage_24h': 3.90811,
#   'circulating_supply': 154533651.9,
#   'total_supply': 170533651.9,
#   'max_supply': 170533651.9,
#   'ath': 683.09,
#   'ath_change_percentage': -0.85646,
#   'ath_date': '2021-05-10T01:03:13.852Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1700738.53911,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:18.882Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 1.57,
#   'market_cap': 72301211054,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': None,
#   'total_volume': 8554350205,
#   'high_24h': 1.59,
#   'low_24h': 1.47,
#   'price_change_24h': 0.00740238,
#   'price_change_percentage_24h': 0.47356,
#   'market_cap_change_24h': 146752907,
#   'market_cap_change_percentage_24h': 0.20339,
#   'circulating_supply': 46030731641.0,
#   'total_supply': 100000000000.0,
#   'max_supply': None,
#   'ath': 3.4,
#   'ath_change_percentage': -53.86044,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 58273.38506,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:37:59.309Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.527073,
#   'market_cap': 69096476437,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 46376304188,
#   'high_24h': 0.66551,
#   'low_24h': 0.432345,
#   'price_change_24h': -0.1327815,
#   'price_change_percentage_24h': -20.12284,
#   'market_cap_change_24h': -14513217216.207184,
#   'market_cap_change_percentage_24h': -17.35829,
#   'circulating_supply': 129531248765.146,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -24.71725,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 633649.46039,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:04.272Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 1.0,
#   'market_cap': 56202815798,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': None,
#   'total_volume': 207573311183,
#   'high_24h': 1.0,
#   'low_24h': 0.988826,
#   'price_change_24h': 0.00313397,
#   'price_change_percentage_24h': 0.3131,
#   'market_cap_change_24h': 430664703,
#   'market_cap_change_percentage_24h': 0.77219,
#   'circulating_supply': 55973495222.6165,
#   'total_supply': 55973495222.6165,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.11001,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 75.38168,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:07:09.008Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 1.75,
#   'market_cap': 56068930545,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': None,
#   'total_volume': 8600082856,
#   'high_24h': 1.82,
#   'low_24h': 1.59,
#   'price_change_24h': 0.125006,
#   'price_change_percentage_24h': 7.68054,
#   'market_cap_change_24h': 3697019907,
#   'market_cap_change_percentage_24h': 7.05917,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': None,
#   'ath': 1.82,
#   'ath_change_percentage': -4.17593,
#   'ath_date': '2021-05-09T14:43:39.019Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 8949.71594,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:47.350Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776',
#   'current_price': 41.46,
#   'market_cap': 41115368893,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': None,
#   'total_volume': 2134773474,
#   'high_24h': 41.56,
#   'low_24h': 38.2,
#   'price_change_24h': 1.89,
#   'price_change_percentage_24h': 4.78658,
#   'market_cap_change_24h': 1793047187,
#   'market_cap_change_percentage_24h': 4.55987,
#   'circulating_supply': 991146515.75971,
#   'total_supply': 1072095651.71259,
#   'max_supply': None,
#   'ath': 47.63,
#   'ath_change_percentage': -12.76455,
#   'ath_date': '2021-04-17T10:04:11.809Z',
#   'atl': 2.7,
#   'atl_change_percentage': 1440.52388,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:05.518Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 1517.93,
#   'market_cap': 28170159229,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': None,
#   'total_volume': 9172183136,
#   'high_24h': 1516.33,
#   'low_24h': 1299.37,
#   'price_change_24h': 114.04,
#   'price_change_percentage_24h': 8.12343,
#   'market_cap_change_24h': 1716856545,
#   'market_cap_change_percentage_24h': 6.49014,
#   'circulating_supply': 18732756.1467895,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 3785.82,
#   'ath_change_percentage': -60.92551,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 1822.78403,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:47.658Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 407.07,
#   'market_cap': 27199392159,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': None,
#   'total_volume': 16015257442,
#   'high_24h': 410.26,
#   'low_24h': 336.1,
#   'price_change_24h': 57.43,
#   'price_change_percentage_24h': 16.42555,
#   'market_cap_change_24h': 3821337716,
#   'market_cap_change_percentage_24h': 16.34583,
#   'circulating_supply': 66752414.5153875,
#   'total_supply': 84000000.0,
#   'max_supply': None,
#   'ath': 410.26,
#   'ath_change_percentage': -0.0238,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 35602.21408,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:38.552Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 51.61,
#   'market_cap': 21922103722,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 51580261008,
#   'total_volume': 3146475501,
#   'high_24h': 52.7,
#   'low_24h': 46.71,
#   'price_change_24h': 3.35,
#   'price_change_percentage_24h': 6.93557,
#   'market_cap_change_24h': 1349996174,
#   'market_cap_change_percentage_24h': 6.56226,
#   'circulating_supply': 425009553.9174637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -1.79172,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 34824.62306,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:32.886Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 40.79,
#   'market_cap': 21183932450,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 40749507333,
#   'total_volume': 899988358,
#   'high_24h': 40.75,
#   'low_24h': 38.2,
#   'price_change_24h': 0.583656,
#   'price_change_percentage_24h': 1.45169,
#   'market_cap_change_24h': 201495817,
#   'market_cap_change_percentage_24h': 0.96031,
#   'circulating_supply': 519857388.1320768,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -9.74871,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 3835.18492,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:40.067Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 1.0,
#   'market_cap': 15695546064,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': None,
#   'total_volume': 2815134936,
#   'high_24h': 1.0,
#   'low_24h': 0.992119,
#   'price_change_24h': 0.00088697,
#   'price_change_percentage_24h': 0.08868,
#   'market_cap_change_24h': 214172155,
#   'market_cap_change_percentage_24h': 1.38342,
#   'circulating_supply': 15689850131.2147,
#   'total_supply': 15684657823.6747,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.57749,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.924188,
#   'atl_change_percentage': 8.39303,
#   'atl_date': '2020-08-02T04:44:57.506Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:10.154Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 124.08,
#   'market_cap': 15679748964,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': None,
#   'total_volume': 15340345113,
#   'high_24h': 123.68,
#   'low_24h': 114.55,
#   'price_change_24h': 0.933711,
#   'price_change_percentage_24h': 0.7582,
#   'market_cap_change_24h': -287665006.8246479,
#   'market_cap_change_percentage_24h': -1.80158,
#   'circulating_supply': 127251168.075152,
#   'total_supply': 210700000.0,
#   'max_supply': None,
#   'ath': 167.09,
#   'ath_change_percentage': -27.76843,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 19522.91491,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 274.7394099738769,
#    'currency': 'usd',
#    'percentage': 27473.94099738769},
#   'last_updated': '2021-05-10T03:38:08.138Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.235287,
#   'market_cap': 15296799522,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 2555822853,
#   'high_24h': 0.24097,
#   'low_24h': 0.212107,
#   'price_change_24h': 0.01004321,
#   'price_change_percentage_24h': 4.45882,
#   'market_cap_change_24h': 612871241,
#   'market_cap_change_percentage_24h': 4.17376,
#   'circulating_supply': 64968961033.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -16.00862,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 12210.48008,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 19.345494689810483,
#    'currency': 'eth',
#    'percentage': 1934.5494689810484},
#   'last_updated': '2021-05-10T03:38:46.799Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.654485,
#   'market_cap': 15080289699,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': None,
#   'total_volume': 2222218609,
#   'high_24h': 0.661622,
#   'low_24h': 0.577742,
#   'price_change_24h': 0.03239878,
#   'price_change_percentage_24h': 5.20808,
#   'market_cap_change_24h': 657038306,
#   'market_cap_change_percentage_24h': 4.55541,
#   'circulating_supply': 23061607861.1599,
#   'total_supply': 50000000000.0,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -24.83679,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 138120.73623,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:33.640Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/coinmarketcap-solana-200.png?1616489452',
#   'current_price': 44.93,
#   'market_cap': 12260927537,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 21974500240,
#   'total_volume': 603962456,
#   'high_24h': 45.9,
#   'low_24h': 43.39,
#   'price_change_24h': -0.38252596,
#   'price_change_percentage_24h': -0.84413,
#   'market_cap_change_24h': -207534286.15605164,
#   'market_cap_change_percentage_24h': -1.66447,
#   'circulating_supply': 272637122.50492,
#   'total_supply': 488630611.0,
#   'max_supply': 488630611.0,
#   'ath': 49.67,
#   'ath_change_percentage': -9.48285,
#   'ath_date': '2021-05-01T23:43:44.771Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 8877.89886,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:45.932Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 12.02,
#   'market_cap': 12025924959,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': None,
#   'total_volume': 465382911,
#   'high_24h': 12.45,
#   'low_24h': 11.53,
#   'price_change_24h': -0.41668804,
#   'price_change_percentage_24h': -3.34916,
#   'market_cap_change_24h': -491371872.65950966,
#   'market_cap_change_percentage_24h': -3.92554,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -23.64347,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 29610.62407,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 79.165970873324,
#    'currency': 'usd',
#    'percentage': 7916.5970873324},
#   'last_updated': '2021-05-10T03:38:02.531Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.145982,
#   'market_cap': 10462893117,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': None,
#   'total_volume': 4015191106,
#   'high_24h': 0.147667,
#   'low_24h': 0.135983,
#   'price_change_24h': 0.00163497,
#   'price_change_percentage_24h': 1.13267,
#   'market_cap_change_24h': 65236540,
#   'market_cap_change_percentage_24h': 0.62742,
#   'circulating_supply': 71660220128.0,
#   'total_supply': 100850743812.0,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -36.81682,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 8012.55494,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 75.83278053785368,
#    'currency': 'usd',
#    'percentage': 7583.278053785369},
#   'last_updated': '2021-05-10T03:38:45.252Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 148.33,
#   'market_cap': 10409398466,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 292987038365,
#   'total_volume': 912859664,
#   'high_24h': 149.04,
#   'low_24h': 140.94,
#   'price_change_24h': 0.150531,
#   'price_change_percentage_24h': 0.10159,
#   'market_cap_change_24h': 5904823,
#   'market_cap_change_percentage_24h': 0.05676,
#   'circulating_supply': 70177768.0,
#   'total_supply': 1975251161.0,
#   'max_supply': 1975251161.0,
#   'ath': 236.84,
#   'ath_change_percentage': -37.43474,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 638.69758,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:44.031Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 59429,
#   'market_cap': 10189720971,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 10189720971,
#   'total_volume': 534204702,
#   'high_24h': 59422,
#   'low_24h': 56640,
#   'price_change_24h': 541.87,
#   'price_change_percentage_24h': 0.92018,
#   'market_cap_change_24h': 131936612,
#   'market_cap_change_percentage_24h': 1.31179,
#   'circulating_supply': 171665.79363022,
#   'total_supply': 171665.79363022,
#   'max_supply': 171665.79363022,
#   'ath': 64565,
#   'ath_change_percentage': -8.06695,
#   'ath_date': '2021-04-14T12:00:05.340Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1790.84141,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:06.410Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 10.58,
#   'market_cap': 10105485460,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': None,
#   'total_volume': 8505019679,
#   'high_24h': 10.58,
#   'low_24h': 9.29,
#   'price_change_24h': 0.00124702,
#   'price_change_percentage_24h': 0.01178,
#   'market_cap_change_24h': -126655912.59507371,
#   'market_cap_change_percentage_24h': -1.23782,
#   'circulating_supply': 956962421.4661,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -53.87202,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 1985.24111,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': 9.69081075817395,
#    'currency': 'usd',
#    'percentage': 969.081075817395},
#   'last_updated': '2021-05-10T03:38:27.267Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 35.89,
#   'market_cap': 9837349922,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': None,
#   'total_volume': 1885337650,
#   'high_24h': 38.28,
#   'low_24h': 30.42,
#   'price_change_24h': 3.54,
#   'price_change_percentage_24h': 10.95048,
#   'market_cap_change_24h': 1132814808,
#   'market_cap_change_percentage_24h': 13.01408,
#   'circulating_supply': 269444871.26,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -16.4137,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 6235.15294,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:39.042Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 482.04,
#   'market_cap': 8631941318,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': None,
#   'total_volume': 676438637,
#   'high_24h': 495.29,
#   'low_24h': 450.09,
#   'price_change_24h': 18.74,
#   'price_change_percentage_24h': 4.04489,
#   'market_cap_change_24h': 312331350,
#   'market_cap_change_percentage_24h': 3.75416,
#   'circulating_supply': 17906017.4258979,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -10.89816,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 223431.06257,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:11.762Z'},
#  {'id': 'neo',
#   'symbol': 'neo',
#   'name': 'NEO',
#   'image': 'https://assets.coingecko.com/coins/images/480/large/NEO_512_512.png?1594357361',
#   'current_price': 118.03,
#   'market_cap': 8325117700,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': None,
#   'total_volume': 1885516735,
#   'high_24h': 119.39,
#   'low_24h': 110.55,
#   'price_change_24h': -0.80112859,
#   'price_change_percentage_24h': -0.67415,
#   'market_cap_change_24h': -127010353.36680032,
#   'market_cap_change_percentage_24h': -1.5027,
#   'circulating_supply': 70530000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 198.38,
#   'ath_change_percentage': -40.51351,
#   'ath_date': '2018-01-15T00:00:00.000Z',
#   'atl': 0.078349,
#   'atl_change_percentage': 150520.30195,
#   'atl_date': '2016-10-21T00:00:00.000Z',
#   'roi': {'times': 3277.7440003997363,
#    'currency': 'usd',
#    'percentage': 327774.4000399736},
#   'last_updated': '2021-05-10T03:38:41.049Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 1.0,
#   'market_cap': 7682705246,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': None,
#   'total_volume': 10079224252,
#   'high_24h': 1.01,
#   'low_24h': 0.992445,
#   'price_change_24h': 0.00205635,
#   'price_change_percentage_24h': 0.20598,
#   'market_cap_change_24h': -263384724.54592037,
#   'market_cap_change_percentage_24h': -3.31465,
#   'circulating_supply': 7669413004.96,
#   'total_supply': 7669413004.96,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.04236,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.906729,
#   'atl_change_percentage': 10.69112,
#   'atl_date': '2020-03-12T23:35:12.774Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:09.553Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 17.95,
#   'market_cap': 6955366884,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': None,
#   'total_volume': 474463519,
#   'high_24h': 18.02,
#   'low_24h': 16.68,
#   'price_change_24h': 0.980316,
#   'price_change_percentage_24h': 5.77589,
#   'market_cap_change_24h': 394335835,
#   'market_cap_change_percentage_24h': 6.01027,
#   'circulating_supply': 385998236.701321,
#   'total_supply': 955549852.496296,
#   'max_supply': None,
#   'ath': 22.36,
#   'ath_change_percentage': -19.65643,
#   'ath_date': '2021-03-21T11:59:15.174Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 14647.70913,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:46.016Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 29.1,
#   'market_cap': 6949622353,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 1246854152,
#   'high_24h': 29.23,
#   'low_24h': 26.76,
#   'price_change_24h': 1.13,
#   'price_change_percentage_24h': 4.04278,
#   'market_cap_change_24h': 227067674,
#   'market_cap_change_percentage_24h': 3.3777,
#   'circulating_supply': 238526146.88641,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 31.7,
#   'ath_change_percentage': -8.33074,
#   'ath_date': '2021-05-07T16:18:33.469Z',
#   'atl': 1.16,
#   'atl_change_percentage': 2405.12555,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 289.9752175537501,
#    'currency': 'usd',
#    'percentage': 28997.52175537501},
#   'last_updated': '2021-05-10T03:38:45.515Z'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'image': 'https://assets.coingecko.com/coins/images/6799/large/BSV.png?1558947902',
#   'current_price': 368.48,
#   'market_cap': 6878532943,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 2239839683,
#   'high_24h': 370.4,
#   'low_24h': 333.83,
#   'price_change_24h': -0.86000417,
#   'price_change_percentage_24h': -0.23285,
#   'market_cap_change_24h': -111317605.03583336,
#   'market_cap_change_percentage_24h': -1.59256,
#   'circulating_supply': 18728451.644239,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 489.75,
#   'ath_change_percentage': -25.41744,
#   'ath_date': '2021-04-16T17:09:04.630Z',
#   'atl': 42.02,
#   'atl_change_percentage': 769.32927,
#   'atl_date': '2018-11-23T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:20.236Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'image': 'https://assets.coingecko.com/coins/images/12632/large/IMG_0440.PNG?1602654093',
#   'current_price': 39.31,
#   'market_cap': 6503601399,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': None,
#   'total_volume': 621311277,
#   'high_24h': 39.72,
#   'low_24h': 36.22,
#   'price_change_24h': 2.12,
#   'price_change_percentage_24h': 5.69019,
#   'market_cap_change_24h': 369418584,
#   'market_cap_change_percentage_24h': 6.02229,
#   'circulating_supply': 165115480.718668,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 43.96,
#   'ath_change_percentage': -10.31362,
#   'ath_date': '2021-04-30T10:08:22.934Z',
#   'atl': 0.194441,
#   'atl_change_percentage': 20178.82937,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:07.102Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 2.26,
#   'market_cap': 6300767897,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': None,
#   'total_volume': 202096133,
#   'high_24h': 2.3,
#   'low_24h': 2.07,
#   'price_change_24h': 0.133495,
#   'price_change_percentage_24h': 6.27235,
#   'market_cap_change_24h': 365899696,
#   'market_cap_change_percentage_24h': 6.16525,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -56.88405,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 2672.08965,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 27.47816065966724,
#    'currency': 'btc',
#    'percentage': 2747.8160659667237},
#   'last_updated': '2021-05-10T03:38:12.137Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 80.99,
#   'market_cap': 5991142032,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': None,
#   'total_volume': 1502815,
#   'high_24h': 80.81,
#   'low_24h': 75.23,
#   'price_change_24h': 2.03,
#   'price_change_percentage_24h': 2.56724,
#   'market_cap_change_24h': 139767069,
#   'market_cap_change_percentage_24h': 2.38862,
#   'circulating_supply': 74403232.1340925,
#   'total_supply': 74403232.1340925,
#   'max_supply': None,
#   'ath': 80.31,
#   'ath_change_percentage': 0.22234,
#   'ath_date': '2021-05-10T03:18:12.069Z',
#   'atl': 1.89,
#   'atl_change_percentage': 4167.2058,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:34.879Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://assets.coingecko.com/coins/images/12645/large/AAVE.png?1601374110',
#   'current_price': 469.48,
#   'market_cap': 5977358510,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 7505951495,
#   'total_volume': 453942430,
#   'high_24h': 469.12,
#   'low_24h': 440.67,
#   'price_change_24h': 5.16,
#   'price_change_percentage_24h': 1.11041,
#   'market_cap_change_24h': 35401697,
#   'market_cap_change_percentage_24h': 0.59579,
#   'circulating_supply': 12741587.288287552,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 575.15,
#   'ath_change_percentage': -18.5904,
#   'ath_date': '2021-02-10T06:12:13.409Z',
#   'atl': 26.02,
#   'atl_change_percentage': 1699.29508,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:19.018Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic___polygon.jpg?1612939050',
#   'current_price': 0.928997,
#   'market_cap': 5627515660,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 9318505847,
#   'total_volume': 3610455684,
#   'high_24h': 1.04,
#   'low_24h': 0.819239,
#   'price_change_24h': 0.05651,
#   'price_change_percentage_24h': 6.47687,
#   'market_cap_change_24h': 314964689,
#   'market_cap_change_percentage_24h': 5.92869,
#   'circulating_supply': 6039075097.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 1.04,
#   'ath_change_percentage': -9.14835,
#   'ath_date': '2021-05-09T21:17:50.956Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 29971.45827,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 352.2306683743877,
#    'currency': 'usd',
#    'percentage': 35223.06683743877},
#   'last_updated': '2021-05-10T03:38:30.351Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 2.26,
#   'market_cap': 5552292358,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 43710194,
#   'high_24h': 2.33,
#   'low_24h': 2.21,
#   'price_change_24h': -0.07612127,
#   'price_change_percentage_24h': -3.26495,
#   'market_cap_change_24h': -163577755.04325104,
#   'market_cap_change_percentage_24h': -2.86182,
#   'circulating_supply': 2461861334.8,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -48.06927,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 3628.06897,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:36:18.523Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 62.48,
#   'market_cap': 5479042181,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 21107181568,
#   'total_volume': 102508680,
#   'high_24h': 62.46,
#   'low_24h': 59.17,
#   'price_change_24h': 1.09,
#   'price_change_percentage_24h': 1.76957,
#   'market_cap_change_24h': 61346153,
#   'market_cap_change_percentage_24h': 1.13233,
#   'circulating_supply': 87952895.55626523,
#   'total_supply': 338825231.623493,
#   'max_supply': 338825231.623493,
#   'ath': 62.3,
#   'ath_change_percentage': 0.0248,
#   'ath_date': '2021-05-10T03:18:37.379Z',
#   'atl': 1.15,
#   'atl_change_percentage': 5320.19094,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:47.496Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 7.11,
#   'market_cap': 5460266117,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': None,
#   'total_volume': 338911874,
#   'high_24h': 7.19,
#   'low_24h': 6.52,
#   'price_change_24h': 0.094882,
#   'price_change_percentage_24h': 1.35269,
#   'market_cap_change_24h': 36614841,
#   'market_cap_change_percentage_24h': 0.6751,
#   'circulating_supply': 769271024.029388,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 8.27,
#   'ath_change_percentage': -14.18859,
#   'ath_date': '2021-05-07T02:09:26.683Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 1923.93023,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 14.126059137135815,
#    'currency': 'usd',
#    'percentage': 1412.6059137135815},
#   'last_updated': '2021-05-10T03:38:20.105Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi Token',
#   'image': 'https://assets.coingecko.com/coins/images/2822/large/huobi-token-logo.png?1547036992',
#   'current_price': 29.7,
#   'market_cap': 5353891244,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 14931153980,
#   'total_volume': 1291156578,
#   'high_24h': 30.41,
#   'low_24h': 25.12,
#   'price_change_24h': 3.78,
#   'price_change_percentage_24h': 14.5929,
#   'market_cap_change_24h': 707335873,
#   'market_cap_change_percentage_24h': 15.2228,
#   'circulating_supply': 179285916.25441208,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 30.41,
#   'ath_change_percentage': -1.80653,
#   'ath_date': '2021-05-10T02:29:55.821Z',
#   'atl': 0.90862,
#   'atl_change_percentage': 3186.56471,
#   'atl_date': '2019-01-30T00:00:00.000Z',
#   'roi': {'times': 28.998731940762415,
#    'currency': 'usd',
#    'percentage': 2899.8731940762414},
#   'last_updated': '2021-05-10T03:38:02.195Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 38.88,
#   'market_cap': 5023390834,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 28066559185,
#   'total_volume': 298136539,
#   'high_24h': 39.47,
#   'low_24h': 35.71,
#   'price_change_24h': 1.19,
#   'price_change_percentage_24h': 3.15563,
#   'market_cap_change_24h': 145361536,
#   'market_cap_change_percentage_24h': 2.97992,
#   'circulating_supply': 128866576.662061,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 59.4,
#   'ath_change_percentage': -34.40808,
#   'ath_date': '2021-02-10T22:23:34.616Z',
#   'atl': 2.8,
#   'atl_change_percentage': 1291.03817,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:37:48.703Z'},
#  {'id': 'bittorrent-2',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'image': 'https://assets.coingecko.com/coins/images/7595/large/BTT_Token_Graphic.png?1555066995',
#   'current_price': 0.00746085,
#   'market_cap': 4915958180,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': None,
#   'total_volume': 2074032551,
#   'high_24h': 0.00765142,
#   'low_24h': 0.00706473,
#   'price_change_24h': -0.00015762,
#   'price_change_percentage_24h': -2.06892,
#   'market_cap_change_24h': -140277788.61303237,
#   'market_cap_change_percentage_24h': -2.77435,
#   'circulating_supply': 659071882049.0,
#   'total_supply': 990000000000.0,
#   'max_supply': None,
#   'ath': 0.01356626,
#   'ath_change_percentage': -45.01761,
#   'ath_date': '2021-04-05T04:09:06.433Z',
#   'atl': 0.00013814,
#   'atl_change_percentage': 5299.52319,
#   'atl_date': '2020-03-13T02:22:57.629Z',
#   'roi': {'times': 61.1737571194204,
#    'currency': 'usd',
#    'percentage': 6117.37571194204},
#   'last_updated': '2021-05-10T03:37:44.308Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://assets.coingecko.com/coins/images/1364/large/Mark_Maker.png?1585191826',
#   'current_price': 5391.93,
#   'market_cap': 4854426783,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 5415999812,
#   'total_volume': 340637453,
#   'high_24h': 5575.45,
#   'low_24h': 5094.57,
#   'price_change_24h': -128.84797541,
#   'price_change_percentage_24h': -2.33387,
#   'market_cap_change_24h': -155005684.84335423,
#   'market_cap_change_percentage_24h': -3.09428,
#   'circulating_supply': 901310.9472893132,
#   'total_supply': 994818.294392238,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -14.31468,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 3102.46362,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:08.132Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02140565,
#   'market_cap': 4726474392,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': None,
#   'total_volume': 86028196,
#   'high_24h': 0.0216903,
#   'low_24h': 0.0212065,
#   'price_change_24h': 9.9e-07,
#   'price_change_percentage_24h': 0.00464,
#   'market_cap_change_24h': 90538826,
#   'market_cap_change_percentage_24h': 1.95298,
#   'circulating_supply': 220792984741.45,
#   'total_supply': 220792984741.45,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -31.96665,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 194.8782,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:35.595Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.186109,
#   'market_cap': 4696523984,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': None,
#   'total_volume': 159127377,
#   'high_24h': 0.185978,
#   'low_24h': 0.174558,
#   'price_change_24h': 0.00501893,
#   'price_change_percentage_24h': 2.77151,
#   'market_cap_change_24h': 114232875,
#   'market_cap_change_percentage_24h': 2.49292,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.27702,
#   'ath_change_percentage': -32.92796,
#   'ath_date': '2021-02-22T11:33:57.751Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1433.07879,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:29.158Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 1.53,
#   'market_cap': 4620437083,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 15315394373,
#   'total_volume': 465379082,
#   'high_24h': 1.54,
#   'low_24h': 1.44,
#   'price_change_24h': 0.0424351,
#   'price_change_percentage_24h': 2.84972,
#   'market_cap_change_24h': 129553890,
#   'market_cap_change_percentage_24h': 2.88482,
#   'circulating_supply': 3016858051.95453,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -57.04027,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 1352.37072,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.36186221028798166,
#    'currency': 'usd',
#    'percentage': -36.186221028798165},
#   'last_updated': '2021-05-10T03:38:45.631Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/dai-multi-collateral-mcd.png?1574218774',
#   'current_price': 1.0,
#   'market_cap': 4510113397,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 4510113397,
#   'total_volume': 587785676,
#   'high_24h': 1.0,
#   'low_24h': 0.990257,
#   'price_change_24h': 0.00430249,
#   'price_change_percentage_24h': 0.42995,
#   'market_cap_change_24h': 87113507,
#   'market_cap_change_percentage_24h': 1.96956,
#   'circulating_supply': 4487713654.8249,
#   'total_supply': 4487713654.8249,
#   'max_supply': 4487713654.8249,
#   'ath': 1.22,
#   'ath_change_percentage': -17.55138,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 11.26477,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:06:57.600Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02197648,
#   'market_cap': 4445287053,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': None,
#   'total_volume': 22118750,
#   'high_24h': 0.02213014,
#   'low_24h': 0.02177246,
#   'price_change_24h': 2.516e-05,
#   'price_change_percentage_24h': 0.11461,
#   'market_cap_change_24h': 49561582,
#   'market_cap_change_percentage_24h': 1.12749,
#   'circulating_supply': 202346368548.119,
#   'total_supply': 202346368548.119,
#   'max_supply': None,
#   'ath': 0.058843,
#   'ath_change_percentage': -62.51832,
#   'ath_date': '2020-10-21T11:24:27.820Z',
#   'atl': 0.00620705,
#   'atl_change_percentage': 255.32954,
#   'atl_date': '2021-03-04T08:11:37.438Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:36.461Z'},
#  {'id': 'thorchain',
#   'symbol': 'rune',
#   'name': 'THORChain',
#   'image': 'https://assets.coingecko.com/coins/images/6595/large/RUNE.png?1614160507',
#   'current_price': 18.35,
#   'market_cap': 4380479029,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 9130457561,
#   'total_volume': 128783135,
#   'high_24h': 19.03,
#   'low_24h': 17.58,
#   'price_change_24h': -0.58809893,
#   'price_change_percentage_24h': -3.10604,
#   'market_cap_change_24h': -148982551.63511756,
#   'market_cap_change_percentage_24h': -3.28919,
#   'circulating_supply': 239882776.95691225,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 19.24,
#   'ath_change_percentage': -5.139,
#   'ath_date': '2021-05-05T15:09:37.480Z',
#   'atl': 0.00851264,
#   'atl_change_percentage': 214266.37071,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 481.78726137788027,
#    'currency': 'usd',
#    'percentage': 48178.72613778803},
#   'last_updated': '2021-05-10T03:38:28.448Z'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'image': 'https://assets.coingecko.com/coins/images/19/large/dash-logo.png?1548385930',
#   'current_price': 426.75,
#   'market_cap': 4299847428,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': None,
#   'total_volume': 2071374657,
#   'high_24h': 426.81,
#   'low_24h': 377.0,
#   'price_change_24h': 26.9,
#   'price_change_percentage_24h': 6.72825,
#   'market_cap_change_24h': 236612441,
#   'market_cap_change_percentage_24h': 5.82325,
#   'circulating_supply': 10123296.4027755,
#   'total_supply': 18920000.0,
#   'max_supply': None,
#   'ath': 1493.59,
#   'ath_change_percentage': -71.58919,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 0.213899,
#   'atl_change_percentage': 198283.90995,
#   'atl_date': '2014-02-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:46.885Z'},
#  {'id': 'kusama',
#   'symbol': 'ksm',
#   'name': 'Kusama',
#   'image': 'https://assets.coingecko.com/coins/images/9568/large/m4zRhP5e_400x400.jpg?1576190080',
#   'current_price': 450.02,
#   'market_cap': 4052866790,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 4513165399,
#   'total_volume': 260494296,
#   'high_24h': 457.29,
#   'low_24h': 426.88,
#   'price_change_24h': 10.55,
#   'price_change_percentage_24h': 2.4004,
#   'market_cap_change_24h': 100675488,
#   'market_cap_change_percentage_24h': 2.54733,
#   'circulating_supply': 8980098.074112339,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 566.41,
#   'ath_change_percentage': -20.18342,
#   'ath_date': '2021-03-29T12:24:40.358Z',
#   'atl': 0.876572,
#   'atl_change_percentage': 51474.80177,
#   'atl_date': '2020-01-14T19:20:20.768Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:22.666Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 787.88,
#   'market_cap': 4026683879,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 7840667115,
#   'total_volume': 210230118,
#   'high_24h': 785.01,
#   'low_24h': 735.5,
#   'price_change_24h': 26.72,
#   'price_change_percentage_24h': 3.51015,
#   'market_cap_change_24h': 98971982,
#   'market_cap_change_percentage_24h': 2.51984,
#   'circulating_supply': 5135639.37848587,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 874.66,
#   'ath_change_percentage': -10.29487,
#   'ath_date': '2021-05-02T13:04:56.504Z',
#   'atl': 61.32,
#   'atl_change_percentage': 1179.5076,
#   'atl_date': '2020-06-18T12:54:32.788Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:22.464Z'},
#  {'id': 'nem',
#   'symbol': 'xem',
#   'name': 'NEM',
#   'image': 'https://assets.coingecko.com/coins/images/242/large/NEM_Logo_256x256.png?1598687029',
#   'current_price': 0.385149,
#   'market_cap': 3462933431,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': None,
#   'total_volume': 319241033,
#   'high_24h': 0.391538,
#   'low_24h': 0.35143,
#   'price_change_24h': -0.00615023,
#   'price_change_percentage_24h': -1.57175,
#   'market_cap_change_24h': -79097605.29269268,
#   'market_cap_change_percentage_24h': -2.23311,
#   'circulating_supply': 8999999999.0,
#   'total_supply': 8999999999.0,
#   'max_supply': None,
#   'ath': 1.87,
#   'ath_change_percentage': -79.39197,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 8.482e-05,
#   'atl_change_percentage': 453901.41665,
#   'atl_date': '2015-09-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:23.380Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://assets.coingecko.com/coins/images/486/large/circle-zcash-color.png?1547034197',
#   'current_price': 312.12,
#   'market_cap': 3459446198,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 6557980110,
#   'total_volume': 2373297233,
#   'high_24h': 314.5,
#   'low_24h': 289.62,
#   'price_change_24h': 6.36,
#   'price_change_percentage_24h': 2.07902,
#   'market_cap_change_24h': 64863311,
#   'market_cap_change_percentage_24h': 1.91079,
#   'circulating_supply': 11077857.6525399,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -90.22745,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 19.75,
#   'atl_change_percentage': 1479.11484,
#   'atl_date': '2020-03-13T02:20:55.002Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:37.691Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/Elrond.png?1599132180',
#   'current_price': 187.78,
#   'market_cap': 3315264308,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': None,
#   'total_volume': 90801111,
#   'high_24h': 189.69,
#   'low_24h': 180.36,
#   'price_change_24h': 2.68,
#   'price_change_percentage_24h': 1.4481,
#   'market_cap_change_24h': 26910226,
#   'market_cap_change_percentage_24h': 0.81835,
#   'circulating_supply': 17654766.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 243.92,
#   'ath_change_percentage': -22.99391,
#   'ath_date': '2021-04-12T02:24:35.343Z',
#   'atl': 6.51,
#   'atl_change_percentage': 2786.80636,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:36:55.819Z'},
#  {'id': 'waves',
#   'symbol': 'waves',
#   'name': 'Waves',
#   'image': 'https://assets.coingecko.com/coins/images/425/large/waves.png?1548386117',
#   'current_price': 31.72,
#   'market_cap': 3174754109,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 329641638,
#   'high_24h': 32.18,
#   'low_24h': 30.07,
#   'price_change_24h': 0.132285,
#   'price_change_percentage_24h': 0.41882,
#   'market_cap_change_24h': 8968111,
#   'market_cap_change_percentage_24h': 0.28328,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 43.01,
#   'ath_change_percentage': -26.30736,
#   'ath_date': '2021-05-04T06:49:41.528Z',
#   'atl': 0.130878,
#   'atl_change_percentage': 24119.51617,
#   'atl_date': '2016-08-02T00:00:00.000Z',
#   'roi': {'times': 167.71084241504323,
#    'currency': 'usd',
#    'percentage': 16771.084241504326},
#   'last_updated': '2021-05-10T03:38:12.226Z'},
#  {'id': 'telcoin',
#   'symbol': 'tel',
#   'name': 'Telcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1899/large/tel.png?1547036203',
#   'current_price': 0.057057,
# ...
#   'atl': 0.350917,
#   'atl_change_percentage': 3265.7972,
#   'atl_date': '2020-03-13T02:30:10.072Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:13.275Z'},
#  {'id': 'icon',
#   'symbol': 'icx',
#   'name': 'ICON',
#   'image': 'https://assets.coingecko.com/coins/images/1060/large/icon-icx-logo.png?1547035003',
#   'current_price': 2.67,
#   'market_cap': 1666447461,
#   'market_cap_rank': 83,
#   'fully_diluted_valuation': None,
#   'total_volume': 135203536,
#   'high_24h': 2.69,
#   'low_24h': 2.46,
#   'price_change_24h': 0.073114,
#   'price_change_percentage_24h': 2.81729,
#   'market_cap_change_24h': 51401605,
#   'market_cap_change_percentage_24h': 3.18267,
#   'circulating_supply': 625124914.917097,
#   'total_supply': 800460000.0,
#   'max_supply': None,
#   'ath': 13.16,
#   'ath_change_percentage': -79.80098,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.107465,
#   'atl_change_percentage': 2374.38097,
#   'atl_date': '2020-01-03T02:14:53.139Z',
#   'roi': {'times': 23.25741017533451,
#    'currency': 'usd',
#    'percentage': 2325.7410175334508},
#   'last_updated': '2021-05-10T03:37:29.394Z'},
#  {'id': 'bancor',
#   'symbol': 'bnt',
#   'name': 'Bancor Network Token',
#   'image': 'https://assets.coingecko.com/coins/images/736/large/bancor.png?1547034477',
#   'current_price': 8.21,
#   'market_cap': 1604224732,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 1604224732,
#   'total_volume': 345571510,
#   'high_24h': 8.19,
#   'low_24h': 7.75,
#   'price_change_24h': 0.230582,
#   'price_change_percentage_24h': 2.88954,
#   'market_cap_change_24h': 49392569,
#   'market_cap_change_percentage_24h': 3.17671,
#   'circulating_supply': 195867261.580674,
#   'total_supply': 195867261.580674,
#   'max_supply': 195867261.580674,
#   'ath': 10.72,
#   'ath_change_percentage': -23.66855,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.120935,
#   'atl_change_percentage': 6663.32977,
#   'atl_date': '2020-03-13T02:29:21.245Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:21.956Z'},
#  {'id': '0x',
#   'symbol': 'zrx',
#   'name': '0x',
#   'image': 'https://assets.coingecko.com/coins/images/863/large/0x.png?1547034672',
#   'current_price': 2.01,
#   'market_cap': 1594638744,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 2014259262,
#   'total_volume': 382892330,
#   'high_24h': 2.01,
#   'low_24h': 1.84,
#   'price_change_24h': 0.084846,
#   'price_change_percentage_24h': 4.41753,
#   'market_cap_change_24h': 67197659,
#   'market_cap_change_percentage_24h': 4.39936,
#   'circulating_supply': 791675021.5210257,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 2.5,
#   'ath_change_percentage': -19.61278,
#   'ath_date': '2018-01-13T00:00:00.000Z',
#   'atl': 0.120667,
#   'atl_change_percentage': 1563.44366,
#   'atl_date': '2020-03-13T02:27:49.563Z',
#   'roi': {'times': 40.781371364066835,
#    'currency': 'usd',
#    'percentage': 4078.137136406683},
#   'last_updated': '2021-05-10T03:38:38.420Z'},
#  {'id': 'zencash',
#   'symbol': 'zen',
#   'name': 'Horizen',
#   'image': 'https://assets.coingecko.com/coins/images/691/large/horizen.png?1555052241',
#   'current_price': 142.95,
#   'market_cap': 1581346664,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': None,
#   'total_volume': 122082733,
#   'high_24h': 144.61,
#   'low_24h': 136.31,
#   'price_change_24h': -1.53697567,
#   'price_change_percentage_24h': -1.06373,
#   'market_cap_change_24h': -25984164.31147838,
#   'market_cap_change_percentage_24h': -1.6166,
#   'circulating_supply': 11064218.75,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 165.92,
#   'ath_change_percentage': -14.19556,
#   'ath_date': '2021-05-08T06:00:30.087Z',
#   'atl': 3.26,
#   'atl_change_percentage': 4260.97616,
#   'atl_date': '2019-10-17T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:36:06.725Z'},
#  {'id': 'uma',
#   'symbol': 'uma',
#   'name': 'UMA',
#   'image': 'https://assets.coingecko.com/coins/images/10951/large/UMA.png?1586307916',
#   'current_price': 25.89,
#   'market_cap': 1558051441,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 2643349093,
#   'total_volume': 42694512,
#   'high_24h': 26.58,
#   'low_24h': 25.09,
#   'price_change_24h': -0.37933883,
#   'price_change_percentage_24h': -1.44405,
#   'market_cap_change_24h': -30518010.73657227,
#   'market_cap_change_percentage_24h': -1.9211,
#   'circulating_supply': 60311049.724758595,
#   'total_supply': 102322140.610725,
#   'max_supply': 102322140.610725,
#   'ath': 41.56,
#   'ath_change_percentage': -37.88662,
#   'ath_date': '2021-02-04T11:27:11.433Z',
#   'atl': 0.303625,
#   'atl_change_percentage': 8401.19908,
#   'atl_date': '2020-04-29T17:00:41.760Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:06.842Z'},
#  {'id': 'liquity-usd',
#   'symbol': 'lusd',
#   'name': 'Liquity USD',
#   'image': 'https://assets.coingecko.com/coins/images/14666/large/Group_3.png?1617631327',
#   'current_price': 1.0,
#   'market_cap': 1550209798,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': None,
#   'total_volume': 40036182,
#   'high_24h': 1.01,
#   'low_24h': 0.98949,
#   'price_change_24h': 0.0003743,
#   'price_change_percentage_24h': 0.03741,
#   'market_cap_change_24h': 16200120,
#   'market_cap_change_percentage_24h': 1.05606,
#   'circulating_supply': 1549150216.64596,
#   'total_supply': 1549150216.64596,
#   'max_supply': None,
#   'ath': 1.16,
#   'ath_change_percentage': -13.35417,
#   'ath_date': '2021-04-05T14:47:52.665Z',
#   'atl': 0.952915,
#   'atl_change_percentage': 5.32315,
#   'atl_date': '2021-04-18T03:49:53.759Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:36:42.931Z'},
#  {'id': 'ravencoin',
#   'symbol': 'rvn',
#   'name': 'Ravencoin',
#   'image': 'https://assets.coingecko.com/coins/images/3412/large/ravencoin.png?1548386057',
#   'current_price': 0.172193,
#   'market_cap': 1505862184,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': None,
#   'total_volume': 139951338,
#   'high_24h': 0.17349,
#   'low_24h': 0.162132,
#   'price_change_24h': -0.00094937,
#   'price_change_percentage_24h': -0.54832,
#   'market_cap_change_24h': -11880018.95996618,
#   'market_cap_change_percentage_24h': -0.78274,
#   'circulating_supply': 8736820000.0,
#   'total_supply': 21000000000.0,
#   'max_supply': None,
#   'ath': 0.285218,
#   'ath_change_percentage': -39.35787,
#   'ath_date': '2021-02-20T11:19:07.791Z',
#   'atl': 0.00893232,
#   'atl_change_percentage': 1836.36385,
#   'atl_date': '2020-03-13T02:30:00.004Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:37:30.251Z'},
#  {'id': 'bitcoin-diamond',
#   'symbol': 'bcd',
#   'name': 'Bitcoin Diamond',
#   'image': 'https://assets.coingecko.com/coins/images/1254/large/bitcoin-diamond.png?1547035280',
#   'current_price': 7.69,
#   'market_cap': 1449307898,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': None,
#   'total_volume': 141251638,
#   'high_24h': 9.57,
#   'low_24h': 7.36,
#   'price_change_24h': -1.51185623,
#   'price_change_percentage_24h': -16.43193,
#   'market_cap_change_24h': -315096611.1542294,
#   'market_cap_change_percentage_24h': -17.85852,
#   'circulating_supply': 188156897.953024,
#   'total_supply': 210000000.0,
#   'max_supply': None,
#   'ath': 147.18,
#   'ath_change_percentage': -94.64934,
#   'ath_date': '2018-01-13T00:00:00.000Z',
#   'atl': 0.260892,
#   'atl_change_percentage': 2918.5282,
#   'atl_date': '2020-03-13T02:22:31.096Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:49.923Z'},
#  {'id': 'iostoken',
#   'symbol': 'iost',
#   'name': 'IOST',
#   'image': 'https://assets.coingecko.com/coins/images/2523/large/IOST.png?1557555183',
#   'current_price': 0.064165,
#   'market_cap': 1444302771,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 5772867907,
#   'total_volume': 364002076,
#   'high_24h': 0.064993,
#   'low_24h': 0.060877,
#   'price_change_24h': -1.631e-05,
#   'price_change_percentage_24h': -0.02542,
#   'market_cap_change_24h': -6562317.51860237,
#   'market_cap_change_percentage_24h': -0.4523,
#   'circulating_supply': 22516927713.3241,
#   'total_supply': 22515056346.2987,
#   'max_supply': 90000000000.0,
#   'ath': 0.129829,
#   'ath_change_percentage': -50.53469,
#   'ath_date': '2018-01-24T00:00:00.000Z',
#   'atl': 0.00160309,
#   'atl_change_percentage': 3906.02557,
#   'atl_date': '2020-03-13T02:25:35.257Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:12.648Z'},
#  {'id': 'helium',
#   'symbol': 'hnt',
#   'name': 'Helium',
#   'image': 'https://assets.coingecko.com/coins/images/4284/large/Helium_HNT.png?1612620071',
#   'current_price': 17.02,
#   'market_cap': 1384628769,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 3785338658,
#   'total_volume': 14211241,
#   'high_24h': 17.22,
#   'low_24h': 16.39,
#   'price_change_24h': -0.0129678,
#   'price_change_percentage_24h': -0.07612,
#   'market_cap_change_24h': -7136705.53168655,
#   'market_cap_change_percentage_24h': -0.51278,
#   'circulating_supply': 81570565.652124,
#   'total_supply': 223000000.0,
#   'max_supply': 223000000.0,
#   'ath': 20.86,
#   'ath_change_percentage': -18.69217,
#   'ath_date': '2021-04-07T06:49:56.212Z',
#   'atl': 0.113248,
#   'atl_change_percentage': 14879.6951,
#   'atl_date': '2020-04-18T00:19:10.902Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:02.764Z'},
#  {'id': 'pirate-chain',
#   'symbol': 'arrr',
#   'name': 'Pirate Chain',
#   'image': 'https://assets.coingecko.com/coins/images/6905/large/Pirate_Chain.png?1560913844',
#   'current_price': 7.63,
#   'market_cap': 1378100761,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': None,
#   'total_volume': 5590950,
#   'high_24h': 9.89,
#   'low_24h': 6.53,
#   'price_change_24h': -2.10312195,
#   'price_change_percentage_24h': -21.60745,
#   'market_cap_change_24h': -384278672.796422,
#   'market_cap_change_percentage_24h': -21.80454,
#   'circulating_supply': 181118991.98203,
#   'total_supply': 200000000.0,
#   'max_supply': None,
#   'ath': 16.76,
#   'ath_change_percentage': -54.56904,
#   'ath_date': '2021-04-23T18:13:27.423Z',
#   'atl': 0.00797788,
#   'atl_change_percentage': 95345.53135,
#   'atl_date': '2020-11-26T02:10:52.806Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:36:33.528Z'},
#  {'id': 'venus',
#   'symbol': 'xvs',
#   'name': 'Venus',
#   'image': 'https://assets.coingecko.com/coins/images/12677/large/venus.png?1618319812',
#   'current_price': 139.81,
#   'market_cap': 1372912870,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 4195262505,
#   'total_volume': 406284951,
#   'high_24h': 146.82,
#   'low_24h': 123.75,
#   'price_change_24h': 14.0,
#   'price_change_percentage_24h': 11.13076,
#   'market_cap_change_24h': 128923751,
#   'market_cap_change_percentage_24h': 10.36374,
#   'circulating_supply': 9817594.501836928,
#   'total_supply': 30000000.0,
#   'max_supply': 30000000.0,
#   'ath': 146.82,
#   'ath_change_percentage': -3.55645,
#   'ath_date': '2021-05-10T03:04:27.466Z',
#   'atl': 1.65,
#   'atl_change_percentage': 8462.23695,
#   'atl_date': '2020-10-06T05:02:54.510Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:38.821Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'GateToken',
#   'image': 'https://assets.coingecko.com/coins/images/8183/large/gt.png?1556085624',
#   'current_price': 8.23,
#   'market_cap': 1363425917,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': None,
#   'total_volume': 143057701,
#   'high_24h': 8.57,
#   'low_24h': 6.57,
#   'price_change_24h': 1.66,
#   'price_change_percentage_24h': 25.3144,
#   'market_cap_change_24h': 286901037,
#   'market_cap_change_percentage_24h': 26.65066,
#   'circulating_supply': 165700942.50951442,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 8.57,
#   'ath_change_percentage': -4.4311,
#   'ath_date': '2021-05-10T02:04:21.078Z',
#   'atl': 0.25754,
#   'atl_change_percentage': 3080.29217,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:37:52.768Z'},
#  {'id': 'lisk',
#   'symbol': 'lsk',
#   'name': 'Lisk',
#   'image': 'https://assets.coingecko.com/coins/images/385/large/Lisk_Symbol_-_Blue.png?1573444104',
#   'current_price': 9.33,
#   'market_cap': 1355147357,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': None,
#   'total_volume': 250501028,
#   'high_24h': 10.78,
#   'low_24h': 7.73,
#   'price_change_24h': 0.536855,
#   'price_change_percentage_24h': 6.1028,
#   'market_cap_change_24h': 66850675,
#   'market_cap_change_percentage_24h': 5.18907,
#   'circulating_supply': 143934028.0,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 34.92,
#   'ath_change_percentage': -72.83271,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.101672,
#   'atl_change_percentage': 9231.89824,
#   'atl_date': '2017-03-01T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:38:42.851Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 4003.69,
#   'market_cap': 1337064030,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 1337064030,
#   'total_volume': 3575685,
#   'high_24h': 3966.98,
#   'low_24h': 3807.73,
#   'price_change_24h': 95.31,
#   'price_change_percentage_24h': 2.43849,
#   'market_cap_change_24h': 36693957,
#   'market_cap_change_percentage_24h': 2.82181,
#   'circulating_supply': 333957.874908024,
#   'total_supply': 333957.874908024,
#   'max_supply': 333957.874908024,
#   'ath': 3966.98,
#   'ath_change_percentage': -0.36867,
#   'ath_date': '2021-05-09T07:30:36.258Z',
#   'atl': 482.9,
#   'atl_change_percentage': 718.4692,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:30:02.948Z'},
#  {'id': 'harmony',
#   'symbol': 'one',
#   'name': 'Harmony',
#   'image': 'https://assets.coingecko.com/coins/images/4344/large/Y88JAze.png?1565065793',
#   'current_price': 0.134763,
#   'market_cap': 1282463274,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': None,
#   'total_volume': 99799875,
#   'high_24h': 0.137208,
#   'low_24h': 0.121105,
#   'price_change_24h': 0.00849913,
#   'price_change_percentage_24h': 6.73123,
#   'market_cap_change_24h': 75317798,
#   'market_cap_change_percentage_24h': 6.23933,
#   'circulating_supply': 9507148903.79313,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.222092,
#   'ath_change_percentage': -38.868,
#   'ath_date': '2021-03-29T08:19:36.363Z',
#   'atl': 0.00127355,
#   'atl_change_percentage': 10560.68787,
#   'atl_date': '2020-03-13T02:24:14.005Z',
#   'roi': {'times': 41.44512837900003,
#    'currency': 'usd',
#    'percentage': 4144.512837900003},
#   'last_updated': '2021-05-10T03:38:27.344Z'},
#  {'id': 'nano',
#   'symbol': 'nano',
#   'name': 'Nano',
#   'image': 'https://assets.coingecko.com/coins/images/756/large/nano-coin-logo.png?1547034501',
#   'current_price': 9.57,
#   'market_cap': 1277047182,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': None,
#   'total_volume': 92954039,
#   'high_24h': 9.93,
#   'low_24h': 9.29,
#   'price_change_24h': -0.21252761,
#   'price_change_percentage_24h': -2.17206,
#   'market_cap_change_24h': -30319423.24573827,
#   'market_cap_change_percentage_24h': -2.31912,
#   'circulating_supply': 133248290.0,
#   'total_supply': 133248290.0,
#   'max_supply': None,
#   'ath': 33.69,
#   'ath_change_percentage': -71.53332,
#   'ath_date': '2018-01-02T00:00:00.000Z',
#   'atl': 0.026179,
#   'atl_change_percentage': 36538.06354,
#   'atl_date': '2017-07-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-05-10T03:37:23.654Z'},
#  {'id': 'swissborg',
#   'symbol': 'chsb',
#   'name': 'SwissBorg',
#   'image': 'https://assets.coingecko.com/coins/images/2117/large/YJUrRy7r_400x400.png?1589794215',
#   'current_price': 1.31,
#   'market_cap': 1238626152,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 5493914,
#   'high_24h': 1.35,
#   'low_24h': 1.27,
#   'price_change_24h': 0.00237745,
#   'price_change_percentage_24h': 0.18207,
#   'market_cap_change_24h': -7225639.62542081,
#   'market_cap_change_percentage_24h': -0.57998,
#   'circulating_supply': 951754603.4742761,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 1.64,
#   'ath_change_percentage': -20.23093,
#   'ath_date': '2021-05-04T17:14:50.120Z',
#   'atl': 0.00502687,
#   'atl_change_percentage': 25922.46245,
#   'atl_date': '2019-07-28T00:00:00.000Z',
#   'roi': {'times': 12.08186378738945,
#    'currency': 'usd',
#    'percentage': 1208.186378738945},
#   'last_updated': '2021-05-10T03:32:37.188Z'}]

# %%
coins_market_df = pd.DataFrame(data=coins_market)
coins_market_df.head(10)
# Out:
#              id symbol          name  \
# 0       bitcoin    btc       Bitcoin
# 1      ethereum    eth      Ethereum
# 2   binancecoin    bnb  Binance Coin
# 3        ripple    xrp           XRP
# 4      dogecoin   doge      Dogecoin
# 5        tether   usdt        Tether
# 6       cardano    ada       Cardano
# 7      polkadot    dot      Polkadot
# 8  bitcoin-cash    bch  Bitcoin Cash
# 9      litecoin    ltc      Litecoin
#
#                                                                                     image  \
# 0                https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579
# 1             https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880
# 2    https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615
# 3  https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731
# 4               https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256
# 5          https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707
# 6              https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860
# 7   https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776
# 8  https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492
# 9               https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580
#
#    current_price     market_cap  market_cap_rank  fully_diluted_valuation  \
# 0   59453.000000  1107036449279                1             1.242837e+12
# 1    4048.370000   465059983465                2                      NaN
# 2     675.840000   104544376774                3             1.153686e+11
# 3       1.570000    72301211054                4                      NaN
# 4       0.527073    69096476437                5                      NaN
# 5       1.000000    56202815798                6                      NaN
# 6       1.750000    56068930545                7                      NaN
# 7      41.460000    41115368893                8                      NaN
# 8    1517.930000    28170159229                9                      NaN
# 9     407.070000    27199392159               10                      NaN
#
#    total_volume     high_24h       low_24h  price_change_24h  \
# 0   71795395430  59457.00000  56637.000000        442.620000
# 1   63923144229   4033.30000   3767.190000        109.110000
# 2    5914944621    683.09000    633.130000         25.860000
# 3    8554350205      1.59000      1.470000          0.007402
# 4   46376304188      0.66551      0.432345         -0.132781
# 5  207573311183      1.00000      0.988826          0.003134
# 6    8600082856      1.82000      1.590000          0.125006
# 7    2134773474     41.56000     38.200000          1.890000
# 8    9172183136   1516.33000   1299.370000        114.040000
# 9   16015257442    410.26000    336.100000         57.430000
#
#    price_change_percentage_24h  market_cap_change_24h  \
# 0                      0.75007           5.321199e+09
# 1                      2.76975           7.842485e+09
# 2                      3.97901           3.932036e+09
# 3                      0.47356           1.467529e+08
# 4                    -20.12284          -1.451322e+10
# 5                      0.31310           4.306647e+08
# 6                      7.68054           3.697020e+09
# 7                      4.78658           1.793047e+09
# 8                      8.12343           1.716857e+09
# 9                     16.42555           3.821338e+09
#
#    market_cap_change_percentage_24h  circulating_supply  total_supply  \
# 0                           0.48299        1.870540e+07  2.100000e+07
# 1                           1.71526        1.158111e+08           NaN
# 2                           3.90811        1.545337e+08  1.705337e+08
# 3                           0.20339        4.603073e+10  1.000000e+11
# 4                         -17.35829        1.295312e+11           NaN
# 5                           0.77219        5.597350e+10  5.597350e+10
# 6                           7.05917        3.206639e+10  4.500000e+10
# 7                           4.55987        9.911465e+08  1.072096e+09
# 8                           6.49014        1.873276e+07  2.100000e+07
# 9                          16.34583        6.675241e+07  8.400000e+07
#
#     max_supply           ath  ath_change_percentage                  ath_date  \
# 0   21000000.0  64805.000000               -8.57197  2021-04-14T11:54:46.763Z
# 1          NaN   4018.990000                0.10921  2021-05-10T03:18:21.646Z
# 2  170533651.9    683.090000               -0.85646  2021-05-10T01:03:13.852Z
# 3          NaN      3.400000              -53.86044  2018-01-07T00:00:00.000Z
# 4          NaN      0.731578              -24.71725  2021-05-08T05:08:23.458Z
# 5          NaN      1.320000              -24.11001  2018-07-24T00:00:00.000Z
# 6          NaN      1.820000               -4.17593  2021-05-09T14:43:39.019Z
# 7          NaN     47.630000              -12.76455  2021-04-17T10:04:11.809Z
# 8          NaN   3785.820000              -60.92551  2017-12-20T00:00:00.000Z
# 9          NaN    410.260000               -0.02380  2021-05-10T03:13:07.904Z
#
#          atl  atl_change_percentage                  atl_date  \
# 0  67.810000           8.727731e+04  2013-07-06T00:00:00.000Z
# 1   0.432979           9.291330e+05  2015-10-20T00:00:00.000Z
# 2   0.039818           1.700739e+06  2017-10-19T00:00:00.000Z
# 3   0.002686           5.827339e+04  2014-05-22T00:00:00.000Z
# 4   0.000087           6.336495e+05  2015-05-06T00:00:00.000Z
# 5   0.572521           7.538168e+01  2015-03-02T00:00:00.000Z
# 6   0.019253           8.949716e+03  2020-03-13T02:22:55.044Z
# 7   2.700000           1.440524e+03  2020-08-20T05:48:11.359Z
# 8  76.930000           1.822784e+03  2018-12-16T00:00:00.000Z
# 9   1.150000           3.560221e+04  2015-01-14T00:00:00.000Z
#
#                                                                                 roi  \
# 0                                                                              None
# 1  {'times': 90.32183094261613, 'currency': 'btc', 'percentage': 9032.183094261612}
# 2                                                                              None
# 3                                                                              None
# 4                                                                              None
# 5                                                                              None
# 6                                                                              None
# 7                                                                              None
# 8                                                                              None
# 9                                                                              None
#
#                last_updated
# 0  2021-05-10T03:38:32.553Z
# 1  2021-05-10T03:38:31.978Z
# 2  2021-05-10T03:38:18.882Z
# 3  2021-05-10T03:37:59.309Z
# 4  2021-05-10T03:38:04.272Z
# 5  2021-05-10T03:07:09.008Z
# 6  2021-05-10T03:38:47.350Z
# 7  2021-05-10T03:38:05.518Z
# 8  2021-05-10T03:38:47.658Z
# 9  2021-05-10T03:38:38.552Z

# %%
# Get current data (name, price, market, ... including exchange tickers) for a coin
cg.get_coin_by_id(id='ethereum')
# Out:
# {'id': 'ethereum',
#  'symbol': 'eth',
#  'name': 'Ethereum',
#  'asset_platform_id': None,
#  'platforms': {'': '',
#   'huobi-token': '0x64ff637fb478863b7468bc97d30a5bf3a428a1fd',
#   'binance-smart-chain': '0x2170ed0880ac9a755fd29b2688956bd959f933f8'},
#  'block_time_in_minutes': 0,
#  'hashing_algorithm': 'Ethash',
#  'categories': ['Smart Contract Platform'],
#  'public_notice': None,
#  'additional_notices': [],
#  'localization': {'en': 'Ethereum',
#   'de': 'Ethereum',
#   'es': 'Ethereum',
#   'fr': 'Ethereum',
#   'it': 'Ethereum',
#   'pl': 'Ethereum',
#   'ro': 'Ethereum',
#   'hu': 'Ethereum',
#   'nl': 'Ethereum',
#   'pt': 'Ethereum',
#   'sv': 'Ethereum',
#   'vi': 'Ethereum',
#   'tr': 'Ethereum',
#   'ru': 'эфириум',
#   'ja': 'イーサリアム',
#   'zh': '以太坊',
#   'zh-tw': '以太幣',
#   'ko': '이더리움',
#   'ar': 'يثريوم',
#   'th': 'Ethereum',
#   'id': 'Ethereum'},
#  'description': {'en': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'de': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'es': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'fr': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'it': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'pl': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'ro': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'hu': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'nl': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'pt': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'sv': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'vi': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'tr': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'ru': 'Эфириум трудно назвать типичным альткойном. Это одновременно и подобная Биткойну сеть, и платформа приложений, и полноценный язык программирования. Цель проекта состоит в том, чтобы разработчики смогли создавать и публиковать распределенные приложения, не требующие доверия к третьему лицу.\r\n\r\nУмные контракты в Ethereum представлены в виде классов, которые могут быть реализованы на различных языках, включая визуальное программирование и компилируются в байт-код для виртуальной машины Эфириума (Ethereum Virtual Machine, EVM) перед отправкой в блокчейн. Изменение состояния виртуальной машины может быть записано на полном по Тьюрингу языке сценариев.',
#   'ja': 'イーサリアム (Ethereum, ETH)・プロジェクトにより開発が進められている、分散型アプリケーション（DApps）やスマート・コントラクトを構築するためのプラットフォームの名称、及び関連するオープンソース・ソフトウェア・プロジェクトの総称である。\r\n\r\nイーサリアムでは、イーサリアム・ネットワークと呼ばれるP2Pのネットワーク上でスマート・コントラクトの履行履歴をブロックチェーンに記録していく。またイーサリアムは、スマート・コントラクトを記述するチューリング完全なプログラミング言語を持ち、ネットワーク参加者はこのネットワーク上のブロックチェーンに任意のDAppsやスマート・コントラクトを記述しそれを実行することが可能になる。ネットワーク参加者が「Ether」と呼ばれるイーサリアム内部通貨の報酬を目当てに、採掘と呼ばれるブロックチェーンへのスマート・コントラクトの履行結果の記録を行うことで、その正統性を保証していく。このような仕組みにより特定の中央管理組織に依拠せず、P2P全体を実行環境としてプログラムの実行とその結果を共有することが可能になった。',
#   'zh': 'Ethereum（以太坊）是一个平台和一种编程语言，使开发人员能够建立和发布下一代分布式应用。Ethereum 是使用甲醚作为燃料，以激励其网络的第一个图灵完备cryptocurrency。\r\nEthereum（以太坊） 是由Vitalik Buterin的创建。该项目于2014年8月获得了美国1800万$比特币的价值及其crowdsale期间。\r\n在2016年，Ethereum（以太坊）的价格上涨超过50倍。',
#   'zh-tw': 'Ethereum（以太幣）是一個平台和一種編程語言，使開發人員能夠建立和發布下一代分佈式應用。 Ethereum 是使用甲醚作為燃料，以激勵其網絡的第一個圖靈完備cryptocurrency。\r\nEthereum（以太幣） 是由Vitalik Buterin的創建。該項目於2014年8月獲得了美國1800萬$比特幣的價值及其crowdsale期間。\r\n在2016年，Ethereum（以太幣）的價格上漲超過50倍。',
#   'ko': '이더리움(Ethereum/ETH)은 블록체인 기술에 기반한 클라우드 컴퓨팅 플랫폼 또는 프로그래밍 언어이다. 비탈릭 부테린이 개발하였다.\r\n\r\n비탈릭 부테린은 가상화폐인 비트코인에 사용된 핵심 기술인 블록체인(blockchain)에 화폐 거래 기록뿐 아니라 계약서 등의 추가 정보를 기록할 수 있다는 점에 착안하여, 전 세계 수많은 사용자들이 보유하고 있는 컴퓨팅 자원을 활용해 분산 네트워크를 구성하고, 이 플랫폼을 이용하여 SNS, 이메일, 전자투표 등 다양한 정보를 기록하는 시스템을 창안했다. 이더리움은 C++, 자바, 파이썬, GO 등 주요 프로그래밍 언어를 지원한다.\r\n\r\n이더리움을 사물 인터넷(IoT)에 적용하면 기계 간 금융 거래도 가능해진다. 예를 들어 고장난 청소로봇이 정비로봇에 돈을 내고 정비를 받고, 청소로봇은 돈을 벌기 위해 정비로봇의 집을 청소하는 것도 가능해진다.',
#   'ar': '',
#   'th': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>',
#   'id': 'Ethereum is a <a href="https://www.coingecko.com/en?category_id=29&view=market">smart contract platform</a> that enables developers to build tokens and decentralized applications (dapps). ETH is the native currency for the Ethereum platform and also works as the transaction fees to miners on the Ethereum network.\r\n\r\nEthereum is the pioneer for blockchain based smart contracts. Smart contract is essentially a computer code that runs exactly as programmed without any possibility of downtime, censorship, fraud or third-party interference. It can facilitate the exchange of money, content, property, shares, or anything of value. When running on the blockchain a smart contract becomes like a self-operating computer program that automatically executes when specific conditions are met.\r\n\r\nEthereum allows programmers to run complete-turing smart contracts that is capable of any customizations. Rather than giving a set of limited operations, Ethereum allows developers to have complete control over customization of their smart contract, giving developers the power to build unique and innovative applications.\r\n\r\nEthereum being the first blockchain based smart contract platform, they have gained much popularity, resulting in new competitors fighting for market share. The competitors includes: <a href="https://www.coingecko.com/en/coins/ethereum_classic">Ethereum Classic</a> which is the oldchain of Ethereum, <a href="https://www.coingecko.com/en/coins/qtum">Qtum</a>, <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/neo">Neo</a>, <a href="https://www.coingecko.com/en/coins/icon">Icon</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a> and <a href="https://www.coingecko.com/en/coins/cardano">Cardano</a>.\r\n\r\nEthereum wallets are fairly simple to set up with multiple popular choices such as myetherwallet, <a href="https://www.coingecko.com/buzz/complete-beginners-guide-to-metamask?locale=en">metamask</a>, and <a href="https://www.coingecko.com/buzz/trezor-model-t-wallet-review">Trezor</a>. Read here for more guide on using ethereum wallet: <a href="https://www.coingecko.com/buzz/how-to-use-an-ethereum-wallet">How to Use an Ethereum Wallet</a>'},
#  'links': {'homepage': ['https://www.ethereum.org/', '', ''],
#   'blockchain_site': ['https://etherscan.io/',
#    'https://ethplorer.io/',
#    'https://blockchair.com/ethereum',
#    'https://eth.tokenview.com/',
#    'https://hecoinfo.com/token/0x64ff637fb478863b7468bc97d30a5bf3a428a1fd'],
#   'official_forum_url': ['https://forum.ethereum.org/', '', ''],
#   'chat_url': ['', '', ''],
#   'announcement_url': ['', ''],
#   'twitter_screen_name': 'ethereum',
#   'facebook_username': 'ethereumproject',
#   'bitcointalk_thread_identifier': 428589,
#   'telegram_channel_identifier': '',
#   'subreddit_url': 'https://www.reddit.com/r/ethereum',
#   'repos_url': {'github': ['https://github.com/ethereum/go-ethereum',
#     'https://github.com/ethereum/py-evm',
#     'https://github.com/ethereum/aleth',
#     'https://github.com/ethereum/web3.py',
#     'https://github.com/ethereum/solidity',
#     'https://github.com/ethereum/sharding',
#     'https://github.com/ethereum/casper',
#     'https://github.com/paritytech/parity'],
#    'bitbucket': []}},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/279/thumb/ethereum.png?1595348880',
#   'small': 'https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880',
#   'large': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880'},
#  'country_origin': '',
#  'genesis_date': '2015-07-30',
#  'sentiment_votes_up_percentage': 90.17,
#  'sentiment_votes_down_percentage': 9.83,
#  'ico_data': {'ico_start_date': '2014-07-20T00:00:00.000Z',
#   'ico_end_date': '2014-09-01T00:00:00.000Z',
#   'short_desc': 'A decentralized platform for applications',
#   'description': None,
#   'links': {},
#   'softcap_currency': '',
#   'hardcap_currency': '',
#   'total_raised_currency': '',
#   'softcap_amount': None,
#   'hardcap_amount': None,
#   'total_raised': None,
#   'quote_pre_sale_currency': '',
#   'base_pre_sale_amount': None,
#   'quote_pre_sale_amount': None,
#   'quote_public_sale_currency': 'BTC',
#   'base_public_sale_amount': 1.0,
#   'quote_public_sale_amount': 0.00074794,
#   'accepting_currencies': '',
#   'country_origin': '',
#   'pre_sale_start_date': None,
#   'pre_sale_end_date': None,
#   'whitelist_url': '',
#   'whitelist_start_date': None,
#   'whitelist_end_date': None,
#   'bounty_detail_url': '',
#   'amount_for_sale': None,
#   'kyc_required': True,
#   'whitelist_available': None,
#   'pre_sale_available': None,
#   'pre_sale_ended': False},
#  'market_cap_rank': 2,
#  'coingecko_rank': 3,
#  'coingecko_score': 77.163,
#  'developer_score': 97.176,
#  'community_score': 62.612,
#  'liquidity_score': 98.968,
#  'public_interest_score': 0.0,
#  'market_data': {'current_price': {'aed': 14153.17,
#    'ars': 358677,
#    'aud': 4911.43,
#    'bch': 2.883651,
#    'bdt': 324070,
#    'bhd': 1441.67,
#    'bmd': 3853.09,
#    'bnb': 5.801464,
#    'brl': 20177,
#    'btc': 0.06725438,
#    'cad': 4675.95,
#    'chf': 3472.5,
#    'clp': 2679438,
#    'cny': 24785,
#    'czk': 81209,
#    'dkk': 23555,
#    'dot': 97.192,
#    'eos': 393.127,
#    'eth': 1.0,
#    'eur': 3167.81,
#    'gbp': 2757.23,
#    'hkd': 29923,
#    'huf': 1135428,
#    'idr': 54449925,
#    'ils': 12484.03,
#    'inr': 282416,
#    'jpy': 418388,
#    'krw': 4288372,
#    'kwd': 1150.55,
#    'lkr': 753339,
#    'ltc': 10.750114,
#    'mmk': 5955957,
#    'mxn': 76708,
#    'myr': 15845.83,
#    'ngn': 1563094,
#    'nok': 31667,
#    'nzd': 5291.62,
#    'php': 183123,
#    'pkr': 581562,
#    'pln': 14420.38,
#    'rub': 284046,
#    'sar': 14450.53,
#    'sek': 32010,
#    'sgd': 5103.8,
#    'thb': 119607,
#    'try': 31738,
#    'twd': 106576,
#    'uah': 106142,
#    'usd': 3853.09,
#    'vef': 385.81,
#    'vnd': 88201388,
#    'xag': 140.37,
#    'xau': 2.1,
#    'xdr': 2675.48,
#    'xlm': 6410,
#    'xrp': 2554,
#    'yfi': 0.07314185,
#    'zar': 54184,
#    'bits': 67254,
#    'link': 77.134,
#    'sats': 6725438},
#   'total_value_locked': None,
#   'mcap_to_tvl_ratio': None,
#   'fdv_to_tvl_ratio': None,
#   'roi': {'times': 88.91949044314723,
#    'currency': 'btc',
#    'percentage': 8891.949044314722},
#   'ath': {'aed': 14660.42,
#    'ars': 374016,
#    'aud': 5087.45,
#    'bch': 3.993247,
#    'bdt': 338127,
#    'bhd': 1504.6,
#    'bmd': 3991.18,
#    'bnb': 7747,
#    'brl': 20900,
#    'btc': 0.1474984,
#    'cad': 4843.54,
#    'chf': 3595.21,
#    'clp': 2775469,
#    'cny': 25673,
#    'czk': 84119,
#    'dkk': 24399,
#    'dot': 141.356,
#    'eos': 550.951,
#    'eth': 1.003981,
#    'eur': 3281.35,
#    'gbp': 2856.05,
#    'hkd': 30995,
#    'huf': 1176122,
#    'idr': 56401410,
#    'ils': 12983.84,
#    'inr': 292538,
#    'jpy': 433383,
#    'krw': 4442068,
#    'kwd': 1201.85,
#    'lkr': 786017,
#    'ltc': 13.727593,
#    'mmk': 6214343,
#    'mxn': 79457,
#    'myr': 16413.74,
#    'ngn': 1619115,
#    'nok': 32802,
#    'nzd': 5481.27,
#    'php': 190677,
#    'pkr': 607535,
#    'pln': 14937.2,
#    'rub': 294227,
#    'sar': 14968.44,
#    'sek': 33158,
#    'sgd': 5286.72,
#    'thb': 123894,
#    'try': 32876,
#    'twd': 110618,
#    'uah': 110746,
#    'usd': 3991.18,
#    'vef': 283483138,
#    'vnd': 91362525,
#    'xag': 145.4,
#    'xau': 2.18,
#    'xdr': 2771.37,
#    'xlm': 7475,
#    'xrp': 5280,
#    'yfi': 0.07382993,
#    'zar': 56126,
#    'bits': 68633,
#    'link': 84.442,
#    'sats': 6863316},
#   'ath_change_percentage': {'aed': -3.24062,
#    'ars': -3.88308,
#    'aud': -3.24062,
#    'bch': -27.62533,
#    'bdt': -3.93965,
#    'bhd': -3.96481,
#    'bmd': -3.24062,
#    'bnb': -99.92509,
#    'brl': -3.24062,
#    'btc': -54.31932,
#    'cad': -3.24062,
#    'chf': -3.19368,
#    'clp': -3.24062,
#    'cny': -3.24062,
#    'czk': -3.24062,
#    'dkk': -3.24062,
#    'dot': -31.0107,
#    'eos': -29.10633,
#    'eth': -0.39652,
#    'eur': -3.24062,
#    'gbp': -3.24062,
#    'hkd': -3.24062,
#    'huf': -3.24062,
#    'idr': -3.24062,
#    'ils': -3.63101,
#    'inr': -3.24062,
#    'jpy': -3.24062,
#    'krw': -3.24062,
#    'kwd': -4.0509,
#    'lkr': -3.93964,
#    'ltc': -21.83631,
#    'mmk': -3.94011,
#    'mxn': -3.24062,
#    'myr': -3.24062,
#    'ngn': -3.24062,
#    'nok': -3.24062,
#    'nzd': -3.24062,
#    'php': -3.74373,
#    'pkr': -4.05757,
#    'pln': -3.24062,
#    'rub': -3.24062,
#    'sar': -3.24062,
#    'sek': -3.24062,
#    'sgd': -3.24062,
#    'thb': -3.24062,
#    'try': -3.24062,
#    'twd': -3.43459,
#    'uah': -3.93965,
#    'usd': -3.24062,
#    'vef': -99.99986,
#    'vnd': -3.24062,
#    'xag': -3.24062,
#    'xau': -3.24062,
#    'xdr': -3.24062,
#    'xlm': -13.81885,
#    'xrp': -51.60218,
#    'yfi': -0.91623,
#    'zar': -3.24062,
#    'bits': -1.8284,
#    'link': -7.91331,
#    'sats': -1.8284},
#   'ath_date': {'aed': '2021-05-09T07:23:27.353Z',
#    'ars': '2021-05-09T06:53:44.474Z',
#    'aud': '2021-05-09T07:23:27.353Z',
#    'bch': '2021-02-05T16:37:22.595Z',
#    'bdt': '2021-05-09T06:53:44.474Z',
#    'bhd': '2021-05-09T06:53:44.474Z',
#    'bmd': '2021-05-09T07:23:27.353Z',
#    'bnb': '2017-10-19T00:00:00.000Z',
#    'brl': '2021-05-09T07:23:27.353Z',
#    'btc': '2017-06-12T00:00:00.000Z',
#    'cad': '2021-05-09T07:23:27.353Z',
#    'chf': '2021-05-09T07:23:27.353Z',
#    'clp': '2021-05-09T07:23:27.353Z',
#    'cny': '2021-05-09T07:23:27.353Z',
#    'czk': '2021-05-09T07:23:27.353Z',
#    'dkk': '2021-05-09T07:23:27.353Z',
#    'dot': '2021-01-11T03:44:27.861Z',
#    'eos': '2021-02-05T16:07:31.647Z',
#    'eth': '2019-10-15T16:26:30.106Z',
#    'eur': '2021-05-09T07:23:27.353Z',
#    'gbp': '2021-05-09T07:23:27.353Z',
#    'hkd': '2021-05-09T07:23:27.353Z',
#    'huf': '2021-05-09T07:23:27.353Z',
#    'idr': '2021-05-09T07:23:27.353Z',
#    'ils': '2021-05-09T06:53:44.474Z',
#    'inr': '2021-05-09T07:23:27.353Z',
#    'jpy': '2021-05-09T07:23:27.353Z',
#    'krw': '2021-05-09T07:23:27.353Z',
#    'kwd': '2021-05-09T06:53:44.474Z',
#    'lkr': '2021-05-09T06:53:44.474Z',
#    'ltc': '2017-06-12T00:00:00.000Z',
#    'mmk': '2021-05-09T06:53:44.474Z',
#    'mxn': '2021-05-09T07:23:27.353Z',
#    'myr': '2021-05-09T07:23:27.353Z',
#    'ngn': '2021-05-09T07:23:27.353Z',
#    'nok': '2021-05-09T07:23:27.353Z',
#    'nzd': '2021-05-09T07:23:27.353Z',
#    'php': '2021-05-09T06:53:44.474Z',
#    'pkr': '2021-05-09T06:53:44.474Z',
#    'pln': '2021-05-09T07:23:27.353Z',
#    'rub': '2021-05-09T07:23:27.353Z',
#    'sar': '2021-05-09T07:23:27.353Z',
#    'sek': '2021-05-09T07:23:27.353Z',
#    'sgd': '2021-05-09T07:23:27.353Z',
#    'thb': '2021-05-09T07:23:27.353Z',
#    'try': '2021-05-09T07:23:27.353Z',
#    'twd': '2021-05-09T06:53:44.474Z',
#    'uah': '2021-05-09T06:53:44.474Z',
#    'usd': '2021-05-09T07:23:27.353Z',
#    'vef': '2021-01-04T06:47:56.457Z',
#    'vnd': '2021-05-09T07:23:27.353Z',
#    'xag': '2021-05-09T07:23:27.353Z',
#    'xau': '2021-05-09T07:23:27.353Z',
#    'xdr': '2021-05-09T07:23:27.353Z',
#    'xlm': '2021-01-04T07:33:12.561Z',
#    'xrp': '2021-01-25T00:56:00.256Z',
#    'yfi': '2021-05-09T04:24:49.665Z',
#    'zar': '2021-05-09T07:23:27.353Z',
#    'bits': '2021-05-09T08:38:41.771Z',
#    'link': '2021-05-04T06:03:17.775Z',
#    'sats': '2021-05-09T08:38:41.771Z'},
#   'atl': {'aed': 1.59,
#    'ars': 4.1,
#    'aud': 0.596152,
#    'bch': 0.20411961,
#    'bdt': 33.7,
#    'bhd': 0.163288,
#    'bmd': 0.432979,
#    'bnb': 3.541506,
#    'brl': 1.69,
#    'btc': 0.00160204,
#    'cad': 0.561954,
#    'chf': 0.413801,
#    'clp': 297.03,
#    'cny': 2.81,
#    'czk': 10.33,
#    'dkk': 2.84,
#    'dot': 40.15685,
#    'eos': 30.013555,
#    'eth': 0.99987722,
#    'eur': 0.381455,
#    'gbp': 0.280314,
#    'hkd': 3.35,
#    'huf': 118.42,
#    'idr': 5876.48,
#    'ils': 1.67,
#    'inr': 28.13,
#    'jpy': 51.85,
#    'krw': 489.4,
#    'kwd': 0.130639,
#    'lkr': 61.02,
#    'ltc': 0.13982924,
#    'mmk': 468.1,
#    'mxn': 7.16,
#    'myr': 1.85,
#    'ngn': 138690,
#    'nok': 3.52,
#    'nzd': 0.641302,
#    'php': 20.05,
#    'pkr': 45.2,
#    'pln': 1.62,
#    'rub': 26.88,
#    'sar': 1.62,
#    'sek': 3.59,
#    'sgd': 0.601615,
#    'thb': 15.33,
#    'try': 1.26,
#    'twd': 14.02,
#    'uah': 9.54,
#    'usd': 0.432979,
#    'vef': 2.74,
#    'vnd': 9662.0,
#    'xag': 0.02721328,
#    'xau': 0.00036799,
#    'xdr': 0.306291,
#    'xlm': 664.668,
#    'xrp': 286.238,
#    'yfi': 0.00878891,
#    'zar': 5.74,
#    'bits': 22873,
#    'link': 21.519699,
#    'sats': 2287269},
#   'atl_change_percentage': {'aed': 891861.45573,
#    'ars': 8758574.28193,
#    'aud': 825627.31327,
#    'bch': 1315.88514,
#    'bdt': 963698.65897,
#    'bhd': 884807.9215,
#    'bmd': 891825.0313,
#    'bnb': 63.86862,
#    'brl': 1195448.72451,
#    'btc': 4105.76975,
#    'cad': 833879.51164,
#    'chf': 840976.78352,
#    'clp': 904035.81321,
#    'cny': 883088.05116,
#    'czk': 787719.09082,
#    'dkk': 829758.01077,
#    'dot': 142.84899,
#    'eos': 1201.37592,
#    'eth': 0.01228,
#    'eur': 832241.43458,
#    'gbp': 985755.52616,
#    'hkd': 893952.38702,
#    'huf': 960929.60528,
#    'idr': 928579.72863,
#    'ils': 750093.77678,
#    'inr': 1006104.45998,
#    'jpy': 808727.68684,
#    'krw': 878134.29466,
#    'kwd': 882610.78926,
#    'lkr': 1237250.44206,
#    'ltc': 7573.64086,
#    'mmk': 1275168.86042,
#    'mxn': 1074145.17755,
#    'myr': 858344.92408,
#    'ngn': 1029.6006,
#    'nok': 902653.77071,
#    'nzd': 826911.50183,
#    'php': 915448.16576,
#    'pkr': 1289606.23768,
#    'pln': 889865.2455,
#    'rub': 1058974.33089,
#    'sar': 891872.83625,
#    'sek': 892602.1866,
#    'sgd': 850177.17812,
#    'thb': 781911.15969,
#    'try': 2533443.43972,
#    'twd': 761828.77077,
#    'uah': 1114503.77755,
#    'usd': 891825.0313,
#    'vef': 14029.39423,
#    'vnd': 914843.52688,
#    'xag': 516878.12425,
#    'xau': 572917.60419,
#    'xdr': 875396.85987,
#    'xlm': 869.16134,
#    'xrp': 792.72671,
#    'yfi': 732.33834,
#    'zar': 945617.89633,
#    'bits': 194.57963,
#    'link': 261.34126,
#    'sats': 194.57963},
# ...
#    'coin_id': 'usd-coin',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'CBX',
#     'identifier': 'cbx',
#     'has_trading_incentive': False},
#    'last': 3841.47,
#    'volume': 58888.86665,
#    'converted_last': {'btc': 0.06700678, 'eth': 0.99641851, 'usd': 3838.9},
#    'converted_volume': {'btc': 3946, 'eth': 58678, 'usd': 226068673},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.033054,
#    'timestamp': '2021-05-09T15:07:42+00:00',
#    'last_traded_at': '2021-05-09T15:07:42+00:00',
#    'last_fetch_at': '2021-05-09T15:07:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.cbx.one/trade/ETH-USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Bitcoin.com Exchange',
#     'identifier': 'bitcoin_com',
#     'has_trading_incentive': False},
#    'last': 0.067032,
#    'volume': 20313.0609,
#    'converted_last': {'btc': 0.067032, 'eth': 0.99669339, 'usd': 3843.4},
#    'converted_volume': {'btc': 1362, 'eth': 20246, 'usd': 78071151},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010442,
#    'timestamp': '2021-05-09T15:08:02+00:00',
#    'last_traded_at': '2021-05-09T15:08:02+00:00',
#    'last_fetch_at': '2021-05-09T15:08:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://exchange.bitcoin.com/exchange/ETH-to-BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Changelly PRO',
#     'identifier': 'changelly',
#     'has_trading_incentive': False},
#    'last': 0.066994,
#    'volume': 20311.5637,
#    'converted_last': {'btc': 0.066994, 'eth': 0.99622843, 'usd': 3837.93},
#    'converted_volume': {'btc': 1361, 'eth': 20235, 'usd': 77954317},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.015973,
#    'timestamp': '2021-05-09T15:06:10+00:00',
#    'last_traded_at': '2021-05-09T15:06:10+00:00',
#    'last_fetch_at': '2021-05-09T15:06:10+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.changelly.com',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'DAI',
#    'market': {'name': 'dYdX',
#     'identifier': 'dydx',
#     'has_trading_incentive': False},
#    'last': 3783.75,
#    'volume': 6807.795,
#    'converted_last': {'btc': 0.06598824, 'eth': 0.98513347, 'usd': 3786.55},
#    'converted_volume': {'btc': 449.234, 'eth': 6707, 'usd': 25778083},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.198255,
#    'timestamp': '2021-05-09T14:18:47+00:00',
#    'last_traded_at': '2021-05-09T14:18:47+00:00',
#    'last_fetch_at': '2021-05-09T15:07:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://trade.dydx.exchange/markets',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'dai'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'BW.com',
#     'identifier': 'bw',
#     'has_trading_incentive': False},
#    'last': 3836.39,
#    'volume': 30816.8562,
#    'converted_last': {'btc': 0.06691817, 'eth': 0.99510083, 'usd': 3833.58},
#    'converted_volume': {'btc': 2062, 'eth': 30666, 'usd': 118139002},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.058352,
#    'timestamp': '2021-05-09T15:06:53+00:00',
#    'last_traded_at': '2021-05-09T15:06:53+00:00',
#    'last_fetch_at': '2021-05-09T15:06:53+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bw.com/trade/eth_usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.06705,
#    'volume': 57231.90405723,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 3837, 'eth': 57058, 'usd': 220023977},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014914,
#    'timestamp': '2021-05-09T15:08:19+00:00',
#    'last_traded_at': '2021-05-09T15:08:19+00:00',
#    'last_fetch_at': '2021-05-09T15:08:19+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Bitoffer',
#     'identifier': 'bitoffer',
#     'has_trading_incentive': False},
#    'last': 0.066978,
#    'volume': 155640.773,
#    'converted_last': {'btc': 0.066978, 'eth': 0.99599051, 'usd': 3837.01},
#    'converted_volume': {'btc': 10425, 'eth': 155017, 'usd': 597195401},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.025375,
#    'timestamp': '2021-05-09T15:06:08+00:00',
#    'last_traded_at': '2021-05-09T15:06:08+00:00',
#    'last_fetch_at': '2021-05-09T15:06:08+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitoffer.com/en/exchange',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': '0X6B175474E89094C44DA98B954EEDEAC495271D0F',
#    'target': 'ETH',
#    'market': {'name': 'Sushiswap',
#     'identifier': 'sushiswap',
#     'has_trading_incentive': False},
#    'last': 0.000261117374978665,
#    'volume': 96760800.6383438,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 1694, 'eth': 25189, 'usd': 97133053},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:08:25+00:00',
#    'last_traded_at': '2021-05-09T15:08:25+00:00',
#    'last_fetch_at': '2021-05-09T15:08:25+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.sushi.com/swap?outputCurrency=0x6b175474e89094c44da98b954eedeac495271d0f',
#    'token_info_url': 'https://analytics.sushi.com/tokens/0x6b175474e89094c44da98b954eedeac495271d0f',
#    'coin_id': 'dai',
#    'target_coin_id': 'ethereum'},
#   {'base': '0X6B175474E89094C44DA98B954EEDEAC495271D0F',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000260977026718754,
#    'volume': 53925912.9937045,
#    'converted_last': {'btc': 0.06703, 'eth': 0.99618851, 'usd': 3837.7},
#    'converted_volume': {'btc': 943.342, 'eth': 14020, 'usd': 54009524},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:04:57+00:00',
#    'last_traded_at': '2021-05-09T15:04:57+00:00',
#    'last_fetch_at': '2021-05-09T15:04:57+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x6b175474e89094c44da98b954eedeac495271d0f&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x6b175474e89094c44da98b954eedeac495271d0f',
#    'coin_id': 'dai',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'KRW',
#    'market': {'name': 'Bithumb',
#     'identifier': 'bithumb',
#     'has_trading_incentive': False},
#    'last': 4736000.0,
#    'volume': 108686.81085759,
#    'converted_last': {'btc': 0.07427922, 'eth': 1.104563, 'usd': 4255.28},
#    'converted_volume': {'btc': 8073, 'eth': 120051, 'usd': 462492912},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.084388,
#    'timestamp': '2021-05-09T15:06:11+00:00',
#    'last_traded_at': '2021-05-09T15:06:11+00:00',
#    'last_fetch_at': '2021-05-09T15:06:11+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bithumb.com/trade/order/ETH_KRW',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'LBank',
#     'identifier': 'lbank',
#     'has_trading_incentive': False},
#    'last': 3837.92,
#    'volume': 137460.8452,
#    'converted_last': {'btc': 0.06694486, 'eth': 0.99549769, 'usd': 3835.11},
#    'converted_volume': {'btc': 9202, 'eth': 136842, 'usd': 527177836},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.057045,
#    'timestamp': '2021-05-09T15:06:50+00:00',
#    'last_traded_at': '2021-05-09T15:06:50+00:00',
#    'last_fetch_at': '2021-05-09T15:06:50+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.lbank.info/exchange/eth/usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Dex-Trade',
#     'identifier': 'dextrade',
#     'has_trading_incentive': False},
#    'last': 0.067042,
#    'volume': 2174.6967218,
#    'converted_last': {'btc': 0.067042, 'eth': 0.99694221, 'usd': 3840.92},
#    'converted_volume': {'btc': 145.796, 'eth': 2168, 'usd': 8352839},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.146142,
#    'timestamp': '2021-05-09T15:07:51+00:00',
#    'last_traded_at': '2021-05-09T15:07:51+00:00',
#    'last_fetch_at': '2021-05-09T15:07:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Dcoin',
#     'identifier': 'dcoin',
#     'has_trading_incentive': False},
#    'last': 3841.95,
#    'volume': 113599.0,
#    'converted_last': {'btc': 0.06701515, 'eth': 0.99654301, 'usd': 3839.38},
#    'converted_volume': {'btc': 7613, 'eth': 113206, 'usd': 436150083},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.066349,
#    'timestamp': '2021-05-09T15:07:40+00:00',
#    'last_traded_at': '2021-05-09T15:07:40+00:00',
#    'last_fetch_at': '2021-05-09T15:07:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.dcoin.com/currencyTrading/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3173.54,
#    'volume': 43262.46325161,
#    'converted_last': {'btc': 0.06738024, 'eth': 1.001972, 'usd': 3860.05},
#    'converted_volume': {'btc': 2915, 'eth': 43348, 'usd': 166995469},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.061431,
#    'timestamp': '2021-05-09T15:06:33+00:00',
#    'last_traded_at': '2021-05-09T15:06:33+00:00',
#    'last_fetch_at': '2021-05-09T15:08:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-EUR',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'CEX.IO',
#     'identifier': 'cex',
#     'has_trading_incentive': False},
#    'last': 3823.68,
#    'volume': 5651.610391,
#    'converted_last': {'btc': 0.0667619, 'eth': 0.99277706, 'usd': 3823.68},
#    'converted_volume': {'btc': 377.312, 'eth': 5611, 'usd': 21609950},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010261,
#    'timestamp': '2021-05-09T15:05:43+00:00',
#    'last_traded_at': '2021-05-09T15:05:43+00:00',
#    'last_fetch_at': '2021-05-09T15:05:43+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 3173.7,
#    'volume': 78053.95546202631,
#    'converted_last': {'btc': 0.06734542, 'eth': 0.99849556, 'usd': 3860.25},
#    'converted_volume': {'btc': 5257, 'eth': 77937, 'usd': 301307717},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010315,
#    'timestamp': '2021-05-09T14:56:40+00:00',
#    'last_traded_at': '2021-05-09T14:56:40+00:00',
#    'last_fetch_at': '2021-05-09T14:56:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/ETH_EUR?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'AUD',
#    'market': {'name': 'FTX.US',
#     'identifier': 'ftx_us',
#     'has_trading_incentive': False},
#    'last': 4900.0,
#    'volume': 0.03427018367346939,
#    'converted_last': {'btc': 0.06709789, 'eth': 0.99777333, 'usd': 3844.12},
#    'converted_volume': {'btc': 0.00229946, 'eth': 0.03419388, 'usd': 131.74},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.327495,
#    'timestamp': '2021-05-09T15:07:37+00:00',
#    'last_traded_at': '2021-05-09T15:07:37+00:00',
#    'last_fetch_at': '2021-05-09T15:07:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.us/trade/ETH/AUD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Bitstamp',
#     'identifier': 'bitstamp',
#     'has_trading_incentive': False},
#    'last': 3172.95,
#    'volume': 30719.85400567,
#    'converted_last': {'btc': 0.06728414, 'eth': 0.99827205, 'usd': 3859.34},
#    'converted_volume': {'btc': 2067, 'eth': 30667, 'usd': 118558267},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.085853,
#    'timestamp': '2021-05-09T14:54:33+00:00',
#    'last_traded_at': '2021-05-09T14:54:33+00:00',
#    'last_fetch_at': '2021-05-09T14:54:33+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': '0X66A0F676479CEE1D7373F3DC2E2952778BFF5BD6',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000202451613997576,
#    'volume': 354516.68036255,
#    'converted_last': {'btc': 0.06703, 'eth': 0.99618851, 'usd': 3837.7},
#    'converted_volume': {'btc': 4.810909, 'eth': 71.499, 'usd': 275441},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:03:53+00:00',
#    'last_traded_at': '2021-05-09T15:03:53+00:00',
#    'last_fetch_at': '2021-05-09T15:08:43+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x66a0f676479cee1d7373f3dc2e2952778bff5bd6&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x66a0f676479cee1d7373f3dc2e2952778bff5bd6',
#    'coin_id': 'wise-token11',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Bidesk',
#     'identifier': 'bidesk',
#     'has_trading_incentive': False},
#    'last': 3839.6,
#    'volume': 113788.8975,
#    'converted_last': {'btc': 0.06697416, 'eth': 0.99583343, 'usd': 3840.08},
#    'converted_volume': {'btc': 7621, 'eth': 113315, 'usd': 436958530},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.015626,
#    'timestamp': '2021-05-09T15:08:27+00:00',
#    'last_traded_at': '2021-05-09T15:08:27+00:00',
#    'last_fetch_at': '2021-05-09T15:08:27+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bidesk.com/exchange/ETH/USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': '0X2260FAC5E5542A773AA44FBCFEDF7C193BC2C599',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 14.9856945677295,
#    'volume': 698.44516586,
#    'converted_last': {'btc': 0.06703, 'eth': 0.99618851, 'usd': 3837.7},
#    'converted_volume': {'btc': 701.582, 'eth': 10427, 'usd': 40167955},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:03:41+00:00',
#    'last_traded_at': '2021-05-09T15:03:41+00:00',
#    'last_fetch_at': '2021-05-09T15:03:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#    'coin_id': 'wrapped-bitcoin',
#    'target_coin_id': 'ethereum'}]}

# %%
# Get coin tickers paginated to 100 items
cg.get_coin_ticker_by_id(id='ethereum')
# Out:
# {'name': 'Ethereum',
#  'tickers': [{'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'FTX',
#     'identifier': 'ftx_spot',
#     'has_trading_incentive': False},
#    'last': 0.06709,
#    'volume': 7977.3028535549265,
#    'converted_last': {'btc': 0.06709, 'eth': 0.99755579, 'usd': 3847.17},
#    'converted_volume': {'btc': 535.197, 'eth': 7958, 'usd': 30690037},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.055866,
#    'timestamp': '2021-05-09T15:09:59+00:00',
#    'last_traded_at': '2021-05-09T15:09:59+00:00',
#    'last_fetch_at': '2021-05-09T15:09:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.com/trade/ETH/BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 3840.1,
#    'volume': 1320229.8925011482,
#    'converted_last': {'btc': 0.06698289, 'eth': 0.99495105, 'usd': 3838.96},
#    'converted_volume': {'btc': 88433, 'eth': 1313564, 'usd': 5068310309},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010262,
#    'timestamp': '2021-05-09T15:12:05+00:00',
#    'last_traded_at': '2021-05-09T15:12:05+00:00',
#    'last_fetch_at': '2021-05-09T15:12:05+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/ETH_USDT?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'FTX',
#     'identifier': 'ftx_spot',
#     'has_trading_incentive': False},
#    'last': 3844.2,
#    'volume': 30653.50988517767,
#    'converted_last': {'btc': 0.0670544, 'eth': 0.99702648, 'usd': 3844.9},
#    'converted_volume': {'btc': 2055, 'eth': 30562, 'usd': 117859813},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.054632,
#    'timestamp': '2021-05-09T15:10:02+00:00',
#    'last_traded_at': '2021-05-09T15:10:02+00:00',
#    'last_fetch_at': '2021-05-09T15:10:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.com/trade/ETH/USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'TopBTC',
#     'identifier': 'topbtc',
#     'has_trading_incentive': False},
#    'last': 3841.34,
#    'volume': 25283.8286,
#    'converted_last': {'btc': 0.06700451, 'eth': 0.99527232, 'usd': 3842.03},
#    'converted_volume': {'btc': 1694, 'eth': 25164, 'usd': 97141145},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 1.061679,
#    'timestamp': '2021-05-09T15:11:42+00:00',
#    'last_traded_at': '2021-05-09T15:11:42+00:00',
#    'last_fetch_at': '2021-05-09T15:11:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://topbtc.com/home/market/index/market/USDT/coin/ETH.html',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 3839.9389152,
#    'volume': 84923.55030546,
#    'converted_last': {'btc': 0.0669681, 'eth': 0.99473148, 'usd': 3839.94},
#    'converted_volume': {'btc': 5687, 'eth': 84476, 'usd': 326101246},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.026048,
#    'timestamp': '2021-05-09T15:11:58+00:00',
#    'last_traded_at': '2021-05-09T15:11:58+00:00',
#    'last_fetch_at': '2021-05-09T15:11:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHUSD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 3158.77868549,
#    'volume': 5115.26765701,
#    'converted_last': {'btc': 0.06700579, 'eth': 0.99529131, 'usd': 3842.1},
#    'converted_volume': {'btc': 342.753, 'eth': 5091, 'usd': 19653370},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.031686,
#    'timestamp': '2021-05-09T15:11:52+00:00',
#    'last_traded_at': '2021-05-09T15:11:52+00:00',
#    'last_fetch_at': '2021-05-09T15:11:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHEUR',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'FTX.US',
#     'identifier': 'ftx_us',
#     'has_trading_incentive': False},
#    'last': 0.0670275,
#    'volume': 13346.302742269963,
#    'converted_last': {'btc': 0.0670275, 'eth': 0.99672659, 'usd': 3840.09},
#    'converted_volume': {'btc': 894.569, 'eth': 13303, 'usd': 51251009},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.055916,
#    'timestamp': '2021-05-09T15:07:37+00:00',
#    'last_traded_at': '2021-05-09T15:07:37+00:00',
#    'last_fetch_at': '2021-05-09T15:07:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.us/trade/ETH/BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'GBP',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 2748.2,
#    'volume': 5113.10285854,
#    'converted_last': {'btc': 0.066981, 'eth': 0.99593512, 'usd': 3840.47},
#    'converted_volume': {'btc': 342.481, 'eth': 5092, 'usd': 19636732},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.036403,
#    'timestamp': '2021-05-09T15:08:40+00:00',
#    'last_traded_at': '2021-05-09T15:08:40+00:00',
#    'last_fetch_at': '2021-05-09T15:11:56+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHGBP',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'BETH',
#    'target': 'ETH',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 0.9376,
#    'volume': 9110.65291793942,
#    'converted_last': {'btc': 0.06706, 'eth': 0.99527634, 'usd': 3842.6},
#    'converted_volume': {'btc': 572.836, 'eth': 8502, 'usd': 32824018},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.085242,
#    'timestamp': '2021-05-09T15:00:03+00:00',
#    'last_traded_at': '2021-05-09T15:00:03+00:00',
#    'last_fetch_at': '2021-05-09T15:00:03+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/BETH_ETH?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'binance-eth',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'JPY',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 416960.0,
#    'volume': 5330.78886324,
#    'converted_last': {'btc': 0.06696814, 'eth': 0.99473204, 'usd': 3839.94},
#    'converted_volume': {'btc': 356.993, 'eth': 5303, 'usd': 20469915},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.047962,
#    'timestamp': '2021-05-09T15:11:49+00:00',
#    'last_traded_at': '2021-05-09T15:11:49+00:00',
#    'last_fetch_at': '2021-05-09T15:11:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHJPY',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'FTX.US',
#     'identifier': 'ftx_us',
#     'has_trading_incentive': False},
#    'last': 3844.9,
#    'volume': 10073.215959192697,
#    'converted_last': {'btc': 0.06711145, 'eth': 0.99797496, 'usd': 3844.9},
#    'converted_volume': {'btc': 676.028, 'eth': 10053, 'usd': 38730508},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.088376,
#    'timestamp': '2021-05-09T15:07:37+00:00',
#    'last_traded_at': '2021-05-09T15:07:37+00:00',
#    'last_fetch_at': '2021-05-09T15:07:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.us/trade/ETH/USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'FTX.US',
#     'identifier': 'ftx_us',
#     'has_trading_incentive': False},
#    'last': 3841.5,
#    'volume': 4649.619923831837,
#    'converted_last': {'btc': 0.06700731, 'eth': 0.99642629, 'usd': 3838.93},
#    'converted_volume': {'btc': 311.559, 'eth': 4633, 'usd': 17849581},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.171598,
#    'timestamp': '2021-05-09T15:07:37+00:00',
#    'last_traded_at': '2021-05-09T15:07:37+00:00',
#    'last_fetch_at': '2021-05-09T15:07:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.us/trade/ETH/USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'VCC Exchange',
#     'identifier': 'vcc',
#     'has_trading_incentive': False},
#    'last': 3842.81,
#    'volume': 438136.0429,
#    'converted_last': {'btc': 0.06703016, 'eth': 0.99565319, 'usd': 3843.5},
#    'converted_volume': {'btc': 29368, 'eth': 436232, 'usd': 1683974553},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01026,
#    'timestamp': '2021-05-09T15:11:01+00:00',
#    'last_traded_at': '2021-05-09T15:11:01+00:00',
#    'last_fetch_at': '2021-05-09T15:11:01+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://vcc.exchange/exchange/basic?currency=usdt&coin=eth',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'BitZ',
#     'identifier': 'bit_z',
#     'has_trading_incentive': False},
#    'last': 3835.24,
#    'volume': 770324.0,
#    'converted_last': {'btc': 0.06689811, 'eth': 0.99480254, 'usd': 3832.68},
#    'converted_volume': {'btc': 51533, 'eth': 766320, 'usd': 2952403542},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.108207,
#    'timestamp': '2021-05-09T15:07:22+00:00',
#    'last_traded_at': '2021-05-09T15:07:22+00:00',
#    'last_fetch_at': '2021-05-09T15:07:22+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bit-z.com/exchange/eth_usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Huobi Global',
#     'identifier': 'huobi',
#     'has_trading_incentive': False},
#    'last': 3841.01,
#    'volume': 701713.775815074,
#    'converted_last': {'btc': 0.06699876, 'eth': 0.99629919, 'usd': 3838.44},
#    'converted_volume': {'btc': 47014, 'eth': 699117, 'usd': 2693488856},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01026,
#    'timestamp': '2021-05-09T15:07:40+00:00',
#    'last_traded_at': '2021-05-09T15:07:40+00:00',
#    'last_fetch_at': '2021-05-09T15:07:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.hbg.com/en-us/exchange/?s=eth_usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3842.11,
#    'volume': 394014.04489404,
#    'converted_last': {'btc': 0.06700597, 'eth': 0.9952939, 'usd': 3842.11},
#    'converted_volume': {'btc': 26401, 'eth': 392160, 'usd': 1513845302},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01026,
#    'timestamp': '2021-05-09T15:11:31+00:00',
#    'last_traded_at': '2021-05-09T15:11:31+00:00',
#    'last_fetch_at': '2021-05-09T15:11:31+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'BTSE',
#     'identifier': 'btse',
#     'has_trading_incentive': False},
#    'last': 3839.1,
#    'volume': 12356.61534976158,
#    'converted_last': {'btc': 0.06695347, 'eth': 0.99451416, 'usd': 3839.1},
#    'converted_volume': {'btc': 827.318, 'eth': 12289, 'usd': 47438282},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.041678,
#    'timestamp': '2021-05-09T15:11:21+00:00',
#    'last_traded_at': '2021-05-09T15:11:21+00:00',
#    'last_fetch_at': '2021-05-09T15:11:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.btse.com/en/trading/ETH-USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Bitoffer',
#     'identifier': 'bitoffer',
#     'has_trading_incentive': False},
#    'last': 3837.11,
#    'volume': 680992.42122,
#    'converted_last': {'btc': 0.06693073, 'eth': 0.99417635, 'usd': 3837.8},
#    'converted_volume': {'btc': 45579, 'eth': 677027, 'usd': 2613509957},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.019898,
#    'timestamp': '2021-05-09T15:11:42+00:00',
#    'last_traded_at': '2021-05-09T15:11:42+00:00',
#    'last_fetch_at': '2021-05-09T15:11:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitoffer.com/en/exchange',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'ZBG',
#     'identifier': 'zbg',
#     'has_trading_incentive': False},
#    'last': 3841.68,
#    'volume': 57278.591,
#    'converted_last': {'btc': 0.06701045, 'eth': 0.99536042, 'usd': 3842.37},
#    'converted_volume': {'btc': 3838, 'eth': 57013, 'usd': 220085355},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.382108,
#    'timestamp': '2021-05-09T15:11:48+00:00',
#    'last_traded_at': '2021-05-09T15:11:48+00:00',
#    'last_fetch_at': '2021-05-09T15:11:48+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'FTX',
#     'identifier': 'ftx_spot',
#     'has_trading_incentive': False},
#    'last': 3845.0,
#    'volume': 100879.80419305591,
#    'converted_last': {'btc': 0.06705216, 'eth': 0.99699322, 'usd': 3845.0},
#    'converted_volume': {'btc': 6764, 'eth': 100576, 'usd': 387882847},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.012601,
#    'timestamp': '2021-05-09T15:09:58+00:00',
#    'last_traded_at': '2021-05-09T15:09:58+00:00',
#    'last_fetch_at': '2021-05-09T15:09:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.com/trade/ETH/USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'KKCoin',
#     'identifier': 'kkcoin',
#     'has_trading_incentive': False},
#    'last': 3841.24,
#    'volume': 686800.4,
#    'converted_last': {'btc': 0.06700277, 'eth': 0.99625878, 'usd': 3842.17},
#    'converted_volume': {'btc': 46018, 'eth': 684231, 'usd': 2638802219},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.067359,
#    'timestamp': '2021-05-09T15:09:38+00:00',
#    'last_traded_at': '2021-05-09T15:09:38+00:00',
#    'last_fetch_at': '2021-05-09T15:09:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.kkcoin.com/trade?symbol=ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BUSD',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 3844.5,
#    'volume': 395372.6954517141,
#    'converted_last': {'btc': 0.06702777, 'eth': 0.99663057, 'usd': 3843.38},
#    'converted_volume': {'btc': 26501, 'eth': 394041, 'usd': 1519566542},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01026,
#    'timestamp': '2021-05-09T15:10:40+00:00',
#    'last_traded_at': '2021-05-09T15:10:40+00:00',
#    'last_fetch_at': '2021-05-09T15:10:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/ETH_BUSD?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'binance-usd'},
#   {'base': 'ETH',
#    'target': 'USDC',
#    'market': {'name': 'Serum DEX',
#     'identifier': 'serum_dex',
#     'has_trading_incentive': False},
#    'last': 3827.85,
#    'volume': 722.812,
#    'converted_last': {'btc': 0.06686886, 'eth': 0.99379375, 'usd': 3828.49},
#    'converted_volume': {'btc': 48.333618, 'eth': 718.326, 'usd': 2767279},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.075385,
#    'timestamp': '2021-05-09T15:02:20+00:00',
#    'last_traded_at': '2021-05-09T15:02:20+00:00',
#    'last_fetch_at': '2021-05-09T15:11:28+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://dex.projectserum.com',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 0.067072,
#    'volume': 381418.1160387345,
#    'converted_last': {'btc': 0.067072, 'eth': 0.99444176, 'usd': 3844.58},
#    'converted_volume': {'btc': 25582, 'eth': 379298, 'usd': 1466391282},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.0115,
#    'timestamp': '2021-05-09T14:56:12+00:00',
#    'last_traded_at': '2021-05-09T14:56:12+00:00',
#    'last_fetch_at': '2021-05-09T14:56:12+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/ETH_BTC?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'KRW',
#    'market': {'name': 'Upbit',
#     'identifier': 'upbit',
#     'has_trading_incentive': False},
#    'last': 4749000.0,
#    'volume': 516985.57895221,
#    'converted_last': {'btc': 0.074415, 'eth': 1.106471, 'usd': 4266.96},
#    'converted_volume': {'btc': 38471, 'eth': 572029, 'usd': 2205957496},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.021053,
#    'timestamp': '2021-05-09T15:10:08+00:00',
#    'last_traded_at': '2021-05-09T15:10:08+00:00',
#    'last_fetch_at': '2021-05-09T15:10:08+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': '0X956F47F50A910163D8BF957CF5846D573E7F87CA',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.00025801748632065,
#    'volume': 29438704.5909983,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 509.292, 'eth': 7573, 'usd': 29201130},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602711,
#    'timestamp': '2021-05-09T15:08:30+00:00',
#    'last_traded_at': '2021-05-09T15:08:30+00:00',
#    'last_fetch_at': '2021-05-09T15:08:30+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x956f47f50a910163d8bf957cf5846d573e7f87ca&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x956f47f50a910163d8bf957cf5846d573e7f87ca',
#    'coin_id': 'fei-protocol',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Bitstamp',
#     'identifier': 'bitstamp',
#     'has_trading_incentive': False},
#    'last': 3846.45,
#    'volume': 58751.34944422,
#    'converted_last': {'btc': 0.06705947, 'eth': 0.99493866, 'usd': 3846.45},
#    'converted_volume': {'btc': 3940, 'eth': 58454, 'usd': 225984128},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.068425,
#    'timestamp': '2021-05-09T14:54:33+00:00',
#    'last_traded_at': '2021-05-09T14:54:33+00:00',
#    'last_fetch_at': '2021-05-09T14:54:33+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'IDCM',
#     'identifier': 'idcm',
#     'has_trading_incentive': False},
#    'last': 3840.94,
#    'volume': 489513.087,
#    'converted_last': {'btc': 0.06699754, 'eth': 0.99618097, 'usd': 3841.42},
#    'converted_volume': {'btc': 32796, 'eth': 487644, 'usd': 1880425706},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.030203,
#    'timestamp': '2021-05-09T15:08:28+00:00',
#    'last_traded_at': '2021-05-09T15:08:28+00:00',
#    'last_fetch_at': '2021-05-09T15:08:28+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.idcm.io/trading/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'LBank',
#     'identifier': 'lbank',
#     'has_trading_incentive': False},
#    'last': 0.06691116,
#    'volume': 2219.1433,
#    'converted_last': {'btc': 0.06691116, 'eth': 0.99499657, 'usd': 3833.18},
#    'converted_volume': {'btc': 148.485, 'eth': 2208, 'usd': 8506381},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.189364,
#    'timestamp': '2021-05-09T15:06:49+00:00',
#    'last_traded_at': '2021-05-09T15:06:49+00:00',
#    'last_fetch_at': '2021-05-09T15:06:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.lbank.info/exchange/eth/btc',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Digifinex',
#     'identifier': 'digifinex',
#     'has_trading_incentive': False},
#    'last': 3834.33,
#    'volume': 113785.2568,
#    'converted_last': {'btc': 0.06688224, 'eth': 0.9945665, 'usd': 3830.57},
#    'converted_volume': {'btc': 7610, 'eth': 113167, 'usd': 435862619},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.06411,
#    'timestamp': '2021-05-09T15:05:33+00:00',
#    'last_traded_at': '2021-05-09T15:05:33+00:00',
#    'last_fetch_at': '2021-05-09T15:05:33+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.digifinex.com/en-ww/trade/USDT/ETH',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'DKKT',
#    'market': {'name': 'BitZ',
#     'identifier': 'bit_z',
#     'has_trading_incentive': False},
#    'last': 25603.11,
#    'volume': 686461.6,
#    'converted_last': {'btc': 0.06681141, 'eth': 0.99351321, 'usd': 3827.71},
#    'converted_volume': {'btc': 45863, 'eth': 682009, 'usd': 2627576059},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.570733,
#    'timestamp': '2021-05-09T15:07:21+00:00',
#    'last_traded_at': '2021-05-09T15:07:21+00:00',
#    'last_fetch_at': '2021-05-09T15:07:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bit-z.com/exchange/eth_dkkt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'dkk-token'},
#   {'base': 'ETH2',
#    'target': 'ETH',
#    'market': {'name': 'KuCoin',
#     'identifier': 'kucoin',
#     'has_trading_incentive': False},
#    'last': 0.9939,
#    'volume': 68.46354849,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99800186, 'usd': 3848.67},
#    'converted_volume': {'btc': 4.567242, 'eth': 67.91, 'usd': 261886},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.261596,
#    'timestamp': '2021-05-09T15:10:24+00:00',
#    'last_traded_at': '2021-05-09T15:10:24+00:00',
#    'last_fetch_at': '2021-05-09T15:10:24+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.kucoin.com/trade/ETH2-ETH',
#    'token_info_url': None,
#    'coin_id': 'eth2-staking-by-poolx',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'VCC Exchange',
#     'identifier': 'vcc',
#     'has_trading_incentive': False},
#    'last': 0.066944,
#    'volume': 187865.128,
#    'converted_last': {'btc': 0.066944, 'eth': 0.99548491, 'usd': 3835.31},
#    'converted_volume': {'btc': 12576, 'eth': 187017, 'usd': 720520362},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.011492,
#    'timestamp': '2021-05-09T15:07:34+00:00',
#    'last_traded_at': '2021-05-09T15:07:34+00:00',
#    'last_fetch_at': '2021-05-09T15:07:34+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://vcc.exchange/exchange/basic?currency=btc&coin=eth',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Digifinex',
#     'identifier': 'digifinex',
#     'has_trading_incentive': False},
#    'last': 0.066957,
#    'volume': 41092.3476,
#    'converted_last': {'btc': 0.066957, 'eth': 0.99567823, 'usd': 3834.85},
#    'converted_volume': {'btc': 2751, 'eth': 40915, 'usd': 157583146},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.189532,
#    'timestamp': '2021-05-09T15:05:33+00:00',
#    'last_traded_at': '2021-05-09T15:05:33+00:00',
#    'last_fetch_at': '2021-05-09T15:05:33+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.digifinex.com/en-ww/trade/BTC/ETH',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'BiKi',
#     'identifier': 'biki',
#     'has_trading_incentive': False},
#    'last': 3838.61,
#    'volume': 194789.83445986,
#    'converted_last': {'btc': 0.0669569, 'eth': 0.99557667, 'usd': 3839.31},
#    'converted_volume': {'btc': 13043, 'eth': 193928, 'usd': 747859205},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.013017,
#    'timestamp': '2021-05-09T15:10:21+00:00',
#    'last_traded_at': '2021-05-09T15:10:21+00:00',
#    'last_fetch_at': '2021-05-09T15:10:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.biki.com/trade/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Kraken',
#     'identifier': 'kraken',
#     'has_trading_incentive': False},
#    'last': 3838.35,
#    'volume': 139133.59983747,
#    'converted_last': {'btc': 0.06700137, 'eth': 0.99633801, 'usd': 3838.35},
#    'converted_volume': {'btc': 9322, 'eth': 138624, 'usd': 534043453},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.015623,
#    'timestamp': '2021-05-09T15:06:20+00:00',
#    'last_traded_at': '2021-05-09T15:06:20+00:00',
#    'last_fetch_at': '2021-05-09T15:06:20+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://trade.kraken.com/markets/kraken/eth/usd',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'AlterDice',
#     'identifier': 'alterdice',
#     'has_trading_incentive': False},
#    'last': 3840.96,
#    'volume': 6757.96421003,
#    'converted_last': {'btc': 0.06699789, 'eth': 0.99618616, 'usd': 3841.89},
#    'converted_volume': {'btc': 452.769, 'eth': 6732, 'usd': 25963338},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.162564,
#    'timestamp': '2021-05-09T15:09:17+00:00',
#    'last_traded_at': '2021-05-09T15:09:17+00:00',
#    'last_fetch_at': '2021-05-09T15:09:17+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': '0X2260FAC5E5542A773AA44FBCFEDF7C193BC2C599',
#    'target': 'ETH',
#    'market': {'name': 'Sushiswap',
#     'identifier': 'sushiswap',
#     'has_trading_incentive': False},
#    'last': 14.9838000775728,
#    'volume': 1659.22508313999,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 1667, 'eth': 24786, 'usd': 95578253},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:08:23+00:00',
#    'last_traded_at': '2021-05-09T15:08:23+00:00',
#    'last_fetch_at': '2021-05-09T15:08:23+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.sushi.com/swap?outputCurrency=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#    'token_info_url': 'https://analytics.sushi.com/tokens/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#    'coin_id': 'wrapped-bitcoin',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'KKCoin',
#     'identifier': 'kkcoin',
#     'has_trading_incentive': False},
#    'last': 0.067,
#    'volume': 324363.1,
#    'converted_last': {'btc': 0.067, 'eth': 0.99631765, 'usd': 3838.51},
#    'converted_volume': {'btc': 21732, 'eth': 323169, 'usd': 1245072589},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010447,
#    'timestamp': '2021-05-09T15:07:50+00:00',
#    'last_traded_at': '2021-05-09T15:07:50+00:00',
#    'last_fetch_at': '2021-05-09T15:07:50+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.kkcoin.com/trade?symbol=ETH_BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'XT.COM',
#     'identifier': 'xt',
#     'has_trading_incentive': False},
#    'last': 3837.3,
#    'volume': 254909.3616,
#    'converted_last': {'btc': 0.06693404, 'eth': 0.99533687, 'usd': 3834.74},
#    'converted_volume': {'btc': 17062, 'eth': 253721, 'usd': 977510164},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.013127,
#    'timestamp': '2021-05-09T15:07:00+00:00',
#    'last_traded_at': '2021-05-09T15:07:00+00:00',
#    'last_fetch_at': '2021-05-09T15:07:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.xt.com/trade/eth_usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Kraken',
#     'identifier': 'kraken',
#     'has_trading_incentive': False},
#    'last': 3170.72,
#    'volume': 65593.27124349,
#    'converted_last': {'btc': 0.06732036, 'eth': 1.001082, 'usd': 3856.62},
#    'converted_volume': {'btc': 4416, 'eth': 65664, 'usd': 252968619},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.019228,
#    'timestamp': '2021-05-09T15:06:23+00:00',
#    'last_traded_at': '2021-05-09T15:06:23+00:00',
#    'last_fetch_at': '2021-05-09T15:06:23+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://trade.kraken.com/markets/kraken/eth/eur',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'BW.com',
#     'identifier': 'bw',
#     'has_trading_incentive': False},
#    'last': 0.06706,
#    'volume': 9252.8268,
#    'converted_last': {'btc': 0.06706, 'eth': 0.9960965, 'usd': 3843.38},
#    'converted_volume': {'btc': 620.495, 'eth': 9217, 'usd': 35562130},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.327527,
#    'timestamp': '2021-05-09T15:12:08+00:00',
#    'last_traded_at': '2021-05-09T15:12:08+00:00',
#    'last_fetch_at': '2021-05-09T15:12:08+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bw.com/trade/eth_btc',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Cryptology',
#     'identifier': 'cryptology',
#     'has_trading_incentive': False},
#    'last': 0.06701,
#    'volume': 265.16190261,
#    'converted_last': {'btc': 0.06701, 'eth': 0.99646636, 'usd': 3838.84},
#    'converted_volume': {'btc': 17.768499, 'eth': 264.225, 'usd': 1017915},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.312826,
#    'timestamp': '2021-05-09T15:06:49+00:00',
#    'last_traded_at': '2021-05-09T15:06:49+00:00',
#    'last_fetch_at': '2021-05-09T15:06:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Serum DEX',
#     'identifier': 'serum_dex',
#     'has_trading_incentive': False},
#    'last': 3827.19,
#    'volume': 531.567,
#    'converted_last': {'btc': 0.0667577, 'eth': 0.99214157, 'usd': 3822.13},
#    'converted_volume': {'btc': 35.486188, 'eth': 527.39, 'usd': 2031716},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.128107,
#    'timestamp': '2021-05-09T15:02:20+00:00',
#    'last_traded_at': '2021-05-09T15:02:20+00:00',
#    'last_fetch_at': '2021-05-09T15:11:28+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://dex.projectserum.com',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': '0X6B3595068778DD592E39A122F4F5A5CF09C90FE2',
#    'target': 'ETH',
#    'market': {'name': 'Sushiswap',
#     'identifier': 'sushiswap',
#     'has_trading_incentive': False},
#    'last': 0.00408157969870855,
#    'volume': 2700898.66302299,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 739.155, 'eth': 10990, 'usd': 42380726},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:08:23+00:00',
#    'last_traded_at': '2021-05-09T15:08:23+00:00',
#    'last_fetch_at': '2021-05-09T15:08:23+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.sushi.com/swap?outputCurrency=0x6b3595068778dd592e39a122f4f5a5cf09c90fe2',
#    'token_info_url': 'https://analytics.sushi.com/tokens/0x6b3595068778dd592e39a122f4f5a5cf09c90fe2',
#    'coin_id': 'sushi',
#    'target_coin_id': 'ethereum'},
#   {'base': '0XDAC17F958D2EE523A2206206994597C13D831EC7',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000260326165616401,
#    'volume': 377251162.680332,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99800186, 'usd': 3848.89},
#    'converted_volume': {'btc': 6592, 'eth': 98012, 'usd': 377993124},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:09:58+00:00',
#    'last_traded_at': '2021-05-09T15:09:58+00:00',
#    'last_fetch_at': '2021-05-09T15:09:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0xdac17f958d2ee523a2206206994597c13d831ec7&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0xdac17f958d2ee523a2206206994597c13d831ec7',
#    'coin_id': 'tether',
#    'target_coin_id': 'ethereum'},
#   {'base': '0X2170ED0880AC9A755FD29B2688956BD959F933F8',
#    'target': 'WBNB',
#    'market': {'name': 'PancakeSwap (v2)',
#     'identifier': 'pancakeswap',
#     'has_trading_incentive': False},
#    'last': 5.749959599327476,
#    'volume': 26297.942082480673,
#    'converted_last': {'btc': 0.06694678, 'eth': 0.99441474, 'usd': 3836.89},
#    'converted_volume': {'btc': 1761, 'eth': 26151, 'usd': 100902341},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:12:02+00:00',
#    'last_traded_at': '2021-05-09T15:12:02+00:00',
#    'last_fetch_at': '2021-05-09T15:12:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://exchange.pancakeswap.finance/#/swap?outputCurrency=0x2170ed0880ac9a755fd29b2688956bd959f933f8',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'wbnb'},
#   {'base': '0XA0B86991C6218B36C1D19D4A2E9EB0CE3606EB48',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000260922975161165,
#    'volume': 160909647.937148,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99698772, 'usd': 3848.65},
#    'converted_volume': {'btc': 2818, 'eth': 41859, 'usd': 161585605},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:11:26+00:00',
#    'last_traded_at': '2021-05-09T15:11:26+00:00',
#    'last_fetch_at': '2021-05-09T15:11:26+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#    'coin_id': 'usd-coin',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'HitBTC',
#     'identifier': 'hitbtc',
#     'has_trading_incentive': False},
#    'last': 3843.781,
#    'volume': 140781.8416,
#    'converted_last': {'btc': 0.06703481, 'eth': 0.99673519, 'usd': 3843.78},
#    'converted_volume': {'btc': 9437, 'eth': 140322, 'usd': 541134568},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.016403,
#    'timestamp': '2021-05-09T15:10:03+00:00',
#    'last_traded_at': '2021-05-09T15:10:03+00:00',
#    'last_fetch_at': '2021-05-09T15:10:03+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://hitbtc.com/ETH-to-USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'BitZ',
#     'identifier': 'bit_z',
#     'has_trading_incentive': False},
#    'last': 0.06689607,
#    'volume': 106774.69,
#    'converted_last': {'btc': 0.06689607, 'eth': 0.99477217, 'usd': 3832.56},
#    'converted_volume': {'btc': 7143, 'eth': 106216, 'usd': 409220471},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.336236,
#    'timestamp': '2021-05-09T15:07:22+00:00',
#    'last_traded_at': '2021-05-09T15:07:22+00:00',
#    'last_fetch_at': '2021-05-09T15:07:22+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bit-z.com/exchange/eth_btc',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'CoinBene',
#     'identifier': 'coinbene',
#     'has_trading_incentive': False},
#    'last': 3847.04,
#    'volume': 254077.61665072368,
#    'converted_last': {'btc': 0.06716915, 'eth': 1.004781, 'usd': 3850.34},
#    'converted_volume': {'btc': 17066, 'eth': 255292, 'usd': 978284278},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014046,
#    'timestamp': '2021-05-09T14:48:12+00:00',
#    'last_traded_at': '2021-05-09T14:48:12+00:00',
#    'last_fetch_at': '2021-05-09T14:48:12+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.coinbene.com/spot/exchange/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Bitcoin.com Exchange',
#     'identifier': 'bitcoin_com',
#     'has_trading_incentive': False},
#    'last': 3840.521,
#    'volume': 139892.0043,
#    'converted_last': {'btc': 0.06698185, 'eth': 0.99594765, 'usd': 3840.52},
#    'converted_volume': {'btc': 9370, 'eth': 139325, 'usd': 537258180},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01595,
#    'timestamp': '2021-05-09T15:08:04+00:00',
#    'last_traded_at': '2021-05-09T15:08:04+00:00',
#    'last_fetch_at': '2021-05-09T15:08:04+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://exchange.bitcoin.com/exchange/ETH-to-USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 0.067125,
#    'volume': 38614.34520717,
#    'converted_last': {'btc': 0.067125, 'eth': 0.99706199, 'usd': 3848.94},
#    'converted_volume': {'btc': 2592, 'eth': 38501, 'usd': 148624117},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.059604,
#    'timestamp': '2021-05-09T15:11:55+00:00',
#    'last_traded_at': '2021-05-09T15:11:55+00:00',
#    'last_fetch_at': '2021-05-09T15:11:55+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHBTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Cryptology',
#     'identifier': 'cryptology',
#     'has_trading_incentive': False},
#    'last': 3172.94,
#    'volume': 1031.75009139,
#    'converted_last': {'btc': 0.0673675, 'eth': 1.001783, 'usd': 3859.32},
#    'converted_volume': {'btc': 69.506, 'eth': 1034, 'usd': 3981859},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.054183,
#    'timestamp': '2021-05-09T15:06:52+00:00',
#    'last_traded_at': '2021-05-09T15:06:52+00:00',
#    'last_fetch_at': '2021-05-09T15:06:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Changelly PRO',
#     'identifier': 'changelly',
#     'has_trading_incentive': False},
#    'last': 3832.99,
#    'volume': 137433.2929,
#    'converted_last': {'btc': 0.06685887, 'eth': 0.99163315, 'usd': 3832.07},
#    'converted_volume': {'btc': 9189, 'eth': 136283, 'usd': 526654585},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014403,
#    'timestamp': '2021-05-09T14:59:21+00:00',
#    'last_traded_at': '2021-05-09T14:59:21+00:00',
#    'last_fetch_at': '2021-05-09T14:59:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.changelly.com',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'BiONE',
#     'identifier': 'bione',
#     'has_trading_incentive': False},
#    'last': 3840.11,
#    'volume': 164782.592159,
#    'converted_last': {'btc': 0.06698306, 'eth': 0.99495364, 'usd': 3840.8},
#    'converted_volume': {'btc': 11038, 'eth': 163951, 'usd': 632896401},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.06327,
#    'timestamp': '2021-05-09T15:11:07+00:00',
#    'last_traded_at': '2021-05-09T15:11:07+00:00',
#    'last_fetch_at': '2021-05-09T15:11:07+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bione.me/zh_CN/trade/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BNT',
#    'market': {'name': 'Bancor Network',
#     'identifier': 'bancor',
#     'has_trading_incentive': False},
#    'last': 478.631496052336,
#    'volume': 14315.1027721509,
#    'converted_last': {'btc': 0.06637183, 'eth': 0.98587454, 'usd': 3805.75},
#    'converted_volume': {'btc': 950.12, 'eth': 14113, 'usd': 54479683},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602711,
#    'timestamp': '2021-05-09T15:11:00+00:00',
#    'last_traded_at': '2021-05-09T15:11:00+00:00',
#    'last_fetch_at': '2021-05-09T15:11:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bancor'},
#   {'base': '0XC7283B66EB1EB5FB86327F08E1B5816B0720212B',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000456423893285763,
#    'volume': 3825501.33202039,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99698772, 'usd': 3848.65},
#    'converted_volume': {'btc': 117.195, 'eth': 1741, 'usd': 6719934},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:11:05+00:00',
#    'last_traded_at': '2021-05-09T15:11:05+00:00',
#    'last_fetch_at': '2021-05-09T15:11:05+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0xc7283b66eb1eb5fb86327f08e1b5816b0720212b&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0xc7283b66eb1eb5fb86327f08e1b5816b0720212b',
#    'coin_id': 'tribe-2',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'ZB',
#     'identifier': 'zb',
#     'has_trading_incentive': False},
#    'last': 3842.46,
#    'volume': 39606.506,
#    'converted_last': {'btc': 0.06702405, 'eth': 0.9965752, 'usd': 3843.16},
#    'converted_volume': {'btc': 2655, 'eth': 39471, 'usd': 152214299},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.043981,
#    'timestamp': '2021-05-09T15:10:58+00:00',
#    'last_traded_at': '2021-05-09T15:10:58+00:00',
#    'last_fetch_at': '2021-05-09T15:10:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://trans.zb.com/ethusdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'OKEx',
#     'identifier': 'okex',
#     'has_trading_incentive': False},
#    'last': 3838.39,
#    'volume': 166753.379654,
#    'converted_last': {'btc': 0.06695306, 'eth': 0.9956196, 'usd': 3835.83},
#    'converted_volume': {'btc': 11165, 'eth': 166023, 'usd': 639636866},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.01026,
#    'timestamp': '2021-05-09T15:07:59+00:00',
#    'last_traded_at': '2021-05-09T15:07:59+00:00',
#    'last_fetch_at': '2021-05-09T15:07:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.okex.com/markets/spot-info/eth-usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': '0X95AD61B0A150D79219DCF64E1E6CC01F0B64C4CE',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 3.86089851115971e-09,
#    'volume': 83439110828127.3,
#    'converted_last': {'btc': 0.06704, 'eth': 0.99691247, 'usd': 3840.81},
#    'converted_volume': {'btc': 21597, 'eth': 321155, 'usd': 1237315592},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.60272,
#    'timestamp': '2021-05-09T15:07:21+00:00',
#    'last_traded_at': '2021-05-09T15:07:21+00:00',
#    'last_fetch_at': '2021-05-09T15:07:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce',
#    'coin_id': 'shiba-inu',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'BITFRONT',
#     'identifier': 'bitbox',
#     'has_trading_incentive': False},
#    'last': 3845.67,
#    'volume': 59073.27270916501,
#    'converted_last': {'btc': 0.06707165, 'eth': 0.99728293, 'usd': 3845.67},
#    'converted_volume': {'btc': 3962, 'eth': 58913, 'usd': 227176313},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.039015,
#    'timestamp': '2021-05-09T15:08:37+00:00',
#    'last_traded_at': '2021-05-09T15:08:37+00:00',
#    'last_fetch_at': '2021-05-09T15:08:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfront.me/exchange/?coin=ETH&market=USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'UST',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 3841.3,
#    'volume': 31937.40836192,
#    'converted_last': {'btc': 0.06722275, 'eth': 0.99952964, 'usd': 3854.56},
#    'converted_volume': {'btc': 2147, 'eth': 31922, 'usd': 123104576},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.052056,
#    'timestamp': '2021-05-09T15:10:59+00:00',
#    'last_traded_at': '2021-05-09T15:10:59+00:00',
#    'last_fetch_at': '2021-05-09T15:10:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitfinex.com/t/ETHUST',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': '0XA47C8BF37F92ABED4A126BDA807A7B7498661ACD',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000262214350065484,
#    'volume': 10059665.823189,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.88},
#    'converted_volume': {'btc': 176.864, 'eth': 2630, 'usd': 10141970},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602712,
#    'timestamp': '2021-05-09T15:09:25+00:00',
#    'last_traded_at': '2021-05-09T15:09:25+00:00',
#    'last_fetch_at': '2021-05-09T15:09:25+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0xa47c8bf37f92abed4a126bda807a7b7498661acd&use=V2',
# ...
#    'trade_url': 'https://exchange.bitcoin.com/exchange/ETH-to-BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'CBX',
#     'identifier': 'cbx',
#     'has_trading_incentive': False},
#    'last': 3841.05,
#    'volume': 58825.37782,
#    'converted_last': {'btc': 0.06699946, 'eth': 0.99519719, 'usd': 3839.91},
#    'converted_volume': {'btc': 3941, 'eth': 58543, 'usd': 225884165},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.035144,
#    'timestamp': '2021-05-09T15:12:18+00:00',
#    'last_traded_at': '2021-05-09T15:12:18+00:00',
#    'last_fetch_at': '2021-05-09T15:12:18+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.cbx.one/trade/ETH-USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Changelly PRO',
#     'identifier': 'changelly',
#     'has_trading_incentive': False},
#    'last': 0.067165,
#    'volume': 20260.2558,
#    'converted_last': {'btc': 0.067165, 'eth': 0.99765615, 'usd': 3851.23},
#    'converted_volume': {'btc': 1361, 'eth': 20213, 'usd': 78026883},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014471,
#    'timestamp': '2021-05-09T15:11:21+00:00',
#    'last_traded_at': '2021-05-09T15:11:21+00:00',
#    'last_fetch_at': '2021-05-09T15:11:21+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.changelly.com',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'DAI',
#    'market': {'name': 'dYdX',
#     'identifier': 'dydx',
#     'has_trading_incentive': False},
#    'last': 3783.75,
#    'volume': 6807.795,
#    'converted_last': {'btc': 0.06598824, 'eth': 0.98513347, 'usd': 3786.55},
#    'converted_volume': {'btc': 449.234, 'eth': 6707, 'usd': 25778083},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.198255,
#    'timestamp': '2021-05-09T14:18:47+00:00',
#    'last_traded_at': '2021-05-09T14:18:47+00:00',
#    'last_fetch_at': '2021-05-09T15:07:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://trade.dydx.exchange/markets',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'dai'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.06712,
#    'volume': 57338.43539424,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99698772, 'usd': 3848.65},
#    'converted_volume': {'btc': 3849, 'eth': 57166, 'usd': 220675491},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014899,
#    'timestamp': '2021-05-09T15:11:49+00:00',
#    'last_traded_at': '2021-05-09T15:11:49+00:00',
#    'last_fetch_at': '2021-05-09T15:11:49+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Bitoffer',
#     'identifier': 'bitoffer',
#     'has_trading_incentive': False},
#    'last': 0.067085,
#    'volume': 155520.797,
#    'converted_last': {'btc': 0.067085, 'eth': 0.99646784, 'usd': 3846.64},
#    'converted_volume': {'btc': 10433, 'eth': 154971, 'usd': 598232788},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.02385,
#    'timestamp': '2021-05-09T15:11:42+00:00',
#    'last_traded_at': '2021-05-09T15:11:42+00:00',
#    'last_fetch_at': '2021-05-09T15:11:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bitoffer.com/en/exchange',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': '0X6B175474E89094C44DA98B954EEDEAC495271D0F',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000260891695212808,
#    'volume': 53911105.3186732,
#    'converted_last': {'btc': 0.06712, 'eth': 0.99698772, 'usd': 3848.65},
#    'converted_volume': {'btc': 944.04, 'eth': 14023, 'usd': 54131088},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:11:07+00:00',
#    'last_traded_at': '2021-05-09T15:11:07+00:00',
#    'last_fetch_at': '2021-05-09T15:11:07+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x6b175474e89094c44da98b954eedeac495271d0f&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x6b175474e89094c44da98b954eedeac495271d0f',
#    'coin_id': 'dai',
#    'target_coin_id': 'ethereum'},
#   {'base': '0X6B175474E89094C44DA98B954EEDEAC495271D0F',
#    'target': 'ETH',
#    'market': {'name': 'Sushiswap',
#     'identifier': 'sushiswap',
#     'has_trading_incentive': False},
#    'last': 0.000261117374978665,
#    'volume': 96760800.6383438,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 1694, 'eth': 25189, 'usd': 97133053},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:08:25+00:00',
#    'last_traded_at': '2021-05-09T15:08:25+00:00',
#    'last_fetch_at': '2021-05-09T15:08:25+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.sushi.com/swap?outputCurrency=0x6b175474e89094c44da98b954eedeac495271d0f',
#    'token_info_url': 'https://analytics.sushi.com/tokens/0x6b175474e89094c44da98b954eedeac495271d0f',
#    'coin_id': 'dai',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'LBank',
#     'identifier': 'lbank',
#     'has_trading_incentive': False},
#    'last': 3837.92,
#    'volume': 137460.8452,
#    'converted_last': {'btc': 0.06694486, 'eth': 0.99549769, 'usd': 3835.11},
#    'converted_volume': {'btc': 9202, 'eth': 136842, 'usd': 527177836},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.057045,
#    'timestamp': '2021-05-09T15:06:50+00:00',
#    'last_traded_at': '2021-05-09T15:06:50+00:00',
#    'last_fetch_at': '2021-05-09T15:06:50+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.lbank.info/exchange/eth/usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'BW.com',
#     'identifier': 'bw',
#     'has_trading_incentive': False},
#    'last': 3840.51,
#    'volume': 30864.6478,
#    'converted_last': {'btc': 0.06699004, 'eth': 0.99505727, 'usd': 3839.37},
#    'converted_volume': {'btc': 2068, 'eth': 30712, 'usd': 118500812},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.074177,
#    'timestamp': '2021-05-09T15:12:07+00:00',
#    'last_traded_at': '2021-05-09T15:12:07+00:00',
#    'last_fetch_at': '2021-05-09T15:12:07+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bw.com/trade/eth_usdt',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'AlterDice',
#     'identifier': 'alterdice',
#     'has_trading_incentive': False},
#    'last': 0.067032,
#    'volume': 2529.25835136,
#    'converted_last': {'btc': 0.067032, 'eth': 0.99669339, 'usd': 3843.84},
#    'converted_volume': {'btc': 169.541, 'eth': 2521, 'usd': 9722074},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.257318,
#    'timestamp': '2021-05-09T15:09:17+00:00',
#    'last_traded_at': '2021-05-09T15:09:17+00:00',
#    'last_fetch_at': '2021-05-09T15:09:17+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Dex-Trade',
#     'identifier': 'dextrade',
#     'has_trading_incentive': False},
#    'last': 0.067042,
#    'volume': 2174.6967218,
#    'converted_last': {'btc': 0.067042, 'eth': 0.99694221, 'usd': 3840.92},
#    'converted_volume': {'btc': 145.796, 'eth': 2168, 'usd': 8352839},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.146142,
#    'timestamp': '2021-05-09T15:07:51+00:00',
#    'last_traded_at': '2021-05-09T15:07:51+00:00',
#    'last_fetch_at': '2021-05-09T15:07:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Dcoin',
#     'identifier': 'dcoin',
#     'has_trading_incentive': False},
#    'last': 3841.95,
#    'volume': 113599.0,
#    'converted_last': {'btc': 0.06701515, 'eth': 0.99654301, 'usd': 3839.38},
#    'converted_volume': {'btc': 7613, 'eth': 113206, 'usd': 436150083},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.066349,
#    'timestamp': '2021-05-09T15:07:40+00:00',
#    'last_traded_at': '2021-05-09T15:07:40+00:00',
#    'last_fetch_at': '2021-05-09T15:07:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.dcoin.com/currencyTrading/ETH_USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'CEX.IO',
#     'identifier': 'cex',
#     'has_trading_incentive': False},
#    'last': 3823.68,
#    'volume': 5651.610391,
#    'converted_last': {'btc': 0.0667619, 'eth': 0.99277706, 'usd': 3823.68},
#    'converted_volume': {'btc': 377.312, 'eth': 5611, 'usd': 21609950},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010261,
#    'timestamp': '2021-05-09T15:05:43+00:00',
#    'last_traded_at': '2021-05-09T15:05:43+00:00',
#    'last_fetch_at': '2021-05-09T15:05:43+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 3173.7,
#    'volume': 78053.95546202631,
#    'converted_last': {'btc': 0.06734542, 'eth': 0.99849556, 'usd': 3860.25},
#    'converted_volume': {'btc': 5257, 'eth': 77937, 'usd': 301307717},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010315,
#    'timestamp': '2021-05-09T14:56:40+00:00',
#    'last_traded_at': '2021-05-09T14:56:40+00:00',
#    'last_fetch_at': '2021-05-09T14:56:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/ETH_EUR?ref=37754157',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'AUD',
#    'market': {'name': 'FTX.US',
#     'identifier': 'ftx_us',
#     'has_trading_incentive': False},
#    'last': 4900.0,
#    'volume': 0.03427018367346939,
#    'converted_last': {'btc': 0.06709789, 'eth': 0.99777333, 'usd': 3844.12},
#    'converted_volume': {'btc': 0.00229946, 'eth': 0.03419388, 'usd': 131.74},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.327495,
#    'timestamp': '2021-05-09T15:07:37+00:00',
#    'last_traded_at': '2021-05-09T15:07:37+00:00',
#    'last_fetch_at': '2021-05-09T15:07:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://ftx.us/trade/ETH/AUD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Bitstamp',
#     'identifier': 'bitstamp',
#     'has_trading_incentive': False},
#    'last': 3172.95,
#    'volume': 30719.85400567,
#    'converted_last': {'btc': 0.06728414, 'eth': 0.99827205, 'usd': 3859.34},
#    'converted_volume': {'btc': 2067, 'eth': 30667, 'usd': 118558267},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.085853,
#    'timestamp': '2021-05-09T14:54:33+00:00',
#    'last_traded_at': '2021-05-09T14:54:33+00:00',
#    'last_fetch_at': '2021-05-09T14:54:33+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': None,
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': '0X66A0F676479CEE1D7373F3DC2E2952778BFF5BD6',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 0.000202451613997576,
#    'volume': 354516.68036255,
#    'converted_last': {'btc': 0.06703, 'eth': 0.99618851, 'usd': 3837.7},
#    'converted_volume': {'btc': 4.810909, 'eth': 71.499, 'usd': 275441},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:03:53+00:00',
#    'last_traded_at': '2021-05-09T15:03:53+00:00',
#    'last_fetch_at': '2021-05-09T15:08:43+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x66a0f676479cee1d7373f3dc2e2952778bff5bd6&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x66a0f676479cee1d7373f3dc2e2952778bff5bd6',
#    'coin_id': 'wise-token11',
#    'target_coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Bidesk',
#     'identifier': 'bidesk',
#     'has_trading_incentive': False},
#    'last': 3839.6,
#    'volume': 113788.8975,
#    'converted_last': {'btc': 0.06697416, 'eth': 0.99583343, 'usd': 3840.08},
#    'converted_volume': {'btc': 7621, 'eth': 113315, 'usd': 436958530},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.015626,
#    'timestamp': '2021-05-09T15:08:27+00:00',
#    'last_traded_at': '2021-05-09T15:08:27+00:00',
#    'last_fetch_at': '2021-05-09T15:08:27+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.bidesk.com/exchange/ETH/USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'CoinHe',
#     'identifier': 'coinhe',
#     'has_trading_incentive': False},
#    'last': 0.06714,
#    'volume': 151845.82978070798,
#    'converted_last': {'btc': 0.06714, 'eth': 0.9972848, 'usd': 3849.8},
#    'converted_volume': {'btc': 10195, 'eth': 151434, 'usd': 584575381},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.221799,
#    'timestamp': '2021-05-09T15:11:19+00:00',
#    'last_traded_at': '2021-05-09T15:11:19+00:00',
#    'last_fetch_at': '2021-05-09T15:11:19+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://coinhe.io/trading/BTC-ETH',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3175.09,
#    'volume': 43307.5786517,
#    'converted_last': {'btc': 0.0673518, 'eth': 1.000431, 'usd': 3861.94},
#    'converted_volume': {'btc': 2917, 'eth': 43326, 'usd': 167251265},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.065825,
#    'timestamp': '2021-05-09T15:11:31+00:00',
#    'last_traded_at': '2021-05-09T15:11:31+00:00',
#    'last_fetch_at': '2021-05-09T15:11:31+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-EUR',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': '0X2260FAC5E5542A773AA44FBCFEDF7C193BC2C599',
#    'target': 'ETH',
#    'market': {'name': 'Uniswap (v2)',
#     'identifier': 'uniswap_v2',
#     'has_trading_incentive': False},
#    'last': 14.9955550294347,
#    'volume': 699.33995905,
#    'converted_last': {'btc': 0.06705, 'eth': 0.99696104, 'usd': 3844.43},
#    'converted_volume': {'btc': 703.153, 'eth': 10455, 'usd': 40316489},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602713,
#    'timestamp': '2021-05-09T15:08:54+00:00',
#    'last_traded_at': '2021-05-09T15:08:54+00:00',
#    'last_fetch_at': '2021-05-09T15:08:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://app.uniswap.org/#/swap?outputCurrency=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599&use=V2',
#    'token_info_url': 'https://v2.info.uniswap.org/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#    'coin_id': 'wrapped-bitcoin',
#    'target_coin_id': 'ethereum'}]}

# %%
# Get historical data (name, price, market, stats) at a given date for a coin
cg.get_coin_history_by_id(id='ethereum', date='01-01-2021', localization='false')
# Out:
# {'id': 'ethereum',
#  'symbol': 'eth',
#  'name': 'Ethereum',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/279/thumb/ethereum.png?1595348880',
#   'small': 'https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880'},
#  'market_data': {'current_price': {'aed': 2712.9459227679636,
#    'ars': 62098.96720675696,
#    'aud': 959.3518715018406,
#    'bch': 2.149101840754451,
#    'bdt': 62510.965519007295,
#    'bhd': 278.4438133445556,
#    'bmd': 738.6169381520413,
#    'bnb': 19.756413227674095,
#    'brl': 3836.0809299864463,
#    'btc': 0.02545829679150563,
#    'cad': 940.2593622675483,
#    'chf': 652.1514849042125,
#    'clp': 524787.0103041892,
#    'cny': 4825.16287186585,
#    'czk': 15856.480704860396,
#    'dkk': 4499.580525528412,
#    'dot': 78.49453425770511,
#    'eos': 284.40221565391164,
#    'eth': 1.0,
#    'eur': 604.6554613132835,
#    'gbp': 540.2406781370432,
#    'hkd': 5726.903360808755,
#    'huf': 219310.14127610414,
#    'idr': 10308349.971911158,
#    'ils': 2373.190994621274,
#    'inr': 53961.43309734888,
#    'jpy': 76255.18200328587,
#    'krw': 801879.4789047649,
#    'kwd': 224.6237515291701,
#    'lkr': 136800.40126649867,
#    'ltc': 5.914702829403843,
#    'mmk': 980680.0043260235,
#    'mxn': 14697.738452287482,
#    'myr': 2991.767907984839,
#    'ngn': 286262.7561169478,
#    'nok': 6351.902548449561,
#    'nzd': 1028.7146495467614,
#    'php': 35464.2587172276,
#    'pkr': 118301.88703525142,
#    'pln': 2753.7485996653572,
#    'rub': 54617.915831978426,
#    'sar': 2770.6525869119027,
#    'sek': 6077.144433626378,
#    'sgd': 976.4552853216901,
#    'thb': 22155.572142232108,
#    'try': 5494.423679525399,
#    'twd': 20749.89178181149,
#    'uah': 20924.381908663607,
#    'usd': 738.6169381520413,
#    'vef': 183537181.4806674,
#    'vnd': 17130720.829293184,
#    'xag': 27.993899561245858,
#    'xau': 0.3891034030184966,
#    'xdr': 512.1207926846564,
#    'xlm': 5741.083803292366,
#    'xrp': 3351.830684863358,
#    'yfi': 0.0323222937923585,
#    'zar': 10829.896993960501,
#    'bits': 25458.29679150563,
#    'link': 65.63677121064919,
#    'sats': 2545829.6791505627},
#   'market_cap': {'aed': 308671122537.48706,
#    'ars': 7065440470177.705,
#    'aud': 109114962139.55603,
#    'bch': 245327394.47766054,
#    'bdt': 7112316443804.235,
#    'bhd': 31680529901.9718,
#    'bmd': 84037694047.35515,
#    'bnb': 2256373873.570356,
#    'brl': 436458167804.3421,
#    'btc': 2903485.7760187383,
#    'cad': 106979984522.28287,
#    'chf': 75541483179.16747,
#    'clp': 59708890785610.34,
#    'cny': 548993043903.1553,
#    'czk': 1804104408269.809,
#    'dkk': 511949228367.0808,
#    'dot': 9074073262.204956,
#    'eos': 32490818202.564644,
#    'eth': 114064806.6865,
#    'eur': 68795945553.37424,
#    'gbp': 61390712029.30945,
#    'hkd': 651573655142.0603,
#    'huf': 24952472116540.67,
#    'idr': 1172854176943079.5,
#    'ils': 270014791728.03265,
#    'inr': 6139575429095.247,
#    'jpy': 8676051533448.944,
#    'krw': 91235522542510.86,
#    'kwd': 25557039287.51731,
#    'lkr': 15564753085614.908,
#    'ltc': 675851955.82828,
#    'mmk': 111578928000354.78,
#    'mxn': 1672266073848.3176,
#    'myr': 340394679738.81067,
#    'ngn': 32570146544292.36,
#    'nok': 722701058441.389,
#    'nzd': 116995260748.0707,
#    'php': 4035020549557.349,
#    'pkr': 13460045761700.002,
#    'pln': 313347147909.6703,
#    'rub': 6214268131564.538,
#    'sar': 315236819498.0206,
#    'sek': 691796196455.4766,
#    'sgd': 111098251719.07358,
#    'thb': 2520780636349.5566,
#    'try': 625139598479.4655,
#    'twd': 2360862535102.9395,
#    'uah': 2380715515906.992,
#    'usd': 84037694047.35515,
#    'vef': 20882328453197772,
#    'vnd': 1949083755734899,
#    'xag': 3185064740.6032076,
#    'xau': 44271057.224146724,
#    'xdr': 58267619205.42775,
#    'xlm': 655418291052.8228,
#    'xrp': 382325610070.0532,
#    'yfi': 3685492.646774335,
#    'zar': 1232194285199.9387,
#    'bits': 2903485776018.7383,
#    'link': 7511709755.269196,
#    'sats': 290348577601873.8},
#   'total_volume': {'aed': 66724275063.586296,
#    'ars': 1527309679966.1746,
#    'aud': 23595036531.92796,
#    'bch': 52856660.78292276,
#    'bdt': 1537442682795.9092,
#    'bhd': 6848260938.574209,
#    'bmd': 18166112097.655663,
#    'bnb': 485904396.1806048,
#    'brl': 94347519790.38457,
#    'btc': 626140.8985379637,
#    'cad': 23125460700.315655,
#    'chf': 16039514351.055742,
#    'clp': 12907014670461.13,
#    'cny': 118673760500.3554,
#    'czk': 389986461290.05237,
#    'dkk': 110666138287.70834,
#    'dot': 1930554844.7701855,
#    'eos': 6994806459.917792,
#    'eth': 24588309.234796006,
#    'eur': 14871360678.72809,
#    'gbp': 13287094042.691523,
#    'hkd': 140851858454.77795,
#    'huf': 5393882004035.92,
#    'idr': 253531474109054.94,
#    'ils': 58368081492.00966,
#    'inr': 1327168917963.2673,
#    'jpy': 1875478496018.0208,
#    'krw': 19722039598819.9,
#    'kwd': 5524569014.466459,
#    'lkr': 3364574106070.5767,
#    'ltc': 145470742.78054774,
#    'mmk': 24119597006654.09,
#    'mxn': 361487464631.2503,
#    'myr': 73581837051.55415,
#    'ngn': 7040566020615.521,
#    'nok': 156223568359.0118,
#    'nzd': 25300997952.906723,
#    'php': 872235208861.1364,
#    'pkr': 2909607443641.096,
#    'pln': 67727807428.08495,
#    'rub': 1343314958395.664,
#    'sar': 68143557069.55185,
#    'sek': 149465956319.80472,
#    'sgd': 24015691023.661293,
#    'thb': 544911152634.0823,
#    'try': 135134074672.0408,
#    'twd': 510338770548.23096,
#    'uah': 514630314704.0695,
#    'usd': 18166112097.655663,
#    'vef': 4514054363832166,
#    'vnd': 421326101290308.9,
#    'xag': 688503459.9293537,
#    'xau': 9569907.853045035,
#    'xdr': 12595491989.021664,
#    'xlm': 141200623145.16827,
#    'xrp': 82437497447.50073,
#    'yfi': 794959.3110528933,
#    'zar': 266358802020.66666,
#    'bits': 626140898537.9637,
#    'link': 1614321148.0148692,
#    'sats': 62614089853796.375}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 547539,
#   'reddit_average_posts_48h': 4.273,
#   'reddit_average_comments_48h': 100.0,
#   'reddit_subscribers': 511013,
#   'reddit_accounts_active_48h': '1724.33333333333'},
#  'developer_data': {'forks': 10165,
#   'stars': 27554,
#   'subscribers': 2016,
#   'total_issues': 5240,
#   'closed_issues': 5059,
#   'pull_requests_merged': 3401,
#   'pull_request_contributors': 495,
#   'code_additions_deletions_4_weeks': {'additions': 10928, 'deletions': -4455},
#   'commit_count_4_weeks': 43},
#  'public_interest_stats': {'alexa_rank': 7761, 'bing_matches': None}}

# %%
# Get historical market data including price, market cap, and 24h volume (granularity auto)
cg.get_coin_market_chart_by_id(id='ethereum', vs_currency='usd', days=30)
# Out:
# {'prices': [[1617984181512, 2064.7059124924513],
#   [1617988050462, 2070.3717316574475],
#   [1617991339474, 2076.7230343069714],
#   [1617995164559, 2077.87309168414],
#   [1617998503587, 2076.1907384806295],
#   [1618002076857, 2072.218680731788],
#   [1618006095410, 2073.882870498134],
#   [1618009308808, 2065.4771458606274],
#   [1618013045975, 2069.6677960855295],
#   [1618016777706, 2067.520351492066],
#   [1618020345964, 2100.80506387203],
#   [1618023721523, 2106.3981394566804],
#   [1618027349600, 2144.0407275179323],
#   [1618030994133, 2186.967921003995],
#   [1618034809983, 2172.378585383291],
#   [1618038408205, 2165.90811860934],
#   [1618041682426, 2158.131798675004],
#   [1618045301462, 2161.1126941026746],
#   [1618048912290, 2164.810648451861],
#   [1618052514482, 2157.70824810457],
#   [1618056284397, 2160.657408025468],
#   [1618059904516, 2145.961513626798],
#   [1618063562472, 2158.939847577851],
#   [1618066882239, 2152.9727679924995],
#   [1618070678876, 2154.5643488310984],
#   [1618074162516, 2151.3398845231613],
#   [1618077865139, 2148.143315710693],
#   [1618081483911, 2138.1197476104344],
#   [1618085014234, 2133.7794006545387],
#   [1618088856156, 2096.5793740168037],
#   [1618092068859, 2113.4591133136582],
#   [1618095706623, 2116.2365360510375],
#   [1618099743502, 2140.7594587112762],
#   [1618103038435, 2136.584529746628],
#   [1618106580636, 2151.5774981686895],
#   [1618110289786, 2150.345911229015],
#   [1618114028816, 2142.9645585486774],
#   [1618117521727, 2132.9488152621357],
#   [1618121188122, 2123.8882876546063],
#   [1618124540980, 2130.4675199532317],
#   [1618128451924, 2133.1233357311066],
#   [1618131723985, 2145.0219992726],
#   [1618135398906, 2135.9074584036734],
#   [1618138883216, 2139.445692959495],
#   [1618142485753, 2149.6598960197343],
#   [1618146081759, 2142.844645646203],
#   [1618149845307, 2128.6378939780725],
#   [1618153533502, 2143.2702998850586],
#   [1618156962756, 2152.476023567402],
#   [1618160422745, 2144.79459025667],
#   [1618164116357, 2146.7374299372395],
#   [1618167900554, 2149.604051268654],
#   [1618171288560, 2143.569764740119],
#   [1618175355721, 2144.2853460455717],
#   [1618178647204, 2135.56476280008],
#   [1618182233024, 2143.054719866377],
#   [1618185763515, 2150.2651427927744],
#   [1618189341595, 2137.1965735726767],
#   [1618193036206, 2150.1415626926023],
#   [1618196653131, 2134.026854103353],
#   [1618200153808, 2155.5417085235713],
#   [1618203739672, 2155.5544473867913],
#   [1618207300961, 2146.3625750458305],
#   [1618211160057, 2182.640564425057],
#   [1618214516037, 2184.1031740764297],
#   [1618218398261, 2183.3021325298514],
#   [1618222245913, 2154.197819234156],
#   [1618225544231, 2137.0967869848714],
#   [1618229068193, 2149.7317263510236],
#   [1618232936692, 2154.3735167455857],
#   [1618236266640, 2151.751744914427],
#   [1618239720727, 2135.934794403809],
#   [1618243609301, 2136.2441940786425],
#   [1618247073786, 2128.307676096012],
#   [1618250664927, 2122.965877151885],
#   [1618254159064, 2135.80734079351],
#   [1618257753036, 2140.849821527155],
#   [1618261391339, 2148.923302396853],
#   [1618265301242, 2147.791344737089],
#   [1618268753452, 2151.5245488360515],
#   [1618272550713, 2140.933734342732],
#   [1618275983894, 2160.1665139279366],
#   [1618280588171, 2164.4861495228956],
#   [1618283145791, 2170.928759805125],
#   [1618286757007, 2163.980258794465],
#   [1618290610325, 2162.5985867903864],
#   [1618294417074, 2167.900981268373],
#   [1618297270622, 2159.052405804475],
#   [1618300986925, 2167.5694210205784],
#   [1618304675394, 2214.000615392595],
#   [1618308724842, 2216.6972970001902],
#   [1618311725544, 2210.987435697782],
#   [1618315327296, 2230.888134835818],
#   [1618318938729, 2223.866993958237],
#   [1618322526283, 2229.2395439736183],
#   [1618326048413, 2256.8785794810588],
#   [1618329899566, 2267.156672140868],
#   [1618333623102, 2275.177559551023],
#   [1618337208496, 2309.316988414364],
#   [1618340665733, 2274.8435630057506],
#   [1618344359956, 2302.726943427221],
#   [1618348080020, 2299.4395709249957],
#   [1618351649903, 2285.071856388157],
#   [1618354950548, 2282.5942058263145],
#   [1618358986673, 2309.20653984663],
#   [1618362477400, 2298.130295833426],
#   [1618365825307, 2294.0918549830917],
#   [1618369673032, 2292.226674865835],
#   [1618373250553, 2355.5272015353507],
#   [1618376820732, 2376.8894349419465],
#   [1618380293248, 2369.533996298162],
#   [1618383845983, 2385.0217617176604],
#   [1618387809699, 2386.5311137101344],
#   [1618391026724, 2359.641862619536],
#   [1618394946460, 2347.8416615930387],
#   [1618398229877, 2359.9247929000326],
#   [1618401997051, 2389.3960427053544],
#   [1618405836880, 2381.845112736616],
#   [1618408905665, 2354.7866042387527],
#   [1618412882110, 2332.192621495653],
#   [1618416161209, 2347.3975457662145],
#   [1618419777927, 2384.742287376309],
#   [1618423563648, 2334.8010482602886],
#   [1618426926812, 2338.052182857028],
#   [1618430933272, 2341.2807040653224],
#   [1618434632067, 2386.2183512916217],
#   [1618438001368, 2421.6271974060865],
#   [1618441541775, 2428.3451166527843],
#   [1618444854764, 2429.6615277515734],
#   [1618449719172, 2415.4696870388234],
#   [1618452162605, 2422.403062539694],
#   [1618456124092, 2436.872078356369],
#   [1618459551290, 2472.4331245255535],
#   [1618462831344, 2457.905263429404],
#   [1618466675689, 2477.3928602223536],
#   [1618470219470, 2467.742744060915],
#   [1618473785541, 2472.5329647984363],
#   [1618477489622, 2448.2525374743545],
#   [1618481122920, 2450.56440816973],
#   [1618484563646, 2423.0669742240616],
#   [1618488399976, 2430.7479470982303],
#   [1618492205736, 2438.4635313536537],
#   [1618495233889, 2467.368816681972],
#   [1618499257735, 2466.3242353302458],
#   [1618504508821, 2476.520917897438],
#   [1618507160895, 2453.5640732449056],
#   [1618509948046, 2455.3421644132018],
#   [1618513408369, 2467.7077994080373],
#   [1618516854940, 2492.168608990058],
#   [1618520676787, 2496.457062686549],
#   [1618524104932, 2499.28631942227],
#   [1618528004840, 2529.5187316523798],
#   [1618531560620, 2516.2919310321254],
#   [1618535362194, 2537.742574995679],
#   [1618538670100, 2505.5176024309867],
#   [1618542401132, 2495.0779022473885],
#   [1618545747080, 2504.824035313258],
#   [1618549872926, 2435.7075239955498],
#   [1618553605320, 2406.1180269594397],
#   [1618556634217, 2418.9061350528737],
#   [1618560048166, 2429.6665869042204],
#   [1618565455999, 2401.8082922920985],
#   [1618567366588, 2392.0099538413365],
#   [1618572031149, 2371.633188899906],
#   [1618575043568, 2376.5614920672415],
#   [1618578424856, 2389.3593518867156],
#   [1618581879961, 2356.106209512162],
#   [1618585406726, 2421.809254502852],
#   [1618588831797, 2434.628670666728],
#   [1618592621484, 2431.9330336686658],
#   [1618596309923, 2439.216518175949],
#   [1618600150713, 2449.8995520073618],
#   [1618603312147, 2428.007052779147],
#   [1618606825254, 2460.157160377607],
#   [1618611083236, 2460.533639483193],
#   [1618614547900, 2428.7656641552917],
#   [1618618021285, 2432.6690843101374],
#   [1618621365418, 2466.8587739926843],
#   [1618624952362, 2479.402778244101],
#   [1618628569946, 2486.204747654911],
#   [1618632089962, 2490.8314589058837],
#   [1618635817579, 2477.956247733962],
#   [1618639360838, 2479.8138707056128],
#   [1618643447984, 2471.638883348749],
#   [1618646625513, 2464.6103729085617],
#   [1618650360846, 2466.1637113593683],
#   [1618654296126, 2433.278907236489],
#   [1618659832134, 2418.265333527776],
#   [1618664251256, 2416.176785891737],
#   [1618667846825, 2402.9685461248137],
#   [1618672276666, 2390.8548013057502],
#   [1618677722112, 2362.32546471699],
#   [1618683062883, 2360.7370627003324],
#   [1618688673491, 2378.5865182744683],
#   [1618690089355, 2378.297012531034],
#   [1618692458691, 2387.2372451647193],
#   [1618698801003, 2393.6621829943565],
#   [1618701298699, 2381.874042739294],
#   [1618704352780, 2329.9076987335543],
#   [1618706793337, 2283.1496012307207],
#   [1618708995153, 2283.807741565468],
#   [1618711647369, 2293.9967201136124],
#   [1618713824603, 2291.4235656814813],
#   [1618716448211, 2192.3081154833353],
#   [1618718976062, 2177.3774091610167],
#   [1618721785460, 2172.274840982236],
#   [1618724145081, 2179.1715391555285],
#   [1618726991262, 2202.1004819424147],
#   [1618729374682, 2183.132102570847],
#   [1618733203208, 2223.659610500089],
#   [1618736558923, 2155.741188125982],
#   [1618740398277, 2122.087360855065],
#   [1618743801023, 2138.755305164117],
#   [1618747387745, 2058.8066610771803],
#   [1618751298352, 2103.793560088014],
#   [1618754544399, 2124.727209877945],
#   [1618759255380, 2139.6227971619414],
#   [1618761885677, 2156.3543868954084],
#   [1618766066394, 2167.9263376567596],
#   [1618768837188, 2148.3036253935093],
#   [1618772764964, 2182.4646308300694],
#   [1618776592050, 2193.390638353356],
#   [1618779967912, 2230.2822690945163],
#   [1618785175744, 2222.1624418171973],
#   [1618788757768, 2236.3437674391944],
#   [1618791348335, 2220.4935932307876],
#   [1618794051248, 2265.262862382139],
#   [1618798004332, 2248.825075614047],
#   [1618801323951, 2258.29921138317],
#   [1618806480166, 2264.8175892344343],
#   [1618809494457, 2259.307836828005],
#   [1618812841032, 2246.039516478358],
#   [1618816403637, 2273.556433012705],
#   [1618820794163, 2263.9127356051254],
#   [1618825289794, 2255.442204892825],
#   [1618826753724, 2239.3791947433037],
#   [1618830245838, 2211.457322329902],
#   [1618835218697, 2247.9787131094376],
#   [1618839381350, 2215.801922896621],
#   [1618843937951, 2147.4216757475815],
#   [1618844823529, 2141.645987567698],
#   [1618848342478, 2105.331063890701],
#   [1618851700482, 2115.3798495444184],
#   [1618856647061, 2172.557959447831],
#   [1618859242921, 2169.0859317306117],
#   [1618862613768, 2193.7909137025763],
#   [1618866103902, 2215.752649070204],
#   [1618869773271, 2206.5738274798814],
#   [1618874817084, 2188.225285982221],
#   [1618877082374, 2168.032726735651],
#   [1618880852646, 2089.6679886411384],
#   [1618884551793, 2106.032241561652],
#   [1618889541466, 2096.8850963006394],
#   [1618894398397, 2139.430189742782],
#   [1618895566258, 2149.36296961579],
#   [1618898471566, 2121.4746249474492],
#   [1618902320071, 2069.8496286953127],
#   [1618905930088, 2088.3925585876536],
#   [1618909625574, 2148.884635756773],
#   [1618912998887, 2144.044661004245],
#   [1618916827346, 2195.415778374049],
#   [1618920296609, 2203.2879709852955],
#   [1618924146485, 2188.4136139723923],
#   [1618927378189, 2223.4053637199454],
#   [1618930929866, 2183.986114662908],
#   [1618934787827, 2184.4325188741213],
#   [1618938249886, 2249.7591587227976],
#   [1618941769687, 2274.604266131579],
#   [1618945257607, 2292.2757189029826],
#   [1618948953954, 2308.139794852405],
#   [1618952548901, 2313.198324725278],
#   [1618956256123, 2345.972555754124],
#   [1618959777031, 2317.4190051941687],
#   [1618963552208, 2337.549292396464],
#   [1618966858314, 2300.849007961593],
#   [1618970567563, 2322.42394937498],
#   [1618974136420, 2336.8253080568074],
#   [1618977830092, 2296.265215092091],
#   [1618981482440, 2312.6659569974545],
#   [1618984935369, 2295.487412378628],
#   [1618988802832, 2314.1630225024373],
#   [1618992192993, 2293.6326529076864],
#   [1618995777482, 2302.8995442026626],
#   [1618999560393, 2299.729410448873],
#   [1619003187091, 2265.608506322644],
#   [1619006471999, 2252.048699375423],
#   [1619010713160, 2377.486768527913],
#   [1619013840964, 2381.4299639700553],
#   [1619017247317, 2431.3829136238123],
#   [1619021138689, 2450.525374444657],
#   [1619024623856, 2430.1948366992565],
#   [1619028152426, 2422.2796380785367],
#   [1619031877651, 2413.051584096142],
#   [1619035350889, 2441.8987429574477],
#   [1619038931060, 2408.6594771492323],
#   [1619042556171, 2390.2934398395387],
#   [1619046240626, 2360.791106997758],
#   [1619049811427, 2373.501344298211],
#   [1619053439664, 2399.9301598121115],
#   [1619057034206, 2434.2194646582716],
#   [1619060689734, 2419.9793666594774],
#   [1619065955271, 2420.220305651172],
#   [1619067662816, 2440.776116871729],
#   [1619071345198, 2468.7582069612617],
#   [1619075196488, 2480.57001425084],
#   [1619078552390, 2474.5347100121535],
#   [1619082186522, 2432.1887534247567],
#   [1619085892464, 2493.412561531183],
#   [1619089456402, 2506.638610907091],
#   [1619093085470, 2550.4129721845143],
#   [1619096983057, 2569.331123062303],
#   [1619100233974, 2546.099244426414],
#   [1619103808304, 2603.3496037959776],
#   [1619107320545, 2603.9071740312897],
#   [1619111043341, 2625.372199130437],
#   [1619114723370, 2504.882126943361],
#   [1619118046771, 2556.0141816962278],
#   [1619121779885, 2532.3120094090214],
#   [1619125498017, 2403.8522597397664],
#   [1619129034196, 2406.353239800805],
#   [1619132593108, 2400.320485959924],
#   [1619136167188, 2416.713234165697],
#   [1619139694038, 2389.492917245277],
#   [1619143484375, 2330.8976175878383],
#   [1619147019897, 2256.282847712673],
#   [1619150887156, 2278.55203594466],
#   [1619154287825, 2212.0958070950232],
#   [1619157731897, 2245.6295045332904],
#   [1619161498378, 2209.6624328855105],
#   [1619164808510, 2144.112371182617],
#   [1619168589803, 2210.6968671034174],
#   [1619172203823, 2191.5050240895093],
#   [1619175908151, 2271.3811325398165],
#   [1619179382603, 2298.769015701375],
#   [1619183272340, 2258.877478023931],
#   [1619186613445, 2233.2376562040763],
#   [1619190207156, 2301.949546821811],
#   [1619194122048, 2338.0545970136104],
#   [1619197260745, 2343.1516322373072],
#   [1619201027737, 2312.316347323387],
#   [1619204626986, 2360.7179362268425],
#   [1619208285609, 2363.8616437537785],
#   [1619211875488, 2338.085541341873],
#   [1619215541035, 2318.9297769033747],
#   [1619218813223, 2323.6800863428616],
#   [1619222744588, 2371.556038804917],
#   [1619226344986, 2270.0429946453396],
#   [1619229839261, 2280.9180441692483],
#   [1619233466350, 2281.1056148986495],
#   [1619237128436, 2292.5313682871956],
#   [1619240668995, 2324.7039635131],
#   [1619244183175, 2320.4223097031595],
#   [1619247886614, 2296.0599964918774],
#   [1619251302791, 2280.4639216910623],
#   [1619255096624, 2287.0062563541587],
#   [1619258650140, 2266.1581479554],
#   [1619262144647, 2208.3134295393565],
#   [1619265788726, 2173.315177740998],
#   [1619269700262, 2231.018215136454],
#   [1619273068196, 2227.820406410141],
#   [1619276502150, 2206.027089797697],
#   [1619280179389, 2256.942681721669],
#   [1619283773542, 2243.3315401500276],
#   [1619287453683, 2248.2124563940615],
#   [1619290992731, 2275.6115038409935],
#   [1619294590694, 2273.2551367479014],
#   [1619298362142, 2293.909870068462],
#   [1619301727095, 2293.9643343061684],
#   [1619305263740, 2276.0179466653403],
#   [1619309066117, 2212.8437976342047],
#   [1619312720849, 2217.637163587428],
#   [1619316178665, 2244.7007174830574],
#   [1619319645723, 2247.8437965207295],
#   [1619323257661, 2193.3275804103323],
#   [1619327122931, 2189.510404890882],
#   [1619330572609, 2187.871200142124],
#   [1619334089066, 2166.228015513627],
#   [1619337801066, 2178.4279629674165],
#   [1619341431197, 2232.384411628377],
#   [1619345041895, 2255.0180302036833],
#   [1619348650762, 2257.781073470266],
#   [1619352066717, 2294.1071962077713],
#   [1619356278921, 2319.0867170171596],
#   [1619360395118, 2316.6564117294424],
#   [1619362945742, 2350.1005727147967],
#   [1619366608630, 2343.9683650691086],
#   [1619370193852, 2348.579245675349],
#   [1619373757016, 2326.8383268638777],
#   [1619377540263, 2300.1900867915797],
#   [1619380970967, 2273.051617222478],
#   [1619384718591, 2212.1245345501716],
#   [1619388320331, 2211.847381590683],
#   [1619391712140, 2285.696332581504],
#   [1619395463456, 2307.35532084471],
#   [1619399328522, 2414.220523997117],
#   [1619402621058, 2463.299493245959],
#   [1619406165111, 2450.99465139311],
#   [1619409945181, 2467.9627377156453],
#   [1619413313470, 2461.8174111441954],
#   [1619417023040, 2469.9162546375105],
#   [1619420501186, 2483.891189842007],
#   [1619424204690, 2457.949240831028],
#   [1619427884171, 2444.3152003290734],
#   [1619431257433, 2485.522645163319],
#   [1619435188620, 2482.6260472198346],
#   [1619438744324, 2524.1773502808505],
#   [1619442447758, 2488.1296850469384],
#   [1619449361447, 2492.632606265411],
#   [1619451400657, 2490.2810964583364],
#   [1619453786169, 2488.5362331577526],
#   [1619456603666, 2484.3900208990267],
#   [1619460193488, 2516.7864413362104],
#   [1619463952103, 2505.1684342814933],
#   [1619467418297, 2489.284505277234],
#   [1619471143099, 2463.5463767919614],
#   [1619474573195, 2486.699378417755],
#   [1619478404064, 2509.9455500488316],
#   [1619481875633, 2532.3868028851084],
#   [1619485548848, 2513.894055368828],
#   [1619489819796, 2530.9318178215676],
#   [1619493449531, 2508.5823349396173],
#   [1619496021684, 2502.5166729598905],
#   [1619499787139, 2505.7603340934807],
#   [1619503451254, 2528.6823444516526],
#   [1619507105769, 2564.6425810376522],
#   [1619510539649, 2538.4391439884625],
#   [1619514085284, 2542.7136241133235],
#   [1619517910271, 2545.8363511122993],
#   [1619521212960, 2552.8657047699285],
#   [1619524988321, 2576.4210526375996],
#   [1619528907794, 2558.227254661889],
#   [1619533130473, 2544.3415669223737],
#   [1619536688730, 2627.3709728310423],
#   [1619539459117, 2662.4052920741174],
#   [1619543045360, 2631.4718083797334],
#   [1619546537404, 2644.1423046461096],
#   [1619550063120, 2639.983288416694],
#   [1619553727919, 2622.8160020979576],
#   [1619557262612, 2642.3068196800036],
#   [1619560967905, 2646.1319450404176],
#   [1619564429739, 2623.0585927047628],
#   [1619568350769, 2662.1899759705298],
#   [1619572006133, 2692.545203208627],
#   [1619575473627, 2709.262621594003],
#   [1619579098208, 2666.6180163297163],
#   [1619582575456, 2635.0930260166238],
#   [1619586189120, 2630.0763657190423],
#   [1619589830671, 2619.0354413687983],
#   [1619593444033, 2586.1056852985894],
#   [1619596938381, 2611.4392169157736],
#   [1619600578941, 2606.622629764184],
#   [1619604198752, 2610.5090930485712],
#   [1619607929862, 2642.6877250466296],
#   [1619611405528, 2695.4048947968336],
#   [1619615253333, 2721.1599431679438],
#   [1619618513640, 2695.1508940353533],
#   [1619622032640, 2713.127492141248],
#   [1619625676646, 2679.365923496418],
#   [1619629357580, 2720.608837217996],
#   [1619632892889, 2725.4110626184424],
#   [1619636601508, 2721.172850653217],
#   [1619640240503, 2737.338785772335],
#   [1619643646334, 2713.945095939563],
#   [1619647215021, 2755.606786945332],
#   [1619650834106, 2717.8001360808507],
#   [1619654561409, 2748.7845851218613],
#   [1619658332480, 2722.8052534717604],
#   [1619661807576, 2726.64927570814],
#   [1619665376478, 2715.7431318522854],
#   [1619668800973, 2695.5645598185615],
#   [1619672671026, 2688.4997057768946],
#   [1619676080139, 2722.354197348763],
#   [1619679855866, 2736.5196000107617],
#   [1619683412386, 2729.96275226027],
#   [1619687081264, 2721.408866716535],
#   [1619690575140, 2772.9504985487674],
#   [1619694006599, 2767.7524401155233],
#   [1619697892882, 2764.3761211386213],
#   [1619701436007, 2793.226257461288],
#   [1619704988192, 2755.8880464177014],
#   [1619708651707, 2769.1975786078124],
#   [1619712162225, 2785.9247793740838],
#   [1619715933107, 2728.424546874186],
#   [1619719306364, 2741.1611536641267],
#   [1619722902555, 2725.3601917913315],
#   [1619726658553, 2729.3457198140663],
#   [1619730150419, 2707.86020567565],
#   [1619733657798, 2734.9455514040146],
#   [1619737347901, 2768.463525382388],
#   [1619741026408, 2757.497552304977],
#   [1619744856120, 2734.6607348416774],
#   [1619748084784, 2746.6040310288854],
#   [1619751783501, 2743.637331990562],
#   [1619755463733, 2742.56497609051],
#   [1619758993980, 2762.5439167275467],
#   [1619762696524, 2777.8027493384584],
#   [1619766082221, 2790.721494150906],
#   [1619769651119, 2777.257871280347],
#   [1619773252828, 2792.731896613565],
#   [1619776948994, 2788.4434060568346],
#   [1619780627268, 2766.155665736354],
#   [1619784373009, 2742.25319425421],
#   [1619788398842, 2752.2537355859317],
#   [1619791960392, 2754.555732511723],
#   [1619795184307, 2786.507776653877],
#   [1619798477652, 2751.0925086272],
#   [1619802029531, 2763.85784937136],
#   [1619805832962, 2761.1210008428748],
#   [1619809336546, 2775.0665986217878],
#   [1619812945216, 2780.7179778866566],
#   [1619816403973, 2762.1100097208755],
#   [1619820145057, 2759.4188097789665],
#   [1619823887070, 2744.641221829803],
#   [1619827358295, 2776.70371169874],
#   [1619831127726, 2767.724211278541],
#   [1619834484872, 2793.361577045569],
#   [1619838247363, 2826.282103114337],
#   [1619841889158, 2845.2983967425334],
#   [1619845415804, 2845.964140928755],
#   [1619849133662, 2850.4033633918634],
#   [1619852446100, 2861.0518448241805],
#   [1619856319948, 2856.0520714016634],
#   [1619859942360, 2834.1299842525655],
#   [1619863476703, 2832.1669476143015],
#   [1619867097545, 2842.248335561564],
#   [1619870689639, 2864.8934323470444],
#   [1619874733744, 2874.1088273218334],
#   [1619878446036, 2863.74491669324],
#   [1619881360766, 2858.481380864635],
#   [1619885009678, 2858.6077528109613],
#   [1619888625806, 2900.0459043871033],
#   [1619892135606, 2929.228694434188],
#   [1619895635834, 2943.7983946005384],
#   [1619899290798, 2925.4169017258478],
#   [1619903127120, 2946.894947309837],
#   [1619906433650, 2924.125989560606],
#   [1619910043057, 2940.2858896385364],
#   [1619913921870, 2946.0910412729286],
#   [1619917502975, 2940.0901985235364],
#   [1619920979032, 2942.6027854576014],
#   [1619924534949, 2954.7437528603964],
#   [1619928218481, 2909.0068402957177],
#   [1619931813963, 2931.5244264561798],
#   [1619935321079, 2918.9489112269302],
#   [1619938918633, 2917.3710387489955],
#   [1619942584730, 2899.8126063297564],
#   [1619946030783, 2880.9256946976357],
#   [1619949874411, 2897.2900352700735],
#   [1619953388442, 2928.4058753092927],
#   [1619957108885, 2945.569891261253],
#   [1619960962007, 2930.5504211887974],
#   [1619964981704, 2923.218898360683],
#   [1619967821335, 2919.569643301663],
#   [1619971451504, 2928.155126147829],
#   [1619974935462, 2930.1679927592545],
#   [1619978645234, 2937.436434521464],
#   [1619982033753, 2969.151466880701],
#   [1619985620694, 2973.7986391421573],
#   [1619989217194, 2971.4370432069995],
#   [1619993055088, 2974.6464455324294],
#   [1619996675212, 2950.261922905021],
#   [1620000408627, 2953.777448939646],
#   [1620004036904, 2998.257702706348],
#   [1620007458313, 3020.633946974935],
#   [1620011064191, 3035.4828050062138],
#   [1620014556826, 3054.4931680535915],
#   [1620018161074, 3051.9292059433524],
#   [1620021735624, 3105.3231488479337],
#   [1620025335128, 3083.4166912173123],
#   [1620028894576, 3148.061293511937],
#   [1620032685046, 3193.5677919556783],
#   [1620036281456, 3178.5722777487],
#   [1620040266825, 3161.890673540407],
#   [1620043375412, 3160.512386102504],
#   [1620047237679, 3148.7065133573483],
#   [1620050595373, 3110.4071935301786],
#   [1620054209386, 3160.1306400464664],
#   [1620057602761, 3167.1347081360973],
#   [1620061505153, 3256.248991591289],
#   [1620064988723, 3291.9760146462145],
#   [1620068670206, 3331.611548022662],
#   [1620072281302, 3294.566494445466],
#   [1620075830121, 3296.8541883340745],
#   [1620079580947, 3346.33831321738],
#   [1620082988002, 3384.8879815236564],
#   [1620086749734, 3438.1430926954904],
#   [1620090287001, 3276.3278895718922],
#   [1620093779299, 3318.363579599763],
#   [1620097662512, 3248.05965053223],
#   [1620101149647, 3244.404164006859],
#   [1620104671242, 3352.713314865695],
#   [1620108267359, 3388.392971577294],
#   [1620111895164, 3373.5782809527573],
#   [1620115450214, 3341.1091357907962],
#   [1620118993641, 3308.925197158718],
#   [1620122551140, 3360.4755235277844],
#   [1620126274843, 3440.432403375466],
#   [1620129625859, 3488.675304139683],
#   [1620133277966, 3485.6208547145793],
#   [1620137206909, 3491.3263047559717],
#   [1620142055713, 3281.8642634257913],
#   [1620144134404, 3295.9596117960864],
#   [1620147862951, 3255.199530227276],
#   [1620151498173, 3336.1657227209157],
#   [1620154917683, 3415.1189488622636],
#   [1620158547888, 3393.719191652139],
#   [1620162110354, 3422.133844340418],
#   [1620165719217, 3355.4434859790827],
#   [1620169320366, 3316.063567389495],
#   [1620173019449, 3245.663148933579],
#   [1620176655903, 3333.298757291368],
#   [1620181262129, 3390.9865718365786],
#   [1620183803463, 3327.6822517034275],
#   [1620187277523, 3290.9178848859738],
#   [1620191076327, 3277.5732351213687],
#   [1620194515152, 3282.7787530547866],
#   [1620198322148, 3272.518565112157],
#   [1620201849372, 3351.3356383444107],
#   [1620205336625, 3363.862815906287],
#   [1620209136340, 3399.382281676815],
#   [1620212668967, 3385.0240220741334],
#   [1620216387726, 3354.414808417009],
#   [1620219726623, 3383.4693627050447],
#   [1620223574717, 3383.9674967098617],
#   [1620226919066, 3392.7226357930413],
#   [1620230702841, 3329.05650581122],
#   [1620234280611, 3433.2925233012256],
#   [1620237901130, 3412.60274688405],
#   [1620241475465, 3419.6221240365926],
#   [1620245611995, 3473.7409044426577],
#   [1620248479493, 3469.620555958864],
#   [1620252077828, 3428.2181541141777],
#   [1620255830609, 3521.088386686321],
#   [1620259470107, 3527.87795953073],
#   [1620263129706, 3480.4997668489546],
#   [1620266583857, 3484.6467897250045],
#   [1620270258886, 3492.264680838447],
#   [1620273931503, 3467.676500222258],
#   [1620277298202, 3446.282991433171],
#   [1620281129991, 3451.9042243576014],
#   [1620284700059, 3408.76136423494],
#   [1620288175199, 3445.7522777818926],
#   [1620291868679, 3440.868543481238],
#   [1620295313681, 3464.995359788644],
#   [1620298981205, 3492.59630945043],
#   [1620302675383, 3520.9661085415037],
#   [1620306159856, 3487.5691386955646],
#   [1620309698419, 3488.402078691339],
#   [1620313458331, 3516.6383000331757],
#   [1620316921570, 3540.313801559023],
#   [1620320609143, 3562.7402215238008],
#   [1620324266792, 3574.8156981870047],
#   [1620327697732, 3458.5966934410703],
#   [1620331450161, 3496.98402619183],
#   [1620334940296, 3468.693223164822],
#   [1620338738177, 3517.7207865146297],
#   [1620342072196, 3534.8612920843816],
#   [1620345818683, 3495.0758690360576],
#   [1620349256353, 3512.8785782396976],
#   [1620353047744, 3466.411634392586],
#   [1620356662268, 3440.331883738236],
#   [1620360488169, 3442.692976925818],
#   [1620363739303, 3416.355644492579],
#   [1620367575096, 3418.120430057583],
#   [1620371044310, 3453.169594083792],
#   [1620374537386, 3447.459294124285],
#   [1620378149792, 3442.263665117788],
#   [1620381788079, 3464.664136025594],
#   [1620385334483, 3467.292972859075],
#   [1620389005314, 3451.7544590850157],
#   [1620392578227, 3506.861353833723],
#   [1620396149176, 3508.563396808798],
#   [1620399914118, 3509.6050714739067],
#   [1620403546581, 3571.371038957259],
#   [1620407088804, 3562.144324464752],
#   [1620410476705, 3541.427374928315],
#   [1620414076715, 3528.2466096204616],
#   [1620417871541, 3518.1965493123944],
#   [1620421279331, 3499.8235960706047],
#   [1620424833417, 3480.596043363512],
#   [1620428697268, 3451.976252905467],
#   [1620432148694, 3493.534500000208],
#   [1620435750956, 3529.390217512424],
#   [1620439367615, 3538.8563540624696],
#   [1620443045879, 3538.54429695307],
#   [1620446589929, 3530.5520872754505],
#   [1620450131419, 3566.670367539735],
#   [1620454186247, 3538.0283647673673],
#   [1620457319890, 3524.493553943708],
#   [1620460986518, 3542.317389540226],
#   [1620464732506, 3552.696857825752],
#   [1620468134914, 3566.9189300745993],
#   [1620471865237, 3541.6035419417735],
#   [1620475208637, 3546.820265954613],
#   [1620481119979, 3582.042377325529],
#   [1620482472850, 3629.9594066416944],
#   [1620486069417, 3665.5108975811786],
#   [1620489733234, 3634.4183806356286],
#   [1620493262676, 3817.1250505839075],
#   [1620496915325, 3831.609275265956],
#   [1620500494793, 3833.127505351828],
#   [1620504125827, 3808.4438587302466],
#   [1620507736880, 3852.211486271376],
#   [1620511295701, 3895.8263244829504],
#   [1620515021981, 3899.949945967818],
#   [1620518618838, 3912.7429165968124],
#   [1620522418823, 3844.961117933399],
#   [1620525650618, 3899.423449067518],
#   [1620529267935, 3877.0539019211114],
#   [1620532936213, 3931.61467569066],
#   [1620536487307, 3906.968627186809],
#   [1620540158329, 3946.927409958456],
#   [1620543732433, 3972.4996563615805],
#   [1620547275139, 3967.4369399692036],
#   [1620550845232, 3945.6327200185033],
#   [1620554578740, 3933.0136062995634],
#   [1620558094171, 3932.4033514902126],
#   [1620561853737, 3898.193085648839],
#   [1620565894622, 3805.458615422006],
#   [1620569004650, 3830.0409728910395],
#   [1620572578879, 3861.8445049305633],
#   [1620573013000, 3860.294033230665]],
#  'market_caps': [[1617984181512, 238022255262.4932],
#   [1617988050462, 238747202412.37482],
#   [1617991339474, 239747622254.7869],
#   [1617995164559, 239586108283.3203],
#   [1617998503587, 239810703869.74118],
#   [1618002076857, 239426853358.72153],
#   [1618006095410, 239474652364.30124],
#   [1618009308808, 238935234718.91608],
#   [1618013045975, 238825167325.68292],
#   [1618016777706, 238591542578.0233],
#   [1618020345964, 241743655095.34232],
#   [1618023721523, 241394997987.97858],
#   [1618027349600, 247436055716.72543],
#   [1618030994133, 250833087460.5033],
#   [1618034809983, 250704721320.05438],
#   [1618038408205, 250292134253.56436],
#   [1618041682426, 248505583149.6775],
#   [1618045301462, 249800109556.74084],
#   [1618048912290, 249483415120.09494],
#   [1618052514482, 249618741859.94022],
#   [1618056284397, 249599965257.74957],
#   [1618059904516, 247312281594.98438],
#   [1618063562472, 248820865541.4333],
#   [1618066882239, 248312870858.49463],
#   [1618070678876, 248682795186.54602],
#   [1618074162516, 248702395976.4496],
#   [1618077865139, 247926455603.43198],
#   [1618081483911, 246770982559.64038],
#   [1618085014234, 246270160743.9121],
#   [1618088856156, 241844261556.24875],
#   [1618092068859, 243499226550.33167],
#   [1618095706623, 244748800177.60886],
#   [1618099743502, 247248413642.8763],
#   [1618103038435, 246790157999.76215],
#   [1618106580636, 247108094050.32117],
#   [1618110289786, 247921497495.71167],
#   [1618114028816, 247556608848.3043],
#   [1618117521727, 246244964852.26974],
#   [1618121188122, 245398441793.24515],
#   [1618124540980, 246533914064.7611],
#   [1618128451924, 246015130830.01376],
#   [1618131723985, 248715772876.70065],
#   [1618135398906, 246045227561.84802],
#   [1618138883216, 247521189166.5455],
#   [1618142485753, 248067766121.39844],
#   [1618146081759, 247810805653.32065],
#   [1618149845307, 246059016924.52228],
#   [1618153533502, 247105912544.3164],
#   [1618156962756, 247798051074.2338],
#   [1618160422745, 248056204107.062],
#   [1618164116357, 247721561423.6172],
#   [1618167900554, 248016636394.14594],
#   [1618171288560, 248049777232.2734],
#   [1618175355721, 247227145961.76526],
#   [1618178647204, 247032593185.09378],
#   [1618182233024, 247004200791.13882],
#   [1618185763515, 247431817683.18906],
#   [1618189341595, 247192611649.00195],
#   [1618193036206, 248076477888.9903],
#   [1618196653131, 246577792611.54434],
#   [1618200153808, 249083944451.03864],
#   [1618203739672, 248644499783.16815],
#   [1618207300961, 248021441348.42645],
#   [1618211160057, 251494390090.4389],
#   [1618214516037, 252724237401.7609],
#   [1618218398261, 252015936673.34943],
#   [1618222245913, 248501025563.92224],
#   [1618225544231, 246638312539.88712],
#   [1618229068193, 248131765051.50867],
#   [1618232936692, 248698037421.58417],
#   [1618236266640, 248879959009.2621],
#   [1618239720727, 247306073513.75388],
#   [1618243609301, 246797883908.7149],
#   [1618247073786, 245693466148.7483],
#   [1618250664927, 245187363720.2891],
#   [1618254159064, 246554542033.83844],
#   [1618257753036, 246779935690.6397],
#   [1618261391339, 248101768530.5098],
#   [1618265301242, 248313055643.07666],
#   [1618268753452, 248083161246.38422],
#   [1618272550713, 247210701730.68222],
#   [1618275983894, 249318201428.53247],
#   [1618280588171, 250075228465.22897],
#   [1618283145791, 250270936492.82394],
#   [1618286757007, 249754846506.76944],
#   [1618290610325, 249741692738.99927],
#   [1618294417074, 250280533392.78925],
#   [1618297270622, 250250272250.22763],
#   [1618300986925, 249680422507.66275],
#   [1618304675394, 255360969278.44608],
#   [1618308724842, 256207392326.71005],
#   [1618311725544, 255403059001.38528],
#   [1618315327296, 256682361683.6719],
#   [1618318938729, 256648801123.19785],
#   [1618322526283, 256791670841.09872],
#   [1618326048413, 259573747948.39542],
#   [1618329899566, 262101735571.9812],
#   [1618333623102, 262688944923.11685],
#   [1618337208496, 265752400101.34872],
#   [1618340665733, 264362037614.11377],
#   [1618344359956, 266253416916.8584],
#   [1618348080020, 265318398632.902],
#   [1618351649903, 264778149325.38324],
#   [1618354950548, 263543449241.2679],
#   [1618358986673, 266055934979.15903],
#   [1618362477400, 265424312970.3283],
#   [1618365825307, 264611422362.27295],
#   [1618369673032, 264684717054.8098],
#   [1618373250553, 270918198143.0644],
#   [1618376820732, 274316919486.90533],
#   [1618380293248, 275374658026.7377],
#   [1618383845983, 275345742643.32477],
#   [1618387809699, 275627092884.43805],
#   [1618391026724, 274102051174.31067],
#   [1618394946460, 270493784724.64334],
#   [1618398229877, 272702421963.91522],
#   [1618401997051, 276127027887.0038],
#   [1618405836880, 273629038575.15973],
#   [1618408905665, 274007018792.63052],
#   [1618412882110, 270050932651.92087],
#   [1618416161209, 270863970693.34665],
#   [1618419777927, 275247593960.06305],
#   [1618423563648, 270190086605.08163],
#   [1618426926812, 271335027144.5508],
#   [1618430933272, 270490666787.4389],
#   [1618434632067, 274983746537.17523],
#   [1618438001368, 280057549385.0037],
#   [1618441541775, 280224742624.85315],
#   [1618444854764, 281118122172.12756],
#   [1618449719172, 278920199641.3536],
#   [1618452162605, 279815685411.03076],
#   [1618456124092, 280646381933.77814],
#   [1618459551290, 285357155255.18634],
#   [1618462831344, 284685201365.23694],
#   [1618466675689, 284298008945.99615],
#   [1618470219470, 285113770276.6843],
#   [1618473785541, 285462427742.4833],
#   [1618477489622, 283367820952.33386],
#   [1618481122920, 282810673526.54144],
#   [1618484563646, 281345078323.47766],
#   [1618488399976, 280606504603.5719],
#   [1618492205736, 281538638738.7552],
#   [1618495233889, 285184915447.0741],
#   [1618499257735, 285027495176.7436],
#   [1618504508821, 285857623563.42035],
#   [1618507160895, 283936884020.99176],
#   [1618509948046, 283483544913.4754],
#   [1618513408369, 284959513085.38464],
#   [1618516854940, 286145099305.4083],
#   [1618520676787, 288299800473.11633],
#   [1618524104932, 288484359948.4348],
#   [1618528004840, 292598414957.5773],
#   [1618531560620, 290594884707.67596],
#   [1618535362194, 293831224388.3834],
#   [1618538670100, 287414171981.11975],
#   [1618542401132, 287759687481.761],
#   [1618545747080, 288936133014.08575],
#   [1618549872926, 281903832700.92615],
#   [1618553605320, 277879286580.03284],
#   [1618556634217, 278664562422.08813],
#   [1618560048166, 280738991819.8263],
#   [1618565455999, 277795770813.89087],
#   [1618567366588, 274516588417.59177],
#   [1618572031149, 273903463019.97714],
#   [1618575043568, 274867993126.64587],
#   [1618578424856, 275876223093.21277],
#   [1618581879961, 273573952748.00833],
#   [1618585406726, 279343346846.2082],
#   [1618588831797, 279522511319.9814],
#   [1618592621484, 280041374108.16003],
#   [1618596309923, 281267256381.40375],
#   [1618600150713, 282149762386.3021],
#   [1618603312147, 279507965326.505],
#   [1618606825254, 283077165587.6059],
#   [1618611083236, 284185924459.271],
#   [1618614547900, 281138501377.09033],
#   [1618618021285, 280001387823.9684],
#   [1618621365418, 284173359692.1783],
#   [1618624952362, 286370833844.76715],
#   [1618628569946, 287427324809.92],
#   [1618632089962, 287098541297.5592],
#   [1618635817579, 287368616596.65344],
#   [1618639360838, 287628651137.3607],
#   [1618643447984, 285528468101.6643],
#   [1618646625513, 285660454702.7271],
#   [1618650360846, 284831027620.3896],
#   [1618654296126, 281720442729.2418],
#   [1618659832134, 279692730684.5652],
#   [1618664251256, 278800263793.8793],
#   [1618667846825, 277217644580.35034],
#   [1618672276666, 276956787794.3164],
#   [1618677722112, 272226776459.90704],
#   [1618683062883, 272685651741.53726],
#   [1618688673491, 274728668712.56708],
#   [1618690089355, 274463956977.33826],
#   [1618692458691, 274688705061.68378],
#   [1618698801003, 275796386884.7282],
#   [1618701298699, 275134247064.2812],
#   [1618704352780, 269522758837.43893],
#   [1618706793337, 263440340171.605],
#   [1618708995153, 264661370678.93927],
#   [1618711647369, 265229754222.0307],
#   [1618713824603, 262066561318.64392],
#   [1618716448211, 258007009266.36865],
#   [1618718976062, 245845529861.9704],
#   [1618721785460, 250716506580.71924],
#   [1618724145081, 251727795877.18176],
#   [1618726991262, 254391821424.64465],
#   [1618729374682, 253529932417.19528],
#   [1618733203208, 256487979397.87668],
#   [1618736558923, 250932093999.8263],
#   [1618740398277, 243191527323.5976],
#   [1618743801023, 248265852199.74353],
#   [1618747387745, 237950379815.34784],
#   [1618751298352, 244713094621.98376],
#   [1618754544399, 244849738111.04993],
#   [1618759255380, 246596417242.24313],
#   [1618761885677, 246880475482.527],
#   [1618766066394, 250253222293.84387],
#   [1618768837188, 249101400823.41757],
#   [1618772764964, 249924172497.33594],
#   [1618776592050, 253350158728.1264],
#   [1618779967912, 257283204920.189],
#   [1618785175744, 257265118585.49493],
#   [1618788757768, 258923772806.94327],
#   [1618791348335, 259329079995.44214],
#   [1618794051248, 261903851131.84164],
#   [1618798004332, 260065101285.44104],
#   [1618801323951, 260033543758.81976],
#   [1618806480166, 261771386410.3375],
#   [1618809494457, 261570089169.51862],
#   [1618812841032, 259642825331.92685],
#   [1618816403637, 262662981017.42575],
#   [1618820794163, 261427630745.73413],
#   [1618825289794, 259667555493.16562],
#   [1618826753724, 258718152325.17426],
#   [1618830245838, 255378823615.68008],
#   [1618835218697, 259664347198.7242],
#   [1618839381350, 257578824707.8564],
#   [1618843937951, 253256999888.50797],
#   [1618844823529, 245947232000.972],
#   [1618848342478, 246377814844.96588],
#   [1618851700482, 244598705084.0908],
#   [1618856647061, 247787025048.99637],
#   [1618859242921, 250834978367.68665],
#   [1618862613768, 253142495670.49536],
#   [1618866103902, 256189278696.8367],
#   [1618869773271, 254160019735.92184],
#   [1618874817084, 254061731463.10208],
#   [1618877082374, 251090482814.8267],
#   [1618880852646, 241643839050.7009],
#   [1618884551793, 244161656171.35428],
#   [1618889541466, 242338692676.17197],
#   [1618894398397, 245210699834.8986],
#   [1618895566258, 248492155791.62793],
#   [1618898471566, 245637986393.7708],
#   [1618902320071, 238697353878.7257],
#   [1618905930088, 241528488021.70566],
#   [1618909625574, 248019435988.26068],
#   [1618912998887, 248760947174.62402],
#   [1618916827346, 253418134452.19867],
#   [1618920296609, 252732371542.2384],
#   [1618924146485, 252657163112.35904],
#   [1618927378189, 256067421352.93933],
#   [1618930929866, 252058684312.23474],
#   [1618934787827, 251201579688.0316],
#   [1618938249886, 256902759742.26288],
#   [1618941769687, 260444467500.2978],
#   [1618945257607, 264062014352.38397],
#   [1618948953954, 267600724376.76163],
#   [1618952548901, 267292279283.04007],
#   [1618956256123, 271080781494.31238],
#   [1618959777031, 269077070988.24554],
#   [1618963552208, 268577322075.03503],
#   [1618966858314, 269567905113.47623],
#   [1618970567563, 267611883129.1184],
#   [1618974136420, 269137085117.13055],
#   [1618977830092, 267313609785.60712],
#   [1618981482440, 266604522229.74808],
#   [1618984935369, 265791660644.63846],
#   [1618988802832, 268199832439.24243],
#   [1618992192993, 265075732050.98553],
#   [1618995777482, 265252625033.4721],
#   [1618999560393, 266631607630.13297],
#   [1619003187091, 261933484152.5382],
#   [1619006471999, 260344045741.29907],
#   [1619010713160, 274191536197.86755],
#   [1619013840964, 275199474003.58276],
#   [1619017247317, 279540047050.896],
#   [1619021138689, 281883002665.85376],
#   [1619024623856, 280838611024.8594],
#   [1619028152426, 278974883775.24805],
#   [1619031877651, 278638078753.57996],
#   [1619035350889, 281401055027.50037],
#   [1619038931060, 277961768056.4423],
#   [1619042556171, 276859426090.02673],
#   [1619046240626, 272608096368.57205],
#   [1619049811427, 274296843910.20834],
#   [1619053439664, 275214250803.8866],
#   [1619057034206, 281639884329.5952],
#   [1619060689734, 279353829971.4621],
#   [1619065955271, 279169983543.784],
#   [1619067662816, 279776310046.0817],
#   [1619071345198, 282220142644.00885],
#   [1619075196488, 286796065310.8896],
#   [1619078552390, 285819022437.7823],
#   [1619082186522, 281111871831.36786],
#   [1619085892464, 286648864651.43866],
#   [1619089456402, 290180912205.285],
#   [1619093085470, 296037544308.0116],
#   [1619096983057, 296946657511.86414],
#   [1619100233974, 294262848611.7998],
#   [1619103808304, 298271640140.5692],
#   [1619107320545, 299284446622.77844],
#   [1619111043341, 304181157118.42896],
#   [1619114723370, 293691149625.8729],
#   [1619118046771, 296929739743.1254],
#   [1619121779885, 292677904137.74036],
#   [1619125498017, 283001059176.4156],
#   [1619129034196, 277976974386.86884],
#   [1619132593108, 278997112369.51337],
#   [1619136167188, 280712855517.3182],
#   [1619139694038, 279010352569.43427],
#   [1619143484375, 268755685873.85312],
#   [1619147019897, 257943757242.15155],
#   [1619150887156, 264408491333.5891],
#   [1619154287825, 258880136237.23297],
#   [1619157731897, 258634699756.20255],
#   [1619161498378, 254634223024.4365],
#   [1619164808510, 249743157516.41028],
#   [1619168589803, 252307491064.56454],
#   [1619172203823, 252510714758.63544],
#   [1619175908151, 263160593336.2606],
#   [1619179382603, 267195153040.9026],
#   [1619183272340, 261075398474.23923],
#   [1619186613445, 255904804491.10577],
#   [1619190207156, 265327783834.45874],
#   [1619194122048, 269555014772.25378],
#   [1619197260745, 270997027940.7168],
#   [1619201027737, 267740205940.347],
#   [1619204626986, 272446411035.2335],
#   [1619208285609, 273240802536.26926],
#   [1619211875488, 270262655129.2125],
#   [1619215541035, 268100347210.99167],
#   [1619218813223, 269593414390.64044],
#   [1619222744588, 274109538049.2621],
#   [1619226344986, 262644656667.78915],
#   [1619229839261, 263669228348.64224],
#   [1619233466350, 264730855822.93903],
#   [1619237128436, 266304022493.95367],
#   [1619240668995, 268041752092.2363],
#   [1619244183175, 268256864600.65817],
#   [1619247886614, 265417585131.54803],
#   [1619251302791, 263009586769.78958],
#   [1619255096624, 264373623803.42972],
#   [1619258650140, 263223182516.1414],
#   [1619262144647, 256487352730.24118],
#   [1619265788726, 254489446479.7294],
#   [1619269700262, 257906781297.20004],
#   [1619273068196, 257106571563.049],
#   [1619276502150, 255869862109.27524],
#   [1619280179389, 261345412291.35355],
#   [1619283773542, 259978071023.24744],
#   [1619287453683, 259469791144.88217],
#   [1619290992731, 263000263023.13507],
#   [1619294590694, 263679999291.90814],
#   [1619298362142, 265338213009.03995],
#   [1619301727095, 264761057308.97513],
#   [1619305263740, 263079241197.14127],
#   [1619309066117, 258340689899.58817],
#   [1619312720849, 256141090425.60007],
#   [1619316178665, 259504703548.6953],
#   [1619319645723, 259126068674.36893],
#   [1619323257661, 255398231124.33084],
#   [1619327122931, 252739815753.9572],
#   [1619330572609, 252956131687.66406],
#   [1619334089066, 251781961728.6129],
#   [1619337801066, 252038048941.6694],
#   [1619341431197, 254670152598.36386],
#   [1619345041895, 255449177817.24112],
#   [1619348650762, 262285912627.28314],
#   [1619352066717, 263778145555.96823],
#   [1619356278921, 269203278502.6082],
#   [1619360395118, 267423024870.6234],
#   [1619362945742, 271828272883.3114],
#   [1619366608630, 270819912968.2328],
#   [1619370193852, 270756204605.8958],
#   [1619373757016, 268767261305.14282],
#   [1619377540263, 266227868802.9331],
#   [1619380970967, 265010864037.28845],
#   [1619384718591, 256432616180.00262],
#   [1619388320331, 256117815073.71573],
#   [1619391712140, 264452506643.86804],
#   [1619395463456, 266776799157.93356],
#   [1619399328522, 279134154983.1855],
#   [1619402621058, 284809769148.2568],
#   [1619406165111, 281929003348.7167],
#   [1619409945181, 284502131436.647],
#   [1619413313470, 284678382844.49786],
#   [1619417023040, 285189428186.21295],
#   [1619420501186, 287609942700.81244],
#   [1619424204690, 284199379661.5577],
#   [1619427884171, 282494489365.5871],
#   [1619431257433, 283436562569.91266],
#   [1619435188620, 287092604173.96606],
#   [1619438744324, 291907049241.3804],
#   [1619442447758, 288601773545.2857],
#   [1619449361447, 288232838542.7546],
#   [1619451400657, 287902761874.25507],
#   [1619453786169, 289450678368.86084],
#   [1619456603666, 286548345918.48474],
#   [1619460193488, 291874333890.4818],
#   [1619463952103, 289182506630.4476],
#   [1619467418297, 287393535012.58887],
#   [1619471143099, 285177869849.61523],
#   [1619474573195, 286660658531.98615],
#   [1619478404064, 290327539029.5186],
#   [1619481875633, 292829223558.3116],
#   [1619485548848, 291064073564.02686],
#   [1619489819796, 292089922091.56384],
#   [1619493449531, 290405328929.68427],
#   [1619496021684, 288765274034.0846],
#   [1619499787139, 289089520570.3708],
#   [1619503451254, 292054050950.10626],
#   [1619507105769, 296947381072.12476],
#   [1619510539649, 295473958319.145],
#   [1619514085284, 293914335239.9261],
#   [1619517910271, 295161203091.1351],
#   [1619521212960, 294461500609.69916],
#   [1619524988321, 297363164797.1766],
#   [1619528907794, 295836024787.4843],
#   [1619533130473, 295041554008.6266],
#   [1619536688730, 303881283848.3997],
#   [1619539459117, 307887619321.24426],
#   [1619543045360, 306616070354.5123],
#   [1619546537404, 305173208132.98065],
#   [1619550063120, 304771006158.8619],
#   [1619553727919, 302525088185.7924],
#   [1619557262612, 305655530744.3845],
#   [1619560967905, 306048851742.5281],
#   [1619564429739, 303508857258.5725],
#   [1619568350769, 306136280873.3804],
#   [1619572006133, 310942601557.88513],
#   [1619575473627, 313321597811.99994],
#   [1619579098208, 309943573974.4125],
#   [1619582575456, 305169557735.0885],
#   [1619586189120, 305336534919.12274],
#   [1619589830671, 303329398948.50916],
#   [1619593444033, 299985013014.65106],
#   [1619596938381, 302896823727.61176],
#   [1619600578941, 302776143864.68604],
#   [1619604198752, 301895928752.37177],
#   [1619607929862, 304978237659.4183],
#   [1619611405528, 312065653161.0638],
#   [1619615253333, 314714740952.8685],
#   [1619618513640, 310719201061.53314],
#   [1619622032640, 313383935920.3519],
#   [1619625676646, 310094666698.3882],
#   [1619629357580, 314535790177.68085],
#   [1619632892889, 316093459078.6214],
#   [1619636601508, 314922260023.1068],
#   [1619640240503, 315902362894.8417],
#   [1619643646334, 312838225894.70703],
#   [1619647215021, 316547552223.7429],
#   [1619650834106, 314826194961.5214],
#   [1619654561409, 317353332381.2044],
#   [1619658332480, 315040662990.19794],
#   [1619661807576, 314393796453.43195],
#   [1619665376478, 314267618484.73315],
#   [1619668800973, 311336980148.1166],
#   [1619672671026, 310961281515.6566],
#   [1619676080139, 312680396354.1505],
#   [1619679855866, 316518798961.89154],
#   [1619683412386, 315763942883.1308],
#   [1619687081264, 314512738195.2712],
#   [1619690575140, 321014814880.5663],
#   [1619694006599, 319958482384.8798],
#   [1619697892882, 319748141190.6204],
#   [1619701436007, 323549566562.1489],
#   [1619704988192, 320329156008.4272],
#   [1619708651707, 321053071036.39795],
#   [1619712162225, 322931338698.47437],
#   [1619715933107, 316835855930.73865],
#   [1619719306364, 316535857154.64465],
#   [1619722902555, 314290502261.90735],
#   [1619726658553, 316484000356.46216],
#   [1619730150419, 312662326197.1893],
#   [1619733657798, 315511824154.9588],
#   [1619737347901, 320238183973.8566],
#   [1619741026408, 318971242360.58826],
#   [1619744856120, 316339856026.7268],
#   [1619748084784, 318501498785.306],
#   [1619751783501, 317269319132.0309],
#   [1619755463733, 317250040112.1081],
#   [1619758993980, 319878623964.7183],
#   [1619762696524, 320533076661.38214],
#   [1619766082221, 321731153461.4355],
#   [1619769651119, 321199855391.59424],
#   [1619773252828, 321192491159.1359],
#   [1619776948994, 322566221737.42786],
#   [1619780627268, 320964566076.4775],
#   [1619784373009, 317520779974.1486],
#   [1619788398842, 318763561718.85016],
#   [1619791960392, 318342506423.132],
#   [1619795184307, 322350525475.6109],
#   [1619798477652, 318071656760.0334],
#   [1619802029531, 318472122422.4613],
#   [1619805832962, 319751854161.3997],
#   [1619809336546, 320473916456.2642],
#   [1619812945216, 321685394380.15137],
#   [1619816403973, 320652611644.1815],
#   [1619820145057, 319505324205.3781],
#   [1619823887070, 318364238289.4177],
#   [1619827358295, 321155845972.33514],
#   [1619831127726, 320351040665.8696],
#   [1619834484872, 323231574819.7736],
#   [1619838247363, 327164194577.1628],
#   [1619841889158, 329159618111.86053],
#   [1619845415804, 328055734367.20135],
#   [1619849133662, 330171969132.1948],
#   [1619852446100, 330953036334.93634],
#   [1619856319948, 329823822697.9047],
#   [1619859942360, 329168943208.2249],
# ...
#   [1619067662816, 48322199322.03732],
#   [1619071345198, 49385059975.64202],
#   [1619075196488, 50291902239.42907],
#   [1619078552390, 50468541307.91039],
#   [1619082186522, 50362594850.42825],
#   [1619085892464, 52501738732.99085],
#   [1619089456402, 53319174385.3139],
#   [1619093085470, 55686191015.26003],
#   [1619096983057, 55750338803.68805],
#   [1619100233974, 55359583053.13384],
#   [1619103808304, 56163902364.567696],
#   [1619107320545, 55546213580.40827],
#   [1619111043341, 56251881006.17285],
#   [1619114723370, 54539488639.396065],
#   [1619118046771, 58121294820.866295],
#   [1619121779885, 59015020208.261986],
#   [1619125498017, 58412202877.87095],
#   [1619129034196, 62009010382.41759],
#   [1619132593108, 62716356249.459694],
#   [1619136167188, 63214220752.29202],
#   [1619139694038, 62263430503.69055],
#   [1619143484375, 62937678137.23789],
#   [1619147019897, 64239750605.985565],
#   [1619150887156, 66699995744.633286],
#   [1619154287825, 65821964273.56631],
#   [1619157731897, 68607618993.45624],
#   [1619161498378, 68876746755.89445],
#   [1619164808510, 68876031010.194],
#   [1619168589803, 72335388580.96703],
#   [1619172203823, 71697624154.9977],
#   [1619175908151, 76095828574.10388],
#   [1619179382603, 77635177800.4071],
#   [1619183272340, 75882739492.35202],
#   [1619186613445, 75813334325.42085],
#   [1619190207156, 78133528054.6598],
#   [1619194122048, 78543981065.56621],
#   [1619197260745, 78687071669.05067],
#   [1619201027737, 77248193449.10243],
#   [1619204626986, 76848041217.15465],
#   [1619208285609, 75548506779.75812],
#   [1619211875488, 73002731004.94768],
#   [1619215541035, 69616102907.2909],
#   [1619218813223, 68839279159.81862],
#   [1619222744588, 69055987726.29962],
#   [1619226344986, 66659385130.39125],
#   [1619229839261, 64313874594.564125],
#   [1619233466350, 60328839003.052536],
#   [1619237128436, 57566456150.169624],
#   [1619240668995, 57041298906.465004],
#   [1619244183175, 53798605508.36333],
#   [1619247886614, 51814050787.7065],
#   [1619251302791, 49399584554.827896],
#   [1619255096624, 46991120375.303154],
#   [1619258650140, 45544526247.65086],
#   [1619262144647, 40333843520.863686],
#   [1619265788726, 40034254748.67109],
#   [1619269700262, 40666128583.99617],
#   [1619273068196, 39272698513.84582],
#   [1619276502150, 38565520098.40793],
#   [1619280179389, 39129586263.583305],
#   [1619283773542, 38000211824.20834],
#   [1619287453683, 37055061102.22384],
#   [1619290992731, 37807955434.056335],
#   [1619294590694, 37616302898.77057],
#   [1619298362142, 36732772576.607475],
#   [1619301727095, 36693865714.13846],
#   [1619305263740, 36227912415.6607],
#   [1619309066117, 35640594314.43296],
#   [1619312720849, 34941592183.84803],
#   [1619316178665, 34783448659.45558],
#   [1619319645723, 34544391846.79119],
#   [1619323257661, 33790179911.859623],
#   [1619327122931, 32592415190.153996],
#   [1619330572609, 29075641308.65333],
#   [1619334089066, 28823092371.23209],
#   [1619337801066, 27674141484.929493],
#   [1619341431197, 32092399548.136173],
#   [1619345041895, 32663512523.55464],
#   [1619348650762, 32825609342.183968],
#   [1619352066717, 32624389226.84502],
#   [1619356278921, 32564765937.874523],
#   [1619360395118, 32584042862.84175],
#   [1619362945742, 34688925761.10597],
#   [1619366608630, 33407836348.121296],
#   [1619370193852, 33861150844.033688],
#   [1619373757016, 33566773799.453587],
#   [1619377540263, 33246728529.299072],
#   [1619380970967, 33143056023.030342],
#   [1619384718591, 32618292590.257786],
#   [1619388320331, 34394668768.20543],
#   [1619391712140, 36374372589.37193],
#   [1619395463456, 36744402576.60037],
#   [1619399328522, 39871771533.62236],
#   [1619402621058, 41633658853.91225],
#   [1619406165111, 42522943066.6106],
#   [1619409945181, 42883527167.99443],
#   [1619413313470, 43725828528.642075],
#   [1619417023040, 44511961931.08675],
#   [1619420501186, 45823935067.130554],
#   [1619424204690, 46090357860.57607],
#   [1619427884171, 46333718060.61795],
#   [1619431257433, 46854592147.30893],
#   [1619435188620, 45869771369.4846],
#   [1619438744324, 46461560158.74323],
#   [1619442447758, 45459489834.8783],
#   [1619449361447, 45454260599.06787],
#   [1619451400657, 45211993754.33779],
#   [1619453786169, 45134360569.08626],
#   [1619456603666, 45698591895.55887],
#   [1619460193488, 46314579421.23567],
#   [1619463952103, 45736307232.85847],
#   [1619467418297, 44895695747.128494],
#   [1619471143099, 44122605595.583595],
#   [1619474573195, 42875461026.78004],
#   [1619478404064, 42137256596.38676],
#   [1619481875633, 42791797037.03227],
#   [1619485548848, 40561230567.8137],
#   [1619489819796, 38927166003.95288],
#   [1619493449531, 37939912670.17911],
#   [1619496021684, 37813320154.829834],
#   [1619499787139, 37305849731.62071],
#   [1619503451254, 36638550845.84552],
#   [1619507105769, 37166256059.54265],
#   [1619510539649, 37245177934.346794],
#   [1619514085284, 37173528307.6857],
#   [1619517910271, 36619852285.56443],
#   [1619521212960, 35893571363.57119],
#   [1619524988321, 35847540131.01196],
#   [1619528907794, 35421409038.301414],
#   [1619533130473, 35242826313.872116],
#   [1619536688730, 38222620544.222206],
#   [1619539459117, 39136606402.8018],
#   [1619543045360, 38557150963.80027],
#   [1619546537404, 39122359706.19226],
#   [1619550063120, 38987720737.19587],
#   [1619553727919, 38874529181.31943],
#   [1619557262612, 39175157979.04948],
#   [1619560967905, 38421785464.382],
#   [1619564429739, 37308770350.43508],
#   [1619568350769, 37792633594.63468],
#   [1619572006133, 38434717061.74177],
#   [1619575473627, 38855648538.275505],
#   [1619579098208, 38895193637.247765],
#   [1619582575456, 39046983294.996605],
#   [1619586189120, 39153754349.4745],
#   [1619589830671, 39126898255.5181],
#   [1619593444033, 39429979818.27449],
#   [1619596938381, 38262354644.30733],
#   [1619600578941, 38073935482.17215],
#   [1619604198752, 38264717092.69016],
#   [1619607929862, 38730533550.93969],
#   [1619611405528, 40351618699.54179],
#   [1619615253333, 41274806256.6269],
#   [1619618513640, 41481746619.647736],
#   [1619622032640, 40676884355.64026],
#   [1619625676646, 40089268181.50755],
#   [1619629357580, 40003889274.49869],
#   [1619632892889, 39928480986.45111],
#   [1619636601508, 40158382686.07444],
#   [1619640240503, 40351919854.85955],
#   [1619643646334, 41678842722.04188],
#   [1619647215021, 42636974977.41718],
#   [1619650834106, 42362327481.25734],
#   [1619654561409, 42878743228.1645],
#   [1619658332480, 42026954716.2704],
#   [1619661807576, 42046295361.20989],
#   [1619665376478, 40781219962.76504],
#   [1619668800973, 40601763921.04514],
#   [1619672671026, 40691740187.020035],
#   [1619676080139, 40950956842.73061],
#   [1619679855866, 40333609546.36703],
#   [1619683412386, 39262778456.94537],
#   [1619687081264, 40003485793.03418],
#   [1619690575140, 41179063400.43346],
#   [1619694006599, 40726983822.59946],
#   [1619697892882, 39842587012.500755],
#   [1619701436007, 39831585391.19018],
#   [1619704988192, 40175178323.658226],
#   [1619708651707, 40169769433.3306],
#   [1619712162225, 40008593378.57277],
#   [1619715933107, 39204807303.390205],
#   [1619719306364, 40152585096.22566],
#   [1619722902555, 40415277485.3976],
#   [1619726658553, 39529105479.09874],
#   [1619730150419, 38557942844.52743],
#   [1619733657798, 39151212501.68997],
#   [1619737347901, 39401418324.00809],
#   [1619741026408, 38536865198.32878],
#   [1619744856120, 38723670163.406],
#   [1619748084784, 38160703930.41452],
#   [1619751783501, 38117555219.09586],
#   [1619755463733, 38039012258.00282],
#   [1619758993980, 38077594546.6305],
#   [1619762696524, 38714039351.99649],
#   [1619766082221, 38529634181.413506],
#   [1619769651119, 38163930424.023094],
#   [1619773252828, 38401447232.03421],
#   [1619776948994, 37612028683.8467],
#   [1619780627268, 37109409728.21699],
#   [1619784373009, 36873255196.2217],
#   [1619788398842, 37062889721.59564],
#   [1619791960392, 37254263555.780624],
#   [1619795184307, 38037928911.43081],
#   [1619798477652, 37639878742.16343],
#   [1619802029531, 37560112860.88322],
#   [1619805832962, 36801844717.11778],
#   [1619809336546, 36342224387.95662],
#   [1619812945216, 35594202425.601685],
#   [1619816403973, 35467019868.79127],
#   [1619820145057, 35265223758.709625],
#   [1619823887070, 35045757783.31796],
#   [1619827358295, 35477884578.62226],
#   [1619831127726, 35258264464.19651],
#   [1619834484872, 35641411087.80363],
#   [1619838247363, 37146923852.022385],
#   [1619841889158, 37452182187.42886],
#   [1619845415804, 37301400016.78334],
#   [1619849133662, 37634189012.50376],
#   [1619852446100, 37679339858.07473],
#   [1619856319948, 37476203118.30425],
#   [1619859942360, 37478583468.28286],
#   [1619863476703, 37832825781.36397],
#   [1619867097545, 37817895071.31048],
#   [1619870689639, 37775315517.885345],
#   [1619874733744, 36628977178.59246],
#   [1619878446036, 36205479788.1237],
#   [1619881360766, 35647703962.42014],
#   [1619885009678, 34620185879.921906],
#   [1619888625806, 35111279283.88402],
#   [1619892135606, 36002146981.47488],
#   [1619895635834, 36547501112.64064],
#   [1619899290798, 36704987301.288246],
#   [1619903127120, 36921486957.830376],
#   [1619906433650, 36889343606.70013],
#   [1619910043057, 36643208369.092545],
#   [1619913921870, 36719675811.79499],
#   [1619917502975, 37380197980.85181],
#   [1619920979032, 36892008049.508865],
#   [1619924534949, 36526495079.11598],
#   [1619928218481, 36398795630.306725],
#   [1619931813963, 37653756542.87748],
#   [1619935321079, 36838472481.29301],
#   [1619938918633, 37360384291.58341],
#   [1619942584730, 37458400488.117935],
#   [1619946030783, 36857779322.50486],
#   [1619949874411, 37455559031.4349],
#   [1619953388442, 38291763675.823166],
#   [1619957108885, 38489676925.49886],
#   [1619960962007, 38186195774.368286],
#   [1619964981704, 37347210144.96755],
#   [1619967821335, 37051421269.80698],
#   [1619971451504, 37077912350.67204],
#   [1619974935462, 36866035176.04632],
#   [1619978645234, 35975777359.75386],
#   [1619982033753, 36136824871.82029],
#   [1619985620694, 36426389954.30548],
#   [1619989217194, 36418143366.471855],
#   [1619993055088, 36357626576.762535],
#   [1619996675212, 36201488712.104004],
#   [1620000408627, 35621008482.30482],
#   [1620004036904, 37246886526.44748],
#   [1620007458313, 38159334776.73495],
#   [1620011064191, 38588346078.9484],
#   [1620014556826, 39456133820.87761],
#   [1620018161074, 39000946045.89188],
#   [1620021735624, 40043195379.94874],
#   [1620025335128, 39495765898.7084],
#   [1620028894576, 41787885272.45361],
#   [1620032685046, 43490360162.31494],
#   [1620036281456, 44384435273.775],
#   [1620040266825, 44791275457.449196],
#   [1620043375412, 44187809658.78704],
#   [1620047237679, 45510707166.2377],
#   [1620050595373, 45817267283.288315],
#   [1620054209386, 46664308998.91394],
#   [1620057602761, 47870356703.86337],
#   [1620061505153, 51630792795.24965],
#   [1620064988723, 54273092898.353455],
#   [1620068670206, 56296259600.613945],
#   [1620072281302, 57019591479.777145],
#   [1620075830121, 57978041422.52829],
#   [1620079580947, 59420306338.65713],
#   [1620082988002, 61252002570.531494],
#   [1620086749734, 64342043461.50028],
#   [1620090287001, 65770937170.69449],
#   [1620093779299, 68271106468.085014],
#   [1620097662512, 68221107831.11321],
#   [1620101149647, 68833580079.34918],
#   [1620104671242, 71656031343.77748],
#   [1620108267359, 72687314276.59705],
#   [1620111895164, 72790770425.57558],
#   [1620115450214, 71604815459.52658],
#   [1620118993641, 70496004669.59698],
#   [1620122551140, 71213008351.04373],
#   [1620126274843, 73202102076.073],
#   [1620129625859, 75438086213.53033],
#   [1620133277966, 77267521516.69104],
#   [1620137206909, 79068943406.28075],
#   [1620142055713, 78881573639.11635],
#   [1620144134404, 81488493746.61221],
#   [1620147862951, 81630811726.05623],
#   [1620151498173, 83195616744.89847],
#   [1620154917683, 84560468312.29454],
#   [1620158547888, 80186245771.18727],
#   [1620162110354, 83878661316.71942],
#   [1620165719217, 82130958064.23288],
#   [1620169320366, 81124871786.20503],
#   [1620173019449, 78437235045.70189],
#   [1620176655903, 77619144516.15793],
#   [1620181262129, 77189642317.94707],
#   [1620183803463, 75373043964.9312],
#   [1620187277523, 74634347553.09761],
#   [1620191076327, 74151811743.53206],
#   [1620194515152, 74054848778.30838],
#   [1620198322148, 73686563312.54926],
#   [1620201849372, 75329441304.78043],
#   [1620205336625, 75272629202.84697],
#   [1620209136340, 75503652090.98093],
#   [1620212668967, 75342460395.42818],
#   [1620216387726, 71762261032.18091],
#   [1620219726623, 72818065308.5179],
#   [1620223574717, 70701399110.79504],
#   [1620226919066, 69595225981.45056],
#   [1620230702841, 65212195529.24442],
#   [1620234280611, 64298850454.80748],
#   [1620237901130, 63065644589.781425],
#   [1620241475465, 62062550611.890274],
#   [1620245611995, 62801345166.56435],
#   [1620248479493, 62766474794.12959],
#   [1620252077828, 60121651129.98969],
#   [1620255830609, 63253974451.56881],
#   [1620259470107, 63150697694.19698],
#   [1620263129706, 61818559960.44831],
#   [1620266583857, 61078474250.38274],
#   [1620270258886, 60810725167.00565],
#   [1620273931503, 57802186669.21286],
#   [1620277298202, 58411595878.25377],
#   [1620281129991, 57628889505.838684],
#   [1620284700059, 55849677102.72339],
#   [1620288175199, 56721879033.12478],
#   [1620291868679, 55994377900.01096],
#   [1620295313681, 55834490334.93573],
#   [1620298981205, 55216970913.03861],
#   [1620302675383, 55064477568.35773],
#   [1620306159856, 53592151046.33297],
#   [1620309698419, 54165863893.4857],
#   [1620313458331, 51083376042.22192],
#   [1620316921570, 51491638488.5143],
#   [1620320609143, 50651716839.67681],
#   [1620324266792, 50582580300.62327],
#   [1620327697732, 50858219110.562],
#   [1620331450161, 52419077010.59471],
#   [1620334940296, 51589646836.29194],
#   [1620338738177, 52042693702.501],
#   [1620342072196, 51269714091.14508],
#   [1620345818683, 50430169752.9615],
#   [1620349256353, 50123297885.77945],
#   [1620353047744, 49650808142.0094],
#   [1620356662268, 49953130374.27519],
#   [1620360488169, 50582146052.16547],
#   [1620363739303, 51049435874.89015],
#   [1620367575096, 51021896340.02009],
#   [1620371044310, 51431284239.29609],
#   [1620374537386, 51211539710.187035],
#   [1620378149792, 51298856219.01335],
#   [1620381788079, 51545176364.7982],
#   [1620385334483, 51074601292.813225],
#   [1620389005314, 50103866431.54702],
#   [1620392578227, 51332408223.92173],
#   [1620396149176, 51442626955.92105],
#   [1620399914118, 51197646548.2594],
#   [1620403546581, 50932434273.7258],
#   [1620407088804, 49510232739.42677],
#   [1620410476705, 48965865507.73776],
#   [1620414076715, 46106275935.22374],
#   [1620417871541, 46016178272.572845],
#   [1620421279331, 45388796776.17565],
#   [1620424833417, 45063528954.57154],
#   [1620428697268, 44811364726.384285],
#   [1620432148694, 44980768421.369],
#   [1620435750956, 45108391799.17307],
#   [1620439367615, 44870994088.04314],
#   [1620443045879, 44118106702.04296],
#   [1620446589929, 42327501322.853546],
#   [1620450131419, 42589923056.84225],
#   [1620454186247, 41789483060.79556],
#   [1620457319890, 41707045179.40733],
#   [1620460986518, 41581427785.704704],
#   [1620464732506, 43213166262.49184],
#   [1620468134914, 43613668208.76422],
#   [1620471865237, 43377803954.63428],
#   [1620475208637, 43298897125.791084],
#   [1620481119979, 43937841221.47114],
#   [1620482472850, 45287457868.64273],
#   [1620486069417, 47313887568.393524],
#   [1620489733234, 47668609727.86226],
#   [1620493262676, 52411403802.32274],
#   [1620496915325, 54579064254.84599],
#   [1620500494793, 55165826037.53135],
#   [1620504125827, 54633094090.50183],
#   [1620507736880, 56095485062.20714],
#   [1620511295701, 57280463953.88579],
#   [1620515021981, 58844146522.14873],
#   [1620518618838, 60174921874.24125],
#   [1620522418823, 59595405957.45932],
#   [1620525650618, 61426038117.25522],
#   [1620529267935, 59589736207.05818],
#   [1620532936213, 62611926358.981346],
#   [1620536487307, 64400927735.74863],
#   [1620540158329, 65710771834.254326],
#   [1620543732433, 65140748217.05791],
#   [1620547275139, 67633633199.982666],
#   [1620550845232, 67106077905.698555],
#   [1620554578740, 67834368386.4796],
#   [1620558094171, 68499183029.13473],
#   [1620561853737, 68497276136.67142],
#   [1620565894622, 69369843060.70525],
#   [1620569004650, 66712951999.32822],
#   [1620572578879, 69265469845.64143],
#   [1620573013000, 69123548050.77309]]}

# %%
cg.get_coin_market_chart_range_by_id(id='ethereum',vs_currency='usd',from_timestamp='1605096000',to_timestamp='1605099600')
# Out:
# {'prices': [[1605096605956, 460.3813949665046]],
#  'market_caps': [[1605096605956, 52247697993.73093]],
#  'total_volumes': [[1605096605956, 10127235297.40995]]}

# %%
# Get status updates for a given coin (beta)
cg.get_coin_status_updates_by_id(id='ethereum')
# Out:
# {'status_updates': []}

# %%
# Get coin's OHLC (beta)
cg.get_coin_ohlc_by_id(id='ethereum', vs_currency='usd', days=30)
# Out:
# [[1617998400000, 2064.71, 2077.87, 2064.71, 2077.87],
#  [1618012800000, 2076.19, 2076.19, 2065.48, 2065.48],
#  [1618027200000, 2069.67, 2106.4, 2067.52, 2106.4],
#  [1618041600000, 2144.04, 2186.97, 2144.04, 2165.91],
#  [1618056000000, 2158.13, 2164.81, 2157.71, 2157.71],
#  [1618070400000, 2160.66, 2160.66, 2145.96, 2152.97],
#  [1618084800000, 2154.56, 2154.56, 2138.12, 2138.12],
#  [1618099200000, 2133.78, 2133.78, 2096.58, 2116.24],
#  [1618113600000, 2140.76, 2151.58, 2136.58, 2150.35],
#  [1618128000000, 2142.96, 2142.96, 2123.89, 2130.47],
#  [1618142400000, 2133.12, 2145.02, 2133.12, 2139.45],
#  [1618156800000, 2149.66, 2149.66, 2128.64, 2143.27],
#  [1618171200000, 2152.48, 2152.48, 2144.79, 2149.6],
#  [1618185600000, 2143.57, 2144.29, 2135.56, 2143.05],
#  [1618200000000, 2150.27, 2150.27, 2134.03, 2134.03],
#  [1618214400000, 2155.54, 2182.64, 2146.36, 2182.64],
#  [1618228800000, 2184.1, 2184.1, 2137.1, 2137.1],
#  [1618243200000, 2149.73, 2154.37, 2135.93, 2135.93],
#  [1618257600000, 2136.24, 2136.24, 2122.97, 2135.81],
#  [1618272000000, 2140.85, 2151.52, 2140.85, 2151.52],
#  [1618286400000, 2140.93, 2170.93, 2140.93, 2170.93],
#  [1618300800000, 2163.98, 2167.9, 2159.05, 2159.05],
#  [1618315200000, 2167.57, 2216.7, 2167.57, 2210.99],
#  [1618329600000, 2230.89, 2256.88, 2223.87, 2256.88],
#  [1618344000000, 2267.16, 2309.32, 2267.16, 2274.84],
#  [1618358400000, 2302.73, 2302.73, 2282.59, 2282.59],
#  [1618372800000, 2309.21, 2309.21, 2292.23, 2292.23],
#  [1618387200000, 2355.53, 2385.02, 2355.53, 2385.02],
#  [1618401600000, 2386.53, 2386.53, 2347.84, 2359.92],
#  [1618416000000, 2389.4, 2389.4, 2332.19, 2332.19],
#  [1618430400000, 2347.4, 2384.74, 2334.8, 2338.05],
#  [1618444800000, 2341.28, 2428.35, 2341.28, 2428.35],
#  [1618459200000, 2429.66, 2436.87, 2415.47, 2436.87],
#  [1618473600000, 2472.43, 2477.39, 2457.91, 2467.74],
#  [1618488000000, 2472.53, 2472.53, 2423.07, 2423.07],
#  [1618502400000, 2430.75, 2467.37, 2430.75, 2466.32],
#  [1618516800000, 2476.52, 2476.52, 2453.56, 2467.71],
#  [1618531200000, 2492.17, 2529.52, 2492.17, 2529.52],
#  [1618545600000, 2516.29, 2537.74, 2495.08, 2495.08],
#  [1618560000000, 2504.82, 2504.82, 2406.12, 2418.91],
#  [1618574400000, 2429.67, 2429.67, 2371.63, 2371.63],
#  [1618588800000, 2376.56, 2421.81, 2356.11, 2421.81],
#  [1618603200000, 2434.63, 2449.9, 2431.93, 2449.9],
#  [1618617600000, 2428.01, 2460.53, 2428.01, 2428.77],
#  [1618632000000, 2432.67, 2486.2, 2432.67, 2486.2],
#  [1618646400000, 2490.83, 2490.83, 2471.64, 2471.64],
#  [1618660800000, 2464.61, 2466.16, 2418.27, 2418.27],
#  [1618675200000, 2416.18, 2416.18, 2390.85, 2390.85],
#  [1618689600000, 2362.33, 2378.59, 2360.74, 2378.59],
#  [1618704000000, 2378.3, 2393.66, 2378.3, 2381.87],
#  [1618718400000, 2329.91, 2329.91, 2192.31, 2192.31],
#  [1618732800000, 2177.38, 2202.1, 2172.27, 2183.13],
#  [1618747200000, 2223.66, 2223.66, 2122.09, 2138.76],
#  [1618761600000, 2058.81, 2139.62, 2058.81, 2139.62],
#  [1618776000000, 2156.35, 2182.46, 2148.3, 2182.46],
#  [1618790400000, 2193.39, 2236.34, 2193.39, 2236.34],
#  [1618804800000, 2220.49, 2265.26, 2220.49, 2258.3],
#  [1618819200000, 2264.82, 2273.56, 2246.04, 2273.56],
#  [1618833600000, 2263.91, 2263.91, 2211.46, 2211.46],
#  [1618848000000, 2247.98, 2247.98, 2141.65, 2141.65],
#  [1618862400000, 2105.33, 2172.56, 2105.33, 2169.09],
#  [1618876800000, 2193.79, 2215.75, 2188.23, 2188.23],
#  [1618891200000, 2168.03, 2168.03, 2089.67, 2096.89],
#  [1618905600000, 2139.43, 2149.36, 2069.85, 2069.85],
#  [1618920000000, 2088.39, 2195.42, 2088.39, 2195.42],
#  [1618934400000, 2203.29, 2223.41, 2183.99, 2183.99],
#  [1618948800000, 2184.43, 2292.28, 2184.43, 2292.28],
#  [1618963200000, 2308.14, 2345.97, 2308.14, 2317.42],
#  [1618977600000, 2337.55, 2337.55, 2300.85, 2336.83],
#  [1618992000000, 2296.27, 2314.16, 2295.49, 2314.16],
#  [1619006400000, 2293.63, 2302.9, 2265.61, 2265.61],
#  [1619020800000, 2252.05, 2431.38, 2252.05, 2431.38],
#  [1619035200000, 2450.53, 2450.53, 2413.05, 2413.05],
#  [1619049600000, 2441.9, 2441.9, 2360.79, 2360.79],
#  [1619064000000, 2373.5, 2434.22, 2373.5, 2419.98],
#  [1619078400000, 2420.22, 2480.57, 2420.22, 2480.57],
#  [1619092800000, 2474.53, 2506.64, 2432.19, 2506.64],
#  [1619107200000, 2550.41, 2603.35, 2546.1, 2603.35],
#  [1619121600000, 2603.91, 2625.37, 2504.88, 2556.01],
#  [1619136000000, 2532.31, 2532.31, 2400.32, 2400.32],
#  [1619150400000, 2416.71, 2416.71, 2256.28, 2256.28],
#  [1619164800000, 2278.55, 2278.55, 2209.66, 2209.66],
#  [1619179200000, 2144.11, 2271.38, 2144.11, 2271.38],
#  [1619193600000, 2298.77, 2301.95, 2233.24, 2301.95],
#  [1619208000000, 2338.05, 2360.72, 2312.32, 2360.72],
#  [1619222400000, 2363.86, 2363.86, 2318.93, 2323.68],
#  [1619236800000, 2371.56, 2371.56, 2270.04, 2281.11],
#  [1619251200000, 2292.53, 2324.7, 2292.53, 2296.06],
#  [1619265600000, 2280.46, 2287.01, 2208.31, 2208.31],
#  [1619280000000, 2173.32, 2231.02, 2173.32, 2206.03],
#  [1619294400000, 2256.94, 2275.61, 2243.33, 2275.61],
#  [1619308800000, 2273.26, 2293.96, 2273.26, 2276.02],
#  [1619323200000, 2212.84, 2247.84, 2212.84, 2247.84],
#  [1619337600000, 2193.33, 2193.33, 2166.23, 2166.23],
#  [1619352000000, 2178.43, 2257.78, 2178.43, 2257.78],
#  [1619366400000, 2294.11, 2350.1, 2294.11, 2350.1],
#  [1619380800000, 2343.97, 2348.58, 2300.19, 2300.19],
#  [1619395200000, 2273.05, 2285.7, 2211.85, 2285.7],
#  [1619409600000, 2307.36, 2463.3, 2307.36, 2450.99],
#  [1619424000000, 2467.96, 2483.89, 2461.82, 2483.89],
#  [1619438400000, 2457.95, 2485.52, 2444.32, 2482.63],
#  [1619452800000, 2524.18, 2524.18, 2488.13, 2490.28],
#  [1619467200000, 2488.54, 2516.79, 2484.39, 2505.17],
#  [1619481600000, 2489.28, 2509.95, 2463.55, 2509.95],
#  [1619496000000, 2532.39, 2532.39, 2508.58, 2508.58],
#  [1619510400000, 2502.52, 2564.64, 2502.52, 2564.64],
#  [1619524800000, 2538.44, 2552.87, 2538.44, 2552.87],
#  [1619539200000, 2576.42, 2627.37, 2544.34, 2627.37],
#  [1619553600000, 2662.41, 2662.41, 2631.47, 2639.98],
#  [1619568000000, 2622.82, 2646.13, 2622.82, 2623.06],
#  [1619582400000, 2662.19, 2709.26, 2662.19, 2666.62],
#  [1619596800000, 2635.09, 2635.09, 2586.11, 2586.11],
#  [1619611200000, 2611.44, 2642.69, 2606.62, 2642.69],
#  [1619625600000, 2695.4, 2721.16, 2695.15, 2713.13],
#  [1619640000000, 2679.37, 2725.41, 2679.37, 2721.17],
#  [1619654400000, 2737.34, 2755.61, 2713.95, 2717.8],
#  [1619668800000, 2748.78, 2748.78, 2715.74, 2715.74],
#  [1619683200000, 2695.56, 2736.52, 2688.5, 2736.52],
#  [1619697600000, 2729.96, 2772.95, 2721.41, 2767.75],
#  [1619712000000, 2764.38, 2793.23, 2755.89, 2769.2],
#  [1619726400000, 2785.92, 2785.92, 2725.36, 2725.36],
#  [1619740800000, 2729.35, 2768.46, 2707.86, 2768.46],
#  [1619755200000, 2757.5, 2757.5, 2734.66, 2743.64],
#  [1619769600000, 2742.56, 2790.72, 2742.56, 2790.72],
#  [1619784000000, 2777.26, 2792.73, 2766.16, 2766.16],
#  [1619798400000, 2742.25, 2786.51, 2742.25, 2786.51],
#  [1619812800000, 2751.09, 2775.07, 2751.09, 2775.07],
#  [1619827200000, 2780.72, 2780.72, 2744.64, 2744.64],
#  [1619841600000, 2776.7, 2826.28, 2767.72, 2826.28],
#  [1619856000000, 2845.3, 2861.05, 2845.3, 2861.05],
#  [1619870400000, 2856.05, 2856.05, 2832.17, 2842.25],
#  [1619884800000, 2864.89, 2874.11, 2858.48, 2858.48],
#  [1619899200000, 2858.61, 2943.8, 2858.61, 2943.8],
#  [1619913600000, 2925.42, 2946.89, 2924.13, 2940.29],
#  [1619928000000, 2946.09, 2954.74, 2940.09, 2954.74],
#  [1619942400000, 2909.01, 2931.52, 2909.01, 2917.37],
#  [1619956800000, 2899.81, 2928.41, 2880.93, 2928.41],
#  [1619971200000, 2945.57, 2945.57, 2919.57, 2919.57],
#  [1619985600000, 2928.16, 2969.15, 2928.16, 2969.15],
#  [1620000000000, 2973.8, 2974.65, 2950.26, 2950.26],
#  [1620014400000, 2953.78, 3035.48, 2953.78, 3035.48],
#  [1620028800000, 3054.49, 3105.32, 3051.93, 3083.42],
#  [1620043200000, 3148.06, 3193.57, 3148.06, 3161.89],
#  [1620057600000, 3160.51, 3160.51, 3110.41, 3160.13],
#  [1620072000000, 3167.13, 3331.61, 3167.13, 3331.61],
#  [1620086400000, 3294.57, 3384.89, 3294.57, 3384.89],
#  [1620100800000, 3438.14, 3438.14, 3248.06, 3248.06],
#  [1620115200000, 3244.4, 3388.39, 3244.4, 3373.58],
#  [1620129600000, 3341.11, 3440.43, 3308.93, 3440.43],
#  [1620144000000, 3488.68, 3491.33, 3281.86, 3281.86],
#  [1620158400000, 3295.96, 3415.12, 3255.2, 3415.12],
#  [1620172800000, 3393.72, 3422.13, 3316.06, 3316.06],
#  [1620187200000, 3245.66, 3390.99, 3245.66, 3327.68],
#  [1620201600000, 3290.92, 3290.92, 3272.52, 3272.52],
#  [1620216000000, 3351.34, 3399.38, 3351.34, 3385.02],
#  [1620230400000, 3354.41, 3392.72, 3354.41, 3392.72],
#  [1620244800000, 3329.06, 3433.29, 3329.06, 3419.62],
#  [1620259200000, 3473.74, 3521.09, 3428.22, 3521.09],
#  [1620273600000, 3527.88, 3527.88, 3480.5, 3492.26],
#  [1620288000000, 3467.68, 3467.68, 3408.76, 3408.76],
#  [1620302400000, 3445.75, 3492.6, 3440.87, 3492.6],
#  [1620316800000, 3520.97, 3520.97, 3487.57, 3516.64],
#  [1620331200000, 3540.31, 3574.82, 3458.6, 3458.6],
#  [1620345600000, 3496.98, 3534.86, 3468.69, 3534.86],
#  [1620360000000, 3495.08, 3512.88, 3440.33, 3440.33],
#  [1620374400000, 3442.69, 3453.17, 3416.36, 3453.17],
#  [1620388800000, 3447.46, 3467.29, 3442.26, 3467.29],
#  [1620403200000, 3451.75, 3509.61, 3451.75, 3509.61],
#  [1620417600000, 3571.37, 3571.37, 3528.25, 3528.25],
#  [1620432000000, 3518.2, 3518.2, 3451.98, 3451.98],
#  [1620446400000, 3493.53, 3538.86, 3493.53, 3538.54],
#  [1620460800000, 3530.55, 3566.67, 3524.49, 3524.49],
#  [1620475200000, 3542.32, 3566.92, 3541.6, 3541.6],
#  [1620489600000, 3546.82, 3665.51, 3546.82, 3665.51],
#  [1620504000000, 3634.42, 3833.13, 3634.42, 3833.13],
#  [1620518400000, 3808.44, 3899.95, 3808.44, 3899.95],
#  [1620532800000, 3912.74, 3912.74, 3844.96, 3877.05],
#  [1620547200000, 3931.61, 3972.5, 3906.97, 3972.5],
#  [1620561600000, 3967.44, 3967.44, 3932.4, 3932.4],
#  [1620576000000, 3898.19, 3898.19, 3805.46, 3861.84]]

# %% [markdown]
# ### Contracts

# %%
# Get coin info from contract address
cg.get_coin_info_from_contract_address_by_id()

# %%
# Get historical market data include price, market cap, and 24h volume (granularity auto) from a contract address
cg.get_coin_market_chart_from_contract_address_by_id()

# %%
# Get historical market data include price, market cap, and 24h volume within a range of timestamp (granularity auto) from a contract address
cg.get_coin_market_chart_range_from_contract_address_by_id()

# %% [markdown]
# ### Exchanges

# %%
# List all exchanges
cg.get_exchanges_list()
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 1159761.055523141,
#   'trade_volume_24h_btc_normalized': 1159761.055523141},
#  {'id': 'gdax',
#   'name': 'Coinbase Pro',
#   'year_established': 2012,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.coinbase.com',
#   'image': 'https://assets.coingecko.com/markets/images/23/small/fe290a14-ac8f-4c90-9aed-5e72abf271f0.jpeg?1527171545',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 119087.03350727014,
#   'trade_volume_24h_btc_normalized': 119087.03350727014},
#  {'id': 'kraken',
#   'name': 'Kraken',
#   'year_established': 2011,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://r.kraken.com/Q1m9x',
#   'image': 'https://assets.coingecko.com/markets/images/29/small/kraken.jpg?1584251255',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 3,
#   'trade_volume_24h_btc': 65853.3298002715,
#   'trade_volume_24h_btc_normalized': 65853.3298002715},
#  {'id': 'binance_us',
#   'name': 'Binance US',
#   'year_established': 2019,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.binance.us/en',
#   'image': 'https://assets.coingecko.com/markets/images/469/small/Binance.png?1568875842',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 4,
#   'trade_volume_24h_btc': 44129.82142174668,
#   'trade_volume_24h_btc_normalized': 44129.82142174668},
#  {'id': 'bitfinex',
#   'name': 'Bitfinex',
#   'year_established': 2014,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://www.bitfinex.com',
#   'image': 'https://assets.coingecko.com/markets/images/4/small/BItfinex.png?1615895883',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 5,
#   'trade_volume_24h_btc': 36102.88979425423,
#   'trade_volume_24h_btc_normalized': 36102.88979425423},
#  {'id': 'crypto_com',
#   'name': 'Crypto.com',
#   'year_established': 2019,
#   'country': 'Cayman Islands',
#   'description': 'Crypto.com Exchange is the best place to trade crypto, with deep liquidity, low fees and best execution prices, users can trade major cryptocurrencies like Bitcoin, Ethereum, and many more and receive great CRO-powered rewards',
#   'url': 'https://crypto.com/exchange',
#   'image': 'https://assets.coingecko.com/markets/images/589/small/crypto_com.jpg?1602499898',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 6,
#   'trade_volume_24h_btc': 9496.493014174364,
#   'trade_volume_24h_btc_normalized': 9496.493014174364},
#  {'id': 'gemini',
#   'name': 'Gemini',
#   'year_established': 2014,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://gemini.sjv.io/bZ49k',
#   'image': 'https://assets.coingecko.com/markets/images/50/small/gemini.png?1605704107',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 7,
#   'trade_volume_24h_btc': 5750.461430026504,
#   'trade_volume_24h_btc_normalized': 5750.461430026504},
#  {'id': 'huobi',
#   'name': 'Huobi Global',
#   'year_established': 2013,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.huobi.com',
#   'image': 'https://assets.coingecko.com/markets/images/25/small/1481589873352_.pic_hd.jpg?1589962155',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 8,
#   'trade_volume_24h_btc': 408610.5247713596,
#   'trade_volume_24h_btc_normalized': 408610.5247713596},
#  {'id': 'okex',
#   'name': 'OKEx',
#   'year_established': 2013,
#   'country': 'Belize',
#   'description': '',
#   'url': 'https://www.okex.com',
#   'image': 'https://assets.coingecko.com/markets/images/96/small/okEX.jpg?1519349636',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 9,
#   'trade_volume_24h_btc': 266050.97490995727,
#   'trade_volume_24h_btc_normalized': 266050.97490995727},
#  {'id': 'gate',
#   'name': 'Gate.io',
#   'year_established': None,
#   'country': 'Hong Kong',
#   'description': '',
#   'url': 'https://gate.io/',
#   'image': 'https://assets.coingecko.com/markets/images/60/small/gateio.jpg?1519793974',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 10,
#   'trade_volume_24h_btc': 57497.50613999412,
#   'trade_volume_24h_btc_normalized': 57497.50613999412},
#  {'id': 'kucoin',
#   'name': 'KuCoin',
#   'year_established': 2014,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.kucoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/61/small/kucoin.jpg?1591610627',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 11,
#   'trade_volume_24h_btc': 53599.39172676909,
#   'trade_volume_24h_btc_normalized': 53599.39172676909},
#  {'id': 'ftx_spot',
#   'name': 'FTX',
#   'year_established': 2019,
#   'country': 'Antigua and Barbuda',
#   'description': '',
#   'url': 'https://ftx.com/',
#   'image': 'https://assets.coingecko.com/markets/images/451/small/F.png?1609051590',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 12,
#   'trade_volume_24h_btc': 39816.720193649395,
#   'trade_volume_24h_btc_normalized': 39816.720193649395},
#  {'id': 'bitstamp',
#   'name': 'Bitstamp',
#   'year_established': 2013,
#   'country': 'United Kingdom',
#   'description': None,
#   'url': 'https://www.bitstamp.net/',
#   'image': 'https://assets.coingecko.com/markets/images/9/small/bitstamp.jpg?1519627979',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 13,
#   'trade_volume_24h_btc': 17057.787380270183,
#   'trade_volume_24h_btc_normalized': 17057.787380270183},
#  {'id': 'bittrex',
#   'name': 'Bittrex',
#   'year_established': 2014,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://bittrex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/10/small/BG-color-250x250_icon.png?1596167574',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 14,
#   'trade_volume_24h_btc': 11485.446765069932,
#   'trade_volume_24h_btc_normalized': 11485.446765069932},
#  {'id': 'latoken',
#   'name': 'LATOKEN',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://latoken.com/',
#   'image': 'https://assets.coingecko.com/markets/images/124/small/LA_token.png?1605773251',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 15,
#   'trade_volume_24h_btc': 7894.040884027124,
#   'trade_volume_24h_btc_normalized': 7894.040884027124},
#  {'id': 'bithumb_global',
#   'name': 'Bithumb Global',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://bithumb.pro/',
#   'image': 'https://assets.coingecko.com/markets/images/405/small/bithumbglobal.jpg?1599652253',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 16,
#   'trade_volume_24h_btc': 6642.9989631313865,
#   'trade_volume_24h_btc_normalized': 6642.9989631313865},
#  {'id': 'cex',
#   'name': 'CEX.IO',
#   'year_established': 2013,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://cex.io/',
#   'image': 'https://assets.coingecko.com/markets/images/56/small/main-icon.png?1617267530',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 17,
#   'trade_volume_24h_btc': 1667.1177647357247,
#   'trade_volume_24h_btc_normalized': 1667.1177647357247},
#  {'id': 'bitso',
#   'name': 'Bitso',
#   'year_established': 2014,
#   'country': 'Mexico',
#   'description': '',
#   'url': 'https://bitso.com',
#   'image': 'https://assets.coingecko.com/markets/images/8/small/Bitso-icon-dark.png?1581909156',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 18,
#   'trade_volume_24h_btc': 398.74314573787154,
#   'trade_volume_24h_btc_normalized': 398.74314573787154},
#  {'id': 'nice_hash',
#   'name': 'NiceHash',
#   'year_established': None,
#   'country': 'Slovenia',
#   'description': '',
#   'url': 'https://www.nicehash.com',
#   'image': 'https://assets.coingecko.com/markets/images/546/small/nicehash.png?1594379914',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 19,
#   'trade_volume_24h_btc': 61.88530992310118,
#   'trade_volume_24h_btc_normalized': 61.88530992310118},
#  {'id': 'cointiger',
#   'name': 'CoinTiger',
#   'year_established': 2017,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.cointiger.com/',
#   'image': 'https://assets.coingecko.com/markets/images/204/small/cointiger.png?1588935091',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 20,
#   'trade_volume_24h_btc': 170447.26538561765,
#   'trade_volume_24h_btc_normalized': 170447.26538561765},
#  {'id': 'coinbene',
#   'name': 'CoinBene',
#   'year_established': 2017,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'http://www.coinbene.com/#/',
#   'image': 'https://assets.coingecko.com/markets/images/109/small/CoinBene_logo.png?1607418278',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 21,
#   'trade_volume_24h_btc': 106674.78002857057,
#   'trade_volume_24h_btc_normalized': 106674.78002857057},
#  {'id': 'zb',
#   'name': 'ZB',
#   'year_established': 2017,
#   'country': 'China',
#   'description': '',
#   'url': 'https://www.zb.com/',
#   'image': 'https://assets.coingecko.com/markets/images/115/small/zb.jpg?1519996151',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 22,
#   'trade_volume_24h_btc': 81078.81141897224,
#   'trade_volume_24h_btc_normalized': 81078.81141897224},
#  {'id': 'bithumb',
#   'name': 'Bithumb',
#   'year_established': 2014,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://www.bithumb.com/',
#   'image': 'https://assets.coingecko.com/markets/images/6/small/bithumb_BI.png?1573104549',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 23,
#   'trade_volume_24h_btc': 56237.91885462047,
#   'trade_volume_24h_btc_normalized': 56237.91885462047},
#  {'id': 'bitcoin_com',
#   'name': 'Bitcoin.com Exchange',
#   'year_established': 2019,
#   'country': 'Bahamas',
#   'description': 'The mission of Bitcoin.com Exchange is to empower people from all over the world to trade cryptocurrencies with ease and confidence, from first-time traders to advanced trading professionals. With high liquidity, 24/7 multilingual support and dozens of trading pairs, complemented with a high level of security, we offer an attractive platform for trading any cryptocurrency. Within one year since launch, on average, our exchange has been visited by more than 500K active traders per month, and this number continues to grow as you read this sentence. \r\n\r\nKey Features:\r\n\r\n- Enjoy more than 130 available trading pairs\r\n- Cutting-edge matching engine technologies\r\n- Up 5x and 10x leverage for more than 29 markets\r\n- Deep liquidity\r\n- User-friendly trading terminal\r\n- Tight spreads\r\n- Consistent trading competitions and giveaways',
#   'url': 'https://exchange.bitcoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/467/small/logomark.png?1568799194',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 24,
#   'trade_volume_24h_btc': 45466.67322267982,
#   'trade_volume_24h_btc_normalized': 45466.67322267982},
#  {'id': 'changelly',
#   'name': 'Changelly PRO',
#   'year_established': 2020,
#   'country': 'Seychelles',
#   'description': 'Launched on 06/07/2020, Changelly PRO is a centralized exchange located at 306 Victoria House, Victoria Mahe, Seychelles. It is a professional version of the instant swap platform Changelly. Changelly PRO aims to serve the fast growing Changelly community that has been requesting professional trading features as well as foster the onboarding of beginners to advanced trading. The PRO version has spot and margin trading as well as fiat on-ramp solution.\r\nPRO offers:\r\n• Multi-currency wallet to store a variety of coins\r\n• Interactive and customizable terminal\r\n• Access to 50+ markets\r\n• Competitive trading fees starting from 0.1% both for makers and takers\r\n• Lowest withdrawal fees on the most popular coins and tokens such as BTC, ETH, XRP\r\n• Simple registration process with several verification levels',
#   'url': 'https://pro.changelly.com/',
#   'image': 'https://assets.coingecko.com/markets/images/580/small/pro_logo_cmc.png?1600833621',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 25,
#   'trade_volume_24h_btc': 43533.82340225948,
#   'trade_volume_24h_btc_normalized': 43533.82340225948},
#  {'id': 'biki',
#   'name': 'BiKi',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': 'BiKi is a centralized cryptocurrency exchange located in Singapore. There are 470 coins and 515 trading pairs on the exchange. BiKi volume in the last 24 hours is reported to be at ₿20,541.23. The most active trading pair on BiKi exchange is ETH/USDT. BiKi is established in year 2018.\r\n\r\nMore information about BiKi exchange can be found at https://www.biki.cc/register?inviteCode=WWAETAA. ',
#   'url': 'https://www.biki.cc/',
#   'image': 'https://assets.coingecko.com/markets/images/384/small/BiKi_icon.png?1573632986',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 26,
#   'trade_volume_24h_btc': 43203.34260909101,
#   'trade_volume_24h_btc_normalized': 43203.34260909101},
#  {'id': 'lbank',
#   'name': 'LBank',
#   'year_established': 2017,
#   'country': 'China',
#   'description': "Founded in October 2016, LBank is a centralized digital asset trading platform for international users. It aims to provide professional asset management solutions. At present, LBank offers hundreds of digital currency pairs. LBank also claims to have one of the highest staking rewards on any exchange.\r\n\r\nLBank's claims that its core team comes from the traditional financial industry, IT, and top 500 universities. The team aims to build the most professional integrated service platform for digital assets while ensuring security.",
#   'url': 'https://www.lbank.info/',
#   'image': 'https://assets.coingecko.com/markets/images/118/small/LBank%E5%9C%86%E6%A0%87.png?1572923264',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 27,
#   'trade_volume_24h_btc': 33645.31687030358,
#   'trade_volume_24h_btc_normalized': 33645.31687030358},
#  {'id': 'hoo',
#   'name': 'Hoo.com',
#   'year_established': 2019,
#   'country': 'Hong Kong',
#   'description': 'Hoo.com is a world’s leading blockchain assets service platform, aiming to provide safe and reliable assets management and blockchain services to users worldwide. ',
#   'url': 'https://www.hoo.com',
#   'image': 'https://assets.coingecko.com/markets/images/526/small/Hoo_Logo2.jpg?1602237762',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 28,
#   'trade_volume_24h_btc': 29773.405050326885,
#   'trade_volume_24h_btc_normalized': 29773.405050326885},
#  {'id': 'bigone',
#   'name': 'BigONE',
#   'year_established': 2017,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://bigone.com',
#   'image': 'https://assets.coingecko.com/markets/images/100/small/qcFFufEY_400x400.jpg?1561103345',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 29,
#   'trade_volume_24h_btc': 24061.858891782984,
#   'trade_volume_24h_btc_normalized': 24061.858891782984},
#  {'id': 'coinsbit',
#   'name': 'Coinsbit',
#   'year_established': None,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://coinsbit.io/',
#   'image': 'https://assets.coingecko.com/markets/images/267/small/Coinsbit.png?1605153697',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 30,
#   'trade_volume_24h_btc': 20634.041413167757,
#   'trade_volume_24h_btc_normalized': 20634.041413167757},
#  {'id': 'bitmart',
#   'name': 'BitMart',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.bitmart.com/en',
#   'image': 'https://assets.coingecko.com/markets/images/239/small/BitMart_logo.png?1611891118',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 31,
#   'trade_volume_24h_btc': 14377.442830079897,
#   'trade_volume_24h_btc_normalized': 14377.442830079897},
#  {'id': 'bitforex',
#   'name': 'Bitforex',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.bitforex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/214/small/BitForex-Logo.png?1573808227',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 32,
#   'trade_volume_24h_btc': 13894.626833821934,
#   'trade_volume_24h_btc_normalized': 13894.626833821934},
#  {'id': 'bitget',
#   'name': 'Bitget',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.bitget.com/',
#   'image': 'https://assets.coingecko.com/markets/images/540/small/bitget-logo-1.png?1591831975',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 33,
#   'trade_volume_24h_btc': 12977.049462201825,
#   'trade_volume_24h_btc_normalized': 12977.049462201825},
#  {'id': 'bitflyer',
#   'name': 'bitFlyer',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://bitflyereuropesa.pxf.io/c/2223866/858437/11990',
#   'image': 'https://assets.coingecko.com/markets/images/5/small/bitflyer.jpg?1519611556',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 34,
#   'trade_volume_24h_btc': 8440.365323808803,
#   'trade_volume_24h_btc_normalized': 8440.365323808803},
#  {'id': 'ftx_us',
#   'name': 'FTX.US',
#   'year_established': 2020,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://ftx.us/',
#   'image': 'https://assets.coingecko.com/markets/images/532/small/FTX-US.jpg?1609051756',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 35,
#   'trade_volume_24h_btc': 6010.897427665074,
#   'trade_volume_24h_btc_normalized': 6010.897427665074},
#  {'id': 'bitkub',
#   'name': 'Bitkub',
#   'year_established': 2018,
#   'country': 'Thailand',
#   'description': '',
#   'url': 'https://www.bitkub.com',
#   'image': 'https://assets.coingecko.com/markets/images/249/small/bitkub.png?1537180687',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 36,
#   'trade_volume_24h_btc': 5481.825150376502,
#   'trade_volume_24h_btc_normalized': 5481.825150376502},
#  {'id': 'bitmax',
#   'name': 'AscendEX (BitMax)',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': 'AscendEX (formerly BitMax) is a leading global digital asset financial platform founded by a group of Wall Street quantitative trading veterans in 2018, building on core value of “Efficiency, Resilience and Transparency.” \r\n \r\nDriven by its continuous innovative product development and early-mover advantage in strategic alignment with the leading projects from DeFi ecosystem, AscendEX offers trading services across over 200 trading pairs across cash, margin, and futures products, in particular margin trading of over 50 tokens in cross-asset collateral mode and futures trading in both cross-asset and isolated margin modes.',
#   'url': 'https://ascendex.com/en/global-digital-asset-platform',
#   'image': 'https://assets.coingecko.com/markets/images/277/small/AscendEX.png?1616471675',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 37,
#   'trade_volume_24h_btc': 4208.455227011334,
#   'trade_volume_24h_btc_normalized': 4208.455227011334},
#  {'id': 'indodax',
#   'name': 'Indodax',
#   'year_established': 2014,
#   'country': 'Indonesia',
#   'description': '',
#   'url': 'https://indodax.com',
#   'image': 'https://assets.coingecko.com/markets/images/3/small/logogram-Indodax-new-_JPG_format.jpg?1580974378',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 38,
#   'trade_volume_24h_btc': 4111.6777335292445,
#   'trade_volume_24h_btc_normalized': 4111.6777335292445},
#  {'id': 'etorox',
#   'name': 'eToroX',
#   'year_established': 2019,
#   'country': 'Gibraltar',
#   'description': 'eToroX is eToro’s professional crypto exchange. Designed exclusively for the corporate and institutional-grade crypto trading community, the eToroX exchange is a highly effective, trusted and secure crypto trading solution, which is licensed and regulated by the Gibraltar Financial Services Commission under the Investments and Financial Fiduciary Services Act (licence number FSC1333B). eToroX currently has more than 30 digital assets, including 17 tokenized fiat and commodity stablecoins, and more than 100 trading pairs.',
#   'url': 'https://www.etorox.com/',
#   'image': 'https://assets.coingecko.com/markets/images/503/small/eToroX_Logo_400x400.jpg?1580209571',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 39,
#   'trade_volume_24h_btc': 3701.0451992494845,
#   'trade_volume_24h_btc_normalized': 3701.0451992494845},
#  {'id': 'dextrade',
#   'name': 'Dex-Trade',
#   'year_established': 2019,
#   'country': 'United Kingdom',
#   'description': 'Dex-Trade is young but the most technical equiped crypto exchange, it offers traders easy-to-use interface and transactions safity. Since 2018, Dex-Trade team has the most fully range of security measures and security risk control measures in the industry. Dex-Trade welcomes global users and continues to expands digital currency in various countries to provide users with global trading opportunities. High-quality currencies are listed on Dex-Trade to offer traders comprehensive range of digital assets. By your side 24 hours a day, our support team will assist you with any issue or question you may have.',
#   'url': 'https://dex-trade.com/',
#   'image': 'https://assets.coingecko.com/markets/images/380/small/Dex-Trade_logo_new.png?1599629803',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 40,
#   'trade_volume_24h_btc': 1036.6738078659882,
#   'trade_volume_24h_btc_normalized': 1036.6738078659882},
#  {'id': 'aax',
#   'name': 'AAX',
#   'year_established': 2019,
#   'country': None,
#   'description': 'AAX is the world’s first cryptocurrency exchange to be powered by LSEG Technology’s Millennium Exchange, the same matching engine at the heart of tier-one capital markets. AAX is a member of London Stock Exchange Group’s global ‘Partner Platform’. Offering OTC, Spot, and Futures trading, quoting more than 50 cryptocurrency pairs and listing 5 perpetual futures contracts for Bitcoin, Ether, Litecoin, Ripple, and EOS, which can be traded with high leverage, AAX provides a secure, deeply liquid, ultra-low latency and fully compliant trading platform. It offers an institutional-grade platform, for everyone. ',
#   'url': 'https://www.aax.com',
#   'image': 'https://assets.coingecko.com/markets/images/527/small/aax_app_logo.png?1586779427',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 41,
#   'trade_volume_24h_btc': 727.2602467528874,
#   'trade_volume_24h_btc_normalized': 727.2602467528874},
#  {'id': 'max_maicoin',
#   'name': 'Max Maicoin',
#   'year_established': None,
#   'country': 'Taiwan',
#   'description': '',
#   'url': 'https://max.maicoin.com',
#   'image': 'https://assets.coingecko.com/markets/images/218/small/max.jpg?1533888641',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 42,
#   'trade_volume_24h_btc': 526.5129674732522,
#   'trade_volume_24h_btc_normalized': 526.5129674732522},
#  {'id': 'bitopro',
#   'name': 'BitoPro',
#   'year_established': 2018,
#   'country': 'Taiwan',
#   'description': '',
#   'url': 'https://www.bitopro.com/',
#   'image': 'https://assets.coingecko.com/markets/images/358/small/bitopro_coingecko_250x250_%281%29.png?1575884378',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 43,
#   'trade_volume_24h_btc': 380.5429766972606,
#   'trade_volume_24h_btc_normalized': 380.5429766972606},
#  {'id': 'narkasa',
#   'name': 'Narkasa',
#   'year_established': 2020,
#   'country': 'Turkey',
#   'description': '',
#   'url': 'https://narkasa.com/',
#   'image': 'https://assets.coingecko.com/markets/images/573/small/narkasa.jpg?1599029564',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 44,
#   'trade_volume_24h_btc': 55.69130709295878,
#   'trade_volume_24h_btc_normalized': 55.69130709295878},
#  {'id': 'kuna',
#   'name': 'Kuna Exchange',
#   'year_established': None,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://kuna.io/',
#   'image': 'https://assets.coingecko.com/markets/images/97/small/kuna_exchange.png?1545126178',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 45,
#   'trade_volume_24h_btc': 40.283005130529695,
#   'trade_volume_24h_btc_normalized': 40.283005130529695},
#  {'id': 'upbit',
#   'name': 'Upbit',
#   'year_established': 2017,
#   'country': 'South Korea',
#   'description': None,
#   'url': 'https://upbit.com',
#   'image': 'https://assets.coingecko.com/markets/images/117/small/upbit.png?1520388800',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 46,
#   'trade_volume_24h_btc': 271191.04037764936,
#   'trade_volume_24h_btc_normalized': 271191.04037764936},
#  {'id': 'xt',
#   'name': 'XT.COM',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.xt.com/',
#   'image': 'https://assets.coingecko.com/markets/images/404/small/logo400x400.png?1575881839',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 47,
#   'trade_volume_24h_btc': 116934.16583005787,
#   'trade_volume_24h_btc_normalized': 116934.16583005787},
#  {'id': 'digifinex',
#   'name': 'Digifinex',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.digifinex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/225/small/DF_logo.png?1594264355',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 48,
#   'trade_volume_24h_btc': 116490.99215859507,
#   'trade_volume_24h_btc_normalized': 116490.99215859507},
#  {'id': 'bitrue',
#   'name': 'Bitrue',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.bitrue.com/',
#   'image': 'https://assets.coingecko.com/markets/images/254/small/bitrue-exchange.jpg?1537878894',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 49,
#   'trade_volume_24h_btc': 66090.74787229364,
#   'trade_volume_24h_btc_normalized': 66090.74787229364},
#  {'id': 'coinhe',
#   'name': 'CoinHe',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://coinhe.io/',
#   'image': 'https://assets.coingecko.com/markets/images/458/small/coinhe.png?1565866997',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 50,
#   'trade_volume_24h_btc': 46354.992636926116,
#   'trade_volume_24h_btc_normalized': 46354.992636926116},
#  {'id': 'mxc',
#   'name': 'MXC',
#   'year_established': 2018,
#   'country': None,
#   'description': 'Launched in Apr 2018, MXC is a centralized cryptocurrency exchange registered in Seychelles. It supports CNY, VND, USD, GBP, EUR, AUD deposit, and CNY, VND withdrawal.',
#   'url': 'https://www.mxc.com/',
#   'image': 'https://assets.coingecko.com/markets/images/409/small/MXC.png?1558593762',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 51,
#   'trade_volume_24h_btc': 30129.03432449163,
#   'trade_volume_24h_btc_normalized': 30129.03432449163},
#  {'id': 'whitebit',
#   'name': 'WhiteBIT',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://whitebit.com',
#   'image': 'https://assets.coingecko.com/markets/images/418/small/wb_3_avatar-02.png?1611212424',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 52,
#   'trade_volume_24h_btc': 24918.822906719513,
#   'trade_volume_24h_btc_normalized': 24918.822906719513},
#  {'id': 'paribu',
#   'name': 'Paribu',
#   'year_established': None,
#   'country': 'Turkey',
#   'description': None,
#   'url': 'https://www.paribu.com/',
#   'image': 'https://assets.coingecko.com/markets/images/136/small/paribu.jpg?1527734779',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 53,
#   'trade_volume_24h_btc': 20859.393365957865,
#   'trade_volume_24h_btc_normalized': 20859.393365957865},
#  {'id': 'coinone',
#   'name': 'Coinone',
#   'year_established': 2016,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://coinone.co.kr/',
#   'image': 'https://assets.coingecko.com/markets/images/20/small/coinone_circle_500x500.png?1606460853',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 54,
#   'trade_volume_24h_btc': 20299.310950956966,
#   'trade_volume_24h_btc_normalized': 20299.310950956966},
#  {'id': 'omgfin',
#   'name': 'Omgfin',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://omgfin.com/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/396/small/Screenshot_11.png?1556858288',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 55,
#   'trade_volume_24h_btc': 18960.365885961826,
#   'trade_volume_24h_btc_normalized': 18960.365885961826},
#  {'id': 'cbx',
#   'name': 'CBX',
#   'year_established': 2018,
#   'country': 'United Arab Emirates',
#   'description': '',
#   'url': 'https://www.cbx.one',
#   'image': 'https://assets.coingecko.com/markets/images/355/small/cbx.jpg?1581414643',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 56,
#   'trade_volume_24h_btc': 17833.13257190655,
#   'trade_volume_24h_btc_normalized': 17833.13257190655},
#  {'id': 'oceanex',
#   'name': 'Oceanex',
#   'year_established': 2018,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://oceanex.pro',
#   'image': 'https://assets.coingecko.com/markets/images/341/small/Oceanex.png?1548153658',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 57,
#   'trade_volume_24h_btc': 14403.85801014856,
#   'trade_volume_24h_btc_normalized': 14403.85801014856},
#  {'id': 'btcturk',
#   'name': 'BtcTurk PRO',
#   'year_established': None,
#   'country': 'Turkey',
#   'description': '',
#   'url': 'https://pro.btcturk.com/',
#   'image': 'https://assets.coingecko.com/markets/images/223/small/BTCTurk-exchange.jpg?1536726120',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 58,
#   'trade_volume_24h_btc': 12326.11152349137,
#   'trade_volume_24h_btc_normalized': 12326.11152349137},
#  {'id': 'probit',
#   'name': 'ProBit',
#   'year_established': 2017,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.probit.com/',
#   'image': 'https://assets.coingecko.com/markets/images/370/small/probit.png?1594886584',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 59,
#   'trade_volume_24h_btc': 8646.364077973176,
#   'trade_volume_24h_btc_normalized': 8646.364077973176},
#  {'id': 'bitbank',
#   'name': 'Bitbank',
#   'year_established': 2016,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://bitbank.cc/',
#   'image': 'https://assets.coingecko.com/markets/images/122/small/bitbank.jpg?1521186278',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 60,
#   'trade_volume_24h_btc': 8023.373979328432,
#   'trade_volume_24h_btc_normalized': 8023.373979328432},
#  {'id': 'coineal',
#   'name': 'Coineal',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': None,
#   'url': 'https://www.coineal.com/',
#   'image': 'https://assets.coingecko.com/markets/images/289/small/1537958245x-1566680256.png?1539679939',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 61,
#   'trade_volume_24h_btc': 7368.350577044814,
#   'trade_volume_24h_btc_normalized': 7368.350577044814},
#  {'id': 'poloniex',
#   'name': 'Poloniex',
#   'year_established': 2014,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://poloniex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/37/small/poloniex.jpg?1519639007',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 62,
#   'trade_volume_24h_btc': 6950.353319143658,
#   'trade_volume_24h_btc_normalized': 6950.353319143658},
#  {'id': 'aex',
#   'name': 'AEX',
#   'year_established': 2013,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.aex.cool/',
#   'image': 'https://assets.coingecko.com/markets/images/449/small/aex.png?1596082957',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 63,
#   'trade_volume_24h_btc': 5726.663235278424,
#   'trade_volume_24h_btc_normalized': 5726.663235278424},
#  {'id': 'coincheck',
#   'name': 'Coincheck',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://coincheck.com/',
#   'image': 'https://assets.coingecko.com/markets/images/18/small/Coincheck.jpg?1519703836',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 64,
#   'trade_volume_24h_btc': 2768.586555348105,
#   'trade_volume_24h_btc_normalized': 2768.586555348105},
#  {'id': 'gopax',
#   'name': 'GoPax',
#   'year_established': 2016,
#   'country': 'South Korea',
#   'description': None,
#   'url': 'https://www.gopax.co.kr/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/144/small/gopax.jpg?1523527412',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 65,
#   'trade_volume_24h_btc': 2429.5787426381057,
#   'trade_volume_24h_btc_normalized': 2429.5787426381057},
#  {'id': 'emirex',
#   'name': 'Emirex',
#   'year_established': 2019,
#   'country': 'Estonia',
#   'description': 'Launched on 10/09/2019, Emirex is a centralized exchange located at 405, Al Saaha Offices C, Dubai, UAE. It supports USD, EUR, AED fiat pairs/OTC/IEOs',
#   'url': 'https://www.emirex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/592/small/Emirex.png?1602067691',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 66,
#   'trade_volume_24h_btc': 2366.9606472078412,
#   'trade_volume_24h_btc_normalized': 2366.9606472078412},
#  {'id': 'nominex',
#   'name': 'Nominex',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': 'New trading platform for convenient trading experience with low fees and numerous instruments. \r\n\r\nAbsolutely unique affiliate program that allows to earn from an infinite number of referral levels, compared to 2-3 levels at all other exchanges. \r\n\r\nA unique model for the free 2 phases distribution of the native NMX token.\r\n\r\nAdvanced Trading Instruments – using Stop, Stop Limit, Trailing Stop, Scaled and other types of orders brings some kind of trading automation without the need to develop a trading bot, which allows to easily get more profit while trading.',
#   'url': 'https://www.nominex.io',
#   'image': 'https://assets.coingecko.com/markets/images/530/small/logo-200x200.png?1587543672',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 67,
#   'trade_volume_24h_btc': 2224.3227392103113,
#   'trade_volume_24h_btc_normalized': 2224.3227392103113},
#  {'id': 'alterdice',
#   'name': 'AlterDice',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://alterdice.com/',
#   'image': 'https://assets.coingecko.com/markets/images/327/small/alterdice_%281%29.png?1604294926',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 68,
#   'trade_volume_24h_btc': 1863.2070478244154,
#   'trade_volume_24h_btc_normalized': 1863.2070478244154},
#  {'id': 'korbit',
#   'name': 'Korbit',
#   'year_established': 2013,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://www.korbit.co.kr/',
#   'image': 'https://assets.coingecko.com/markets/images/28/small/korbit-logo.png?1584091827',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 69,
#   'trade_volume_24h_btc': 1624.7830436183963,
#   'trade_volume_24h_btc_normalized': 1624.7830436183963},
#  {'id': 'luno',
#   'name': 'Luno',
#   'year_established': 2013,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.luno.com',
#   'image': 'https://assets.coingecko.com/markets/images/33/small/luno.jpg?1519996997',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 70,
#   'trade_volume_24h_btc': 1456.391358264742,
#   'trade_volume_24h_btc_normalized': 1456.391358264742},
#  {'id': 'okcoin',
#   'name': 'Okcoin',
#   'year_established': 2013,
#   'country': 'United States',
#   'description': 'About OKCoin:\r\nOKCoin is one of the largest and most trusted fiat-to-crypto trading platforms in the world. Founded in 2013, OKCoin offers advanced features for crypto beginners and high-volume traders alike, enabling users in 184 countries worldwide to exchange US dollars and the euro for Bitcoin, Tethers, USDK, Bitcoin Cash, Ethereum, Ethereum Classic, Decred, EOS, Litecoin, XRP, Cardano, 0x, Stellar, Zcash, TRX, and other digital assets. As a registered Money Services Business (MSB) with the Financial Crimes Enforcement Network (FinCEN) and a Virtual Financial Asset Act (VFAA) exchange with a transitory provision permissioned by the Malta Financial Services Authority, OKCoin is on a mission to make digital assets accessible to the world while complying with the highest of regulatory standards. For more information, visit www.okcoin.com. ',
#   'url': 'https://www.okcoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/415/small/okcoin_Logomark_SatoshiBlack.png?1619574335',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 71,
#   'trade_volume_24h_btc': 956.2038377956718,
#   'trade_volume_24h_btc_normalized': 956.2038377956718},
#  {'id': 'atomars',
#   'name': 'Atomars',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://atomars.com',
#   'image': 'https://assets.coingecko.com/markets/images/457/small/logo-ATOMARS-black.png?1565004325',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 72,
#   'trade_volume_24h_btc': 915.1762496612617,
#   'trade_volume_24h_btc_normalized': 915.1762496612617},
#  {'id': 'cryptology',
#   'name': 'Cryptology',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://cryptology.com/',
#   'image': 'https://assets.coingecko.com/markets/images/287/small/cryptology.png?1541390904',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 73,
#   'trade_volume_24h_btc': 710.4716240874153,
#   'trade_volume_24h_btc_normalized': 710.4716240874153},
#  {'id': 'blockchain_com',
#   'name': 'Blockchain.com',
#   'year_established': 2012,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://www.blockchain.com/',
#   'image': 'https://assets.coingecko.com/markets/images/613/small/unnamedddd.png?1610503741',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 74,
#   'trade_volume_24h_btc': 685.4750405178464,
#   'trade_volume_24h_btc_normalized': 685.4750405178464},
#  {'id': 'btcmarkets',
#   'name': 'BTCMarkets',
#   'year_established': None,
#   'country': 'Australia',
#   'description': '',
#   'url': 'https://www.btcmarkets.net/',
#   'image': 'https://assets.coingecko.com/markets/images/237/small/btcmarkets-exchange.jpg?1536726060',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 75,
#   'trade_volume_24h_btc': 658.4040017357471,
#   'trade_volume_24h_btc_normalized': 658.4040017357471},
#  {'id': 'independent_reserve',
#   'name': 'Independent Reserve',
#   'year_established': 2013,
#   'country': 'Australia',
#   'description': '',
#   'url': 'https://www.independentreserve.com/',
#   'image': 'https://assets.coingecko.com/markets/images/389/small/x_V5Jquo_400x400.png?1556071437',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 76,
#   'trade_volume_24h_btc': 487.05093228918014,
#   'trade_volume_24h_btc_normalized': 487.05093228918014},
#  {'id': 'zaif',
#   'name': 'Zaif',
#   'year_established': 2015,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://zaif.jp/',
#   'image': 'https://assets.coingecko.com/markets/images/99/small/zaif.png?1519627467',
#   'has_trading_incentive': None,
#   'trust_score': 6,
#   'trust_score_rank': 77,
#   'trade_volume_24h_btc': 427.952929710606,
#   'trade_volume_24h_btc_normalized': 427.952929710606},
#  {'id': 'bitpanda',
#   'name': 'Bitpanda Pro',
#   'year_established': 2014,
#   'country': 'Austria',
#   'description': '',
#   'url': 'https://exchange.bitpanda.com',
#   'image': 'https://assets.coingecko.com/markets/images/474/small/bitpanda-pro.png?1619079941',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 78,
#   'trade_volume_24h_btc': 392.1794818512491,
#   'trade_volume_24h_btc_normalized': 392.1794818512491},
#  {'id': 'mercado_bitcoin',
#   'name': 'Mercado Bitcoin',
#   'year_established': 2016,
#   'country': 'Brazil',
#   'description': None,
#   'url': 'https://www.mercadobitcoin.com.br/',
#   'image': 'https://assets.coingecko.com/markets/images/34/small/mercado.png?1520923694',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 79,
#   'trade_volume_24h_btc': 376.5275523699773,
#   'trade_volume_24h_btc_normalized': 376.5275523699773},
#  {'id': 'itbit',
#   'name': 'itBit',
#   'year_established': 2013,
#   'country': 'United States',
#   'description': None,
#   'url': 'https://www.itbit.com/',
#   'image': 'https://assets.coingecko.com/markets/images/26/small/itbit.png?1519810172',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 80,
#   'trade_volume_24h_btc': 993.923133963237,
#   'trade_volume_24h_btc_normalized': 0.0},
#  {'id': 'vcc',
#   'name': 'VCC Exchange',
#   'year_established': 2019,
#   'country': 'Vietnam',
#   'description': 'Launched on May 19, 2019, VCC Exchange is an exchange based in Singapore, operates in Vietnam. It has worked with the government in few initiatives including Dialogue on blockchain-based applications’ legal framework (https://bit.ly/32SJVl2) and Vietnam Blockchain Startup (https://bit.ly/341Iv7Q).\r\n\r\nVCC supports trading crypto-crypto, VND-crypto in web, iOS and Android applications. VCC Exchange is backed by Signum Capital and Axiom Associates Capital. It currently supports trading fee of 0%.',
#   'url': 'https://vcc.exchange',
#   'image': 'https://assets.coingecko.com/markets/images/500/small/VCC_Logo_200x200.jpg?1576147069',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 81,
#   'trade_volume_24h_btc': 278653.41577289224,
#   'trade_volume_24h_btc_normalized': 278653.41577289224},
#  {'id': 'bitoffer',
#   'name': 'Bitoffer',
#   'year_established': 2019,
#   'country': 'Hong Kong',
#   'description': '',
#   'url': 'https://www.bitoffer.com/en',
#   'image': 'https://assets.coingecko.com/markets/images/456/small/S1naTFE.png?1565005583',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 82,
#   'trade_volume_24h_btc': 98464.33542864796,
#   'trade_volume_24h_btc_normalized': 98464.33542864796},
#  {'id': 'bidesk',
#   'name': 'Bidesk',
#   'year_established': 2019,
#   'country': 'British Virgin Islands',
#   'description': 'Bidesk exchange is a digital asset trading platform aiming to provide a secure and safe platform for trading liquidity of in demand and quality tokens with a class user experience. Its advanced fast matching engine, 24/7 customer support and high-grade financial support services are expected to maximize the wealth growth opportunities to its users. ',
#   'url': 'https://www.bidesk.com/',
#   'image': 'https://assets.coingecko.com/markets/images/545/small/bidesk.png?1593787873',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 83,
#   'trade_volume_24h_btc': 56311.420437972105,
#   'trade_volume_24h_btc_normalized': 56311.420437972105},
#  {'id': 'hitbtc',
#   'name': 'HitBTC',
#   'year_established': 2013,
#   'country': None,
#   'description': 'HitBTC is the world’s most advanced cryptocurrency exchange. Since 2013, HitBTC has been providing markets for Bitcoin, Ethereum, Litecoin, Dogecoin, Monero, USDT, and more than 300 cryptocurrencies in total.\r\n\r\nCreated by outstanding technical minds, high-level finance professionals and experienced traders, HitBTC delivers the most reliable, fast and powerful platform solution on the market.\r\n\r\nThe platform has earned its reputation for fault-tolerance, flawless uptime and high availability. Its core matching engine is among the best technological products in its class, offering traders a wide range of features such as real-time clearing and cutting-edge order matching algorithms.\r\n\r\nKey Features:\r\nRebate system - attractive to the most powerful market makers, creating high liquidity\r\nNo limits on the deposit or withdrawal of digital assets\r\nCutting-edge matching engine technologies\r\nWide range of available instruments (more than 500)\r\nThe most advanced API on the market (REST API and FIX API)\r\nAccess to the crypto assets exchange platform technology under the registered trademark “HitBTC” is provided in accordance with the Terms of Service.',
#   'url': 'https://hitbtc.com/',
#   'image': 'https://assets.coingecko.com/markets/images/24/small/hitbtc.png?1603975458',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 84,
#   'trade_volume_24h_btc': 53067.02685647881,
#   'trade_volume_24h_btc_normalized': 53067.02685647881},
#  {'id': 'uniswap_v2',
#   'name': 'Uniswap (v2)',
#   'year_established': 2018,
#   'country': None,
#   'description': '',
#   'url': 'https://app.uniswap.org/#/swap?use=V2',
#   'image': 'https://assets.coingecko.com/markets/images/535/small/256x256_Black-1.png?1590893262',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 85,
#   'trade_volume_24h_btc': 46286.33338641596,
#   'trade_volume_24h_btc_normalized': 46286.33338641596},
#  {'id': 'bkex',
#   'name': 'BKEX',
#   'year_established': 2018,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://www.bkex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/293/small/logo.png?1588125944',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 86,
#   'trade_volume_24h_btc': 41022.6080151113,
#   'trade_volume_24h_btc_normalized': 41022.6080151113},
#  {'id': 'bw',
#   'name': 'BW.com',
#   'year_established': 2017,
#   'country': None,
#   'description': '',
#   'url': 'https://www.bw.com/',
#   'image': 'https://assets.coingecko.com/markets/images/326/small/bw.com.jpg?1548664400',
#   'has_trading_incentive': False,
#   'trust_score': 5,
#   'trust_score_rank': 87,
#   'trade_volume_24h_btc': 25594.3466429963,
#   'trade_volume_24h_btc_normalized': 25594.3466429963},
#  {'id': 'pancakeswap',
#   'name': 'PancakeSwap (v2)',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://pancakeswap.finance',
#   'image': 'https://assets.coingecko.com/markets/images/657/small/pancakeswap.png?1619272176',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 88,
#   'trade_volume_24h_btc': 21333.286235513406,
#   'trade_volume_24h_btc_normalized': 21333.286235513406},
#  {'id': 'bibox',
#   'name': 'Bibox',
#   'year_established': 2017,
#   'country': 'China',
#   'description': '',
#   'url': 'https://www.bibox.com/',
#   'image': 'https://assets.coingecko.com/markets/images/114/small/bibox.jpg?1520752603',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 89,
#   'trade_volume_24h_btc': 20283.20853666662,
#   'trade_volume_24h_btc_normalized': 20283.20853666662},
#  {'id': 'flybit',
#   'name': 'Flybit',
#   'year_established': 2018,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://flybit.com',
#   'image': 'https://assets.coingecko.com/markets/images/655/small/flybit_logo_%EA%B0%80%EB%A1%9C%ED%98%95.png?1619148627',
#   'has_trading_incentive': True,
#   'trust_score': 6,
#   'trust_score_rank': 90,
#   'trade_volume_24h_btc': 15894.288330895914,
#   'trade_volume_24h_btc_normalized': 15894.288330895914},
#  {'id': 'phemex',
#   'name': 'Phemex',
#   'year_established': 2019,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://phemex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/564/small/phemex_logo.jpg?1596681293',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 91,
#   'trade_volume_24h_btc': 14583.596594302748,
#   'trade_volume_24h_btc_normalized': 14583.596594302748},
#  {'id': 'exmarkets',
#   'name': 'ExMarkets',
#   'year_established': 2018,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://exmarkets.com',
#   'image': 'https://assets.coingecko.com/markets/images/363/small/42200149_2115011248752220_3911078373144657920_n.jpg?1551247813',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 92,
#   'trade_volume_24h_btc': 12287.11014408112,
#   'trade_volume_24h_btc_normalized': 12287.11014408112},
#  {'id': 'btc_alpha',
#   'name': 'BTC-Alpha',
#   'year_established': 2016,
#   'country': None,
#   'description': None,
#   'url': 'https://btc-alpha.com/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/155/small/btc_alpha.jpg?1526356352',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 93,
#   'trade_volume_24h_btc': 11491.589436268778,
#   'trade_volume_24h_btc_normalized': 11491.589436268778},
#  {'id': 'sushiswap',
#   'name': 'Sushiswap',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://app.sushi.com/swap',
#   'image': 'https://assets.coingecko.com/markets/images/576/small/2048x2048_Logo.png?1609208464',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 94,
#   'trade_volume_24h_btc': 10688.452218948212,
#   'trade_volume_24h_btc_normalized': 10688.452218948212},
#  {'id': 'uniswap',
#   'name': 'Uniswap (v3)',
#   'year_established': 2018,
#   'country': None,
#   'description': '',
#   'url': 'https://app.uniswap.org/#/swap',
#   'image': 'https://assets.coingecko.com/markets/images/665/small/uniswap-v3.png?1620241698',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 95,
#   'trade_volume_24h_btc': 10650.861100848662,
#   'trade_volume_24h_btc_normalized': 10650.861100848662},
#  {'id': 'pancakeswap_v1',
#   'name': 'PancakeSwap (v1)',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://v1exchange.pancakeswap.finance',
#   'image': 'https://assets.coingecko.com/markets/images/595/small/pancakeswap.png?1618240659',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 96,
#   'trade_volume_24h_btc': 7808.84688438209,
#   'trade_volume_24h_btc_normalized': 7808.84688438209},
#  {'id': 'p2pb2b',
#   'name': 'P2PB2B',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': "P2PB2B Exchange is not just a cryptocurrency exchange platform but also a trusted partner for crypto projects. Our Crypto Startup Partner initiative provides trading consulting and helps our clients develop their community, support liquidity, create growth strategies.\r\n\r\nP2PB2B runs token sales of the promising crypto assets, enabling users to easily invest in new currencies. There are also available services for users such as the earning deposit program, regular gamification events - airdrop, trading competitions, referral program games.\r\n\r\nThe platform is compliant with OWASP TOP 10 security requirements and is recognized as the world's 12th most Trust Core secure crypto exchanges according to CER rating.\r\n\r\nP2PB2B utilizes the high processing speed with the ability to handle up to 10,000 trades per second, scaling to 1,000,000 TCP connections. Our KYC identity verification process leverages AI-powered technology which speeds up the authentication process. 24/7 live support is an essential advantage for users.",
#   'url': 'https://p2pb2b.io',
#   'image': 'https://assets.coingecko.com/markets/images/251/small/p2pb2b.jpg?1536307348',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 97,
#   'trade_volume_24h_btc': 6820.446559812845,
#   'trade_volume_24h_btc_normalized': 6820.446559812845},
#  {'id': 'quoine',
#   'name': 'Liquid',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://liquid.com',
#   'image': 'https://assets.coingecko.com/markets/images/40/small/liquid.png?1536133472',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 98,
#   'trade_volume_24h_btc': 5498.458275865965,
#   'trade_volume_24h_btc_normalized': 5498.458275865965},
#  {'id': 'wazirx',
#   'name': 'WazirX',
#   'year_established': 2018,
#   'country': 'India',
#   'description': '',
#   'url': 'https://wazirx.com/',
#   'image': 'https://assets.coingecko.com/markets/images/274/small/wazirx.jpg?1540450020',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 99,
#   'trade_volume_24h_btc': 5573.4495282338885,
#   'trade_volume_24h_btc_normalized': 5573.4495282338885},
#  {'id': 'stormgain',
#   'name': 'Stormgain',
#   'year_established': None,
#   'country': None,
#   'description': 'StormGain is a crypto trading platform for everyone. It’s a convenient solution for those who want to profit from either the growth or decline of the cryptocurrency market and from long-term investments in crypto assets.\r\nAvailable on any device, StormGain allows you to start trading the most popular and most capitalised coins with a multiplier of up to 200x, or you can just buy and hodl crypto.',
#   'url': 'https://stormgain.com/?utm_id=1DSE&utm_source=coingecko_storm&utm_medium=media&utm_campaign=listing&utm_country=en',
#   'image': 'https://assets.coingecko.com/markets/images/608/small/CpDGk9Hn_400x400.png?1607582976',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 100,
#   'trade_volume_24h_btc': 3046.6911823272885,
#   'trade_volume_24h_btc_normalized': 3046.6911823272885}]

# %%
# List all supported markets id and name (no pagination required)
cg.get_exchanges_id_name_list()
# Out:
# [{'id': 'aave', 'name': 'Aave'},
#  {'id': 'aax', 'name': 'AAX'},
#  {'id': 'aax_futures', 'name': 'AAX Futures'},
#  {'id': 'abcc', 'name': 'ABCC'},
#  {'id': 'abit', 'name': 'Abit'},
#  {'id': 'acdx', 'name': 'ACDX'},
#  {'id': 'acdx_futures', 'name': 'ACDX Futures'},
#  {'id': 'aex', 'name': 'AEX'},
#  {'id': 'allbit', 'name': 'Allbit'},
#  {'id': 'allcoin', 'name': 'Allcoin'},
#  {'id': 'alpha_five', 'name': 'Alpha5'},
#  {'id': 'altcointrader', 'name': 'AltcoinTrader'},
#  {'id': 'alterdice', 'name': 'AlterDice'},
#  {'id': 'altilly', 'name': 'Altilly'},
#  {'id': 'altmarkets', 'name': 'Altmarkets'},
#  {'id': 'anyswap', 'name': 'Anyswap'},
#  {'id': 'apeswap', 'name': 'ApeSwap'},
#  {'id': 'aprobit', 'name': 'Aprobit'},
#  {'id': 'artisturba', 'name': 'Artis Turba'},
#  {'id': 'atomars', 'name': 'Atomars'},
#  {'id': 'b2bx', 'name': 'B2BX'},
#  {'id': 'bakeryswap', 'name': 'Bakeryswap'},
#  {'id': 'bakkt', 'name': 'Bakkt'},
#  {'id': 'balancer', 'name': 'Balancer'},
#  {'id': 'bamboo_relay', 'name': 'Bamboo Relay'},
#  {'id': 'bancor', 'name': 'Bancor Network'},
#  {'id': 'bankera', 'name': 'Bankera'},
#  {'id': 'basefex', 'name': 'BaseFEX'},
#  {'id': 'bcex', 'name': 'BCEX'},
#  {'id': 'beaxy', 'name': 'Beaxy'},
#  {'id': 'bepswap', 'name': 'BepSwap'},
#  {'id': 'bgogo', 'name': 'Bgogo'},
#  {'id': 'bibo', 'name': 'Bibo'},
#  {'id': 'bibox', 'name': 'Bibox'},
#  {'id': 'bibox_futures', 'name': 'Bibox (Futures)'},
#  {'id': 'biconomy', 'name': 'Biconomy'},
#  {'id': 'bidesk', 'name': 'Bidesk'},
#  {'id': 'bigone', 'name': 'BigONE'},
#  {'id': 'bigone_futures', 'name': 'BigONE Futures'},
#  {'id': 'biki', 'name': 'BiKi'},
#  {'id': 'biki_futures', 'name': 'Biki (Futures)'},
#  {'id': 'bilaxy', 'name': 'Bilaxy'},
#  {'id': 'binance', 'name': 'Binance'},
#  {'id': 'binance_dex', 'name': 'Binance DEX'},
#  {'id': 'binance_dex_mini', 'name': 'Binance DEX (Mini)'},
#  {'id': 'binance_futures', 'name': 'Binance (Futures)'},
#  {'id': 'binance_jersey', 'name': 'Binance Jersey'},
#  {'id': 'binance_us', 'name': 'Binance US'},
#  {'id': 'bione', 'name': 'BiONE'},
#  {'id': 'birake', 'name': 'Birake'},
#  {'id': 'bisq', 'name': 'Bisq'},
#  {'id': 'bit2c', 'name': 'Bit2c'},
#  {'id': 'bitalong', 'name': 'Bitalong'},
#  {'id': 'bitbank', 'name': 'Bitbank'},
#  {'id': 'bitbay', 'name': 'BitBay'},
#  {'id': 'bitbns', 'name': 'BitBNS'},
#  {'id': 'bitbox', 'name': 'BITFRONT'},
#  {'id': 'bitci', 'name': 'Bitci'},
#  {'id': 'bitcoin_com', 'name': 'Bitcoin.com Exchange'},
#  {'id': 'bit_com_futures', 'name': 'Bit.com'},
#  {'id': 'bitcratic', 'name': 'Bitcratic'},
#  {'id': 'bitex', 'name': 'Bitex.la'},
#  {'id': 'bitexbook', 'name': 'BITEXBOOK'},
#  {'id': 'bitexlive', 'name': 'Bitexlive'},
#  {'id': 'bitfex', 'name': 'Bitfex'},
#  {'id': 'bitfinex', 'name': 'Bitfinex'},
#  {'id': 'bitfinex_futures', 'name': 'Bitfinex (Futures)'},
#  {'id': 'bitflyer', 'name': 'bitFlyer'},
#  {'id': 'bitflyer_futures', 'name': 'Bitflyer (Futures)'},
#  {'id': 'bitforex', 'name': 'Bitforex'},
#  {'id': 'bitforex_futures', 'name': 'Bitforex (Futures)'},
#  {'id': 'bitget', 'name': 'Bitget'},
#  {'id': 'bitget_futures', 'name': 'Bitget Futures'},
#  {'id': 'bithash', 'name': 'BitHash'},
#  {'id': 'bitholic', 'name': 'Bithumb Singapore'},
#  {'id': 'bithumb', 'name': 'Bithumb'},
#  {'id': 'bithumb_futures', 'name': 'Bithumb (Futures)'},
#  {'id': 'bithumb_global', 'name': 'Bithumb Global'},
#  {'id': 'bitinfi', 'name': 'Bitinfi'},
#  {'id': 'bitkonan', 'name': 'BitKonan'},
#  {'id': 'bitkub', 'name': 'Bitkub'},
#  {'id': 'bitmart', 'name': 'BitMart'},
#  {'id': 'bitmax', 'name': 'AscendEX (BitMax)'},
#  {'id': 'bitmax_futures', 'name': 'AscendEX  (BitMax) (Futures)'},
#  {'id': 'bitmesh', 'name': 'Bitmesh'},
#  {'id': 'bitmex', 'name': 'BitMEX'},
#  {'id': 'bitoffer', 'name': 'Bitoffer'},
#  {'id': 'bitonbay', 'name': 'BitOnBay'},
#  {'id': 'bitopro', 'name': 'BitoPro'},
#  {'id': 'bitpanda', 'name': 'Bitpanda Pro'},
#  {'id': 'bitrabbit', 'name': 'BitRabbit'},
#  {'id': 'bitrue', 'name': 'Bitrue'},
#  {'id': 'bits_blockchain', 'name': 'Bits Blockchain'},
#  {'id': 'bitsdaq', 'name': 'Bitsdaq'},
#  {'id': 'bitso', 'name': 'Bitso'},
#  {'id': 'bitsonic', 'name': 'Bitsonic'},
#  {'id': 'bitstamp', 'name': 'Bitstamp'},
#  {'id': 'bitsten', 'name': 'Bitsten'},
#  {'id': 'bitstorage', 'name': 'BitStorage'},
#  {'id': 'bittrex', 'name': 'Bittrex'},
#  {'id': 'bitubu', 'name': 'Bitubu Exchange'},
#  {'id': 'bit_z', 'name': 'BitZ'},
#  {'id': 'bitz_futures', 'name': 'BitZ (Futures)'},
#  {'id': 'bkex', 'name': 'BKEX'},
#  {'id': 'bleutrade', 'name': 'bleutrade'},
#  {'id': 'blockchain_com', 'name': 'Blockchain.com'},
#  {'id': 'blockonix', 'name': 'Blockonix'},
#  {'id': 'boa', 'name': 'BOA Exchange'},
#  {'id': 'braziliex', 'name': 'Braziliex'},
#  {'id': 'bscswap', 'name': 'BSCswap'},
#  {'id': 'btc_alpha', 'name': 'BTC-Alpha'},
#  {'id': 'btcbox', 'name': 'BTCBOX'},
#  {'id': 'btcc', 'name': 'BTCC'},
#  {'id': 'btc_exchange', 'name': 'Btc Exchange'},
#  {'id': 'btcmarkets', 'name': 'BTCMarkets'},
#  {'id': 'btcmex', 'name': 'BTCMEX'},
#  {'id': 'btcnext', 'name': 'BTCNEXT'},
#  {'id': 'btcsquare', 'name': 'BTCSquare'},
#  {'id': 'btc_trade_ua', 'name': 'BTC Trade UA'},
#  {'id': 'btcturk', 'name': 'BtcTurk PRO'},
#  {'id': 'btse', 'name': 'BTSE'},
#  {'id': 'btse_futures', 'name': 'BTSE (Futures)'},
#  {'id': 'burgerswap', 'name': 'BurgerSwap'},
#  {'id': 'buyucoin', 'name': 'BuyUcoin'},
#  {'id': 'bvnex', 'name': 'Bvnex'},
#  {'id': 'bw', 'name': 'BW.com'},
#  {'id': 'bybit', 'name': 'Bybit'},
#  {'id': 'c2cx', 'name': 'C2CX'},
#  {'id': 'catex', 'name': 'Catex'},
#  {'id': 'cbx', 'name': 'CBX'},
#  {'id': 'ccex', 'name': 'C-CEX'},
#  {'id': 'cex', 'name': 'CEX.IO'},
#  {'id': 'chainex', 'name': 'ChainEX'},
#  {'id': 'changelly', 'name': 'Changelly PRO'},
#  {'id': 'chiliz', 'name': 'Chiliz'},
#  {'id': 'citex', 'name': 'CITEX'},
#  {'id': 'cme_futures', 'name': 'CME Bitcoin Futures'},
#  {'id': 'coinasset', 'name': 'CoinAsset'},
#  {'id': 'coinbene', 'name': 'CoinBene'},
#  {'id': 'coinbig', 'name': 'COINBIG'},
#  {'id': 'coinbit', 'name': 'Coinbit'},
#  {'id': 'coincheck', 'name': 'Coincheck'},
#  {'id': 'coindcx', 'name': 'CoinDCX'},
#  {'id': 'coindeal', 'name': 'Coindeal'},
#  {'id': 'coindirect', 'name': 'CoinDirect'},
#  {'id': 'coineal', 'name': 'Coineal'},
#  {'id': 'coin_egg', 'name': 'CoinEgg'},
#  {'id': 'coinex', 'name': 'CoinEx'},
#  {'id': 'coinfalcon', 'name': 'Coinfalcon'},
#  {'id': 'coinfield', 'name': 'Coinfield'},
#  {'id': 'coinflex', 'name': 'CoinFLEX'},
#  {'id': 'coinflex_futures', 'name': 'CoinFLEX (Futures)'},
#  {'id': 'coinfloor', 'name': 'Coinfloor'},
#  {'id': 'coingi', 'name': 'Coingi'},
#  {'id': 'coinhe', 'name': 'CoinHe'},
#  {'id': 'coinhub', 'name': 'Coinhub'},
#  {'id': 'coinjar', 'name': 'CoinJar Exchange'},
#  {'id': 'coinlim', 'name': 'Coinlim'},
#  {'id': 'coinlist', 'name': 'Coinlist'},
#  {'id': 'coinmargin', 'name': 'CoinMargin'},
#  {'id': 'coin_metro', 'name': 'CoinMetro'},
#  {'id': 'coinone', 'name': 'Coinone'},
#  {'id': 'coinpark', 'name': 'Coinpark'},
#  {'id': 'coinplace', 'name': 'Coinplace'},
#  {'id': 'coinsbank', 'name': 'Coinsbank'},
#  {'id': 'coinsbit', 'name': 'Coinsbit'},
#  {'id': 'coinsuper', 'name': 'Coinsuper'},
#  {'id': 'cointiger', 'name': 'CoinTiger'},
#  {'id': 'cointiger_futures', 'name': 'CoinTiger (Futures)'},
#  {'id': 'coinxpro', 'name': 'COINX.PRO'},
#  {'id': 'coinzo', 'name': 'Coinzo'},
#  {'id': 'coinzoom', 'name': 'Coinzoom'},
#  {'id': 'comethswap', 'name': 'ComethSwap'},
#  {'id': 'compound_finance', 'name': 'Compound Finance'},
#  {'id': 'c_patex', 'name': 'C-Patex'},
#  {'id': 'cpdax', 'name': 'CPDAX'},
#  {'id': 'crex24', 'name': 'CREX24'},
#  {'id': 'crxzone', 'name': 'CRXzone'},
#  {'id': 'cryptaldash', 'name': 'CryptalDash'},
#  {'id': 'cryptex', 'name': 'Cryptex'},
#  {'id': 'cryptlocex', 'name': 'Cryptlocex'},
#  {'id': 'crypto_com', 'name': 'Crypto.com'},
#  {'id': 'cryptology', 'name': 'Cryptology'},
#  {'id': 'crytrex', 'name': 'CryTrEx'},
#  {'id': 'c_trade', 'name': 'C-Trade'},
#  {'id': 'currency', 'name': 'Currency.com'},
#  {'id': 'curve', 'name': 'Curve Finance'},
#  {'id': 'cybex', 'name': 'Cybex DEX'},
#  {'id': 'daofi', 'name': 'DAOfi'},
#  {'id': 'darb_finance', 'name': 'Darb Finance'},
#  {'id': 'daybit', 'name': 'Daybit'},
#  {'id': 'dcoin', 'name': 'Dcoin'},
#  {'id': 'ddex', 'name': 'DDEX'},
#  {'id': 'decoin', 'name': 'Decoin'},
#  {'id': 'defi_swap', 'name': 'DeFi Swap'},
#  {'id': 'delta_futures', 'name': 'Delta Exchange (Futures)'},
#  {'id': 'delta_spot', 'name': 'Delta Exchange'},
#  {'id': 'dem_exchange', 'name': 'Demex'},
#  {'id': 'deribit', 'name': 'Deribit'},
#  {'id': 'deversifi', 'name': 'Deversifi '},
#  {'id': 'dex_blue', 'name': 'dex.blue'},
#  {'id': 'dextrade', 'name': 'Dex-Trade'},
#  {'id': 'digifinex', 'name': 'Digifinex'},
#  {'id': 'dmm', 'name': 'DMM'},
#  {'id': 'dobitrade', 'name': 'Dobitrade'},
#  {'id': 'dodo', 'name': 'DODO'},
#  {'id': 'dodo_bsc', 'name': 'Dodo BSC'},
#  {'id': 'dolomite', 'name': 'Dolomite'},
#  {'id': 'dove_wallet', 'name': 'Dove Wallet'},
#  {'id': 'dragonex', 'name': 'DragonEx'},
#  {'id': 'dsx', 'name': 'DSX Global'},
#  {'id': 'duedex', 'name': 'DueDEX'},
#  {'id': 'dydx', 'name': 'dYdX'},
#  {'id': 'dydx_perpetual', 'name': 'dYdX Perpetual'},
#  {'id': 'dydx_perpetual_l1', 'name': 'dYdX Perpetual (L1)'},
#  {'id': 'ecxx', 'name': 'Ecxx'},
#  {'id': 'elitex', 'name': 'Elitex'},
#  {'id': 'emirex', 'name': 'Emirex'},
#  {'id': 'equos', 'name': 'Equos.io'},
#  {'id': 'equos_perpetual', 'name': 'Equos.io (Perpetual)'},
#  {'id': 'eterbase', 'name': 'Eterbase'},
#  {'id': 'etherflyer', 'name': 'EtherFlyer'},
#  {'id': 'ethex', 'name': 'Ethex'},
#  {'id': 'etorox', 'name': 'eToroX'},
#  {'id': 'everbloom', 'name': 'Everbloom'},
#  {'id': 'exmarkets', 'name': 'ExMarkets'},
#  {'id': 'exmo', 'name': 'EXMO'},
#  {'id': 'exnce', 'name': 'EXNCE'},
#  {'id': 'exrates', 'name': 'Exrates'},
#  {'id': 'exx', 'name': 'EXX'},
#  {'id': 'fatbtc', 'name': 'FatBTC'},
#  {'id': 'fex', 'name': 'FEX'},
#  {'id': 'financex', 'name': 'FinanceX'},
#  {'id': 'finexbox', 'name': 'FinexBox'},
#  {'id': 'floatsv', 'name': 'Float SV'},
#  {'id': 'flybit', 'name': 'Flybit'},
#  {'id': 'forkdelta', 'name': 'ForkDelta'},
#  {'id': 'freiexchange', 'name': 'Freiexchange'},
#  {'id': 'ftx', 'name': 'FTX (Derivatives)'},
#  {'id': 'ftx_spot', 'name': 'FTX'},
#  {'id': 'ftx_us', 'name': 'FTX.US'},
#  {'id': 'futureswap', 'name': 'Futureswap'},
#  {'id': 'gate', 'name': 'Gate.io'},
#  {'id': 'gate_futures', 'name': 'Gate.io (Futures)'},
#  {'id': 'gbx', 'name': 'Global Blockchain Exchange'},
#  {'id': 'gdac', 'name': 'GDAC'},
#  {'id': 'gdax', 'name': 'Coinbase Pro'},
#  {'id': 'gemini', 'name': 'Gemini'},
#  {'id': 'getbtc', 'name': 'GetBTC'},
#  {'id': 'gmo_japan', 'name': 'GMO Japan'},
#  {'id': 'gmo_japan_futures', 'name': 'GMO Japan (Futures)'},
#  {'id': 'gobaba', 'name': 'Gobaba'},
#  {'id': 'goku', 'name': 'GokuMarket'},
#  {'id': 'gopax', 'name': 'GoPax'},
#  {'id': 'graviex', 'name': 'Graviex'},
#  {'id': 'hanbitco', 'name': 'Hanbitco'},
#  {'id': 'hbtc', 'name': 'BHEX'},
#  {'id': 'hbtc_futures', 'name': 'HBTC (Futures)'},
#  {'id': 'hb_top', 'name': 'Hb.top'},
#  {'id': 'hitbtc', 'name': 'HitBTC'},
#  {'id': 'honeyswap', 'name': 'Honeyswap'},
#  {'id': 'hoo', 'name': 'Hoo.com'},
#  {'id': 'hopex', 'name': 'Hopex'},
#  {'id': 'hotbit', 'name': 'Hotbit'},
#  {'id': 'hpx', 'name': 'HPX'},
#  {'id': 'hubi', 'name': 'Hubi'},
#  {'id': 'huobi', 'name': 'Huobi Global'},
#  {'id': 'huobi_dm', 'name': 'Huobi Futures'},
#  {'id': 'huobi_id', 'name': 'Huobi Indonesia'},
#  {'id': 'huobi_japan', 'name': 'Huobi Japan'},
#  {'id': 'huobi_korea', 'name': 'Huobi Korea'},
#  {'id': 'huobi_thailand', 'name': 'Huobi Thailand'},
#  {'id': 'ice3x', 'name': 'Ice3x'},
#  {'id': 'idcm', 'name': 'IDCM'},
#  {'id': 'idex', 'name': 'Idex'},
#  {'id': 'incorex', 'name': 'IncoreX'},
#  {'id': 'independent_reserve', 'name': 'Independent Reserve'},
#  {'id': 'indodax', 'name': 'Indodax'},
#  {'id': 'infinity_coin', 'name': 'Infinity Coin'},
#  {'id': 'instantbitex', 'name': 'Instant Bitex'},
#  {'id': 'iqfinex', 'name': 'IQFinex'},
#  {'id': 'itbit', 'name': 'itBit'},
#  {'id': 'jex', 'name': 'Binance JEX'},
#  {'id': 'jex_futures', 'name': 'Binance JEX (Futures)'},
#  {'id': 'joyso', 'name': 'Joyso'},
#  {'id': 'julswap', 'name': 'Julswap'},
#  {'id': 'justswap', 'name': 'JustSwap'},
#  {'id': 'kickex', 'name': 'KickEX'},
#  {'id': 'kkcoin', 'name': 'KKCoin'},
#  {'id': 'k_kex', 'name': 'KKEX'},
#  {'id': 'korbit', 'name': 'Korbit'},
#  {'id': 'kraken', 'name': 'Kraken'},
#  {'id': 'kraken_futures', 'name': 'Kraken (Futures)'},
#  {'id': 'kucoin', 'name': 'KuCoin'},
#  {'id': 'kumex', 'name': 'KuCoin Futures'},
#  {'id': 'kuna', 'name': 'Kuna Exchange'},
#  {'id': 'kyber_network', 'name': 'Kyber Network'},
#  {'id': 'lakebtc', 'name': 'LakeBTC'},
#  {'id': 'latoken', 'name': 'LATOKEN'},
#  {'id': 'lbank', 'name': 'LBank'},
#  {'id': 'lcx', 'name': 'LCX Exchange'},
#  {'id': 'leverj', 'name': 'Leverj'},
#  {'id': 'linkswap', 'name': 'Linkswap'},
#  {'id': 'liquid_derivatives', 'name': 'Liquid Perpetuals'},
#  {'id': 'localtrade', 'name': 'LocalTrade'},
#  {'id': 'loopring', 'name': 'Loopring'},
#  {'id': 'loopring_amm', 'name': 'Loopring AMM'},
#  {'id': 'luaswap', 'name': 'Luaswap'},
#  {'id': 'lucent', 'name': 'Lucent'},
#  {'id': 'lukki', 'name': 'Lukki'},
#  {'id': 'luno', 'name': 'Luno'},
#  {'id': 'lykke', 'name': 'Lykke'},
#  {'id': 'max_maicoin', 'name': 'Max Maicoin'},
#  {'id': 'mcdex', 'name': 'MCDEX'},
#  {'id': 'mdex', 'name': 'Mdex'},
#  {'id': 'mercado_bitcoin', 'name': 'Mercado Bitcoin'},
#  {'id': 'mercatox', 'name': 'Mercatox'},
#  {'id': 'mercuriex', 'name': 'MercuriEx'},
#  {'id': 'mesa', 'name': ' Gnosis Protocol'},
#  {'id': 'mirror', 'name': 'Terraswap'},
#  {'id': 'mooniswap', 'name': 'Mooniswap'},
#  {'id': 'multi', 'name': 'Multi.io'},
#  {'id': 'mxc', 'name': 'MXC'},
#  {'id': 'mxc_futures', 'name': 'MXC (Futures)'},
#  {'id': 'mycoinstory', 'name': 'MyCoinStory'},
#  {'id': 'namebase', 'name': 'Namebase'},
#  {'id': 'nami_exchange', 'name': 'Nami.Exchange'},
#  {'id': 'nanu_exchange', 'name': 'Nanu Exchange'},
#  {'id': 'narkasa', 'name': 'Narkasa'},
#  {'id': 'nash', 'name': 'Nash'},
#  {'id': 'neblidex', 'name': 'Neblidex'},
#  {'id': 'negociecoins', 'name': 'Negociecoins'},
#  {'id': 'neraex', 'name': 'Neraex'},
#  {'id': 'newdex', 'name': 'Newdex'},
#  {'id': 'nexus_mutual', 'name': 'Nexus Mutual'},
#  {'id': 'nice_hash', 'name': 'NiceHash'},
#  {'id': 'niftex', 'name': 'Niftex'},
#  {'id': 'nlexch', 'name': 'NLexch'},
#  {'id': 'nominex', 'name': 'Nominex'},
#  {'id': 'novadax', 'name': 'NovaDAX'},
#  {'id': 'oasis_trade', 'name': 'OasisDEX'},
#  {'id': 'oceanex', 'name': 'Oceanex'},
#  {'id': 'okcoin', 'name': 'Okcoin'},
#  {'id': 'okex', 'name': 'OKEx'},
#  {'id': 'okex_swap', 'name': 'OKEx (Futures)'},
#  {'id': 'omgfin', 'name': 'Omgfin'},
#  {'id': 'omnitrade', 'name': 'OmniTrade'},
#  {'id': 'one_inch', 'name': '1inch'},
#  {'id': 'one_inch_liquidity_protocol', 'name': '1inch Liquidity Protocol'},
#  {'id': 'one_inch_liquidity_protocol_bsc',
#   'name': '1inch Liquidity Protocol (BSC)'},
#  {'id': 'orderbook', 'name': 'Orderbook.io'},
#  {'id': 'otcbtc', 'name': 'OTCBTC'},
#  {'id': 'ovex', 'name': 'Ovex'},
#  {'id': 'p2pb2b', 'name': 'P2PB2B'},
#  {'id': 'pancakeswap', 'name': 'PancakeSwap (v2)'},
#  {'id': 'pancakeswap_others', 'name': 'Pancakeswap (Others)'},
#  {'id': 'pancakeswap_v1', 'name': 'PancakeSwap (v1)'},
#  {'id': 'pangolin', 'name': 'Pangolin'},
#  {'id': 'paraswap', 'name': 'Paraswap'},
#  {'id': 'paribu', 'name': 'Paribu'},
#  {'id': 'paroexchange', 'name': 'Paro Exchange'},
#  {'id': 'paymium', 'name': 'Paymium'},
#  {'id': 'perpetual_protocol', 'name': 'Perpetual Protocol'},
#  {'id': 'phemex', 'name': 'Phemex'},
#  {'id': 'phemex_futures', 'name': 'Phemex (Futures)'},
#  {'id': 'poloniex', 'name': 'Poloniex'},
#  {'id': 'poloniex_futures', 'name': 'Poloniex Futures'},
#  {'id': 'polyient_dex', 'name': 'Polyient Dex'},
#  {'id': 'prime_xbt', 'name': 'Prime XBT'},
#  {'id': 'probit', 'name': 'ProBit'},
#  {'id': 'qtrade', 'name': 'qTrade'},
#  {'id': 'quickswap', 'name': 'Quickswap'},
#  {'id': 'quoine', 'name': 'Liquid'},
#  {'id': 'radar_relay', 'name': 'Radar Relay'},
#  {'id': 'raydium', 'name': 'Raydium'},
#  {'id': 'resfinex', 'name': 'Resfinex'},
#  {'id': 'rfinex', 'name': 'Rfinex'},
#  {'id': 'safe_trade', 'name': 'SafeTrade'},
#  {'id': 'sakeswap', 'name': 'SakeSwap'},
#  {'id': 'sashimiswap', 'name': 'Sashimiswap'},
#  {'id': 'satoexchange', 'name': 'SatoExchange'},
#  {'id': 'saturn_network', 'name': 'Saturn Network'},
#  {'id': 'secondbtc', 'name': 'SecondBTC'},
#  {'id': 'secretswap', 'name': 'SecretSwap'},
#  {'id': 'serum_dex', 'name': 'Serum DEX'},
#  {'id': 'serumswap', 'name': 'SerumSwap'},
#  {'id': 'shortex', 'name': 'Shortex'},
#  {'id': 'simex', 'name': 'Simex'},
#  {'id': 'sinegy', 'name': 'SINEGY'},
#  {'id': 'sistemkoin', 'name': 'Sistemkoin'},
#  {'id': 'six_x', 'name': '6x'},
#  {'id': 'south_xchange', 'name': 'SouthXchange'},
#  {'id': 'spookyswap', 'name': 'Spookyswap'},
#  {'id': 'stake_cube', 'name': 'StakeCube Exchange'},
#  {'id': 'stellar_term', 'name': 'StellarTerm'},
#  {'id': 'stocks_exchange', 'name': 'STEX'},
#  {'id': 'stormgain', 'name': 'Stormgain'},
#  {'id': 'stormgain_futures', 'name': 'Stormgain Futures'},
#  {'id': 'sushiswap', 'name': 'Sushiswap'},
#  {'id': 'sushiswap_polygon', 'name': 'Sushiswap (Polygon POS)'},
#  {'id': 'swiftex', 'name': 'Swiftex'},
#  {'id': 'switcheo', 'name': 'Switcheo'},
#  {'id': 'swop_fi', 'name': 'Swop.Fi'},
#  {'id': 'synthetix', 'name': 'Synthetix Exchange'},
#  {'id': 'tdax', 'name': 'Satang Pro'},
#  {'id': 'therocktrading', 'name': 'TheRockTrading'},
#  {'id': 'thodex', 'name': 'Thodex'},
#  {'id': 'tidebit', 'name': 'Tidebit'},
#  {'id': 'tidex', 'name': 'Tidex'},
#  {'id': 'tokenize', 'name': 'Tokenize'},
#  {'id': 'tokenlon', 'name': 'Tokenlon'},
#  {'id': 'tokenomy', 'name': 'Tokenomy'},
#  {'id': 'token_sets', 'name': 'TokenSets'},
#  {'id': 'tokens_net', 'name': 'TokensNet'},
#  {'id': 'toko_crypto', 'name': 'TokoCrypto'},
#  {'id': 'tokok', 'name': 'TOKOK'},
#  {'id': 'tokpie', 'name': 'Tokpie'},
#  {'id': 'tomodex', 'name': 'TomoDEX'},
#  {'id': 'topbtc', 'name': 'TopBTC'},
#  {'id': 'trade_ogre', 'name': 'TradeOgre'},
#  {'id': 'tron_trade', 'name': 'TronTrade'},
#  {'id': 'trx_market', 'name': 'PoloniDEX'},
#  {'id': 'txbit', 'name': 'Txbit'},
#  {'id': 'ubeswap', 'name': 'Ubeswap'},
#  {'id': 'unicly', 'name': 'Unicly'},
#  {'id': 'uniswap', 'name': 'Uniswap (v3)'},
#  {'id': 'uniswap_v1', 'name': 'Uniswap (v1)'},
#  {'id': 'uniswap_v2', 'name': 'Uniswap (v2)'},
#  {'id': 'unnamed', 'name': 'Unnamed'},
#  {'id': 'upbit', 'name': 'Upbit'},
#  {'id': 'upbit_indonesia', 'name': 'Upbit Indonesia '},
#  {'id': 'value_liquid', 'name': 'Value Liquid'},
#  {'id': 'value_liquid_bsc', 'name': 'vSwap BSC'},
#  {'id': 'vb', 'name': 'VB'},
#  {'id': 'vcc', 'name': 'VCC Exchange'},
#  {'id': 'vebitcoin', 'name': 'Vebitcoin'},
#  {'id': 'velic', 'name': 'Velic'},
#  {'id': 'vindax', 'name': 'Vindax'},
#  {'id': 'vinex', 'name': 'Vinex'},
#  {'id': 'viperswap', 'name': 'ViperSwap'},
#  {'id': 'virgox', 'name': 'Virgox'},
#  {'id': 'vitex', 'name': 'ViteX'},
#  {'id': 'wault_swap', 'name': 'WaultSwap'},
#  {'id': 'waves', 'name': 'Waves.Exchange'},
#  {'id': 'wazirx', 'name': 'WazirX'},
#  {'id': 'whale_ex', 'name': 'WhaleEx'},
#  {'id': 'whitebit', 'name': 'WhiteBIT'},
#  {'id': 'xcoex', 'name': 'XCOEX'},
#  {'id': 'xfutures', 'name': 'xFutures'},
#  {'id': 'xt', 'name': 'XT.COM'},
#  {'id': 'yobit', 'name': 'YoBit'},
#  {'id': 'yunex', 'name': 'Yunex.io'},
#  {'id': 'zaif', 'name': 'Zaif'},
#  {'id': 'zb', 'name': 'ZB'},
#  {'id': 'zbg', 'name': 'ZBG'},
#  {'id': 'zbg_futures', 'name': 'ZBG Futures'},
#  {'id': 'zbx', 'name': 'ZBX'},
#  {'id': 'zebitex', 'name': 'Zebitex'},
#  {'id': 'zebpay', 'name': 'ZebPay'},
#  {'id': 'zero_ex', 'name': '0x Protocol'},
#  {'id': 'zero_exchange', 'name': 'Zero Exchange'},
#  {'id': 'zg', 'name': 'ZG.com'},
#  {'id': 'zgtop', 'name': 'ZG.TOP'},
#  {'id': 'zilswap', 'name': 'Zilswap'},
#  {'id': 'zipmex', 'name': 'Zipmex'},
#  {'id': 'zkswap', 'name': 'ZKSwap'}]

# %% [markdown]
# ### Finance

# %%
# List all finance platforms
cg.get_finance_platforms()
# Out:
# [{'name': 'Binance Staking',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://www.binance.com/en/staking'},
#  {'name': 'Celsius Network',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://celsius.network/'},
#  {'name': 'Cobo',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://cobo.com/'},
#  {'name': 'Dai Savings Rate',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://oasis.app/save'},
#  {'name': 'dYdX',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://dydx.exchange/'},
#  {'name': 'Idle Finance',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://idle.finance/#/'},
#  {'name': 'Staked US',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://staked.us/'},
#  {'name': 'Crypto.com',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://crypto.com/en/'},
#  {'name': 'Aave',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://aave.com/'},
#  {'name': 'Nexo',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://nexo.io/'},
#  {'name': 'Inlock',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://inlock.io/'},
#  {'name': 'Bitfinex',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://www.bitfinex.com'},
#  {'name': 'Compound Finance',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://compound.finance/'},
#  {'name': 'Fulcrum',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://fulcrum.trade/lending'},
#  {'name': 'Binance Savings',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://www.binance.com/en/lending'},
#  {'name': 'CILIO Finance',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://www.ciliofi.com/'},
#  {'name': 'Swissborg',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://swissborg.com/'},
#  {'name': 'Vauld',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://vauld.com/'},
#  {'name': 'Yearn Finance Vaults',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://yearn.finance/vaults'},
#  {'name': 'DDEX Lending',
#   'facts': '',
#   'category': 'DeFi Platform',
#   'centralized': False,
#   'website_url': 'https://ddex.io/loans'},
#  {'name': 'Hodlnaut',
#   'facts': '',
#   'category': 'CeFi Platform',
#   'centralized': True,
#   'website_url': 'https://www.hodlnaut.com/'}]

# %%
# List all finance products
cg.get_finance_products()
# Out:
# [{'platform': 'Crypto.com',
#   'identifier': 'BAT',
#   'supply_rate_percentage': '2.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'XTZ001',
#   'supply_rate_percentage': '1.956035',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'ZEC001',
#   'supply_rate_percentage': '0.182865',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'UNI001',
#   'supply_rate_percentage': '1.0001',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fXTZ',
#   'supply_rate_percentage': '0.0017',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'WAVES001',
#   'supply_rate_percentage': '5.000135',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Celsius Network',
#   'identifier': 'COMP',
#   'supply_rate_percentage': '4.5',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Celsius Network',
#   'identifier': 'ZUSD',
#   'supply_rate_percentage': '9.54',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Celsius Network',
#   'identifier': 'LEO',
#   'supply_rate_percentage': '0.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fEOS',
#   'supply_rate_percentage': '60.6301',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Nexo',
#   'identifier': 'ETH',
#   'supply_rate_percentage': '8.0',
#   'borrow_rate_percentage': '5.9',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Nexo',
#   'identifier': 'BTC',
#   'supply_rate_percentage': '8.0',
#   'borrow_rate_percentage': '5.9',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fLINK',
#   'supply_rate_percentage': '0.034',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Nexo',
#   'identifier': 'EUR',
#   'supply_rate_percentage': '12.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Inlock',
#   'identifier': 'UNI',
#   'supply_rate_percentage': '2.88',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Inlock',
#   'identifier': 'LINK',
#   'supply_rate_percentage': '3.96',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Staked US',
#   'identifier': 'Solana',
#   'supply_rate_percentage': '11.63',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Staked US',
#   'identifier': 'Cardano',
#   'supply_rate_percentage': '4.8',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'CCOCOS7DAYSS001',
#   'supply_rate_percentage': '4.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'DDEX Lending',
#   'identifier': 'USDT',
#   'supply_rate_percentage': '6.73694065509343',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'VET001',
#   'supply_rate_percentage': '1.10376',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Crypto.com',
#   'identifier': 'PAX',
#   'supply_rate_percentage': '6.0',
#   'borrow_rate_percentage': '12.0',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Vauld',
#   'identifier': 'USDC',
#   'supply_rate_percentage': '12.0',
#   'borrow_rate_percentage': '13.0',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'XMR001',
#   'supply_rate_percentage': '0.579985',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'dYdX',
#   'identifier': 'DAI',
#   'supply_rate_percentage': '9.74705499303855',
#   'borrow_rate_percentage': '14.325074072784',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'TRX',
#   'supply_rate_percentage': '8.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1569888000,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Fulcrum',
#   'identifier': 'dai',
#   'supply_rate_percentage': '19.1890320854151',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'THETA',
#   'supply_rate_percentage': '1.5',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1579737600,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fLTC',
#   'supply_rate_percentage': '9.8195',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fFIL',
#   'supply_rate_percentage': '0.2207',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Fulcrum',
#   'identifier': 'usdt',
#   'supply_rate_percentage': '10.8563401301382',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Inlock',
#   'identifier': 'OMG',
#   'supply_rate_percentage': '1.92',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'CILIO Finance',
#   'identifier': 'ETH',
#   'supply_rate_percentage': '0.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Aave',
#   'identifier': 'WBTC',
#   'supply_rate_percentage': '0.0247796768040586',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Aave',
#   'identifier': 'ETH',
#   'supply_rate_percentage': '0.00251293229910618',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'NEO',
#   'supply_rate_percentage': '2.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1500508800,
#   'end_at': 1885420800,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'ARPA',
#   'supply_rate_percentage': '5.5',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1583452800,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'BAND30DAYSS001',
#   'supply_rate_percentage': '14.8',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'KMD',
#   'supply_rate_percentage': '5.5',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1563926400,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'ALGO',
#   'supply_rate_percentage': '9.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1564185600,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Aave',
#   'identifier': 'UNI',
#   'supply_rate_percentage': '0.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Staking',
#   'identifier': 'ONT',
#   'supply_rate_percentage': '4.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 1530921600,
#   'end_at': 1893369600,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fATO',
#   'supply_rate_percentage': '0.4014',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fDOT',
#   'supply_rate_percentage': '1.4212',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fBCHN',
#   'supply_rate_percentage': '0.0183',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Celsius Network',
#   'identifier': 'SPARK',
#   'supply_rate_percentage': '0.0',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Nexo',
#   'identifier': 'PAXG',
#   'supply_rate_percentage': '8.0',
#   'borrow_rate_percentage': '5.9',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Bitfinex',
#   'identifier': 'fETP',
#   'supply_rate_percentage': '0.5324',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Nexo',
#   'identifier': 'USDT',
#   'supply_rate_percentage': '12.0',
#   'borrow_rate_percentage': '5.9',
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0},
#  {'platform': 'Binance Savings',
#   'identifier': 'ARK001',
#   'supply_rate_percentage': '1.0001',
#   'borrow_rate_percentage': None,
#   'number_duration': None,
#   'length_duration': None,
#   'start_at': 0,
#   'end_at': 0,
#   'value_at': 0,
#   'redeem_at': 0}]

# %% [markdown]
# ### Indexes

# %%
cg.get_indexes()
# Out:
# [{'name': 'CoinFLEX (Futures) DFN',
#   'id': 'DFN',
#   'market': 'CoinFLEX (Futures)',
#   'last': None,
#   'is_multi_asset_composite': None},
#  {'name': 'Bibox (Futures) LINK',
#   'id': 'LINK',
#   'market': 'Bibox (Futures)',
#   'last': None,
#   'is_multi_asset_composite': None},
#  {'name': 'RAMP',
#   'id': 'RAMP',
#   'market': 'FTX (Derivatives)',
#   'last': 0.62765063684713,
#   'is_multi_asset_composite': None},
#  {'name': 'CME Bitcoin Futures BTC',
#   'id': 'BTC',
#   'market': 'CME Bitcoin Futures',
#   'last': 0.62765063684713,
#   'is_multi_asset_composite': False},
#  {'name': 'Bibox (Futures) XRP',
#   'id': 'XRP',
#   'market': 'Bibox (Futures)',
#   'last': 0.62765063684713,
#   'is_multi_asset_composite': None},
#  {'name': 'Midcap Index',
#   'id': 'MID',
#   'market': 'FTX (Derivatives)',
#   'last': 6423.57160786912,
#   'is_multi_asset_composite': True},
#  {'name': 'ZBG Futures BSV',
#   'id': 'BSV',
#   'market': 'ZBG Futures',
#   'last': 6423.57160786912,
#   'is_multi_asset_composite': None},
#  {'name': 'Matic',
#   'id': 'MATIC',
#   'market': 'FTX (Derivatives)',
#   'last': 1.02264201318161,
#   'is_multi_asset_composite': False},
#  {'name': 'CoinFLEX (Futures) BCHABC',
#   'id': 'BCHABC',
#   'market': 'CoinFLEX (Futures)',
#   'last': 0.0,
#   'is_multi_asset_composite': None},
#  {'name': 'DeFi Index',
#   'id': 'DEFI',
#   'market': 'FTX (Derivatives)',
#   'last': 15147.8948112963,
#   'is_multi_asset_composite': True},
#  {'name': 'Binance (Futures) NKN',
#   'id': 'NKN',
#   'market': 'Binance (Futures)',
#   'last': 0.62092721,
#   'is_multi_asset_composite': None},
#  {'name': 'MyCoinStory SUN',
#   'id': 'SUN',
#   'market': 'MyCoinStory',
#   'last': 13.407576375,
#   'is_multi_asset_composite': None},
#  {'name': 'Bibox (Futures) EOS',
#   'id': 'EOS',
#   'market': 'Bibox (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'GMO Japan (Futures) BTC',
#   'id': 'BTC',
#   'market': 'GMO Japan (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'GMO Japan (Futures) BCH',
#   'id': 'BCH',
#   'market': 'GMO Japan (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'GMO Japan (Futures) ETH',
#   'id': 'ETH',
#   'market': 'GMO Japan (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'GMO Japan (Futures) XRP',
#   'id': 'XRP',
#   'market': 'GMO Japan (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'CoinFLEX (Futures) D',
#   'id': 'D',
#   'market': 'CoinFLEX (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'Bibox (Futures) SUSHI',
#   'id': 'SUSHI',
#   'market': 'Bibox (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': None},
#  {'name': 'FMex ETH',
#   'id': 'ETH',
#   'market': 'FMex',
#   'last': 13.407576375,
#   'is_multi_asset_composite': None},
#  {'name': 'Prime XBT EOS',
#   'id': 'EOS',
#   'market': 'Prime XBT',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'dYdX Perpetual (L1) WETH',
#   'id': 'WETH',
#   'market': 'dYdX Perpetual (L1)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': None},
#  {'name': 'Bibox (Futures) BCH',
#   'id': 'BCH',
#   'market': 'Bibox (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'Bibox (Futures) UNI',
#   'id': 'UNI',
#   'market': 'Bibox (Futures)',
#   'last': 13.407576375,
#   'is_multi_asset_composite': False},
#  {'name': 'Delta Exchange ADA',
#   'id': 'ADA',
#   'market': 'Delta Exchange (Futures)',
#   'last': 5.09e-06,
#   'is_multi_asset_composite': None},
#  {'name': 'Delta Exchange BCH',
#   'id': 'BCH',
#   'market': 'Delta Exchange (Futures)',
#   'last': 315.526644,
#   'is_multi_asset_composite': None},
#  {'name': 'ETHG20',
#   'id': 'ETHG20',
#   'market': 'BTSE (Futures)',
#   'last': 223.409277154,
#   'is_multi_asset_composite': None},
#  {'name': 'Prime XBT LTC',
#   'id': 'LTC',
#   'market': 'Prime XBT',
#   'last': 223.409277154,
#   'is_multi_asset_composite': False},
#  {'name': 'Phemex (Futures) XTZ',
#   'id': 'XTZ',
#   'market': 'Phemex (Futures)',
#   'last': 6.7848,
#   'is_multi_asset_composite': None},
#  {'name': 'Bibox (Futures) LTC',
#   'id': 'LTC',
#   'market': 'Bibox (Futures)',
#   'last': 6.7848,
#   'is_multi_asset_composite': False},
#  {'name': 'HBTC (Futures) TRX',
#   'id': 'TRX',
#   'market': 'HBTC (Futures)',
#   'last': 0.13938719333,
#   'is_multi_asset_composite': None},
#  {'name': 'GMO Japan (Futures) LTC',
#   'id': 'LTC',
#   'market': 'GMO Japan (Futures)',
#   'last': 0.13938719333,
#   'is_multi_asset_composite': False},
#  {'name': 'CoinFLEX (Futures) XBT',
#   'id': 'XBT',
#   'market': 'CoinFLEX (Futures)',
#   'last': 0.13938719333,
#   'is_multi_asset_composite': False},
#  {'name': 'Bitflyer (Futures) BTC',
#   'id': 'BTC',
#   'market': 'Bitflyer (Futures)',
#   'last': 0.13938719333,
#   'is_multi_asset_composite': False},
#  {'name': 'CoinTiger (Futures) SXP',
#   'id': 'SXP',
#   'market': 'CoinTiger (Futures)',
#   'last': 4.82470638,
#   'is_multi_asset_composite': None},
#  {'name': 'Bitmart Futures HT',
#   'id': 'HT',
#   'market': 'Bitmart Futures',
#   'last': 3.881011111111,
#   'is_multi_asset_composite': None},
#  {'name': 'Bitmart Futures ETC',
#   'id': 'ETC',
#   'market': 'Bitmart Futures',
#   'last': 5.564,
#   'is_multi_asset_composite': None},
#  {'name': 'Bibox (Futures) FIL',
#   'id': 'FIL',
#   'market': 'Bibox (Futures)',
#   'last': 5.564,
#   'is_multi_asset_composite': None},
#  {'name': 'Okex SUN',
#   'id': 'OkexSwap-SUN',
#   'market': 'OKEx (Futures)',
#   'last': 34.17009368,
#   'is_multi_asset_composite': None},
#  {'name': 'Prime XBT XRP',
#   'id': 'XRP',
#   'market': 'Prime XBT',
#   'last': 34.17009368,
#   'is_multi_asset_composite': False},
#  {'name': 'Bibox (Futures) BTC',
#   'id': 'BTC',
#   'market': 'Bibox (Futures)',
#   'last': 34.17009368,
#   'is_multi_asset_composite': False},
#  {'name': 'XMRG20',
#   'id': 'XMRG20',
#   'market': 'BTSE (Futures)',
#   'last': 68.583952985,
#   'is_multi_asset_composite': None},
#  {'name': 'ETHX19',
#   'id': 'ETHX19',
#   'market': 'BTSE (Futures)',
#   'last': 127.299916665,
#   'is_multi_asset_composite': False},
#  {'name': 'BBCXG20',
#   'id': 'BBCXG20',
#   'market': 'BTSE (Futures)',
#   'last': 114.91,
#   'is_multi_asset_composite': True},
#  {'name': 'CoinFLEX (Futures) USDC',
#   'id': 'USDC',
#   'market': 'CoinFLEX (Futures)',
#   'last': 114.91,
#   'is_multi_asset_composite': False},
#  {'name': 'Waves',
#   'id': 'WAVES',
#   'market': 'FTX (Derivatives)',
#   'last': 31.5078779004104,
#   'is_multi_asset_composite': None},
#  {'name': 'Bitcoin',
#   'id': 'BTC',
#   'market': 'FTX (Derivatives)',
#   'last': 56506.0979667427,
#   'is_multi_asset_composite': False},
#  {'name': 'Prime XBT BTC',
#   'id': 'BTC',
#   'market': 'Prime XBT',
#   'last': 56506.0979667427,
#   'is_multi_asset_composite': False},
#  {'name': 'LTCX19',
#   'id': 'LTCX19',
#   'market': 'BTSE (Futures)',
#   'last': 39.783863299,
#   'is_multi_asset_composite': False},
#  {'name': 'FMex BTC',
#   'id': 'BTC',
#   'market': 'FMex',
#   'last': 9767.06,
#   'is_multi_asset_composite': None}]

# %%
cg.get_indexes_list()
# Out:
# [{'id': 'DFN', 'name': 'CoinFLEX (Futures) DFN'},
#  {'id': 'LINK', 'name': 'Bibox (Futures) LINK'},
#  {'id': 'RAMP', 'name': 'RAMP'},
#  {'id': 'BTC', 'name': 'CME Bitcoin Futures BTC'},
#  {'id': 'XRP', 'name': 'Bibox (Futures) XRP'},
#  {'id': 'MID', 'name': 'Midcap Index'},
#  {'id': 'BSV', 'name': 'ZBG Futures BSV'},
#  {'id': 'MATIC', 'name': 'Matic'},
#  {'id': 'BCHABC', 'name': 'CoinFLEX (Futures) BCHABC'},
#  {'id': 'DEFI', 'name': 'DeFi Index'},
#  {'id': 'NKN', 'name': 'Binance (Futures) NKN'},
#  {'id': 'SUN', 'name': 'MyCoinStory SUN'},
#  {'id': 'EOS', 'name': 'Bibox (Futures) EOS'},
#  {'id': 'BTC', 'name': 'GMO Japan (Futures) BTC'},
#  {'id': 'BCH', 'name': 'GMO Japan (Futures) BCH'},
#  {'id': 'ETH', 'name': 'GMO Japan (Futures) ETH'},
#  {'id': 'XRP', 'name': 'GMO Japan (Futures) XRP'},
#  {'id': 'D', 'name': 'CoinFLEX (Futures) D'},
#  {'id': 'SUSHI', 'name': 'Bibox (Futures) SUSHI'},
#  {'id': 'ETH', 'name': 'FMex ETH'},
#  {'id': 'EOS', 'name': 'Prime XBT EOS'},
#  {'id': 'WETH', 'name': 'dYdX Perpetual (L1) WETH'},
#  {'id': 'BCH', 'name': 'Bibox (Futures) BCH'},
#  {'id': 'UNI', 'name': 'Bibox (Futures) UNI'},
#  {'id': 'ADA', 'name': 'Delta Exchange ADA'},
#  {'id': 'BCH', 'name': 'Delta Exchange BCH'},
#  {'id': 'ETHG20', 'name': 'ETHG20'},
#  {'id': 'LTC', 'name': 'Prime XBT LTC'},
#  {'id': 'XTZ', 'name': 'Phemex (Futures) XTZ'},
#  {'id': 'LTC', 'name': 'Bibox (Futures) LTC'},
#  {'id': 'TRX', 'name': 'HBTC (Futures) TRX'},
#  {'id': 'LTC', 'name': 'GMO Japan (Futures) LTC'},
#  {'id': 'XBT', 'name': 'CoinFLEX (Futures) XBT'},
#  {'id': 'BTC', 'name': 'Bitflyer (Futures) BTC'},
#  {'id': 'SXP', 'name': 'CoinTiger (Futures) SXP'},
#  {'id': 'HT', 'name': 'Bitmart Futures HT'},
#  {'id': 'ETC', 'name': 'Bitmart Futures ETC'},
#  {'id': 'FIL', 'name': 'Bibox (Futures) FIL'},
#  {'id': 'OkexSwap-SUN', 'name': 'Okex SUN'},
#  {'id': 'XRP', 'name': 'Prime XBT XRP'},
#  {'id': 'BTC', 'name': 'Bibox (Futures) BTC'},
#  {'id': 'XMRG20', 'name': 'XMRG20'},
#  {'id': 'ETHX19', 'name': 'ETHX19'},
#  {'id': 'BBCXG20', 'name': 'BBCXG20'},
#  {'id': 'USDC', 'name': 'CoinFLEX (Futures) USDC'},
#  {'id': 'WAVES', 'name': 'Waves'},
#  {'id': 'BTC', 'name': 'Bitcoin'},
#  {'id': 'BTC', 'name': 'Prime XBT BTC'},
#  {'id': 'LTCX19', 'name': 'LTCX19'},
#  {'id': 'BTC', 'name': 'FMex BTC'},
#  {'id': 'DOT', 'name': 'Bibox (Futures) DOT'},
#  {'id': 'ETH', 'name': 'Bibox (Futures) ETH'},
#  {'id': 'CVC', 'name': 'MXC (Futures) CVC'},
#  {'id': 'AAVE', 'name': 'Bibox (Futures) AAVE'},
#  {'id': 'ETH', 'name': 'Prime XBT ETH'},
#  {'id': 'BTCG20', 'name': 'BTCG20'},
#  {'id': 'BTCX19', 'name': 'BTCX19'},
#  {'id': 'LTCG20', 'name': 'LTCG20'},
#  {'id': 'WAVES', 'name': 'Delta Exchange WAVES'},
#  {'id': 'XTZ', 'name': 'Delta Exchange XTZ'},
#  {'id': 'LTCH20', 'name': 'LTCH20'},
#  {'id': 'BBCXZ19', 'name': 'BBCXZ19'},
#  {'id': 'XLM', 'name': 'Delta Exchange XLM'},
#  {'id': 'RVN', 'name': 'Delta Exchange RVN'},
#  {'id': 'BTC', 'name': 'Bakkt BTC'},
#  {'id': 'BBCXX19', 'name': 'BBCXX19'},
#  {'id': 'BBAXG20', 'name': 'BBAXG20'},
#  {'id': 'BSV', 'name': 'Delta Exchange BSV'},
#  {'id': 'XMRX19', 'name': 'XMRX19'},
#  {'id': 'XMRH20', 'name': 'XMRH20'},
#  {'id': 'BBAXX20', 'name': 'BBAXX20'},
#  {'id': 'EOS', 'name': 'BaseFEX EOS'},
#  {'id': 'BADGER', 'name': 'Huobi Futures BADGER'},
#  {'id': 'LTC', 'name': 'BaseFEX LTC'},
#  {'id': 'PLINK', 'name': 'dYdX Perpetual (L1) PLINK'},
#  {'id': 'BBAXH20', 'name': 'BBAXH20'},
#  {'id': 'XTZPFC', 'name': 'XTZPFC'},
#  {'id': 'LINK', 'name': 'Delta Exchange LINK'},
#  {'id': 'COMP', 'name': 'AAX Futures COMP'},
#  {'id': 'BTCH20', 'name': 'BTCH20'},
#  {'id': 'BCH', 'name': 'AAX Futures BCH'},
#  {'id': 'HOT', 'name': 'Holo'},
#  {'id': 'FRONT', 'name': 'Gate.io (Futures) FRONT'},
#  {'id': 'BTCM21', 'name': 'BTCM21'},
#  {'id': 'YFII', 'name': 'CoinTiger (Futures) YFII'},
#  {'id': 'ETH', 'name': 'Binance JEX (Futures) ETH'},
#  {'id': 'XMR', 'name': 'Poloniex Futures XMR'},
#  {'id': 'YFI', 'name': 'Perpetual Protocol YFI'},
#  {'id': 'XRP', 'name': 'Binance (Futures) XRP'},
#  {'id': 'BTC', 'name': 'dYdX Perpetual BTC'},
#  {'id': 'LPT', 'name': 'Gate.io (Futures) LPT'},
#  {'id': 'ALCX', 'name': 'Alchemix'},
#  {'id': 'DASH', 'name': 'Gate.io (Futures) DASH'},
#  {'id': 'MANA', 'name': 'CoinTiger (Futures) MANA'},
#  {'id': 'SUSHI', 'name': 'Perpetual Protocol SUSHI'},
#  {'id': 'EOS', 'name': 'Binance (Futures) EOS'},
#  {'id': 'LINK', 'name': 'Binance (Futures) LINK'},
#  {'id': 'BTC', 'name': 'AAX Futures BTC'},
#  {'id': 'LINK', 'name': 'AAX Futures LINK'},
#  {'id': 'SERO', 'name': 'Gate.io (Futures) SERO'},
#  {'id': 'YFI', 'name': 'Poloniex Futures YFI'},
#  {'id': 'UNI', 'name': 'ZBG Futures UNI'},
#  {'id': 'BNC BTC High Frequency Index',
#   'name': 'BNC BTC High Frequency Index'},
#  {'id': 'ETHH20', 'name': 'ETHH20'},
#  {'id': 'BBCXH20', 'name': 'BBCXH20'},
#  {'id': 'BSV', 'name': 'Stormgain Futures BSV'},
#  {'id': 'DOT', 'name': 'Stormgain Futures DOT'},
#  {'id': 'XTZ', 'name': 'Bitget Futures XTZ'},
#  {'id': 'FIL', 'name': 'Bitget Futures FIL'},
#  {'id': 'TRX', 'name': 'Huobi Futures TRX'},
#  {'id': 'EUR', 'name': 'Bitfinex (Futures) EUR'},
#  {'id': 'XMR', 'name': 'Gate.io (Futures) XMR'},
#  {'id': 'LINK', 'name': 'HBTC (Futures) LINK'},
#  {'id': 'SHIT', 'name': 'Shitcoin Index'},
#  {'id': 'ALPHA', 'name': 'CoinTiger (Futures) ALPHA'},
#  {'id': 'OkexSwap-ALGO', 'name': 'Okex ALGO'},
#  {'id': 'CUSDT', 'name': 'Compound USDT'},
#  {'id': 'OkexSwap-KNC', 'name': 'Okex KNC'},
#  {'id': 'OkexSwap-UNI', 'name': 'Okex UNI'},
#  {'id': 'OkexSwap-QTUM', 'name': 'Okex QTUM'},
#  {'id': 'BTC', 'name': 'Bitfinex (Futures) BTC'},
#  {'id': 'IOT', 'name': 'Bitfinex (Futures) IOT'},
#  {'id': 'AAVE', 'name': 'CoinTiger (Futures) AAVE'},
#  {'id': 'OkexSwap-ADA', 'name': 'Okex ADA'},
#  {'id': 'OkexSwap-FTM', 'name': 'Okex FTM'},
#  {'id': 'OkexSwap-LTC', 'name': 'Okex LTC'},
#  {'id': 'OkexSwap-SUSHI', 'name': 'Okex SUSHI'},
#  {'id': 'OkexSwap-CRV', 'name': 'Okex CRV'},
#  {'id': 'OkexSwap-LINK', 'name': 'Okex LINK'},
#  {'id': 'STX', 'name': 'Stacks'},
#  {'id': 'OkexSwap-FIL', 'name': 'Okex FIL'},
#  {'id': 'TRX', 'name': 'Bitmart Futures TRX'},
#  {'id': 'BBCXQ20', 'name': 'BBCXQ20'},
#  {'id': 'ETHZ19', 'name': 'ETHZ19'},
#  {'id': 'XMRF20', 'name': 'XMRF20'},
#  {'id': 'ETH', 'name': 'C-Trade ETH'},
#  {'id': 'YFI', 'name': 'CoinTiger (Futures) YFI'},
#  {'id': 'OkexSwap-MIR', 'name': 'Okex MIR'},
#  {'id': 'OkexSwap-NEAR', 'name': 'Okex NEAR'},
#  {'id': 'PROM', 'name': 'Prometeus'},
#  {'id': 'DODO', 'name': 'Binance (Futures) DODO'},
#  {'id': 'BSV', 'name': 'Bitmart Futures BSV'},
#  {'id': 'CHZ', 'name': 'Stormgain Futures CHZ'},
#  {'id': 'IOST', 'name': 'Huobi Futures IOST'},
#  {'id': 'BCH', 'name': 'BaseFEX BCH'},
#  {'id': 'BBCXF20', 'name': 'BBCXF20'},
#  {'id': 'UMA', 'name': 'MyCoinStory UMA'},
#  {'id': 'FIL', 'name': 'HBTC (Futures) FIL'},
#  {'id': 'BTC', 'name': 'Binance (Futures) BTC'},
#  {'id': 'DOGE', 'name': 'Stormgain Futures DOGE'},
#  {'id': 'BCH', 'name': 'Stormgain Futures BCH'},
#  {'id': 'EOS', 'name': 'CoinTiger (Futures) EOS'},
#  {'id': 'UNI', 'name': 'Bitget Futures UNI'},
#  {'id': 'TRX', 'name': 'Bitget Futures TRX'},
#  {'id': 'BEOSXBT30M', 'name': '.BEOSXBT30M'},
#  {'id': 'OkexSwap-LRC', 'name': 'Okex LRC'},
#  {'id': 'OkexSwap-DOT', 'name': 'Okex DOT'},
#  {'id': 'OkexSwap-ETH', 'name': 'Okex ETH'},
#  {'id': 'OkexSwap-THETA', 'name': 'Okex THETA'},
#  {'id': 'LINA', 'name': 'Linear Token'},
#  {'id': 'ETH', 'name': 'Ethereum'},
#  {'id': 'ALGO', 'name': 'Bitmart Futures ALGO'},
#  {'id': 'LTCF20', 'name': 'LTCF20'},
#  {'id': 'ETHF20', 'name': 'ETHF20'},
#  {'id': 'LTCN20', 'name': 'LTCN20'},
#  {'id': 'OkexSwap-REN', 'name': 'Okex REN'},
#  {'id': 'ETH', 'name': 'DueDEX ETH'},
#  {'id': '1INCH', 'name': 'MXC (Futures) 1INCH'},
#  {'id': 'ETH', 'name': 'Binance (Futures) ETH'},
#  {'id': 'ETC', 'name': 'HBTC (Futures) ETC'},
#  {'id': 'BTC', 'name': 'DueDEX BTC'},
#  {'id': 'XRP', 'name': 'AscendEX  (BitMax) (Futures) XRP'},
#  {'id': 'DOGE', 'name': 'AscendEX  (BitMax) (Futures) DOGE'},
#  {'id': 'ETC', 'name': 'Huobi Futures ETC'},
#  {'id': 'XLM', 'name': 'Stormgain Futures XLM'},
#  {'id': 'ETH', 'name': 'AscendEX  (BitMax) (Futures) ETH'},
#  {'id': 'WAVES', 'name': 'Huobi Futures WAVES'},
#  {'id': 'BTC', 'name': 'BaseFEX BTC'},
#  {'id': 'BTC', 'name': 'ZBG Futures BTC'},
#  {'id': 'DERENUSDT', 'name': '.DERENUSDT'},
#  {'id': 'XTZ', 'name': 'Stormgain Futures XTZ'},
#  {'id': 'DEENJXBT', 'name': '.DEENJXBT'},
#  {'id': 'KrakenFutures-rr_bchusd', 'name': 'Kraken Futures rr_bchusd'},
#  {'id': 'BTC', 'name': 'Hopex BTC'},
#  {'id': 'BETHXBT30M', 'name': '.BETHXBT30M'},
#  {'id': 'LINK', 'name': 'CoinTiger (Futures) LINK'},
#  {'id': 'AAVE', 'name': 'Bitget Futures AAVE'},
#  {'id': 'ETH', 'name': 'Bitfinex (Futures) ETH'},
#  {'id': 'CHZ', 'name': 'CoinTiger (Futures) CHZ'},
#  {'id': 'XRP', 'name': 'XRP'},
#  {'id': 'LTC', 'name': 'Litecoin'},
#  {'id': 'BSV', 'name': 'Poloniex Futures BSV'},
#  {'id': 'ALGO', 'name': 'Stormgain Futures ALGO'},
#  {'id': 'UNI', 'name': 'MXC (Futures) UNI'},
#  {'id': 'MATIC', 'name': 'Delta Exchange MATIC'},
#  {'id': 'BTCF20', 'name': 'BTCF20'},
#  {'id': 'XMRZ19', 'name': 'XMRZ19'},
#  {'id': 'LTCZ19', 'name': 'LTCZ19'},
#  {'id': '1INCH-DIVE-5.00-D1001', 'name': 'ACDX Futures 1INCH-DIVE-5.00-D1001'},
#  {'id': 'ETH', 'name': 'Phemex (Futures) ETH'},
#  {'id': 'LINK', 'name': 'AscendEX  (BitMax) (Futures) LINK'},
#  {'id': 'DOT', 'name': 'AscendEX  (BitMax) (Futures) DOT'},
#  {'id': 'BTC', 'name': 'BigONE Futures BTC'},
#  {'id': 'DEFILUSDT', 'name': '.DEFILUSDT'},
#  {'id': 'ATOM', 'name': 'Stormgain Futures ATOM'},
#  {'id': 'DOT', 'name': 'Huobi Futures DOT'},
#  {'id': 'ALT', 'name': 'Altcoin Index'},
#  {'id': 'BXBT30M', 'name': '.BXBT30M'},
#  {'id': 'BAO', 'name': 'BaoToken'},
#  {'id': 'ICP', 'name': 'Internet Computer'},
#  {'id': 'LTC', 'name': 'Binance (Futures) LTC'},
#  {'id': 'DOGE', 'name': 'Bitmart Futures DOGE'},
#  {'id': 'LINK', 'name': 'Phemex (Futures) LINK'},
#  {'id': 'BNB', 'name': 'Stormgain Futures BNB'},
#  {'id': 'BTC', 'name': 'Liquid Perpetuals BTC'},
#  {'id': 'ZEC', 'name': 'Stormgain Futures ZEC'},
#  {'id': 'BTC', 'name': 'MyCoinStory BTC'},
#  {'id': 'RUNE', 'name': 'Binance (Futures) RUNE'},
#  {'id': 'NEAR', 'name': 'Huobi Futures NEAR'},
#  {'id': 'KrakenFutures-rr_xbtusd', 'name': 'Kraken Futures rr_xbtusd'},
#  {'id': 'BADAXBT30M', 'name': '.BADAXBT30M'},
#  {'id': 'LRC', 'name': 'CoinTiger (Futures) LRC'},
#  {'id': 'BTCZ19', 'name': 'BTCZ19'},
#  {'id': 'OKB', 'name': 'Bitmart Futures OKB'},
#  {'id': 'FIL', 'name': 'Stormgain Futures FIL'},
#  {'id': 'RSR', 'name': 'Huobi Futures RSR'},
#  {'id': 'ADA', 'name': 'Phemex (Futures) ADA'},
#  {'id': 'KrakenFutures-rr_xrpusd', 'name': 'Kraken Futures rr_xrpusd'},
#  {'id': 'BBCHXBT30M', 'name': '.BBCHXBT30M'},
#  {'id': 'SRM', 'name': 'CoinTiger (Futures) SRM'},
#  {'id': 'DOGE', 'name': 'Dogecoin'},
#  {'id': 'OKB', 'name': 'OKB'},
#  {'id': 'BEL', 'name': 'Binance (Futures) BEL'},
#  {'id': 'BBCXV20', 'name': 'BBCXV20'},
#  {'id': 'BXBT', 'name': '.BXBT'},
#  {'id': 'SUSHI-DIVE-20.50-D0901',
#   'name': 'ACDX Futures SUSHI-DIVE-20.50-D0901'},
#  {'id': 'DOGE', 'name': 'Phemex (Futures) DOGE'},
#  {'id': 'ANKR', 'name': 'Huobi Futures ANKR'},
#  {'id': 'EUROPE50IX', 'name': 'Bitfinex (Futures) EUROPE50IX'},
#  {'id': 'NEAR', 'name': 'Near'},
#  {'id': 'AVAX', 'name': 'Avalanche'},
#  {'id': 'KrakenFutures-rr_ethusd', 'name': 'Kraken Futures rr_ethusd'},
#  {'id': 'CONV', 'name': 'Gate.io (Futures) CONV'},
#  {'id': 'XLM', 'name': 'CoinTiger (Futures) XLM'},
#  {'id': 'MASS', 'name': 'Huobi Futures MASS'},
#  {'id': 'RUNE', 'name': 'CoinTiger (Futures) RUNE'},
#  {'id': 'BTC', 'name': 'AscendEX  (BitMax) (Futures) BTC'},
#  {'id': 'BBNBT30M', 'name': '.BBNBT30M'},
#  {'id': 'OkexSwap-LUNA', 'name': 'Okex LUNA'},
#  {'id': 'OkexSwap-JST', 'name': 'Okex JST'},
#  {'id': 'GRT', 'name': 'Graph Token'},
#  {'id': 'RSR', 'name': 'Binance (Futures) RSR'},
#  {'id': 'AVAX', 'name': 'Stormgain Futures AVAX'},
#  {'id': 'BTS', 'name': 'Huobi Futures BTS'},
#  {'id': 'ETH', 'name': 'CoinTiger (Futures) ETH'},
#  {'id': 'DEXAUTUSDT', 'name': '.DEXAUTUSDT'},
#  {'id': 'ETH', 'name': 'Deribit ETH'},
#  {'id': 'LTC', 'name': 'Delta Exchange LTC'},
#  {'id': 'LINK', 'name': 'dYdX Perpetual LINK'},
#  {'id': 'MATIC', 'name': 'CoinTiger (Futures) MATIC'},
#  {'id': 'KNC', 'name': 'CoinTiger (Futures) KNC'},
#  {'id': 'BDOGET', 'name': '.BDOGET'},
#  {'id': 'ADA', 'name': 'CoinTiger (Futures) ADA'},
#  {'id': 'ETH', 'name': 'Perpetual Protocol ETH'},
#  {'id': 'FTT', 'name': 'FTT'},
#  {'id': 'DOT', 'name': 'Perpetual Protocol DOT'},
#  {'id': 'OkexSwap-1INCH', 'name': 'Okex 1INCH'},
#  {'id': 'ETH', 'name': 'dYdX Perpetual ETH'},
#  {'id': 'AVAX', 'name': 'dYdX Perpetual AVAX'},
#  {'id': 'TRU', 'name': 'TrueFi'},
#  {'id': 'ETH', 'name': 'BigONE Futures ETH'},
#  {'id': '1INCH', 'name': 'Huobi Futures 1INCH'},
#  {'id': 'SOL', 'name': 'Stormgain Futures SOL'},
#  {'id': 'REN', 'name': 'CoinTiger (Futures) REN'},
#  {'id': 'BLZ', 'name': 'CoinTiger (Futures) BLZ'},
#  {'id': 'OkexSwap-IOST', 'name': 'Okex IOST'},
#  {'id': 'BNB', 'name': 'Delta Exchange BNB'},
#  {'id': 'TOMO', 'name': 'Delta Exchange TOMO'},
#  {'id': 'ATOM', 'name': 'Delta Exchange ATOM'},
#  {'id': 'BTC', 'name': 'Delta Exchange BTC'},
#  {'id': 'EOS', 'name': 'Delta Exchange EOS'},
#  {'id': 'ETH', 'name': 'Delta Exchange ETH'},
#  {'id': 'CREAM', 'name': 'Cream'},
#  {'id': 'UNI', 'name': 'BigONE Futures UNI'},
#  {'id': 'DOT', 'name': 'BigONE Futures DOT'},
#  {'id': 'FTM', 'name': 'Binance (Futures) FTM'},
#  {'id': 'THETA', 'name': 'Stormgain Futures THETA'},
#  {'id': 'ETH', 'name': 'BaseFEX ETH'},
#  {'id': 'ENJ', 'name': 'Delta Exchange ENJ'},
#  {'id': 'XRP', 'name': 'Delta Exchange XRP'},
#  {'id': 'BAT', 'name': 'Delta Exchange BAT'},
#  {'id': 'XMR', 'name': 'Delta Exchange XMR'},
#  {'id': 'LEO', 'name': 'Delta Exchange LEO'},
#  {'id': 'ETHJ21', 'name': 'ETHJ21'},
#  {'id': 'GXC', 'name': 'Huobi Futures GXC'},
#  {'id': 'BNB', 'name': 'BaseFEX BNB'},
#  {'id': 'EGLD', 'name': 'Stormgain Futures EGLD'},
#  {'id': 'BTCJ21', 'name': 'BTCJ21'},
#  {'id': 'MATIC', 'name': 'Stormgain Futures MATIC'},
#  {'id': 'EOS', 'name': 'BigONE Futures EOS'},
#  {'id': 'DELENDXBT', 'name': '.DELENDXBT'},
#  {'id': 'ALGO', 'name': 'MXC (Futures) ALGO'},
#  {'id': 'RUNE', 'name': 'Stormgain Futures RUNE'},
#  {'id': 'CAKE', 'name': 'Stormgain Futures CAKE'},
#  {'id': 'XMRZ20', 'name': 'XMRZ20'},
#  {'id': 'AAVE', 'name': 'Phemex (Futures) AAVE'},
#  {'id': 'AAVE', 'name': 'Stormgain Futures AAVE'},
#  {'id': 'XEM', 'name': 'Huobi Futures XEM'},
#  {'id': 'ETH', 'name': 'AAX Futures ETH'},
#  {'id': 'ATOM', 'name': 'MXC (Futures) ATOM'},
#  {'id': 'OkexSwap-EOS', 'name': 'Okex EOS'},
#  {'id': 'ONT', 'name': 'Binance (Futures) ONT'},
#  {'id': 'ELF', 'name': 'Bitmart Futures ELF'},
#  {'id': 'NEO', 'name': 'Stormgain Futures NEO'},
#  {'id': 'NEAR', 'name': 'CoinTiger (Futures) NEAR'},
#  {'id': 'OkexSwap-NEO', 'name': 'Okex NEO'},
#  {'id': 'ENJ', 'name': 'Stormgain Futures ENJ'},
#  {'id': 'OkexSwap-SRM', 'name': 'Okex SRM'},
#  {'id': 'BNB', 'name': 'Gate.io (Futures) BNB'},
#  {'id': 'SUSHI', 'name': 'Stormgain Futures SUSHI'},
#  {'id': 'PERP', 'name': 'Perpetual Protocol PERP'},
#  {'id': 'ANKR', 'name': 'CoinTiger (Futures) ANKR'},
#  {'id': 'VET', 'name': 'Huobi Futures VET'},
#  {'id': 'BAT', 'name': 'Huobi Futures BAT'},
#  {'id': 'OkexSwap-BSV', 'name': 'Okex BSV'},
#  {'id': 'BTC', 'name': 'CoinTiger (Futures) BTC'},
#  {'id': 'BTC', 'name': 'Biki (Futures) BTC'},
#  {'id': 'KrakenFutures-rr_ltcusd', 'name': 'Kraken Futures rr_ltcusd'},
#  {'id': 'SRM', 'name': 'Gate.io (Futures) SRM'},
#  {'id': 'LINK', 'name': 'Huobi Futures LINK'},
#  {'id': 'COMP', 'name': 'CoinTiger (Futures) COMP'},
#  {'id': 'AKRO', 'name': 'CoinTiger (Futures) AKRO'},
#  {'id': 'ANT', 'name': 'Gate.io (Futures) ANT'},
#  {'id': 'OkexSwap-SWRV', 'name': 'Okex SWRV'},
#  {'id': 'BBAXU20', 'name': 'BBAXU20'},
#  {'id': 'OkexSwap-ANT', 'name': 'Okex ANT'},
#  {'id': 'DOT', 'name': 'Biki (Futures) DOT'},
#  {'id': 'PERP', 'name': 'Gate.io (Futures) PERP'},
#  {'id': 'EOS', 'name': 'Binance JEX (Futures) EOS'},
#  {'id': 'BTC', 'name': 'Binance JEX (Futures) BTC'},
#  {'id': 'JST', 'name': 'Gate.io (Futures) JST'},
#  {'id': 'AR', 'name': 'Gate.io (Futures) AR'},
#  {'id': 'XRP', 'name': 'Poloniex Futures XRP'},
#  {'id': 'NEO', 'name': 'CoinTiger (Futures) NEO'},
#  {'id': 'OkexSwap-WNXM', 'name': 'Okex WNXM'},
#  {'id': 'XRP', 'name': 'Bitmart Futures XRP'},
#  {'id': 'LTC', 'name': 'Biki (Futures) LTC'},
#  {'id': 'LTC', 'name': 'Bitmart Futures LTC'},
#  {'id': 'XMRQ20', 'name': 'XMRQ20'},
#  {'id': 'XMRJ20', 'name': 'XMRJ20'},
#  {'id': 'ETC', 'name': 'Bitz (Futures) ETC'},
#  {'id': 'ETH', 'name': 'Bitmart Futures ETH'},
#  {'id': 'MKR', 'name': 'CoinTiger (Futures) MKR'},
#  {'id': 'EOS', 'name': 'Bitmart Futures EOS'},
#  {'id': 'XRP', 'name': 'BaseFEX XRP'},
#  {'id': 'BTC', 'name': 'Bithumb (Futures) BTC'},
#  {'id': 'index_BTCUSD', 'name': 'index_BTCUSD'},
#  {'id': 'BTCJ20', 'name': 'BTCJ20'},
#  {'id': 'ETC', 'name': 'CoinTiger (Futures) ETC'},
#  {'id': 'CKB', 'name': 'Bitmart Futures CKB'},
#  {'id': 'BNB', 'name': 'Bitmart Futures BNB'},
#  {'id': 'LTC', 'name': 'Stormgain Futures LTC'},
#  {'id': 'ALPHA', 'name': 'Binance (Futures) ALPHA'},
#  {'id': 'YFI', 'name': 'Binance (Futures) YFI'},
#  {'id': 'MASK', 'name': 'Huobi Futures MASK'},
#  {'id': 'XTZ', 'name': 'Binance (Futures) XTZ'},
#  {'id': 'ETHU20', 'name': 'ETHU20'},
#  {'id': 'LINK', 'name': 'Gate.io (Futures) LINK'},
#  {'id': 'IOST', 'name': 'Bitmart Futures IOST'},
#  {'id': 'LTC', 'name': 'CoinTiger (Futures) LTC'},
#  {'id': 'IOTA', 'name': 'Binance (Futures) IOTA'},
#  {'id': 'BTC', 'name': 'Phemex (Futures) BTC'},
#  {'id': 'LINK', 'name': 'Perpetual Protocol LINK'},
#  {'id': 'UMA', 'name': 'Stormgain Futures UMA'},
#  {'id': 'MEDIA', 'name': 'MEDIA'},
#  {'id': 'COMP', 'name': 'MCDEX COMP'},
#  {'id': 'BNB', 'name': 'Binance (Futures) BNB'},
#  {'id': 'ALPHA', 'name': 'MXC (Futures) ALPHA'},
#  {'id': 'BTC', 'name': 'Huobi Futures BTC'},
#  {'id': 'FRONT', 'name': 'Huobi Futures FRONT'},
#  {'id': 'TOMO', 'name': 'Binance (Futures) TOMO'},
#  {'id': 'EOS', 'name': 'HBTC (Futures) EOS'},
#  {'id': 'REN', 'name': 'Binance (Futures) REN'},
#  {'id': 'XAUT', 'name': 'Tether Gold'},
#  {'id': 'SKL', 'name': 'Binance (Futures) SKL'},
#  {'id': 'STORJ', 'name': 'Huobi Futures STORJ'},
#  {'id': 'XRP', 'name': 'Huobi Futures XRP'},
#  {'id': 'LTC', 'name': 'Gate.io (Futures) LTC'},
#  {'id': 'ZEN', 'name': 'Huobi Futures ZEN'},
#  {'id': 'AVAX', 'name': 'Binance (Futures) AVAX'},
#  {'id': 'EGLD', 'name': 'Binance (Futures) EGLD'},
#  {'id': 'CHZ', 'name': 'Chiliz'},
#  {'id': 'BAND', 'name': 'Gate.io (Futures) BAND'},
#  {'id': 'REN', 'name': 'Huobi Futures REN'},
#  {'id': 'ADA', 'name': 'MXC (Futures) ADA'},
#  {'id': 'SUN', 'name': 'MXC (Futures) SUN'},
#  {'id': 'XMRN20', 'name': 'XMRN20'},
#  {'id': 'XMR', 'name': 'HBTC (Futures) XMR'},
#  {'id': 'TRX', 'name': 'TRX'},
#  {'id': 'THETA', 'name': 'Binance (Futures) THETA'},
#  {'id': 'ADA', 'name': 'Binance (Futures) ADA'},
#  {'id': 'DASH', 'name': 'CoinTiger (Futures) DASH'},
#  {'id': 'BAT', 'name': 'Basic Attention Token'},
#  {'id': 'LTCJ20', 'name': 'LTCJ20'},
#  {'id': 'ETC', 'name': 'Binance (Futures) ETC'},
#  {'id': 'STMX', 'name': 'MXC (Futures) STMX'},
#  {'id': 'SUN', 'name': 'Huobi Futures SUN'},
#  {'id': 'HNT', 'name': 'MXC (Futures) HNT'},
#  {'id': 'SUSHI', 'name': 'HBTC (Futures) SUSHI'},
#  {'id': 'BZRX', 'name': 'CoinTiger (Futures) BZRX'},
#  {'id': 'ATOM', 'name': 'Cosmos'},
#  {'id': 'FLM', 'name': 'Flamingo'},
#  {'id': 'PEARL', 'name': 'Gate.io (Futures) PEARL'},
#  {'id': 'LTC', 'name': 'HBTC (Futures) LTC'},
#  {'id': 'BSV', 'name': 'Huobi Futures BSV'},
#  {'id': 'BBAXQ20', 'name': 'BBAXQ20'},
#  {'id': 'BBAXJ20', 'name': 'BBAXJ20'},
#  {'id': 'DOGE', 'name': 'CoinTiger (Futures) DOGE'},
#  {'id': 'SAND', 'name': 'Binance (Futures) SAND'},
#  {'id': 'AXS', 'name': 'MXC (Futures) AXS'},
#  {'id': 'FIL', 'name': 'MXC (Futures) FIL'},
#  {'id': 'CONV', 'name': 'Convergence'},
#  {'id': 'SUSHI', 'name': 'Binance (Futures) SUSHI'},
#  {'id': 'BCH', 'name': 'Binance (Futures) BCH'},
#  {'id': 'BCHABC', 'name': 'Bitmart Futures BCHABC'},
#  {'id': 'LTCQ20', 'name': 'LTCQ20'},
#  {'id': 'UNI', 'name': 'HBTC (Futures) UNI'},
#  {'id': 'OMG', 'name': 'CoinTiger (Futures) OMG'},
#  {'id': 'OkexSwap-ONT', 'name': 'Okex ONT'},
#  {'id': 'ETHJ20', 'name': 'ETHJ20'},
#  {'id': 'HOT', 'name': 'Binance (Futures) HOT'},
#  {'id': 'RSR', 'name': 'CoinTiger (Futures) RSR'},
#  {'id': 'BTC', 'name': 'C-Trade BTC'},
#  {'id': 'XRP', 'name': 'Stormgain Futures XRP'},
#  {'id': 'ETHQ20', 'name': 'ETHQ20'},
#  {'id': 'BTCQ20', 'name': 'BTCQ20'},
#  {'id': 'BSV', 'name': 'MXC (Futures) BSV'},
#  {'id': 'GRT', 'name': 'CoinTiger (Futures) GRT'},
#  {'id': 'KNC', 'name': 'Kyber Network'},
#  {'id': 'BCH', 'name': 'Poloniex Futures BCH'},
#  {'id': 'XEM', 'name': 'Binance (Futures) XEM'},
#  {'id': 'BCH', 'name': 'BitZ (Futures) BCH'},
#  {'id': 'NPXS', 'name': 'Pundi X'},
#  {'id': 'EXCH', 'name': 'Exchange Token Index'},
#  {'id': 'SOL', 'name': 'Solana'},
#  {'id': 'UNI', 'name': 'Poloniex Futures UNI'},
#  {'id': 'WNXM', 'name': 'Huobi Futures WNXM'},
#  {'id': 'PAXG', 'name': 'BitZ (Futures) PAXG'},
#  {'id': 'SKL', 'name': 'MXC (Futures) SKL'},
#  {'id': 'DRGN', 'name': 'Dragon Index'},
#  {'id': 'LTCZ20', 'name': 'LTCZ20'},
#  {'id': 'UNISWAP', 'name': 'Uniswap Index'},
#  {'id': 'DOGE', 'name': 'BitZ (Futures) DOGE'},
#  {'id': 'KNC', 'name': 'MXC (Futures) KNC'},
#  {'id': 'BBCXJ20', 'name': 'BBCXJ20'},
#  {'id': 'OMG', 'name': 'OMG Network'},
#  {'id': 'ENJ', 'name': 'MXC (Futures) ENJ'},
#  {'id': 'BSV', 'name': 'HBTC (Futures) BSV'},
#  {'id': 'WOO', 'name': 'Huobi Futures WOO'},
#  {'id': 'OkexSwap-BCH', 'name': 'Okex BCH'},
#  {'id': 'COMP', 'name': 'Compound Token'},
#  {'id': 'ONT', 'name': 'Bitmart Futures ONT'},
#  {'id': 'ALPHA', 'name': 'Alpha Finance'},
#  {'id': 'SKL', 'name': 'SKALE'},
#  {'id': 'DOT', 'name': 'Polkadot'},
#  {'id': 'BTCZ20', 'name': 'BTCZ20'},
#  {'id': 'ETHZ20', 'name': 'ETHZ20'},
#  {'id': 'LINK', 'name': 'Chainlink'},
#  {'id': 'KAVA', 'name': 'Binance (Futures) KAVA'},
#  {'id': 'LINK', 'name': 'Biki (Futures) LINK'},
#  {'id': 'ZIL', 'name': 'MXC (Futures) ZIL'},
#  {'id': 'BTC', 'name': 'Bitmart Futures BTC'},
#  {'id': 'OkexSwap-DOGE', 'name': 'Okex DOGE'},
#  {'id': 'ZRX', 'name': 'MXC (Futures) ZRX'},
#  {'id': 'DOT-DIVE-42.00-D0801', 'name': 'ACDX Futures DOT-DIVE-42.00-D0801'},
#  {'id': 'ADA', 'name': 'HBTC (Futures) ADA'},
#  {'id': 'SWRV', 'name': 'Huobi Futures SWRV'},
#  {'id': 'EOS', 'name': 'Biki (Futures) EOS'},
#  {'id': 'DOT', 'name': 'ZBG Futures DOT'},
#  {'id': 'SUSHI', 'name': 'Bitget Futures SUSHI'},
#  {'id': 'FIL', 'name': 'Huobi Futures FIL'},
#  {'id': 'DODO', 'name': 'CoinTiger (Futures) DODO'},
#  {'id': 'OkexSwap-KSM', 'name': 'Okex KSM'},
#  {'id': 'ENJ', 'name': 'Enjin Coin'},
#  {'id': 'HT', 'name': 'Huobi Token'},
#  {'id': 'SFP', 'name': 'Binance (Futures) SFP'},
#  {'id': 'STMX', 'name': 'Binance (Futures) STMX'},
#  {'id': 'BCH', 'name': 'Biki (Futures) BCH'},
#  {'id': 'ONT', 'name': 'Ontology'},
#  {'id': 'ADA', 'name': 'Bitget Futures ADA'},
#  {'id': 'YFI', 'name': 'HBTC (Futures) YFI'},
#  {'id': 'LTC', 'name': 'BitZ (Futures) LTC'},
#  {'id': '1INCH-MOON-3.50-M1001', 'name': 'ACDX Futures 1INCH-MOON-3.50-M1001'},
#  {'id': 'OkexSwap-ZEC', 'name': 'Okex ZEC'},
#  {'id': 'BRZ', 'name': 'Brazilian Digital Token'},
#  {'id': 'NEO', 'name': 'NEO'},
#  {'id': 'OGN', 'name': 'Binance (Futures) OGN'},
#  {'id': 'XLM', 'name': 'Binance (Futures) XLM'},
#  {'id': 'DASH', 'name': 'Dash'},
#  {'id': 'STEP', 'name': 'Step Finance'},
#  {'id': 'SRM', 'name': 'Binance (Futures) SRM'},
#  {'id': 'BTS', 'name': 'Binance (Futures) BTS'},
#  {'id': 'BCH', 'name': 'HBTC (Futures) BCH'},
#  {'id': 'OkexSwap-MASK', 'name': 'Okex MASK'},
#  {'id': 'BTMX', 'name': 'BitMax Token'},
#  {'id': 'BCH', 'name': 'Bitcoin Cash'},
#  {'id': 'ENJ', 'name': 'Binance (Futures) ENJ'},
#  {'id': 'BBCXZ20', 'name': 'BBCXZ20'},
#  {'id': 'ONT', 'name': 'Huobi Futures ONT'},
#  {'id': 'AXS', 'name': 'Axie Infinity'},
#  {'id': 'SECO', 'name': 'Serum Ecosystem Pool Token'},
#  {'id': 'LIT', 'name': 'Binance (Futures) LIT'},
#  {'id': 'UNFI', 'name': 'Binance (Futures) UNFI'},
#  {'id': 'XAUTPFC', 'name': 'XAUTPFC'},
#  {'id': 'MAPS', 'name': 'Maps.me Token'},
#  {'id': 'XEM', 'name': 'NEM'},
#  {'id': 'LINKPFC', 'name': 'LINKPFC'},
#  {'id': 'ACH', 'name': 'Huobi Futures ACH'},
#  {'id': 'HNT', 'name': 'Helium'},
#  {'id': 'SUSHI', 'name': 'Sushi'},
#  {'id': 'XMR', 'name': 'Monero'},
#  {'id': 'LTCJ21', 'name': 'LTCJ21'},
#  {'id': 'ALGO', 'name': 'Algorand'},
#  {'id': 'OkexSwap-GRT', 'name': 'Okex GRT'},
#  {'id': 'ZRX', 'name': '0x'},
#  {'id': 'LTCG21', 'name': 'LTCG21'},
#  {'id': 'ETH', 'name': 'Hopex ETH'},
#  {'id': 'OkexSwap-XRP', 'name': 'Okex XRP'},
#  {'id': 'SNX', 'name': 'Synthetix Network Token'},
#  {'id': 'XMRJ21', 'name': 'XMRJ21'},
#  {'id': 'LRC', 'name': 'Loopring'},
#  {'id': 'TRYB', 'name': 'BiLira'},
#  {'id': 'LTCPFC', 'name': 'LTCPFC'},
#  {'id': 'DOGE', 'name': 'ZBG Futures DOGE'},
#  {'id': 'BNB', 'name': 'BNB'},
#  {'id': 'ETH-DIVE-2200-D0214', 'name': 'ACDX Futures ETH-DIVE-2200-D0214'},
#  {'id': 'BTT', 'name': 'BitTorrent'},
#  {'id': 'FIL', 'name': 'Filecoin'},
#  {'id': 'DEXEMXBT', 'name': '.DEXEMXBT'},
#  {'id': 'FIL', 'name': 'Biki (Futures) FIL'},
#  {'id': 'XRP', 'name': 'Biki (Futures) XRP'},
#  {'id': 'FTT-DIVE-50.0-D0405', 'name': 'ACDX Futures FTT-DIVE-50.0-D0405'},
#  {'id': 'UNI', 'name': 'Biki (Futures) UNI'},
#  {'id': 'XMRG21', 'name': 'XMRG21'},
#  {'id': 'SUSHI', 'name': 'Biki (Futures) SUSHI'},
#  {'id': 'BSV', 'name': 'Biki (Futures) BSV'},
#  {'id': 'ETH', 'name': 'Biki (Futures) ETH'},
#  {'id': 'DE1INCHUSDT', 'name': '.DE1INCHUSDT'},
#  {'id': 'DEAAVEUSDT', 'name': '.DEAAVEUSDT'},
#  {'id': 'OkexSwap-UMA', 'name': 'Okex UMA'},
#  {'id': 'DEWAVESXBT', 'name': '.DEWAVESXBT'},
#  {'id': 'DEKNCUSDT', 'name': '.DEKNCUSDT'},
#  {'id': 'index_ETHUSD', 'name': 'index_ETHUSD'},
#  {'id': 'BTCST', 'name': 'Binance (Futures) BTCST'},
#  {'id': 'BTCX20', 'name': 'BTCX20'},
#  {'id': 'XRP', 'name': 'Bitget Futures XRP'},
#  {'id': 'DEETCUSDT', 'name': '.DEETCUSDT'},
#  {'id': 'XMRX20', 'name': 'XMRX20'},
#  {'id': 'ETH', 'name': 'Bitget Futures ETH'},
#  {'id': 'DEXRPUSDT', 'name': '.DEXRPUSDT'},
#  {'id': 'LTCX20', 'name': 'LTCX20'},
#  {'id': 'ETHG21', 'name': 'ETHG21'},
#  {'id': 'BTC', 'name': 'Bitget Futures BTC'},
#  {'id': 'DEBANDUSDT', 'name': '.DEBANDUSDT'},
#  {'id': 'EOS', 'name': 'Bitget Futures EOS'},
#  {'id': 'XLM', 'name': 'Bitget Futures XLM'},
#  {'id': 'OkexSwap-PERP', 'name': 'Okex PERP'},
#  {'id': 'DESUSHIUSDT', 'name': '.DESUSHIUSDT'},
#  {'id': 'BEOST30M', 'name': '.BEOST30M'},
#  {'id': 'AKRO', 'name': 'Binance (Futures) AKRO'},
#  {'id': 'COMP', 'name': 'Stormgain Futures COMP'},
#  {'id': 'IOST', 'name': 'Binance (Futures) IOST'},
#  {'id': 'LTC', 'name': 'Bitget Futures LTC'},
#  {'id': 'ETC', 'name': 'Bitget Futures ETC'},
#  {'id': 'OkexSwap-AVAX', 'name': 'Okex AVAX'},
#  {'id': 'BBAXZ20', 'name': 'BBAXZ20'},
#  {'id': 'DEBCHUSDT', 'name': '.DEBCHUSDT'},
#  {'id': 'KVETUSDT', 'name': '.KVETUSDT'},
#  {'id': 'DOT', 'name': 'Bitget Futures DOT'},
#  {'id': 'ETH', 'name': 'ZBG Futures ETH'},
#  {'id': 'NEAR', 'name': 'Binance (Futures) NEAR'},
#  {'id': 'UNI', 'name': 'Binance (Futures) UNI'},
#  {'id': 'CTK', 'name': 'Binance (Futures) CTK'},
#  {'id': 'MANA', 'name': 'Binance (Futures) MANA'},
#  {'id': 'BNB', 'name': 'Bitforex (Futures) BNB'},
#  {'id': 'DETRXUSDT', 'name': '.DETRXUSDT'},
#  {'id': 'FLM', 'name': 'Binance (Futures) FLM'},
#  {'id': 'MATIC', 'name': 'Binance (Futures) MATIC'},
#  {'id': 'OkexSwap-ZRX', 'name': 'Okex ZRX'},
#  {'id': 'ETHX20', 'name': 'ETHX20'},
#  {'id': 'BBCXX20', 'name': 'BBCXX20'},
#  {'id': 'OkexSwap-DASH', 'name': 'Okex DASH'},
#  {'id': 'OkexSwap-ALPHA', 'name': 'Okex ALPHA'},
#  {'id': 'LINK', 'name': 'Bitget Futures LINK'},
#  {'id': 'BTCG21', 'name': 'BTCG21'},
#  {'id': 'ZEC', 'name': 'HBTC (Futures) ZEC'},
#  {'id': 'KSM', 'name': 'CoinTiger (Futures) KSM'},
#  {'id': 'ZEN', 'name': 'CoinTiger (Futures) ZEN'},
#  {'id': 'BLZ', 'name': 'Binance (Futures) BLZ'},
#  {'id': 'ALICE', 'name': 'Binance (Futures) ALICE'},
#  {'id': 'OkexSwap-CRO', 'name': 'Okex CRO'},
#  {'id': 'OkexSwap-TORN', 'name': 'Okex TORN'},
#  {'id': 'BTC', 'name': 'Perpetual Protocol BTC'},
#  {'id': 'BEAM', 'name': 'Gate.io (Futures) BEAM'},
#  {'id': 'OCEAN', 'name': 'CoinTiger (Futures) OCEAN'},
#  {'id': 'TRX', 'name': 'CoinTiger (Futures) TRX'},
#  {'id': 'OCEAN', 'name': 'Binance (Futures) OCEAN'},
#  {'id': 'QTUM', 'name': 'Binance (Futures) QTUM'},
#  {'id': 'CRV', 'name': 'CoinTiger (Futures) CRV'},
#  {'id': 'FTM', 'name': 'Fantom'},
#  {'id': 'XLM', 'name': 'Stellar'},
#  {'id': 'OXY', 'name': 'Oxygen Protocol'},
#  {'id': 'STORJ', 'name': 'Binance (Futures) STORJ'},
#  {'id': 'SNX', 'name': 'Binance (Futures) SNX'},
#  {'id': 'MTL', 'name': 'Gate.io (Futures) MTL'},
#  {'id': 'BCH', 'name': 'Phemex (Futures) BCH'},
#  {'id': 'LTCM21', 'name': 'LTCM21'},
#  {'id': 'TOMO', 'name': 'TomoChain'},
#  {'id': 'BNB', 'name': 'CoinTiger (Futures) BNB'},
#  {'id': 'UNI', 'name': 'Stormgain Futures UNI'},
#  {'id': 'SKL', 'name': 'CoinTiger (Futures) SKL'},
#  {'id': 'SXP', 'name': 'Binance (Futures) SXP'},
#  {'id': 'ZRX', 'name': 'Binance (Futures) ZRX'},
#  {'id': 'KSM', 'name': 'MXC (Futures) KSM'},
#  {'id': 'ANT', 'name': 'Huobi Futures ANT'},
#  {'id': 'DOT', 'name': 'MXC (Futures) DOT'},
#  {'id': 'XRP', 'name': 'Phemex (Futures) XRP'},
#  {'id': 'RLC', 'name': 'Binance (Futures) RLC'},
#  {'id': 'ZEC', 'name': 'CoinTiger (Futures) ZEC'},
#  {'id': 'BCH', 'name': 'CoinTiger (Futures) BCH'},
#  {'id': 'AR', 'name': 'Arweave'},
#  {'id': 'QTUM', 'name': 'Stormgain Futures QTUM'},
#  {'id': 'REEF', 'name': 'Binance (Futures) REEF'},
#  {'id': 'DMG', 'name': 'DMM Governance'},
#  {'id': 'BCH', 'name': 'MXC (Futures) BCH'},
#  {'id': 'DASH', 'name': 'Binance (Futures) DASH'},
#  {'id': 'BCH', 'name': 'Gate.io (Futures) BCH'},
#  {'id': 'SNX', 'name': 'CoinTiger (Futures) SNX'},
#  {'id': 'CHR', 'name': 'CoinTiger (Futures) CHR'},
#  {'id': 'DENT', 'name': 'Binance (Futures) DENT'},
#  {'id': 'UNI', 'name': 'Phemex (Futures) UNI'},
#  {'id': 'XAUBPFC', 'name': 'XAUBPFC'},
#  {'id': 'ONT', 'name': 'Stormgain Futures ONT'},
#  {'id': 'IOTA', 'name': 'MXC (Futures) IOTA'},
#  {'id': 'CVC', 'name': 'Huobi Futures CVC'},
#  {'id': 'SFP', 'name': 'CoinTiger (Futures) SFP'},
#  {'id': 'ALGO', 'name': 'Binance (Futures) ALGO'},
#  {'id': 'YFI', 'name': 'Phemex (Futures) YFI'},
#  {'id': 'BCH', 'name': 'AscendEX  (BitMax) (Futures) BCH'},
#  {'id': 'ANKR', 'name': 'Binance (Futures) ANKR'},
#  {'id': 'XRP', 'name': 'MXC (Futures) XRP'},
#  {'id': 'BAL', 'name': 'CoinTiger (Futures) BAL'},
#  {'id': 'AMPL', 'name': 'Gate.io (Futures) AMPL'},
#  {'id': 'DOT', 'name': 'Phemex (Futures) DOT'},
#  {'id': 'LRC', 'name': 'Binance (Futures) LRC'},
#  {'id': 'BTCPFC', 'name': 'BTCPFC'},
#  {'id': 'BTCDOM', 'name': 'Bitfinex (Futures) BTCDOM'},
#  {'id': 'ALGO', 'name': 'Phemex (Futures) ALGO'},
#  {'id': 'NEO', 'name': 'Binance (Futures) NEO'},
#  {'id': 'XRP', 'name': 'CoinTiger (Futures) XRP'},
#  {'id': 'EOS', 'name': 'Bitfinex (Futures) EOS'},
#  {'id': 'USDTPFC', 'name': 'USDTPFC'},
#  {'id': 'OMG', 'name': 'MXC (Futures) OMG'},
#  {'id': 'TRU', 'name': 'Gate.io (Futures) TRU'},
#  {'id': 'ZIL', 'name': 'Huobi Futures ZIL'},
#  {'id': '1INCH', 'name': 'CoinTiger (Futures) 1INCH'},
#  {'id': 'BTC', 'name': 'dYdX Perpetual (L1) BTC'},
#  {'id': 'HNT', 'name': 'Binance (Futures) HNT'},
#  {'id': 'COMP', 'name': 'Phemex (Futures) COMP'},
#  {'id': 'VET', 'name': 'Stormgain Futures VET'},
#  {'id': 'SOL', 'name': 'MXC (Futures) SOL'},
#  {'id': 'XTZ', 'name': 'MXC (Futures) XTZ'},
#  {'id': 'REN', 'name': 'REN'},
#  {'id': 'LTC', 'name': 'Phemex (Futures) LTC'},
#  {'id': 'YFI', 'name': 'Stormgain Futures YFI'},
#  {'id': 'BAND', 'name': 'CoinTiger (Futures) BAND'},
#  {'id': 'XRP', 'name': 'Bitforex (Futures) XRP'},
#  {'id': 'DOT', 'name': 'CoinTiger (Futures) DOT'},
#  {'id': 'LINK', 'name': 'Bitfinex (Futures) LINK'},
#  {'id': 'ANKR', 'name': 'MXC (Futures) ANKR'},
#  {'id': 'KAVA', 'name': 'CoinTiger (Futures) KAVA'},
#  {'id': 'BTC', 'name': 'Bitforex (Futures) BTC'},
#  {'id': 'DASH', 'name': 'Stormgain Futures DASH'},
#  {'id': 'SUSHI', 'name': 'MXC (Futures) SUSHI'},
#  {'id': 'BEAM', 'name': 'Bitforex (Futures) BEAM'},
#  {'id': 'BAND', 'name': 'MXC (Futures) BAND'},
#  {'id': 'OkexSwap-TRX', 'name': 'Okex TRX'},
#  {'id': 'ETH', 'name': 'Stormgain Futures ETH'},
#  {'id': 'XMRF21', 'name': 'XMRF21'},
#  {'id': 'DOGE', 'name': 'MXC (Futures) DOGE'},
#  {'id': 'OkexSwap-ETC', 'name': 'Okex ETC'},
#  {'id': 'AVAX', 'name': 'MXC (Futures) AVAX'},
#  {'id': 'DOT', 'name': 'Bitfinex (Futures) DOT'},
#  {'id': 'MANA', 'name': 'MXC (Futures) MANA'},
#  {'id': 'LTCF21', 'name': 'LTCF21'},
#  {'id': 'ADA', 'name': 'Stormgain Futures ADA'},
#  {'id': 'BTT', 'name': 'CoinTiger (Futures) BTT'},
#  {'id': 'RVN', 'name': 'Binance (Futures) RVN'},
#  {'id': 'BAL', 'name': 'Binance (Futures) BAL'},
#  {'id': 'ETHF21', 'name': 'ETHF21'},
#  {'id': 'REEF', 'name': 'CoinTiger (Futures) REEF'},
#  {'id': 'CHZ', 'name': 'Binance (Futures) CHZ'},
#  {'id': 'ONE', 'name': 'Binance (Futures) ONE'},
#  {'id': 'LRC', 'name': 'MXC (Futures) LRC'},
#  {'id': 'LRC', 'name': 'Gate.io (Futures) LRC'},
#  {'id': 'BXTZT30M', 'name': '.BXTZT30M'},
#  {'id': 'WAVES', 'name': 'Binance (Futures) WAVES'},
#  {'id': 'BNT', 'name': 'Huobi Futures BNT'},
#  {'id': 'BTCF21', 'name': 'BTCF21'},
#  {'id': 'BTC', 'name': 'MXC (Futures) BTC'},
#  {'id': 'ETH', 'name': 'Futureswap ETH'},
#  {'id': 'BYFIT30M', 'name': '.BYFIT30M'},
#  {'id': 'XAUT', 'name': 'Bitfinex (Futures) XAUT'},
#  {'id': 'MDA', 'name': 'Gate.io (Futures) MDA'},
#  {'id': 'ATOM', 'name': 'Binance (Futures) ATOM'},
#  {'id': 'ETC', 'name': 'Stormgain Futures ETC'},
#  {'id': 'LTC', 'name': 'MXC (Futures) LTC'},
#  {'id': 'THETA', 'name': 'Gate.io (Futures) THETA'},
#  {'id': 'EOS', 'name': 'Huobi Futures EOS'},
#  {'id': 'OkexSwap-ENJ', 'name': 'Okex ENJ'},
#  {'id': 'IRIS', 'name': 'Gate.io (Futures) IRIS'},
#  {'id': 'LINA', 'name': 'Binance (Futures) LINA'},
#  {'id': 'DASH', 'name': 'MXC (Futures) DASH'},
#  {'id': 'LRC', 'name': 'Huobi Futures LRC'},
#  {'id': 'MATIC', 'name': 'MXC (Futures) MATIC'},
#  {'id': 'EOS', 'name': 'Stormgain Futures EOS'},
#  {'id': 'ENJ', 'name': 'Huobi Futures ENJ'},
#  {'id': '1INCH', 'name': 'Gate.io (Futures) 1INCH'},
#  {'id': 'BETH', 'name': '.BETH'},
#  {'id': 'XLM', 'name': 'MXC (Futures) XLM'},
#  {'id': 'ONT', 'name': 'MXC (Futures) ONT'},
#  {'id': 'ZEC', 'name': 'MXC (Futures) ZEC'},
#  {'id': 'ZIL', 'name': 'Binance (Futures) ZIL'},
#  {'id': 'REEF', 'name': 'Huobi Futures REEF'},
#  {'id': 'ZRX', 'name': 'Stormgain Futures ZRX'},
#  {'id': 'HOT', 'name': 'MXC (Futures) HOT'},
#  {'id': 'IOST', 'name': 'MXC (Futures) IOST'},
#  {'id': 'LUNA', 'name': 'Huobi Futures LUNA'},
#  {'id': 'SUSHI-MOON-13.50-M0901',
#   'name': 'ACDX Futures SUSHI-MOON-13.50-M0901'},
#  {'id': 'STORJ', 'name': 'MXC (Futures) STORJ'},
#  {'id': 'BTM', 'name': 'MXC (Futures) BTM'},
#  {'id': 'ADA', 'name': 'Bitfinex (Futures) ADA'},
#  {'id': 'IOTA', 'name': 'Huobi Futures IOTA'},
#  {'id': 'MKR', 'name': 'Stormgain Futures MKR'},
#  {'id': 'NEO', 'name': 'Huobi Futures NEO'},
#  {'id': 'AMP', 'name': 'Bitfinex (Futures) AMP'},
#  {'id': 'BADAT30M', 'name': '.BADAT30M'},
#  {'id': 'ETH', 'name': 'MXC (Futures) ETH'},
#  {'id': 'HBAR', 'name': 'MXC (Futures) HBAR'},
#  {'id': 'BTCH21', 'name': 'BTCH21'},
#  {'id': 'DOT', 'name': 'Binance (Futures) DOT'},
#  {'id': 'ETHV20', 'name': 'ETHV20'},
#  {'id': 'TRX', 'name': 'Stormgain Futures TRX'},
#  {'id': 'DOT-MOON-30.00-M0801', 'name': 'ACDX Futures DOT-MOON-30.00-M0801'},
#  {'id': 'AVAX', 'name': 'Huobi Futures AVAX'},
#  {'id': 'CHZ', 'name': 'MXC (Futures) CHZ'},
#  {'id': 'BNB', 'name': 'MXC (Futures) BNB'},
#  {'id': 'BUNIT', 'name': '.BUNIT'},
#  {'id': 'BTT', 'name': 'Gate.io (Futures) BTT'},
#  {'id': 'CTK', 'name': 'MXC (Futures) CTK'},
#  {'id': 'BAGS', 'name': 'Huobi Futures BAGS'},
#  {'id': 'XAG', 'name': 'Bitfinex (Futures) XAG'},
#  {'id': 'OkexSwap-BTC', 'name': 'Okex BTC'},
#  {'id': 'DOGE', 'name': 'Binance (Futures) DOGE'},
#  {'id': 'BBAXK20', 'name': 'BBAXK20'},
#  {'id': 'BTT', 'name': 'MXC (Futures) BTT'},
#  {'id': 'LTC', 'name': 'Bitfinex (Futures) LTC'},
#  {'id': 'AXS', 'name': 'Binance (Futures) AXS'},
#  {'id': 'LTCK20', 'name': 'LTCK20'},
#  {'id': 'OkexSwap-CONV', 'name': 'Okex CONV'},
#  {'id': 'BTS', 'name': 'MXC (Futures) BTS'},
#  {'id': 'SOL', 'name': 'Binance (Futures) SOL'},
#  {'id': 'YFI', 'name': 'Huobi Futures YFI'},
#  {'id': 'OKB', 'name': 'MXC (Futures) OKB'},
#  {'id': 'NEO', 'name': 'MXC (Futures) NEO'},
#  {'id': 'CRV', 'name': 'MXC (Futures) CRV'},
#  {'id': 'DETOMOXBT', 'name': '.DETOMOXBT'},
#  {'id': 'XMRK20', 'name': 'XMRK20'},
#  {'id': 'UNI', 'name': 'Gate.io (Futures) UNI'},
#  {'id': 'ICX', 'name': 'Binance (Futures) ICX'},
#  {'id': 'LINK', 'name': 'MXC (Futures) LINK'},
#  {'id': 'WOZX', 'name': 'ACDX Futures WOZX'},
#  {'id': 'XBT', 'name': 'BTCMEX XBT'},
#  {'id': 'BBCXK20', 'name': 'BBCXK20'},
#  {'id': 'ETHK20', 'name': 'ETHK20'},
#  {'id': 'GBP', 'name': 'Bitfinex (Futures) GBP'},
#  {'id': 'XBT', 'name': 'Poloniex Futures XBT'},
#  {'id': 'KNC', 'name': 'Binance (Futures) KNC'},
#  {'id': 'QTUM', 'name': 'Huobi Futures QTUM'},
#  {'id': 'UNI', 'name': 'Huobi Futures UNI'},
#  {'id': 'VET', 'name': 'Binance (Futures) VET'},
#  {'id': 'XLM', 'name': 'Gate.io (Futures) XLM'},
#  {'id': 'WAVES', 'name': 'MXC (Futures) WAVES'},
#  {'id': 'OGN', 'name': 'MXC (Futures) OGN'},
#  {'id': 'BLTC', 'name': '.BLTC'},
#  {'id': 'MASK', 'name': 'Gate.io (Futures) MASK'},
#  {'id': 'XMR', 'name': 'Huobi Futures XMR'},
#  {'id': 'BCHA', 'name': 'MyCoinStory BCHA'},
#  {'id': 'XMRH21', 'name': 'XMRH21'},
#  {'id': 'DENT', 'name': 'MXC (Futures) DENT'},
#  {'id': 'BAL', 'name': 'Huobi Futures BAL'},
#  {'id': 'ZEC', 'name': 'Binance (Futures) ZEC'},
#  {'id': 'DEZECUSDT', 'name': '.DEZECUSDT'},
#  {'id': 'MKR', 'name': 'Binance (Futures) MKR'},
#  {'id': 'BTC', 'name': 'BTCMEX BTC'},
#  {'id': 'YFII', 'name': 'MXC (Futures) YFII'},
#  {'id': 'OkexSwap-LEND', 'name': 'Okex LEND'},
#  {'id': 'DEXBTUSDT', 'name': '.DEXBTUSDT'},
#  {'id': 'DEAAVEXBT', 'name': '.DEAAVEXBT'},
#  {'id': 'JPY', 'name': 'Bitfinex (Futures) JPY'},
#  {'id': 'BTM', 'name': 'Huobi Futures BTM'},
#  {'id': 'TRX', 'name': 'Poloniex Futures TRX'},
#  {'id': 'YFII', 'name': 'Binance (Futures) YFII'},
#  {'id': 'LEND', 'name': 'MXC (Futures) LEND'},
#  {'id': 'COMP', 'name': 'MXC (Futures) COMP'},
#  {'id': 'KBATUSDT', 'name': '.KBATUSDT'},
#  {'id': 'XTZ', 'name': 'Huobi Futures XTZ'},
#  {'id': 'BLINKT30M', 'name': '.BLINKT30M'},
#  {'id': 'ETH', 'name': 'Alpha5 ETH'},
#  {'id': 'LTCH21', 'name': 'LTCH21'},
#  {'id': 'KAAVEUSDT', 'name': '.KAAVEUSDT'},
#  {'id': 'ETH', 'name': 'MCDEX ETH'},
#  {'id': 'LTC', 'name': 'Poloniex Futures LTC'},
#  {'id': 'RNDR', 'name': 'Huobi Futures RNDR'},
#  {'id': 'TMTG', 'name': 'MyCoinStory TMTG'},
#  {'id': 'ETH', 'name': 'HBTC (Futures) ETH'},
#  {'id': 'KUNIUSDT', 'name': '.KUNIUSDT'},
#  {'id': 'BTC', 'name': 'Alpha5 BTC'},
#  {'id': 'SOL', 'name': 'Huobi Futures SOL'},
#  {'id': 'KDOGEUSDT', 'name': '.KDOGEUSDT'},
#  {'id': 'BTC', 'name': 'HBTC (Futures) BTC'},
#  {'id': 'AAVE', 'name': 'CoinFLEX (Futures) AAVE'},
#  {'id': 'BBCXN20', 'name': 'BBCXN20'},
#  {'id': 'XRP', 'name': 'HBTC (Futures) XRP'},
#  {'id': 'KTRXUSDT', 'name': '.KTRXUSDT'},
#  {'id': 'XLM', 'name': 'Huobi Futures XLM'},
#  {'id': 'KOCEANUSDT', 'name': '.KOCEANUSDT'},
#  {'id': 'HBAR', 'name': 'Huobi Futures HBAR'},
#  {'id': 'BAL', 'name': 'CoinFLEX (Futures) BAL'},
#  {'id': 'RVN', 'name': 'Huobi Futures RVN'},
#  {'id': 'DELTCUSDT', 'name': '.DELTCUSDT'},
#  {'id': 'ROSE', 'name': 'Gate.io (Futures) ROSE'},
#  {'id': 'KALGOUSDT', 'name': '.KALGOUSDT'},
#  {'id': 'OkexSwap-ZEN', 'name': 'Okex ZEN'},
#  {'id': 'ZRX', 'name': 'Gate.io (Futures) ZRX'},
#  {'id': 'DELINKUSDT', 'name': '.DELINKUSDT'},
#  {'id': 'BDIPFC', 'name': 'BDIPFC'},
#  {'id': 'LEND', 'name': 'CoinTiger (Futures) LEND'},
#  {'id': 'DOGE', 'name': 'Gate.io (Futures) DOGE'},
#  {'id': 'CHZ', 'name': 'Gate.io (Futures) CHZ'},
#  {'id': 'KAVA', 'name': 'Gate.io (Futures) KAVA'},
#  {'id': 'DEEOSUSDT', 'name': '.DEEOSUSDT'},
#  {'id': 'USDT', 'name': 'Huobi Futures USDT'},
#  {'id': 'KDENTUSDT', 'name': '.KDENTUSDT'},
#  {'id': 'KXEMUSDT', 'name': '.KXEMUSDT'},
#  {'id': 'LUNA', 'name': 'Gate.io (Futures) LUNA'},
#  {'id': 'KIOSTUSDT', 'name': '.KIOSTUSDT'},
#  {'id': 'KKSMUSDT', 'name': '.KKSMUSDT'},
#  {'id': 'XTZ', 'name': 'Gate.io (Futures) XTZ'},
#  {'id': 'EGLD', 'name': 'Gate.io (Futures) EGLD'},
#  {'id': 'STORJ', 'name': 'Gate.io (Futures) STORJ'},
#  {'id': 'ZEN', 'name': 'Gate.io (Futures) ZEN'},
#  {'id': 'OkexSwap-MKR', 'name': 'Okex MKR'},
#  {'id': 'LINK', 'name': 'Hopex LINK'},
#  {'id': 'ETH', 'name': 'CoinFLEX (Futures) ETH'},
#  {'id': 'BTCV20', 'name': 'BTCV20'},
#  {'id': 'KQTUMUSDT', 'name': '.KQTUMUSDT'},
#  {'id': 'KAVAXUSDT', 'name': '.KAVAXUSDT'},
#  {'id': 'DEADAUSDT', 'name': '.DEADAUSDT'},
#  {'id': 'SXP', 'name': 'Gate.io (Futures) SXP'},
#  {'id': 'KFTMUSDT', 'name': '.KFTMUSDT'},
#  {'id': 'KSM', 'name': 'Gate.io (Futures) KSM'},
#  {'id': 'BTC', 'name': 'CoinFLEX (Futures) BTC'},
#  {'id': 'BAT', 'name': 'Gate.io (Futures) BAT'},
#  {'id': 'BTCK20', 'name': 'BTCK20'},
#  {'id': 'DOT', 'name': 'CoinFLEX (Futures) DOT'},
#  {'id': 'XMRV20', 'name': 'XMRV20'},
#  {'id': 'DESNXUSDT', 'name': '.DESNXUSDT'},
#  {'id': 'KCHZUSDT', 'name': '.KCHZUSDT'},
#  {'id': 'LTC', 'name': 'Hopex LTC'},
#  {'id': 'DASH', 'name': 'CoinFLEX (Futures) DASH'},
#  {'id': 'KXBTUSDT', 'name': '.KXBTUSDT'},
#  {'id': 'XLM', 'name': 'MyCoinStory XLM'},
#  {'id': 'KTHETAUSDT', 'name': '.KTHETAUSDT'},
#  {'id': 'SRM', 'name': 'MXC (Futures) SRM'},
#  {'id': 'BTC', 'name': 'Bit.com BTC'},
#  {'id': 'ETHN20', 'name': 'ETHN20'},
#  {'id': 'XEM', 'name': 'MXC (Futures) XEM'},
#  {'id': 'BTC', 'name': 'ACDX Futures BTC'},
#  {'id': 'QTUM', 'name': 'MXC (Futures) QTUM'},
#  {'id': 'BBAXV20', 'name': 'BBAXV20'},
#  {'id': 'KXLMUSDT', 'name': '.KXLMUSDT'},
#  {'id': 'EGLD', 'name': 'MXC (Futures) EGLD'},
#  {'id': 'NEO', 'name': 'MyCoinStory NEO'},
#  {'id': 'BTCN20', 'name': 'BTCN20'},
#  {'id': 'LTCV20', 'name': 'LTCV20'},
#  {'id': 'DEAVAXUSDT', 'name': '.DEAVAXUSDT'},
#  {'id': 'BXBT', 'name': '.BXBT'},
#  {'id': 'KSUSHIUSDT', 'name': '.KSUSHIUSDT'},
#  {'id': 'ETC', 'name': 'MXC (Futures) ETC'},
#  {'id': 'BBAXN20', 'name': 'BBAXN20'},
#  {'id': 'MTL', 'name': 'MXC (Futures) MTL'},
#  {'id': 'ETH', 'name': 'ACDX Futures ETH'},
#  {'id': 'TRX', 'name': 'MXC (Futures) TRX'},
#  {'id': 'OkexSwap-ZIL', 'name': 'Okex ZIL'},
#  {'id': 'KYFIUSDT', 'name': '.KYFIUSDT'},
#  {'id': 'BCH', 'name': 'MyCoinStory BCH'},
#  {'id': 'YFI', 'name': 'MXC (Futures) YFI'},
#  {'id': 'LUNA', 'name': 'MyCoinStory LUNA'},
#  {'id': 'BTC', 'name': 'Deribit BTC'},
#  {'id': 'KETHUSDT', 'name': '.KETHUSDT'},
#  {'id': 'ETHH21', 'name': 'ETHH21'},
#  {'id': 'LINK', 'name': 'Poloniex Futures LINK'},
#  {'id': 'XMR', 'name': 'Stormgain Futures XMR'},
#  {'id': 'UNI', 'name': 'Perpetual Protocol UNI'},
#  {'id': 'KSXPUSDT', 'name': '.KSXPUSDT'},
#  {'id': 'BAT', 'name': 'MXC (Futures) BAT'},
#  {'id': 'KLAY', 'name': 'MyCoinStory KLAY'},
#  {'id': 'BCH', 'name': 'Hopex BCH'},
#  {'id': 'OkexSwap-SC', 'name': 'Okex SC'},
#  {'id': 'KETHUSD', 'name': '.KETHUSD'},
#  {'id': 'ETH', 'name': 'MyCoinStory ETH'},
#  {'id': 'ETC', 'name': 'Hopex ETC'},
#  {'id': 'KLTCUSDT', 'name': '.KLTCUSDT'},
#  {'id': 'BCH', 'name': 'Bit.com BCH'},
#  {'id': 'LINK', 'name': 'MyCoinStory LINK'},
#  {'id': 'KCRVUSDT', 'name': '.KCRVUSDT'},
#  {'id': 'BCH', 'name': 'Bitforex (Futures) BCH'},
#  {'id': 'XRP', 'name': 'MyCoinStory XRP'},
#  {'id': 'KFILUSDT', 'name': '.KFILUSDT'},
#  {'id': 'COPE-MOON-1.00-M1502', 'name': 'ACDX Futures COPE-MOON-1.00-M1502'},
#  {'id': 'LINK', 'name': 'MCDEX LINK'},
#  {'id': 'ETH', 'name': 'Bit.com ETH'},
#  {'id': 'OkexSwap-YFV', 'name': 'Okex YFV'},
#  {'id': 'KXRPUSDT', 'name': '.KXRPUSDT'},
#  {'id': 'SNX', 'name': 'MCDEX SNX'},
#  {'id': 'IOTA', 'name': 'Stormgain Futures IOTA'},
#  {'id': 'ADA', 'name': 'MyCoinStory ADA'},
#  {'id': 'KDOTUSD', 'name': '.KDOTUSD'},
#  {'id': 'BSV', 'name': 'Bitforex (Futures) BSV'},
#  {'id': 'KSOLUSDT', 'name': '.KSOLUSDT'},
#  {'id': 'RSR', 'name': 'CoinFLEX (Futures) RSR'},
#  {'id': 'BNC ETH High Frequency Index',
#   'name': 'BNC ETH High Frequency Index'},
#  {'id': 'KBCHUSDT', 'name': '.KBCHUSDT'},
#  {'id': 'KATOMUSDT', 'name': '.KATOMUSDT'},
#  {'id': 'KLINKUSDT', 'name': '.KLINKUSDT'},
#  {'id': 'KNC', 'name': 'Huobi Futures KNC'},
#  {'id': 'KZECUSDT', 'name': '.KZECUSDT'},
#  {'id': 'KXRPUSD', 'name': '.KXRPUSD'},
#  {'id': 'XRP', 'name': 'ZBG Futures XRP'},
#  {'id': 'UNI', 'name': 'Bitfinex (Futures) UNI'},
#  {'id': 'LEND', 'name': 'MCDEX LEND'},
#  {'id': 'PHA', 'name': 'Huobi Futures PHA'},
#  {'id': 'LTC', 'name': 'Huobi Futures LTC'},
#  {'id': 'BTT', 'name': 'Huobi Futures BTT'},
#  {'id': 'GERMANY30IX', 'name': 'Bitfinex (Futures) GERMANY30IX'},
#  {'id': 'BTRXXBT30M', 'name': '.BTRXXBT30M'},
#  {'id': 'MANA', 'name': 'Huobi Futures MANA'},
#  {'id': 'MATIC', 'name': 'Huobi Futures MATIC'},
#  {'id': 'ADA', 'name': 'Huobi Futures ADA'},
#  {'id': 'LINK', 'name': 'Stormgain Futures LINK'},
#  {'id': 'LTCU20', 'name': 'LTCU20'},
#  {'id': 'KEOSUSDT', 'name': '.KEOSUSDT'},
#  {'id': 'DEEOSXBT', 'name': '.DEEOSXBT'},
#  {'id': 'BBCXU20', 'name': 'BBCXU20'},
#  {'id': 'PEARL', 'name': 'Huobi Futures PEARL'},
#  {'id': 'BTCU20', 'name': 'BTCU20'},
#  {'id': 'XMRU20', 'name': 'XMRU20'},
#  {'id': 'KMANAUSDT', 'name': '.KMANAUSDT'},
#  {'id': 'SUSHI', 'name': 'Huobi Futures SUSHI'},
#  {'id': 'XRP', 'name': 'Hopex XRP'},
#  {'id': 'SNX', 'name': 'Perpetual Protocol SNX'},
#  {'id': 'LEND', 'name': 'Huobi Futures LEND'},
#  {'id': 'EOS', 'name': 'Bybit EOS'},
#  {'id': 'MKR', 'name': 'Huobi Futures MKR'},
#  {'id': 'AAVE', 'name': 'Huobi Futures AAVE'},
#  {'id': 'OkexSwap-RSR', 'name': 'Okex RSR'},
#  {'id': 'TRB', 'name': 'Huobi Futures TRB'},
#  {'id': 'DEKAVAUSDT', 'name': '.DEKAVAUSDT'},
#  {'id': 'OkexSwap-BNT', 'name': 'Okex BNT'},
#  {'id': 'DOT', 'name': 'Hopex DOT'},
#  {'id': 'KMATICUSDT', 'name': '.KMATICUSDT'},
#  {'id': 'KDOTUSDT', 'name': '.KDOTUSDT'},
#  {'id': 'KENJUSDT', 'name': '.KENJUSDT'},
#  {'id': 'KBTTUSDT', 'name': '.KBTTUSDT'},
#  {'id': 'LEND', 'name': 'Binance (Futures) LEND'},
#  {'id': 'BNB', 'name': 'Huobi Futures BNB'},
#  {'id': 'CRV', 'name': 'Huobi Futures CRV'},
#  {'id': 'OkexSwap-FLM', 'name': 'Okex FLM'},
#  {'id': 'DEXEMUSDT', 'name': '.DEXEMUSDT'},
#  {'id': 'DEXLMUSDT', 'name': '.DEXLMUSDT'},
#  {'id': 'YFV', 'name': 'Huobi Futures YFV'},
#  {'id': 'DEYFIXBT', 'name': '.DEYFIXBT'},
#  {'id': 'OkexSwap-IOTA', 'name': 'Okex IOTA'},
#  {'id': 'OkexSwap-XTZ', 'name': 'Okex XTZ'},
#  {'id': 'DOT', 'name': 'ACDX Futures DOT'},
#  {'id': 'CRO', 'name': 'Huobi Futures CRO'},
#  {'id': 'KGRTUSDT', 'name': '.KGRTUSDT'},
#  {'id': 'GRIN', 'name': 'Bitforex (Futures) GRIN'},
#  {'id': 'OkexSwap-BTM', 'name': 'Okex BTM'},
#  ...]

# %% [markdown]
# ### Derivatives

# %%
# List all derivative tickers
cg.get_derivatives()[:2]
# Out:
# [{'market': 'Huobi Futures',
#   'symbol': 'TRX-USDT',
#   'index_id': 'TRX',
#   'price': '0.14',
#   'price_percentage_change_24h': -5.0221142,
#   'contract_type': 'perpetual',
#   'index': 0.139029405458,
#   'basis': -0.0895371617057361,
#   'spread': 0.01,
#   'funding_rate': 0.0499049437472173,
#   'open_interest': 2375911734.81,
#   'volume_24h': 169964605.66748586,
#   'last_traded_at': 1620574331,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'BTCUSD',
#   'index_id': 'BTC',
#   'price': '57304.0',
#   'price_percentage_change_24h': -2.117229068982893,
#   'contract_type': 'perpetual',
#   'index': 57298.72,
#   'basis': -0.009214016473544605,
#   'spread': 0.01,
#   'funding_rate': 0.0383,
#   'open_interest': 2207616885.0,
#   'volume_24h': 5837525243.68,
#   'last_traded_at': 1620574435,
#   'expired_at': None}]

# %%
# List all derivative exchanges
cg.get_derivatives_exchanges()[:2]
# Out:
# [{'name': 'Binance (Futures)',
#   'id': 'binance_futures',
#   'open_interest_btc': 217805.64,
#   'trade_volume_24h_btc': '1812135.02',
#   'number_of_perpetual_pairs': 130,
#   'number_of_futures_pairs': 32,
#   'image': 'https://assets.coingecko.com/markets/images/466/small/binance_futures.jpg?1568609512',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://www.binance.com/'},
#  {'name': 'Huobi Futures',
#   'id': 'huobi_dm',
#   'open_interest_btc': 145496.35,
#   'trade_volume_24h_btc': '834744.7',
#   'number_of_perpetual_pairs': 157,
#   'number_of_futures_pairs': 56,
#   'image': 'https://assets.coingecko.com/markets/images/433/small/huobifutures.png?1589963675',
#   'year_established': None,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.hbdm.com/en-us/'}]

# %%
# Show derivative exchange data
cg.get_derivatives_exchanges_by_id(id='')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pycoingecko/api.py in __request(self, url)
#      28         try:
# ---> 29             response.raise_for_status()
#      30             content = json.loads(response.content.decode('utf-8'))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 404 Client Error: Not Found for url: https://api.coingecko.com/api/v3/derivatives/exchanges/gdax
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5a4ef6b70c74> in <module>
#       1 # Show derivative exchange data
# ----> 2 cg.get_derivatives_exchanges_by_id(id='gdax')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pycoingecko/utils.py in input_args(*args, **kwargs)
#      10         args = [arg_preprocessing(v) for v in args]
#      11
# ---> 12         return func(*args, **kwargs)
#      13
#      14     return input_args
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pycoingecko/api.py in get_derivatives_exchanges_by_id(self, id, **kwargs)
#     360         api_url = self.__api_url_params(api_url, kwargs)
#     361
# --> 362         return self.__request(api_url)
#     363
#     364     @func_args_preprocessing
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pycoingecko/api.py in __request(self, url)
#      34             try:
#      35                 content = json.loads(response.content.decode('utf-8'))
# ---> 36                 raise ValueError(content)
#      37             # if no json
#      38             except json.decoder.JSONDecodeError:
#
# ValueError: {'error': 'translation missing: en.api.errors.market_not_found'}

# %%
# List all derivative exchanges name and identifer
cg.get_derivatives_exchanges_list()[:2]
# Out:
# [{'id': 'binance_futures', 'name': 'Binance (Futures)'},
#  {'id': 'huobi_dm', 'name': 'Huobi Futures'}]

# %% [markdown]
# ### Status

# %%
# List all status_updates with data (description, category, created_at, user, user_title and pin
cg.get_status_updates()
# Out:
# {'status_updates': [{'description': 'Peach.Finance (PEECH) Token Listed on Tokpie 📈\r\n👉  Food charity with deflationary cryptocurrency 🍲\r\nhttps://tokpie.io/blog/trade-peach-token-finance/\r\n#PEECH #PeachFinance #token #deflationary #charity #crypto',
#    'category': 'general',
#    'created_at': '2021-05-09T15:22:40.195Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': '📄 Wrapped Zero (wZER) Wrap-Up: 9th May\r\n\r\nhttps://twitter.com/ZeroCurrencies/status/1391333944658964481?s=20\r\n\r\n',
#    'category': 'general',
#    'created_at': '2021-05-09T11:44:33.331Z',
#    'user': 'Rick Howe',
#    'user_title': 'Founder & Project Manager - Technical',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'zero',
#     'name': 'Zero',
#     'symbol': 'zer',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/1292/thumb/Zero_Full_Logo.png?1571279702',
#      'small': 'https://assets.coingecko.com/coins/images/1292/small/Zero_Full_Logo.png?1571279702',
#      'large': 'https://assets.coingecko.com/coins/images/1292/large/Zero_Full_Logo.png?1571279702'}}},
#   {'description': '📢 $DYP #NFT dApp v1.0 Coming Soon! 🤩\r\n\r\n🎇 A non-fungible token marketplace dApp allowing users to mint, buy and sell #NFTs at fixed price. \r\n\r\n🧐 Each NFT has an image, a title, a description, an ID, artist profile and some tags.\r\n\r\n#DeFi #Uniswap #Ethereum #PancakeSwap #ETH #DYP\r\n\r\nhttps://twitter.com/dypfinance/status/1391322748358643713?s=20',
#    'category': 'general',
#    'created_at': '2021-05-09T09:25:28.690Z',
#    'user': None,
#    'user_title': 'CEO & Product Manager',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'defi-yield-protocol',
#     'name': 'DeFi Yield Protocol',
#     'symbol': 'dyp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/13480/thumb/dyp_logo.png?1608971751',
#      'small': 'https://assets.coingecko.com/coins/images/13480/small/dyp_logo.png?1608971751',
#      'large': 'https://assets.coingecko.com/coins/images/13480/large/dyp_logo.png?1608971751'}}},
#   {'description': "We've heard you loud and clear. Right after instant send for private transactions, we are going to be placing priority into a Thorchain integration for decentralised cross chain swaps. Stay tuned.\r\n\r\nShow some love in the tweet below!\r\n\r\nhttps://twitter.com/firoorg/status/1391308120052273153",
#    'category': 'general',
#    'created_at': '2021-05-09T09:23:55.241Z',
#    'user': None,
#    'user_title': 'Community Lead',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'zcoin',
#     'name': 'Firo',
#     'symbol': 'firo',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/479/thumb/firo.jpg?1606730284',
#      'small': 'https://assets.coingecko.com/coins/images/479/small/firo.jpg?1606730284',
#      'large': 'https://assets.coingecko.com/coins/images/479/large/firo.jpg?1606730284'}}},
#   {'description': 'We are pleased to announce that #BallSwap staking will be available on BitMart #Staking starting from May 12, 2021.\r\n\r\nThrough @BitMartExchange, every user can stake #BSP & earn up to 70% (APY) BSP rewards.\r\n\r\nTweet: https://twitter.com/BitBallSwap/status/1391021720849436676\r\n\r\nEnglish Ann: https://support.bmx.fund/hc/en-us/articles/1260805361129\r\n\r\nChinese Ann: https://support.bmx.fund/hc/zh-cn/articles/1260805361129',
#    'category': 'general',
#    'created_at': '2021-05-09T02:33:15.683Z',
#    'user': 'B M',
#    'user_title': 'Chief executive officer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'bitball',
#     'name': 'Bitball',
#     'symbol': 'btb',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/7039/thumb/BitBall_png_.png?1588640849',
#      'small': 'https://assets.coingecko.com/coins/images/7039/small/BitBall_png_.png?1588640849',
#      'large': 'https://assets.coingecko.com/coins/images/7039/large/BitBall_png_.png?1588640849'}}},
#   {'description': 'To give our community the best out of all #crypto, here’s some of the exciting stuff coming up for #Ballswap.\r\n\r\n🚀 Staking.\r\n🚀 Possible new exchange listing.\r\n🚀 89 billion #BSP Burn.\r\n🚀 A BIG 🎁 SURPRISE 🎁\r\n🚀 #NFT Auction Page.\r\n🚀 Banner on a news agency with millions of viewers.\r\n\r\nTweet: https://twitter.com/bitballswap/status/1390224835154829317',
#    'category': 'general',
#    'created_at': '2021-05-09T02:28:00.710Z',
#    'user': 'B M',
#    'user_title': 'Chief executive officer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'bitball',
#     'name': 'Bitball',
#     'symbol': 'btb',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/7039/thumb/BitBall_png_.png?1588640849',
#      'small': 'https://assets.coingecko.com/coins/images/7039/small/BitBall_png_.png?1588640849',
#      'large': 'https://assets.coingecko.com/coins/images/7039/large/BitBall_png_.png?1588640849'}}},
#   {'description': 'Awesome news!\r\n\r\nTrading on BitBall #DEX (BitBall-Dex.com) will be available soon.\r\n\r\nTrade wallet to wallet with no third party involvement.\r\n\r\nBuy/Sell on #Ethereum contract.\r\nFunds are always #Safu. \r\n\r\nTweet: https://twitter.com/bitballdex/status/1390983235165777920',
#    'category': 'general',
#    'created_at': '2021-05-09T02:27:51.849Z',
#    'user': 'B M',
#    'user_title': 'Chief executive officer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'bitball',
#     'name': 'Bitball',
#     'symbol': 'btb',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/7039/thumb/BitBall_png_.png?1588640849',
#      'small': 'https://assets.coingecko.com/coins/images/7039/small/BitBall_png_.png?1588640849',
#      'large': 'https://assets.coingecko.com/coins/images/7039/large/BitBall_png_.png?1588640849'}}},
#   {'description': 'Ziticoin (ZITI) Token Listed on Tokpie 📈\r\n👉  Blockchain payments on your favorite social platforms 🐦\r\nhttps://tokpie.io/blog/trade-ziti-token-ziticoin/\r\n#ZITI #Ziticoin #token #blockchain #payments #social',
#    'category': 'general',
#    'created_at': '2021-05-09T00:29:33.741Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': 'Ziticoin (ZITI) Token Listed on Tokpie 📈\r\n👉  Blockchain payments on your favorite social platforms 🐦\r\nhttps://tokpie.io/blog/trade-ziti-token-ziticoin/\r\n#ZITI #Ziticoin #token #blockchain #payments #social',
#    'category': 'general',
#    'created_at': '2021-05-08T23:14:03.494Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': '💲 The USDC airdrop coming on May 10, 2021.  \r\n👉 Learn how to start getting money every month 💲\r\nhttps://tokpie.io/blog/get-airdrop-cryptocurrencies-from-top-icos-every-week/\r\n#USDC #airdrop #stablecoin #tokens #giveaway #cryptocurrency #passiveincome',
#    'category': 'general',
#    'created_at': '2021-05-08T19:54:21.357Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': '🔥 8,061.95 #ETH + 2,461.87 #BNB worth $31,146,418 paid to the liquidity providers since launch!\r\n\r\n💰 Earn up to 277.51% APY !\r\n \r\n🚜 To start earning ETH, BNB, or $DYP rewards, you must add your liquidity to #Uniswap or #PancakeSwap !\r\n✅ https://dyp.finance/#/farm\r\n\r\n#DeFi #Ethereum\r\n\r\nhttps://twitter.com/dypfinance/status/1391047078042820611?s=20',
#    'category': 'general',
#    'created_at': '2021-05-08T15:10:36.254Z',
#    'user': None,
#    'user_title': 'CEO & Product Manager',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'defi-yield-protocol',
#     'name': 'DeFi Yield Protocol',
#     'symbol': 'dyp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/13480/thumb/dyp_logo.png?1608971751',
#      'small': 'https://assets.coingecko.com/coins/images/13480/small/dyp_logo.png?1608971751',
#      'large': 'https://assets.coingecko.com/coins/images/13480/large/dyp_logo.png?1608971751'}}},
#   {'description': '💲 The USDC airdrop coming on May 10, 2021.  \r\n👉 Learn how to start getting money every month 💲\r\nhttps://tokpie.io/blog/get-airdrop-cryptocurrencies-from-top-icos-every-week/\r\n#USDC #airdrop #stablecoin #tokens #giveaway #cryptocurrency #passiveincome',
#    'category': 'general',
#    'created_at': '2021-05-08T13:55:46.595Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': '3/3 Mercatox is still in maintenance. The dev responsible got swamped with work. Still financially depending on our "normal" jobs. Change this via the fundraiser! Currently sitting at 17,441 USD.\r\n\r\n👉Join! https://auxilium.global/community-fundraiser/\r\nOr contact our CEO asdaux on Telegram.',
#    'category': 'general',
#    'created_at': '2021-05-08T12:29:30.968Z',
#    'user': 'Anton Donker',
#    'user_title': 'Co-founder',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'auxilium',
#     'name': 'Auxilium',
#     'symbol': 'aux',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/5533/thumb/auxilium.png?1547041314',
#      'small': 'https://assets.coingecko.com/coins/images/5533/small/auxilium.png?1547041314',
#      'large': 'https://assets.coingecko.com/coins/images/5533/large/auxilium.png?1547041314'}}},
#   {'description': "2/3 Today we've outlined the steps for a successful creation of the ERC-20 Wrapped Auxilium token on the Ethereum blockchain and listing of this token on UniswapV3. \r\n\r\n1 WAUX = 1 AUX\r\n\r\n🚀💸  Aiming to create a liquidity pool with amazing rewards! Throw us your ideas!\r\n",
#    'category': 'general',
#    'created_at': '2021-05-08T12:29:21.657Z',
#    'user': 'Anton Donker',
#    'user_title': 'Co-founder',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'auxilium',
#     'name': 'Auxilium',
#     'symbol': 'aux',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/5533/thumb/auxilium.png?1547041314',
#      'small': 'https://assets.coingecko.com/coins/images/5533/small/auxilium.png?1547041314',
#      'large': 'https://assets.coingecko.com/coins/images/5533/large/auxilium.png?1547041314'}}},
#   {'description': '1/3 Great news! Our Alpha version of the AUX cryptocurrency and blockchain mobile wallet has been approved by GooglePlay! 🔥\r\n\r\nLaunching the Beta version soon after extra tests and adding text and imagery for the Play Store. This Beta version can be downloaded on your android.',
#    'category': 'general',
#    'created_at': '2021-05-08T12:29:04.711Z',
#    'user': 'Anton Donker',
#    'user_title': 'Co-founder',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'auxilium',
#     'name': 'Auxilium',
#     'symbol': 'aux',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/5533/thumb/auxilium.png?1547041314',
#      'small': 'https://assets.coingecko.com/coins/images/5533/small/auxilium.png?1547041314',
#      'large': 'https://assets.coingecko.com/coins/images/5533/large/auxilium.png?1547041314'}}},
#   {'description': 'How to easily buy $smart & activate SmartRewards to get secure, risk free, passive income using our BeeHive platform\r\n\r\nhttps://twitter.com/scashofficial/status/1390773932966486021',
#    'category': 'general',
#    'created_at': '2021-05-08T08:11:26.385Z',
#    'user': 'SmartCash',
#    'user_title': 'Outreach',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'smartcash',
#     'name': 'SmartCash',
#     'symbol': 'smart',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/832/thumb/Smartcash-logo.png?1547034626',
#      'small': 'https://assets.coingecko.com/coins/images/832/small/Smartcash-logo.png?1547034626',
#      'large': 'https://assets.coingecko.com/coins/images/832/large/Smartcash-logo.png?1547034626'}}},
#   {'description': 'TermRewards and SmartRetire: The total number of locked coins is now over 31 million $SMART\r\n\r\nhttps://coinlance.com/2021/05/06/termrewards-and-smartretire-the-total-number-of-locked-coins-is-now-over-31-million-smart/\r\n\r\nhttps://twitter.com/coinlance_news/status/1390340137029181446',
#    'category': 'general',
#    'created_at': '2021-05-08T07:56:46.421Z',
#    'user': 'SmartCash',
#    'user_title': 'Outreach',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'smartcash',
#     'name': 'SmartCash',
#     'symbol': 'smart',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/832/thumb/Smartcash-logo.png?1547034626',
#      'small': 'https://assets.coingecko.com/coins/images/832/small/Smartcash-logo.png?1547034626',
#      'large': 'https://assets.coingecko.com/coins/images/832/large/Smartcash-logo.png?1547034626'}}},
#   {'description': "It is our pleasure to present you with another competition. It's a trading competition hosted by Coinsbit.\r\nAccounts will be ranked according to the maximum trading volume of executed orders.\r\n5 winners will share a prize pool of 5,000 ONION. https://deeponion.org/community/threads/deeponion-presents-coinsbit-trading-competition.45638/",
#    'category': 'exchange_listing',
#    'created_at': '2021-05-08T05:43:15.825Z',
#    'user': 'DeepOnion',
#    'user_title': 'Developer',
#    'pin': True,
#    'project': {'type': 'Coin',
#     'id': 'deeponion',
#     'name': 'DeepOnion',
#     'symbol': 'onion',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/1148/thumb/deeponion-circle-icon.png?1554961318',
#      'small': 'https://assets.coingecko.com/coins/images/1148/small/deeponion-circle-icon.png?1554961318',
#      'large': 'https://assets.coingecko.com/coins/images/1148/large/deeponion-circle-icon.png?1554961318'}}},
#   {'description': "We're very excited to announce that Decred's decentralized treasury is now live.\r\nThe proposal was voted on, funded, and activated via stakeholder voting.\r\nIt will now make stakeholders the sole custodians of Decred's Treasury.\r\n\r\nhttps://dcrdata.decred.org/treasury",
#    'category': 'milestone',
#    'created_at': '2021-05-08T02:21:07.248Z',
#    'user': 'jz',
#    'user_title': 'International Ops Lead',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'decred',
#     'name': 'Decred',
#     'symbol': 'dcr',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/329/thumb/decred.png?1547034093',
#      'small': 'https://assets.coingecko.com/coins/images/329/small/decred.png?1547034093',
#      'large': 'https://assets.coingecko.com/coins/images/329/large/decred.png?1547034093'}}},
#   {'description': '🗒 Particl V3 Progress Report (07-05-21) 🗒\r\n---\r\n\r\nA new Particl V3 progress report has just been published on Particl News. \r\n\r\nCheck it out to get up to with all the recent progress since our last progress update. The report also includes a list of the items that are going to be worked on next week and beyond.\r\n\r\n👉 https://particl.news/particl-v3-progress-update-07-05-21/',
#    'category': 'general',
#    'created_at': '2021-05-07T17:44:06.325Z',
#    'user': 'Cryptoguard',
#    'user_title': 'Lead Community Manager',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'particl',
#     'name': 'Particl',
#     'symbol': 'part',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/839/thumb/Particl.png?1558053958',
#      'small': 'https://assets.coingecko.com/coins/images/839/small/Particl.png?1558053958',
#      'large': 'https://assets.coingecko.com/coins/images/839/large/Particl.png?1558053958'}}},
#   {'description': 'Great news! Syscoin (SYS) and Syscoin Platform Token (SPT) support is now live on the Klever mobile wallet! \r\n\r\nDownload or update the Klever wallet now: http://klever.io',
#    'category': 'general',
#    'created_at': '2021-05-07T17:17:59.580Z',
#    'user': 'Michiel',
#    'user_title': 'Community Marketing Team',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'syscoin',
#     'name': 'Syscoin',
#     'symbol': 'sys',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/119/thumb/Syscoin.png?1560401261',
#      'small': 'https://assets.coingecko.com/coins/images/119/small/Syscoin.png?1560401261',
#      'large': 'https://assets.coingecko.com/coins/images/119/large/Syscoin.png?1560401261'}}},
#   {'description': 'TNOS COIN (TNO) Token Listed on Tokpie 📈\r\n👉 Accounting unit for businesses and individuals 📒\r\nhttps://tokpie.io/blog/trade-tnos-coin-tno-token/\r\n#TNO #TNOSCOIN #token #altcoins #payments #accounting',
#    'category': 'general',
#    'created_at': '2021-05-07T14:21:04.144Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': "Monero's price isn't the only metric on the rise. Checkout the other key ways Monero has been growing over the past year! \r\n\r\nhttps://www.getmonero.org/2021/04/24/this-year-in-monero.html",
#    'category': 'general',
#    'created_at': '2021-05-07T14:00:41.103Z',
#    'user': 'Justin Ehrenhofer',
#    'user_title': 'Monero Space Organizer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'monero',
#     'name': 'Monero',
#     'symbol': 'xmr',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/69/thumb/monero_logo.png?1547033729',
#      'small': 'https://assets.coingecko.com/coins/images/69/small/monero_logo.png?1547033729',
#      'large': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729'}}},
#   {'description': 'TNOS COIN (TNO) Token Listed on Tokpie 📈\r\n👉 Accounting unit for businesses and individuals 📒\r\nhttps://tokpie.io/blog/trade-tnos-coin-tno-token/\r\n#TNO #TNOSCOIN #token #altcoins #payments #accounting',
#    'category': 'general',
#    'created_at': '2021-05-07T13:10:09.922Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': '🔥 DYP Tools will be launched Monday the 10th of May!\r\n🧐 What to expect?\r\n✅ Unique Community Trust Voting\r\n✅ DYP Locker\r\n✅ 100% #Decentralized without featuring sponsored projects\r\n✅ Trust Score based on multiple criteria\r\n🚀and much more!\r\n\r\n\r\nhttps://twitter.com/dypfinance/status/1390604999537926144?s=20',
#    'category': 'general',
#    'created_at': '2021-05-07T09:53:12.048Z',
#    'user': None,
#    'user_title': 'CEO & Product Manager',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'defi-yield-protocol',
#     'name': 'DeFi Yield Protocol',
#     'symbol': 'dyp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/13480/thumb/dyp_logo.png?1608971751',
#      'small': 'https://assets.coingecko.com/coins/images/13480/small/dyp_logo.png?1608971751',
#      'large': 'https://assets.coingecko.com/coins/images/13480/large/dyp_logo.png?1608971751'}}},
#   {'description': 'SmileCoin (SEC) Token Listed on Tokpie 📈\r\n👉 Crypto Payment Gateway for Business 🧾\r\nhttps://tokpie.io/blog/trade-smilecoin-sec-token/\r\n#SEC #SmileCoin #token #Cryptocurrency #payments',
#    'category': 'general',
#    'created_at': '2021-05-06T18:12:25.441Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': 'An update regarding the Output Claim Delegation Proposal currently in discussion phase has just been published on Reddit 🗒\r\n\r\n- Discussion phase ends this Friday\r\n- Voting interval (vote start and end block numbers) to be communicated on Friday\r\n- Important to pre-schedule voting for those who want to vote\r\n\r\n✅ Full update here: https://www.reddit.com/r/Particl/comments/n6d0zf/ccs_update_delegated_output_claim_management/\r\n\r\n✅ The proposal here: https://github.com/particl/ccs-proposals/pull/7',
#    'category': 'general',
#    'created_at': '2021-05-06T17:53:29.922Z',
#    'user': 'Cryptoguard',
#    'user_title': 'Lead Community Manager',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'particl',
#     'name': 'Particl',
#     'symbol': 'part',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/839/thumb/Particl.png?1558053958',
#      'small': 'https://assets.coingecko.com/coins/images/839/small/Particl.png?1558053958',
#      'large': 'https://assets.coingecko.com/coins/images/839/large/Particl.png?1558053958'}}},
#   {'description': "We've been working intensely on a secret project these past few weeks that could seriously boost demand for $smart and $bc\r\n \r\nMore to come soon. Stay tuned!\r\n\r\nhttps://twitter.com/scashofficial/status/1390069841139314689",
#    'category': 'general',
#    'created_at': '2021-05-06T15:05:38.818Z',
#    'user': 'SmartCash',
#    'user_title': 'Outreach',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'smartcash',
#     'name': 'SmartCash',
#     'symbol': 'smart',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/832/thumb/Smartcash-logo.png?1547034626',
#      'small': 'https://assets.coingecko.com/coins/images/832/small/Smartcash-logo.png?1547034626',
#      'large': 'https://assets.coingecko.com/coins/images/832/large/Smartcash-logo.png?1547034626'}}},
#   {'description': 'We are working on a new BeeHive release that fixes some chat glitches. \r\n\r\nWe hope to have it out this week. \r\n\r\nhttps://twitter.com/scashofficial/status/1389332867608715269',
#    'category': 'general',
#    'created_at': '2021-05-06T15:05:00.457Z',
#    'user': 'SmartCash',
#    'user_title': 'Outreach',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'smartcash',
#     'name': 'SmartCash',
#     'symbol': 'smart',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/832/thumb/Smartcash-logo.png?1547034626',
#      'small': 'https://assets.coingecko.com/coins/images/832/small/Smartcash-logo.png?1547034626',
#      'large': 'https://assets.coingecko.com/coins/images/832/large/Smartcash-logo.png?1547034626'}}},
#   {'description': 'SmileCoin (SEC) Token Listed on Tokpie 📈\r\n👉 Crypto Payment Gateway for Business 🧾\r\nhttps://tokpie.io/blog/trade-smilecoin-sec-token/\r\n#SEC #SmileCoin #token #Cryptocurrency #payments',
#    'category': 'general',
#    'created_at': '2021-05-06T13:21:42.506Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': '🎊 We’re excited about the release of $DECL 🎊\r\n\r\nThis exclusive trading tool has enabled trading for $PIT and other assets whose prices contain 8+ decimals. Get more details: https://medium.com/whitebit/a-solution-for-trading-crypto-whatever-the-price-bd1e4ef94e9a\r\n\r\nStart trading the $PIT/$DECL pair: https://whitebit.com/trade/PIT_DECL',
#    'category': 'general',
#    'created_at': '2021-05-06T09:54:30.635Z',
#    'user': 'Stas Bachman',
#    'user_title': 'Marketing Manager',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'whitebit',
#     'name': 'WhiteBIT',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/418/thumb/wb_3_avatar-02.png?1611212424',
#      'small': 'https://assets.coingecko.com/markets/images/418/small/wb_3_avatar-02.png?1611212424',
#      'large': 'https://assets.coingecko.com/markets/images/418/large/wb_3_avatar-02.png?1611212424'}}},
#   {'description': 'Dear CoinMarketAlert users, \r\nAs a consequence of the increasing demand for our portfolio services, we have decided to make the following changes to our subscription plan. Silver plan will continue the free service until June 30, 2021. From that day on, both Gold and Silver plans will be replaced by one single subscription only.  \r\nTo be able to please the high demand, we have decided to offer all services of CoinMarketAlert (GOLD) at a monthly subscription of CHF 3.00 (or CHF 30.00/year).',
#    'category': 'general',
#    'created_at': '2021-05-06T07:35:32.099Z',
#    'user': 'Roderick Warren',
#    'user_title': 'Founder ',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'coinmarketalert',
#     'name': 'CoinMarketAlert',
#     'symbol': 'cma',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/4949/thumb/cma.png?1547040370',
#      'small': 'https://assets.coingecko.com/coins/images/4949/small/cma.png?1547040370',
#      'large': 'https://assets.coingecko.com/coins/images/4949/large/cma.png?1547040370'}}},
#   {'description': 'All things seem possible in May, as LiJun_Ontology was quoted in CNN Business recently, "#Cryptocurrencies are going to become even more important."\r\n\r\nCheck out the full April recap of #Ontology👇\r\n\r\nhttps://medium.com/ontologynetwork/ontology-monthly-report-april-2021-fed2283ce25f\r\n\r\n$ONT $ONG #DID #DeFi',
#    'category': 'general',
#    'created_at': '2021-05-06T03:30:25.813Z',
#    'user': 'The Ontology Team',
#    'user_title': 'Founder',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'ontology',
#     'name': 'Ontology',
#     'symbol': 'ont',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3447/thumb/ONT.png?1583481820',
#      'small': 'https://assets.coingecko.com/coins/images/3447/small/ONT.png?1583481820',
#      'large': 'https://assets.coingecko.com/coins/images/3447/large/ONT.png?1583481820'}}},
#   {'description': 'New LP reward prograom launched on PancakeSwap this week! 🔥 \r\n\r\n- Program Starting: Tuesday, May 4th at 1 pm UTC.\r\n- Duration: 5 weeks.\r\n- Liquidity Pool: FUSE<>BNB\r\n- Total Rewards: 55,000 FUSE.\r\n- DEX: Pancake Swap.\r\n- Platform: Binance Smart Chain.\r\n\r\nDetailed guide 👉 https://2key.me/Introducing-Fusebnb-Liquidity-Rewards-Program-On-Pancake-Swap/NqPMn\r\nFarming 👉 https://2key.me/Liquidity-Provider-Rewards-Fuse-Bnb-Pancakeswap/eZoGv\r\n',
#    'category': 'general',
#    'created_at': '2021-05-05T21:42:58.834Z',
#    'user': 'Robert Miller',
#    'user_title': 'Marcom Director ',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'fuse-network-token',
#     'name': 'Fuse',
#     'symbol': 'fuse',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/10347/thumb/vUXKHEe.png?1601523640',
#      'small': 'https://assets.coingecko.com/coins/images/10347/small/vUXKHEe.png?1601523640',
#      'large': 'https://assets.coingecko.com/coins/images/10347/large/vUXKHEe.png?1601523640'}}},
#   {'description': 'We are pleased to announce we hit our target for our crowdfund. \r\n\r\nThe team will now look for ways to create BEP20 / ERC20 wrapped COLX tokens, bringing COLX to Binance Smart Chain / Ethereum. Without our stellar community, we could not have done this, you made this happen! 💚\r\n\r\nhttps://twitter.com/ColossusCoinXT/status/1390028114110070787',
#    'category': 'general',
#    'created_at': '2021-05-05T19:51:05.232Z',
#    'user': 'ColossusXT',
#    'user_title': 'ColossusXT Business Team',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'colossuscoinxt',
#     'name': 'ColossusXT',
#     'symbol': 'colx',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/966/thumb/colossusxt.png?1547034843',
#      'small': 'https://assets.coingecko.com/coins/images/966/small/colossusxt.png?1547034843',
#      'large': 'https://assets.coingecko.com/coins/images/966/large/colossusxt.png?1547034843'}}},
#   {'description': 'Dirty Finance (DIRTY) Token Listed on Tokpie 📈\r\n👉 Benefit from NFTs and DeFi trends 🍓\r\nhttps://tokpie.io/blog/trade-dirty-token-finance/\r\n#DIRTY #DirtyFinance #token #defi #NFTs #farming',
#    'category': 'general',
#    'created_at': '2021-05-05T15:22:55.435Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': 'Dirty Finance (DIRTY) Token Listed on Tokpie 📈\r\n👉 Benefit from NFTs and DeFi trends 🍓\r\nhttps://tokpie.io/blog/trade-dirty-token-finance/\r\n#DIRTY #DirtyFinance #token #defi #NFTs #farming',
#    'category': 'general',
#    'created_at': '2021-05-05T13:38:55.184Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': 'DigiByte is now available on sevenb.io\r\n\r\n7b is a broker app where you can easily trade DGB.  \r\n\r\nAnnouncement: https://twitter.com/sevenb_roker/status/1389921936776613893',
#    'category': 'exchange_listing',
#    'created_at': '2021-05-05T13:37:55.075Z',
#    'user': 'Murat Akyurt',
#    'user_title': 'DGBAT Outreach Officer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'digibyte',
#     'name': 'DigiByte',
#     'symbol': 'dgb',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/63/thumb/digibyte.png?1547033717',
#      'small': 'https://assets.coingecko.com/coins/images/63/small/digibyte.png?1547033717',
#      'large': 'https://assets.coingecko.com/coins/images/63/large/digibyte.png?1547033717'}}},
#   {'description': 'Attention to all #Ethereum based tokens.\r\n\r\nCreate pools or new pairs of your #Eth tokens on our #defi platform for free (Blockchain fee applies).\r\n\r\n👉 https://app.ballswapper.com/#/create/ETH\r\n\r\nTrading of #Ballswap #BSP can be seen here: https://info.ballswapper.com/#/home\r\n\r\nDollar $ value will be updated soon.\r\n\r\nTweet: https://twitter.com/bitballswap/status/1389578110312484866',
#    'category': 'general',
#    'created_at': '2021-05-05T12:08:23.346Z',
#    'user': 'B M',
#    'user_title': 'Chief executive officer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'bitball',
#     'name': 'Bitball',
#     'symbol': 'btb',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/7039/thumb/BitBall_png_.png?1588640849',
#      'small': 'https://assets.coingecko.com/coins/images/7039/small/BitBall_png_.png?1588640849',
#      'large': 'https://assets.coingecko.com/coins/images/7039/large/BitBall_png_.png?1588640849'}}},
#   {'description': 'Efinity Token (EFI), the native token of the upcoming Efinity NFT blockchain, has been generated.\r\nhttps://twitter.com/enjin/status/1389910038664318980?s=20',
#    'category': 'milestone',
#    'created_at': '2021-05-05T11:54:04.066Z',
#    'user': 'Maxim Blagov',
#    'user_title': 'CEO',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'enjincoin',
#     'name': 'Enjin Coin',
#     'symbol': 'enj',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/1102/thumb/enjin-coin-logo.png?1547035078',
#      'small': 'https://assets.coingecko.com/coins/images/1102/small/enjin-coin-logo.png?1547035078',
#      'large': 'https://assets.coingecko.com/coins/images/1102/large/enjin-coin-logo.png?1547035078'}}},
#   {'description': 'Interested in knowing exactly what Fuse got up to in April? 🧐 \r\n\r\nApril Newsletter 👉 https://bit.ly/3h448xZ  🗞 ',
#    'category': 'general',
#    'created_at': '2021-05-05T10:27:53.840Z',
#    'user': 'Robert Miller',
#    'user_title': 'Marcom Director ',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'fuse-network-token',
#     'name': 'Fuse',
#     'symbol': 'fuse',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/10347/thumb/vUXKHEe.png?1601523640',
#      'small': 'https://assets.coingecko.com/coins/images/10347/small/vUXKHEe.png?1601523640',
#      'large': 'https://assets.coingecko.com/coins/images/10347/large/vUXKHEe.png?1601523640'}}},
#   {'description': '18digits.com Invite Your Community and Earn 18D Token to spend for marketing on 18digits and CoinMarketAlert.com https://info.bakeryswap.org/#/token/0x7d9c30b7131ae9ada3f26bdeb2206fbf08213ba5\r\n#icos #ieo #tokensale #tokensales #nfts #defiprojects #definews #socialmediapromotion\r\n',
#    'category': 'partnership',
#    'created_at': '2021-05-05T06:42:45.807Z',
#    'user': 'Roderick Warren',
#    'user_title': 'Founder ',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'coinmarketalert',
#     'name': 'CoinMarketAlert',
#     'symbol': 'cma',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/4949/thumb/cma.png?1547040370',
#      'small': 'https://assets.coingecko.com/coins/images/4949/small/cma.png?1547040370',
#      'large': 'https://assets.coingecko.com/coins/images/4949/large/cma.png?1547040370'}}},
#   {'description': 'ENJ included among 12 new assets being considered by Bitstamp https://blog.bitstamp.net/post/exploring-support-for-twelve-additional-assets-at-bitstamp/',
#    'category': 'general',
#    'created_at': '2021-05-04T20:26:19.133Z',
#    'user': 'Maxim Blagov',
#    'user_title': 'CEO',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'enjincoin',
#     'name': 'Enjin Coin',
#     'symbol': 'enj',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/1102/thumb/enjin-coin-logo.png?1547035078',
#      'small': 'https://assets.coingecko.com/coins/images/1102/small/enjin-coin-logo.png?1547035078',
#      'large': 'https://assets.coingecko.com/coins/images/1102/large/enjin-coin-logo.png?1547035078'}}},
#   {'description': "BANANO Contest: Wrap That Potassium (25k BAN Prize Pool!)\r\n\r\nWhile everyone's excitedly waiting for wrapped BANANO to launch on Binance Smart Chain, here’s yet another fun community-organized BANANO contest: Wrap That Potassium!\r\nhttps://www.publish0x.com/banano/banano-contest-wrap-that-potassium-25k-ban-prize-pool-xkyldwz?a=QJ0dNjvdLO",
#    'category': 'general',
#    'created_at': '2021-05-04T20:25:51.733Z',
#    'user': 'bantano',
#    'user_title': 'Community Developer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'banano',
#     'name': 'Banano',
#     'symbol': 'ban',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/6226/thumb/banano-transparent.png?1619589798',
#      'small': 'https://assets.coingecko.com/coins/images/6226/small/banano-transparent.png?1619589798',
#      'large': 'https://assets.coingecko.com/coins/images/6226/large/banano-transparent.png?1619589798'}}},
#   {'description': 'Qawalla Token (QWLA) Listed on Tokpie 📈\r\n👉 Govern Mutual Fund for Crypto 💼\r\nhttps://tokpie.io/blog/trade-qawalla-qwla-token/\r\n#Qawalla #QWLA #token #mutualfunds #cryptocurrency',
#    'category': 'general',
#    'created_at': '2021-05-04T16:38:24.743Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'tokpie',
#     'name': 'TOKPIE',
#     'symbol': 'tkp',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/3731/thumb/tokpie-200x200.png?1562207865',
#      'small': 'https://assets.coingecko.com/coins/images/3731/small/tokpie-200x200.png?1562207865',
#      'large': 'https://assets.coingecko.com/coins/images/3731/large/tokpie-200x200.png?1562207865'}}},
#   {'description': 'A perspective on how NIS1 and Symbol (should) interact from our Software CTO - Kristy-Leigh Minehan\r\n\r\nRead this thread 👉 https://twitter.com/NEMofficial/status/1372148166179520521?s=20',
#    'category': 'general',
#    'created_at': '2021-05-04T16:35:47.051Z',
#    'user': 'Mickie Perez',
#    'user_title': 'NEM Group Marketinf',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'nem',
#     'name': 'NEM',
#     'symbol': 'xem',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/242/thumb/NEM_Logo_256x256.png?1598687029',
#      'small': 'https://assets.coingecko.com/coins/images/242/small/NEM_Logo_256x256.png?1598687029',
#      'large': 'https://assets.coingecko.com/coins/images/242/large/NEM_Logo_256x256.png?1598687029'}}},
#   {'description': 'Qawalla Token (QWLA) Listed on Tokpie 📈\r\n👉 Govern Mutual Fund for Crypto 💼\r\nhttps://tokpie.io/blog/trade-qawalla-qwla-token/\r\n#Qawalla #QWLA #token #mutualfunds #cryptocurrency',
#    'category': 'general',
#    'created_at': '2021-05-04T13:42:49.419Z',
#    'user': 'Vasilii Silin, CEO',
#    'user_title': '',
#    'pin': False,
#    'project': {'type': 'Market',
#     'id': 'tokpie',
#     'name': 'Tokpie',
#     'image': {'thumb': 'https://assets.coingecko.com/markets/images/436/thumb/logo_circle_100x100.png?1562226767',
#      'small': 'https://assets.coingecko.com/markets/images/436/small/logo_circle_100x100.png?1562226767',
#      'large': 'https://assets.coingecko.com/markets/images/436/large/logo_circle_100x100.png?1562226767'}}},
#   {'description': 'We are excited to announce that we are working with KnitFinance to enable tokenization of $GRS assets on Ethereum, BSC, Matic and Moonbeam.\r\n\r\nhttps://groestlcoinnews.medium.com/groestlcoin-grs-collaborates-with-knit-finance-de52919a1db1',
#    'category': 'partnership',
#    'created_at': '2021-05-04T12:04:39.838Z',
#    'user': 'Jackie',
#    'user_title': 'Lead Developer',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'groestlcoin',
#     'name': 'Groestlcoin',
#     'symbol': 'grs',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/71/thumb/image001.png?1547033733',
#      'small': 'https://assets.coingecko.com/coins/images/71/small/image001.png?1547033733',
#      'large': 'https://assets.coingecko.com/coins/images/71/large/image001.png?1547033733'}}},
#   {'description': 'Announcing the Pandacoin Network Swap\r\n\r\nPandacoin launched in 2014 as a Scrypt algorithm coin with a 3 month mining phase before a transition to Proof-of-Stake. There was no ICO, no premine, and no instamine. 7 years later, we’re conducting our largest upgrade to modernise Pandacoin. This starts with a fair and automated swap, just upgrade your wallet.\r\n\r\nSee the full announcement here:\r\n\r\nhttps://medium.com/@Pandacoin_PND/announcing-the-pandacoin-swap-dd7b63e35a1a\r\n\r\n',
#    'category': 'software_release',
#    'created_at': '2021-05-04T00:14:39.554Z',
#    'user': 'John Moore',
#    'user_title': 'Development Team Member',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'pandacoin',
#     'name': 'Pandacoin',
#     'symbol': 'pnd',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/138/thumb/Pandacoin.png?1552970580',
#      'small': 'https://assets.coingecko.com/coins/images/138/small/Pandacoin.png?1552970580',
#      'large': 'https://assets.coingecko.com/coins/images/138/large/Pandacoin.png?1552970580'}}},
#   {'description': "Beam 2021 Week #18 - *1280000\r\n\r\nThis week's Beam newsletter finalises the hard fork block height and looks at the amazing work of a valued community member - @vsnation, check out his creations! \r\n\r\nhttps://beamprivacy.substack.com/p/beam-2021-week-18-1280000\r\n\r\nTeam Beam\r\n",
#    'category': 'general',
#    'created_at': '2021-05-03T20:49:18.333Z',
#    'user': 'Angus Sullivan',
#    'user_title': 'Community Lead',
#    'pin': False,
#    'project': {'type': 'Coin',
#     'id': 'beam',
#     'name': 'BEAM',
#     'symbol': 'beam',
#     'image': {'thumb': 'https://assets.coingecko.com/coins/images/7339/thumb/BEAM.png?1558013729',
#      'small': 'https://assets.coingecko.com/coins/images/7339/small/BEAM.png?1558013729',
#      'large': 'https://assets.coingecko.com/coins/images/7339/large/BEAM.png?1558013729'}}}]}

# %% [markdown]
# ### Events

# %%
cg.get_events()
# Out:
# {'data': [], 'count': 0, 'page': 1}

# %%
cg.get_events_countries()
# Out:
# {'data': [{'country': None, 'code': ''},
#   {'country': 'United Arab Emirates', 'code': 'AE'},
#   {'country': 'Armenia', 'code': 'AM'},
#   {'country': 'Austria', 'code': 'AT'},
#   {'country': 'Australia', 'code': 'AU'},
#   {'country': 'Azerbaijan', 'code': 'AZ'},
#   {'country': 'Bangladesh', 'code': 'BD'},
#   {'country': 'Belgium', 'code': 'BE'},
#   {'country': 'Bulgaria', 'code': 'BG'},
#   {'country': 'Bahrain', 'code': 'BH'},
#   {'country': 'Belarus', 'code': 'BY'},
#   {'country': 'Canada', 'code': 'CA'},
#   {'country': 'Switzerland', 'code': 'CH'},
#   {'country': 'Chile', 'code': 'CL'},
#   {'country': 'China', 'code': 'CN'},
#   {'country': 'Colombia', 'code': 'CO'},
#   {'country': 'Cyprus', 'code': 'CY'},
#   {'country': 'Czech Republic', 'code': 'CZ'},
#   {'country': 'Germany', 'code': 'DE'},
#   {'country': 'Estonia', 'code': 'EE'},
#   {'country': 'Egypt', 'code': 'EG'},
#   {'country': 'Spain', 'code': 'ES'},
#   {'country': 'Finland', 'code': 'FI'},
#   {'country': 'France', 'code': 'FR'},
#   {'country': 'United Kingdom', 'code': 'GB'},
#   {'country': 'Georgia', 'code': 'GE'},
#   {'country': 'Gibraltar', 'code': 'GI'},
#   {'country': 'Greece', 'code': 'GR'},
#   {'country': 'Hong Kong', 'code': 'HK'},
#   {'country': 'Croatia', 'code': 'HR'},
#   {'country': 'Hungary', 'code': 'HU'},
#   {'country': 'Indonesia', 'code': 'ID'},
#   {'country': 'Israel', 'code': 'IL'},
#   {'country': 'India', 'code': 'IN'},
#   {'country': 'Japan', 'code': 'JP'},
#   {'country': 'Kenya', 'code': 'KE'},
#   {'country': 'South Korea', 'code': 'KR'},
#   {'country': 'Kazakhstan', 'code': 'KZ'},
#   {'country': 'Lithuania', 'code': 'LT'},
#   {'country': 'Latvia', 'code': 'LV'},
#   {'country': 'Morocco', 'code': 'MA'},
#   {'country': 'Monaco', 'code': 'MC'},
#   {'country': 'Malta', 'code': 'MT'},
#   {'country': 'Mexico', 'code': 'MX'},
#   {'country': 'Malaysia', 'code': 'MY'},
#   {'country': 'Nigeria', 'code': 'NG'},
#   {'country': 'Netherlands', 'code': 'NL'},
#   {'country': 'Norway', 'code': 'NO'},
#   {'country': 'Peru', 'code': 'PE'},
#   {'country': 'Philippines', 'code': 'PH'},
#   {'country': 'Poland', 'code': 'PL'},
#   {'country': 'Portugal', 'code': 'PT'},
#   {'country': 'Qatar', 'code': 'QA'},
#   {'country': 'Russia', 'code': 'RU'},
#   {'country': 'Seychelles', 'code': 'SC'},
#   {'country': 'Sweden', 'code': 'SE'},
#   {'country': 'Singapore', 'code': 'SG'},
#   {'country': 'Thailand', 'code': 'TH'},
#   {'country': 'Turkey', 'code': 'TR'},
#   {'country': 'Taiwan', 'code': 'TW'},
#   {'country': 'Ukraine', 'code': 'UA'},
#   {'country': 'Uganda', 'code': 'UG'},
#   {'country': 'United States', 'code': 'US'},
#   {'country': 'Vietnam', 'code': 'VN'},
#   {'country': 'South Africa', 'code': 'ZA'},
#   {'country': 'Zimbabwe', 'code': 'ZW'}],
#  'count': 66}

# %%
cg.get_events_types()
# Out:
# {'data': ['Event', 'Conference', 'Meetup'], 'count': 3}

# %% [markdown]
# ### Trending

# %%
cg.get_search_trending()
# Out:
# {'coins': [{'item': {'id': 'matic-network',
#     'name': 'Polygon',
#     'symbol': 'MATIC',
#     'market_cap_rank': 31,
#     'thumb': 'https://assets.coingecko.com/coins/images/4713/thumb/matic___polygon.jpg?1612939050',
#     'large': 'https://assets.coingecko.com/coins/images/4713/large/matic___polygon.jpg?1612939050',
#     'score': 0}},
#   {'item': {'id': 'dogecoin',
#     'name': 'Dogecoin',
#     'symbol': 'DOGE',
#     'market_cap_rank': 5,
#     'thumb': 'https://assets.coingecko.com/coins/images/5/thumb/dogecoin.png?1547792256',
#     'large': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#     'score': 1}},
#   {'item': {'id': 'waultswap',
#     'name': 'WaultSwap',
#     'symbol': 'WEX',
#     'market_cap_rank': 258,
#     'thumb': 'https://assets.coingecko.com/coins/images/14882/thumb/WS_200x200.png?1618890232',
#     'large': 'https://assets.coingecko.com/coins/images/14882/large/WS_200x200.png?1618890232',
#     'score': 2}},
#   {'item': {'id': 'cardano',
#     'name': 'Cardano',
#     'symbol': 'ADA',
#     'market_cap_rank': 6,
#     'thumb': 'https://assets.coingecko.com/coins/images/975/thumb/cardano.png?1547034860',
#     'large': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#     'score': 3}},
#   {'item': {'id': 'binancecoin',
#     'name': 'Binance Coin',
#     'symbol': 'BNB',
#     'market_cap_rank': 3,
#     'thumb': 'https://assets.coingecko.com/coins/images/825/thumb/binance-coin-logo.png?1547034615',
#     'large': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#     'score': 4}},
#   {'item': {'id': 'cumrocket',
#     'name': 'CumRocket',
#     'symbol': 'CUMMIES',
#     'market_cap_rank': 261,
#     'thumb': 'https://assets.coingecko.com/coins/images/15088/thumb/logo-2_%282%29.png?1619664664',
#     'large': 'https://assets.coingecko.com/coins/images/15088/large/logo-2_%282%29.png?1619664664',
#     'score': 5}},
#   {'item': {'id': 'pancakeswap-token',
#     'name': 'PancakeSwap',
#     'symbol': 'CAKE',
#     'market_cap_rank': 30,
#     'thumb': 'https://assets.coingecko.com/coins/images/12632/thumb/IMG_0440.PNG?1602654093',
#     'large': 'https://assets.coingecko.com/coins/images/12632/large/IMG_0440.PNG?1602654093',
#     'score': 6}}],
#  'exchanges': []}

# %% [markdown]
# ### Global

# %%
cg.get_global()
# Out:
# {'active_cryptocurrencies': 7106,
#  'upcoming_icos': 0,
#  'ongoing_icos': 50,
#  'ended_icos': 3375,
#  'markets': 610,
#  'total_market_cap': {'btc': 43834955.71898108,
#   'eth': 639674294.6328748,
#   'ltc': 6858042449.147987,
#   'bch': 1860544391.9527361,
#   'bnb': 3775207351.0952597,
#   'eos': 248806375023.4921,
#   'xrp': 1667551086619.2805,
#   'xlm': 4140468546153.455,
#   'link': 48367381153.746414,
#   'dot': 63024873687.0637,
#   'yfi': 47246768.77773599,
#   'usd': 2520767471335.2876,
#   'aed': 9259283075708.773,
#   'ars': 234653903145016.16,
#   'aud': 3213154234989.3633,
#   'bdt': 212012841100999.88,
#   'bhd': 943170357074.8099,
#   'bmd': 2520767471335.2876,
#   'brl': 13200029112856.89,
#   'cad': 3059102572513.654,
#   'chf': 2271776143586.6753,
#   'clp': 1752941699566558.5,
#   'cny': 16214836759364.248,
#   'czk': 53128325417730.47,
#   'dkk': 15409955705766.889,
#   'eur': 2072446455790.834,
#   'gbp': 1803833474045.3494,
#   'hkd': 19575977690293.28,
#   'huf': 742819758453081.5,
#   'idr': 3.56222255211746e+16,
#   'ils': 8167301731731.156,
#   'inr': 184762172578991.16,
#   'jpy': 273717535874942.16,
#   'krw': 2805538572572033.0,
#   'kwd': 752711250010.6002,
#   'lkr': 492849324286320.8,
#   'mmk': 3896505647946051.0,
#   'mxn': 50183690896089.87,
#   'myr': 10366656225866.355,
#   'ngn': 1022607355335115.4,
#   'nok': 20717179539916.203,
#   'nzd': 3461880882153.489,
#   'php': 119802504037710.11,
#   'pkr': 380469643556894.1,
#   'pln': 9434098299845.865,
#   'rub': 185828810126812.16,
#   'sar': 9453825826076.531,
#   'sek': 20941905959985.723,
#   'sgd': 3339008592530.7217,
#   'thb': 78249331103883.88,
#   'try': 20763813738135.906,
#   'twd': 69724329947202.664,
#   'uah': 69439987376436.01,
#   'vef': 252404446904.80243,
#   'vnd': 5.770310481605081e+16,
#   'zar': 35448431207863.4,
#   'xdr': 1750355392140.9702,
#   'xag': 91831357319.34686,
#   'xau': 1376389454.698494,
#   'bits': 43834955718981.08,
#   'sats': 4383495571898108.0},
#  'total_volume': {'btc': 6027015.006148002,
#   'eth': 87950963.0970169,
#   'ltc': 942935245.9894692,
#   'bch': 255812485.4007336,
#   'bnb': 519065914.02164793,
#   'eos': 34209222555.289276,
#   'xrp': 229277188894.7268,
#   'xlm': 569286900165.4995,
#   'link': 6650193372.853845,
#   'dot': 8665501156.375862,
#   'yfi': 6496116.620738741,
#   'usd': 346588769796.998,
#   'aed': 1273089869218.332,
#   'ars': 32263351754540.93,
#   'aud': 441787346963.44855,
#   'bdt': 29150356236324.266,
#   'bhd': 129679654107.24457,
#   'bmd': 346588769796.998,
#   'brl': 1814916252107.2175,
#   'cad': 420606267474.84515,
#   'chf': 312354117471.52997,
#   'clp': 241017830516832.3,
#   'cny': 2229432261719.1904,
#   'czk': 7304791559433.993,
#   'dkk': 2118766467523.009,
#   'eur': 284947610499.8319,
#   'gbp': 248015111190.26428,
#   'hkd': 2691566795591.11,
#   'huf': 102132778683779.2,
#   'idr': 4897819200386274.0,
#   'ils': 1122949693674.8916,
#   'inr': 25403570471040.75,
#   'jpy': 37634341568407.016,
#   'krw': 385742903120964.5,
#   'kwd': 103492793016.4625,
#   'lkr': 67763505734701.445,
#   'mmk': 535743623474046.4,
#   'mxn': 6899923887995.591,
#   'myr': 1425346315790.152,
#   'ngn': 140601713288221.48,
#   'nok': 2848474463453.6084,
#   'nzd': 475985607468.08826,
#   'php': 16472047884303.625,
#   'pkr': 52312046709978.61,
#   'pln': 1297125800403.7524,
#   'rub': 25550226043092.68,
#   'sar': 1299838204116.1833,
#   'sek': 2879372852281.0083,
#   'sgd': 459091484473.10345,
#   'thb': 10758762842320.81,
#   'try': 2854886355694.853,
#   'twd': 9586631855622.94,
#   'uah': 9547536642389.834,
#   'vef': 34703933519.773415,
#   'vnd': 7933793314568750.0,
#   'zar': 4873923637652.621,
#   'xdr': 240662230439.0208,
#   'xag': 12626201156.603056,
#   'xau': 189244400.08455688,
#   'bits': 6027015006148.002,
#   'sats': 602701500614800.2},
#  'market_cap_percentage': {'btc': 42.6712236688779,
#   'eth': 17.889761766061454,
#   'bnb': 4.101802992648453,
#   'xrp': 2.773003533412062,
#   'doge': 2.562442205975199,
#   'ada': 2.296163758708097,
#   'usdt': 2.2179412075140137,
#   'dot': 1.571473761179186,
#   'bch': 1.0060353391528307,
#   'ltc': 0.9731058619872329},
#  'market_cap_change_percentage_24h_usd': 0.2551960654568323,
#  'updated_at': 1620576590}

# %%
cg.get_global_decentralized_finance_defi()
# Out:
# {'defi_market_cap': '139287966896.0806970177908050126',
#  'eth_market_cap': '457518300582.458793993449352717',
#  'defi_to_eth_ratio': '30.4442394367078971823124645561136151288817887867062327096329953',
#  'trading_volume_24h': '13784643297.90623129260422557962',
#  'defi_dominance': '5.5124611521437464405704090303342034746504266070503252016059475',
#  'top_coin_name': 'Chainlink',
#  'top_coin_defi_dominance': 15.906709699177824}

# %%
# Get cryptocurrencies in USD
cg.get_price(ids=['bitcoin', 'ethereum','litecoin'], vs_currencies='usd')
# Out:
# {'ethereum': {'usd': 3854.67},
#  'bitcoin': {'usd': 57254},
#  'litecoin': {'usd': 358.73}}

# %%
cg.get_price(ids=['bitcoin', 'ethereum','litecoin'], vs_currencies='usd', include_market_cap='true', include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')
# Out:
# {'ethereum': {'usd': 3532.97,
#   'usd_market_cap': 408782450842.19116,
#   'usd_24h_vol': 42235199452.95981,
#   'usd_24h_change': 3.991809867100513,
#   'last_updated_at': 1620446601},
#  'litecoin': {'usd': 353.01,
#   'usd_market_cap': 23570051429.351902,
#   'usd_24h_vol': 12314497353.49321,
#   'usd_24h_change': 0.6503388152161852,
#   'last_updated_at': 1620446622},
#  'bitcoin': {'usd': 58109,
#   'usd_market_cap': 1086772314066.3824,
#   'usd_24h_vol': 65848851033.349205,
#   'usd_24h_change': 4.690331770875286,
#   'last_updated_at': 1620446538}}

# %% [markdown]
# ### Getting Historical Data

# %%
btc_data = cg.get_coin_history_by_id(id='bitcoin',date='10-11-2020', localization='false')

# %%
btc_data
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 56326.52786980459,
#    'ars': 1215617.24070744,
#    'aud': 21082.415040368352,
#    'bch': 58.03006574753659,
#    'bdt': 1301263.6700267561,
#    'bhd': 5783.172237724017,
#    'bmd': 15335.342198178862,
#    'bnb': 548.489735186886,
#    'brl': 82599.20481248871,
#    'btc': 1.0,
#    'cad': 19947.369687570146,
#    'chf': 13994.941278004791,
#    'clp': 11618071.458796967,
#    'cny': 101667.18463704686,
#    'czk': 343849.04276756675,
#    'dkk': 96585.05223257001,
#    'dot': 3530.9500103196324,
#    'eos': 6136.865733687228,
#    'eth': 34.44319624770999,
#    'eur': 12970.985144090215,
#    'gbp': 11647.729136493797,
#    'hkd': 118887.24039138111,
#    'huf': 4657417.832667269,
#    'idr': 218928088.9852976,
#    'ils': 51595.14541208477,
#    'inr': 1134162.0370875916,
#    'jpy': 1612209.6370241605,
#    'krw': 17170829.781274468,
#    'kwd': 4683.38283663943,
#    'lkr': 2831336.1357028554,
#    'ltc': 258.8060744084482,
#    'mmk': 19765626.652002573,
#    'mxn': 311877.92135280336,
#    'myr': 62999.11928433854,
#    'ngn': 5871717.3380903015,
#    'nok': 138488.39939348536,
#    'nzd': 22479.250019831645,
#    'php': 740617.5757641097,
#    'pkr': 2439015.894747048,
#    'pln': 58087.76125058096,
#    'rub': 1169868.8478618292,
#    'sar': 57513.391343890435,
#    'sek': 132177.69138414445,
#    'sgd': 20664.373612046023,
#    'thb': 468954.7644203092,
#    'try': 124294.78875730299,
#    'twd': 439265.5419246347,
#    'uah': 431086.5291752898,
#    'usd': 15335.342198178862,
#    'vef': 3810643025.7843738,
#    'vnd': 357418047.8297312,
#    'xag': 632.0976554477277,
#    'xau': 8.200114180210191,
#    'xdr': 10769.259394013277,
#    'xlm': 192403.97515238347,
#    'xrp': 61162.052643197574,
#    'yfi': 1.021790626535115,
#    'zar': 236109.06262004064,
#    'bits': 1000000.0,
#    'link': 1223.3665779769478,
#    'sats': 100000000.0},
#   'market_cap': {'aed': 1044201901812.6936,
#    'ars': 22535559755379.1,
#    'aud': 390833568347.0833,
#    'bch': 1075782713.8920283,
#    'bdt': 24123304779986.574,
#    'bhd': 107210575150.31131,
#    'bmd': 284292217075.7686,
#    'bnb': 10168104555.11704,
#    'brl': 1531254455321.2866,
#    'btc': 18538368.0,
#    'cad': 369791679900.22046,
#    'chf': 259443371550.0431,
#    'clp': 215380084153475.06,
#    'cny': 1884743682325.522,
#    'czk': 6374400091272.89,
#    'dkk': 1790529241586.6045,
#    'dot': 65458050680.909134,
#    'eos': 113767475337.68382,
#    'eth': 638520647.136267,
#    'eur': 240460895923.67734,
#    'gbp': 215929889096.6443,
#    'hkd': 2203975412879.8867,
#    'huf': 86340925711748.25,
#    'idr': 4058569479146193.5,
#    'ils': 956489792662.7391,
#    'inr': 21025513215159.43,
#    'jpy': 29887735544300.305,
#    'krw': 318319161350625.6,
#    'kwd': 86822274510.50563,
#    'lkr': 52488351215357.46,
#    'ltc': 4797842248.019195,
#    'mmk': 366422460625431.56,
#    'mxn': 5781707677113.327,
#    'myr': 1167900856968.9646,
#    'ngn': 108852056805498.42,
#    'nok': 2567348911687.409,
#    'nzd': 416728609231.64624,
#    'php': 13729841166782.947,
#    'pkr': 45215374214670.04,
#    'pln': 1076852294359.41,
#    'rub': 21687459213398.598,
#    'sar': 1066204413661.0553,
#    'sek': 2450358684269.698,
#    'sgd': 383083762509.5983,
#    'thb': 8693655998176.999,
#    'try': 2304222534465.1455,
#    'twd': 8143266265918.307,
#    'uah': 7991640717694.259,
#    'usd': 284292217075.7686,
#    'vef': 70643102728624216,
#    'vnd': 6625947300509158,
#    'xag': 11718058948.62718,
#    'xau': 152016734.31475484,
#    'xdr': 199644493733.67517,
#    'xlm': 3566855696037.741,
#    'xrp': 1133844639534.9692,
#    'yfi': 18942330.653658528,
#    'zar': 4377076690985.357,
#    'bits': 18538368000000.0,
#    'link': 22679219821.43736,
#    'sats': 1853836800000000},
#   'total_volume': {'aed': 108359588578.09189,
#    'ars': 2338574541217.3315,
#    'aud': 40557831387.85573,
#    'bch': 111636812.83705766,
#    'bdt': 2503339034879.6304,
#    'bhd': 11125524474.089893,
#    'bmd': 29501754042.78257,
#    'bnb': 1055171058.6801296,
#    'brl': 158902318123.4813,
#    'btc': 1924639.305469634,
#    'cad': 38374259062.37918,
#    'chf': 26923123728.919025,
#    'clp': 22350560046166.02,
#    'cny': 195584828602.03186,
#    'czk': 661488329147.2714,
#    'dkk': 185807947312.25302,
#    'dot': 6792754761.88467,
#    'eos': 11805951320.103003,
#    'eth': 66260973.57435572,
#    'eur': 24953262109.728436,
#    'gbp': 22407614756.88489,
#    'hkd': 228712348216.6709,
#    'huf': 8959825845303.688,
#    'idr': 421168471549834.2,
#    'ils': 99257471406.7801,
#    'inr': 2181873024443.6846,
#    'jpy': 3101529236337.4106,
#    'krw': 33032819898717.54,
#    'kwd': 9009776681.157717,
#    'lkr': 5446854801705.539,
#    'ltc': 497884758.8339333,
#    'mmk': 38024626281772.57,
#    'mxn': 599983072318.8782,
#    'myr': 121196155783.15501,
#    'ngn': 11295865359799.629,
#    'nok': 266420575679.78058,
#    'nzd': 43245028156.59657,
#    'php': 1424781871678.7017,
#    'pkr': 4692118773965.779,
#    'pln': 111747806026.39725,
#    'rub': 2250564908556.8955,
#    'sar': 110642847330.47899,
#    'sek': 254280190866.61987,
#    'sgd': 39753613572.649536,
#    'thb': 902163638628.2904,
#    'try': 239115256727.237,
#    'twd': 845048242801.4629,
#    'uah': 829313659293.2701,
#    'usd': 29501754042.78257,
#    'vef': 7330821304064920,
#    'vnd': 687592047262983.6,
#    'xag': 1216013918.7668674,
#    'xau': 15775177.92175668,
#    'xdr': 20717636278.298054,
#    'xlm': 370142033900.83765,
#    'xrp': 117662052174.20015,
#    'yfi': 1965695.6693695087,
#    'zar': 454220805944.2968,
#    'bits': 1924639305469.634,
#    'link': 2353482525.608233,
#    'sats': 192463930546963.4}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 72617,
#   'reddit_average_posts_48h': 6.727,
#   'reddit_average_comments_48h': 366.273,
#   'reddit_subscribers': 1747658,
#   'reddit_accounts_active_48h': '4851.91666666667'},
#  'developer_data': {'forks': 26617,
#   'stars': 45862,
#   'subscribers': 3589,
#   'total_issues': 5789,
#   'closed_issues': 5211,
#   'pull_requests_merged': 8022,
#   'pull_request_contributors': 696,
#   'code_additions_deletions_4_weeks': {'additions': 10865, 'deletions': -7137},
#   'commit_count_4_weeks': 280},
#  'public_interest_stats': {'alexa_rank': 9292, 'bing_matches': None}}

# %%
eth_data = cg.get_coin_history_by_id(id='ethereum',date='05-04-2021', localization='false')

# %%
eth_data
# Out:
# {'id': 'ethereum',
#  'symbol': 'eth',
#  'name': 'Ethereum',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/279/thumb/ethereum.png?1595348880',
#   'small': 'https://assets.coingecko.com/coins/images/279/small/ethereum.png?1595348880'},
#  'market_data': {'current_price': {'aed': 7631.52840706071,
#    'ars': 190641.59545770832,
#    'aud': 2727.267725091291,
#    'bch': 3.714411715387766,
#    'bdt': 175635.47800866555,
#    'bhd': 783.5360348909774,
#    'bmd': 2077.755212422407,
#    'bnb': 5.95281955632264,
#    'brl': 11859.826752507113,
#    'btc': 0.03570465692520282,
#    'cad': 2610.969532586372,
#    'chf': 1957.8562701343594,
#    'clp': 1489958.7303230308,
#    'cny': 13645.65735758416,
#    'czk': 46069.02744743594,
#    'dkk': 13135.589230486577,
#    'dot': 47.11057888093593,
#    'eos': 331.6761594133477,
#    'eth': 1.0,
#    'eur': 1765.8218223814333,
#    'gbp': 1502.6616581968608,
#    'hkd': 16157.517966538002,
#    'huf': 638315.4898291396,
#    'idr': 30179796.36270398,
#    'ils': 6920.549661942743,
#    'inr': 152457.90252755137,
#    'jpy': 229973.73849295892,
#    'krw': 2347428.295629309,
#    'kwd': 627.8332147824668,
#    'lkr': 413223.6616053301,
#    'ltc': 10.253029007400523,
#    'mmk': 2920971.243995135,
#    'mxn': 42209.088090334044,
#    'myr': 8601.906579428776,
#    'ngn': 791624.7359329364,
#    'nok': 17728.79541286987,
#    'nzd': 2955.7646990670187,
#    'php': 100886.49100514602,
#    'pkr': 317479.1347894738,
#    'pln': 8130.04629293243,
#    'rub': 158844.80154073567,
#    'sar': 7792.517036429608,
#    'sek': 18124.41039409118,
#    'sgd': 2796.3676301908235,
#    'thb': 65012.96059669709,
#    'try': 17014.945210048354,
#    'twd': 59310.56141620373,
#    'uah': 57669.15765369761,
#    'usd': 2077.755212422407,
#    'vef': 208.04562941985577,
#    'vnd': 47818819.448608205,
#    'xag': 83.26680890725646,
#    'xau': 1.202729382262834,
#    'xdr': 1463.3629961091017,
#    'xlm': 4827.281455597254,
#    'xrp': 3283.164171299071,
#    'yfi': 0.05503352219404529,
#    'zar': 30440.25870511032,
#    'bits': 35704.65692520282,
#    'link': 67.5106959265954,
#    'sats': 3570465.692520282},
#   'market_cap': {'aed': 880488444153.3898,
#    'ars': 21999313861391.08,
#    'aud': 314809603702.6311,
#    'bch': 428483312.66715246,
#    'bdt': 20263962933939.812,
#    'bhd': 90400557725.89148,
#    'bmd': 239721240194.1402,
#    'bnb': 687435830.7719111,
#    'brl': 1368328839028.1536,
#    'btc': 4120729.6907389695,
#    'cad': 301287407985.7603,
#    'chf': 225886447980.0559,
#    'clp': 171904101343217.84,
#    'cny': 1574369244975.0156,
#    'czk': 5316130138917.324,
#    'dkk': 1515639938339.8516,
#    'dot': 5468136983.442523,
#    'eos': 38400591614.3368,
#    'eth': 115336522.874,
#    'eur': 203768328032.30334,
#    'gbp': 173407632961.71567,
#    'hkd': 1864228182555.7605,
#    'huf': 73672569863904.45,
#    'idr': 3481997383339100.5,
#    'ils': 798459191856.3197,
#    'inr': 17589847568565.203,
#    'jpy': 26533665331508.508,
#    'krw': 270834802353354.28,
#    'kwd': 72436327428.2232,
#    'lkr': 47675726209394.34,
#    'ltc': 1181382553.1185098,
#    'mmk': 337007384217106.5,
#    'mxn': 4870353869780.677,
#    'myr': 992445934403.7421,
#    'ngn': 91333792513967.34,
#    'nok': 2045640826891.2795,
#    'nzd': 341092161035.03625,
#    'php': 11640782158327.01,
#    'pkr': 36629190711433.4,
#    'pln': 938160340398.0587,
#    'rub': 18326808673462.117,
#    'sar': 899062525286.1124,
#    'sek': 2091215909913.2686,
#    'sgd': 322702904978.50366,
#    'thb': 7498480393272.707,
#    'try': 1962364304981.4758,
#    'twd': 6842962661961.834,
#    'uah': 6653585519142.119,
#    'usd': 239721240194.1402,
#    'vef': 24003287780.639282,
#    'vnd': 5517101646192201,
#    'xag': 9601331892.74252,
#    'xau': 138721887.27554524,
#    'xdr': 168835669468.73312,
#    'xlm': 557894557834.5629,
#    'xrp': 381028187373.7015,
#    'yfi': 6340734.692196889,
#    'zar': 3511820280348.079,
#    'bits': 4120729690738.969,
#    'link': 7792832824.923861,
#    'sats': 412072969073896.94},
#   'total_volume': {'aed': 98500638270.38287,
#    'ars': 2460623590956.517,
#    'aud': 35201023612.408104,
#    'bch': 47942155.915475205,
#    'bdt': 2266938647672.6147,
#    'bhd': 10113151052.835003,
#    'bmd': 26817722961.480415,
#    'bnb': 76833432.90233956,
#    'brl': 153075562664.1304,
#    'btc': 460842.35146181856,
#    'cad': 33699955205.08517,
#    'chf': 25270179440.265224,
#    'clp': 19230995169665.27,
#    'cny': 176125395549.52264,
#    'czk': 594615962363.426,
#    'dkk': 169541912739.70874,
#    'dot': 608059335.108558,
#    'eos': 4280965968.8952146,
#    'eth': 12905938.590291044,
#    'eur': 22791578213.273388,
#    'gbp': 19394952693.864124,
#    'hkd': 208546145369.34543,
#    'huf': 8238779941888.271,
#    'idr': 389532613394473.44,
#    'ils': 89323988921.08582,
#    'inr': 1967784158994.111,
#    'jpy': 2968286143837.762,
#    'krw': 30298411154378.418,
#    'kwd': 8103484529.547582,
#    'lkr': 5333504934462.589,
#    'ltc': 132336518.65847892,
#    'mmk': 37701167650343.55,
#    'mxn': 544795471620.34766,
#    'myr': 111025373060.52904,
#    'ngn': 10217552448324.03,
#    'nok': 228826726546.2891,
#    'nzd': 38150249059.65096,
#    'php': 1302148564063.7896,
#    'pkr': 4097724039834.4375,
#    'pln': 104935041358.25383,
#    'rub': 2050220283949.772,
#    'sar': 100578529080.88411,
#    'sek': 233932955086.77005,
#    'sgd': 36092900624.938065,
#    'thb': 839126551464.7218,
#    'try': 219613015103.8595,
#    'twd': 765525310796.938,
#    'uah': 744339604652.3242,
#    'usd': 26817722961.480415,
#    'vef': 2685258600.1330357,
#    'vnd': 617200642621762.5,
#    'xag': 1074730170.2388222,
#    'xau': 15523707.113482544,
#    'xdr': 18887722281.77066,
#    'xlm': 62306038728.38729,
#    'xrp': 42376015546.2707,
#    'yfi': 710321.2847069232,
#    'zar': 392894417951.04,
#    'bits': 460842351461.81854,
#    'link': 871364985.3802456,
#    'sats': 46084235146181.85}},
#  'community_data': {'facebook_likes': None,
#   'twitter_followers': 869280,
#   'reddit_average_posts_48h': 4.727,
#   'reddit_average_comments_48h': 134.727,
#   'reddit_subscribers': 760671,
#   'reddit_accounts_active_48h': '2944.0'},
#  'developer_data': {'forks': 10734,
#   'stars': 29240,
#   'subscribers': 2053,
#   'total_issues': 5463,
#   'closed_issues': 5270,
#   'pull_requests_merged': 3606,
#   'pull_request_contributors': 513,
#   'code_additions_deletions_4_weeks': {'additions': 2978, 'deletions': -1554},
#   'commit_count_4_weeks': 74},
#  'public_interest_stats': {'alexa_rank': 6152, 'bing_matches': None}}

# %%
cg.get_coin_market_chart_by_id(id='bitcoin',vs_currency='usd',days='3')
# Out:
# {'prices': [[1620115499332, 55985.93814953248],
#   [1620119305691, 55770.89314888992],
#   [1620122549302, 56160.042476409115],
#   [1620126230565, 56408.93807865467],
#   [1620129657401, 56139.33517516755],
#   [1620133291586, 56245.36807251684],
#   [1620137226240, 55474.5546029899],
#   [1620142057553, 53772.04642670502],
#   [1620144111303, 54365.84448324026],
#   [1620147851346, 53612.73560384135],
#   [1620151236261, 54153.6396133483],
#   [1620155117828, 54645.31720844554],
#   [1620158495178, 54508.335756693654],
#   [1620162038168, 54801.05287593205],
#   [1620165771368, 54379.811458895434],
#   [1620169242225, 54151.075423453054],
#   [1620173008233, 53464.37021950372],
#   [1620176694001, 54746.69578902684],
#   [1620181720146, 55436.74979309785],
#   [1620183654837, 55032.80326941111],
#   [1620187361205, 54935.737282021575],
#   [1620191138648, 54488.3728429022],
#   [1620194546418, 54614.522165147624],
#   [1620198347231, 54507.32400092038],
#   [1620201818491, 55039.77781337696],
#   [1620205402835, 55502.24582389879],
#   [1620209036458, 55316.94578467325],
#   [1620212619283, 55504.97952723182],
#   [1620216362923, 55149.08232751617],
#   [1620219736609, 55634.935816597805],
#   [1620223550300, 56212.07538609557],
#   [1620227037713, 57332.237665518565],
#   [1620230686572, 57674.240224065914],
#   [1620234128874, 57364.45662557184],
#   [1620237794727, 57392.04022506248],
#   [1620241460301, 57312.0694420976],
#   [1620245630505, 57041.564498525906],
#   [1620248472539, 56831.0729333278],
#   [1620252051815, 56819.25954442052],
#   [1620255724922, 57215.27232018931],
#   [1620259378716, 57432.100227087576],
#   [1620263134916, 56886.35755973869],
#   [1620266517694, 57015.26093219081],
#   [1620270174826, 57024.40261514531],
#   [1620273936743, 56829.43230609249],
#   [1620277376272, 57055.48736037687],
#   [1620281000989, 57132.02694806836],
#   [1620284747302, 56606.65895273104],
#   [1620288165127, 56772.01097916502],
#   [1620291729669, 57015.71499958317],
#   [1620295247574, 57292.98216147648],
#   [1620299104298, 57999.34933717332],
#   [1620302725628, 57969.70924004506],
#   [1620306149413, 57671.53481594119],
#   [1620309690336, 57343.59707777673],
#   [1620313240996, 57310.62084801442],
#   [1620316897885, 57032.37003666917],
#   [1620320579898, 56909.36847955484],
#   [1620324255129, 56924.74993838774],
#   [1620328001049, 55774.659224122544],
#   [1620331257346, 56280.09503551131],
#   [1620334937754, 55997.25844649004],
#   [1620338824963, 56320.036515674976],
#   [1620342290199, 56478.83446437289],
#   [1620345794398, 56507.759439869595],
#   [1620349247280, 56572.22842457383],
#   [1620353003716, 56151.37143119505],
#   [1620356499781, 55847.65429325251],
#   [1620360262856, 55847.107640361384],
#   [1620363914498, 55920.02856234392],
#   [1620367558592, 55857.5370638638],
#   [1620370993912, 56224.55048320035],
#   [1620371435000, 56177.20158781303]],
#  'market_caps': [[1620115499332, 1048951948846.5729],
#   [1620119305691, 1042198248740.943],
#   [1620122549302, 1050147473154.5719],
#   [1620126230565, 1054803030281.2648],
#   [1620129657401, 1050511008626.8562],
#   [1620133291586, 1053964169031.655],
#   [1620137226240, 1037109499307.96],
#   [1620142057553, 1017216274595.8474],
#   [1620144111303, 1016610357671.0819],
#   [1620147851346, 1003942097299.5612],
#   [1620151236261, 1012647662712.6345],
#   [1620155117828, 1025968016348.07],
#   [1620158495178, 1019286800732.6564],
#   [1620162038168, 1019089221182.7201],
#   [1620165771368, 1016888498669.7996],
#   [1620169242225, 1012612926426.6018],
#   [1620173008233, 999775008412.3738],
#   [1620176694001, 1026193100663.0865],
#   [1620181720146, 1038095250122.2041],
#   [1620183654837, 1030974291821.5422],
#   [1620187361205, 1027296529230.2106],
#   [1620191138648, 1023891299810.1489],
#   [1620194546418, 1021294295214.3688],
#   [1620198347231, 1016386343973.5308],
#   [1620201818491, 1027018052060.1515],
#   [1620205402835, 1037854942720.7379],
#   [1620209036458, 1034439996289.5408],
#   [1620212619283, 1034586297026.5583],
#   [1620216362923, 1031277629858.4818],
#   [1620219736609, 1035674009239.1166],
#   [1620223550300, 1050724112521.5168],
#   [1620227037713, 1072139675832.4247],
#   [1620230686572, 1078537129310.1445],
#   [1620234128874, 1073668775883.99],
#   [1620237794727, 1073262316086.5106],
#   [1620241460301, 1071209282755.791],
#   [1620245630505, 1068323541223.1335],
#   [1620248472539, 1063653481425.0116],
#   [1620252051815, 1064481690538.1964],
#   [1620255724922, 1070204822376.4777],
#   [1620259378716, 1070969079353.5304],
#   [1620263134916, 1064048664712.4601],
#   [1620266517694, 1066238460639.896],
#   [1620270174826, 1066411186378.5331],
#   [1620273936743, 1063248569297.5801],
#   [1620277376272, 1066997521900.7759],
#   [1620281000989, 1068432091950.6829],
#   [1620284747302, 1059947501039.0374],
#   [1620288165127, 1061701893123.012],
#   [1620291729669, 1066837815388.4158],
#   [1620295247574, 1071452158729.759],
#   [1620299104298, 1085345918529.6311],
#   [1620302725628, 1084143208962.2443],
#   [1620306149413, 1078537691476.89],
#   [1620309690336, 1072405890451.9163],
#   [1620313240996, 1069930653457.907],
#   [1620316897885, 1069936835130.8478],
#   [1620320579898, 1064291237532.8167],
#   [1620324255129, 1064579975640.0065],
#   [1620328001049, 1044409076203.6205],
#   [1620331257346, 1047653862311.9207],
#   [1620334937754, 1047243536307.9137],
#   [1620338824963, 1053595888958.4564],
#   [1620342290199, 1056256544131.8225],
#   [1620345794398, 1056801053574.5111],
#   [1620349247280, 1058009177073.6489],
#   [1620353003716, 1051223078647.1772],
#   [1620356499781, 1044408730059.6896],
#   [1620360262856, 1043785688760.1453],
#   [1620363914498, 1043333616047.1945],
#   [1620367558592, 1047206710228.8082],
#   [1620370993912, 1051522394475.0562],
#   [1620371435000, 1050637596598.8064]],
#  'total_volumes': [[1620115499332, 59224059009.15166],
#   [1620119305691, 59523226162.81009],
#   [1620122549302, 60348801875.58234],
#   [1620126230565, 61491190323.7528],
#   [1620129657401, 61706785750.789665],
#   [1620133291586, 64851525855.10307],
#   [1620137226240, 63922813617.196205],
#   [1620142057553, 67250818714.05027],
#   [1620144111303, 69604261266.96521],
#   [1620147851346, 68880931996.27423],
#   [1620151236261, 70552782884.21268],
#   [1620155117828, 73144187019.37758],
#   [1620158495178, 71897022834.04578],
#   [1620162038168, 73447683985.87405],
#   [1620165771368, 71323357905.78249],
#   [1620169242225, 72226503592.38145],
#   [1620173008233, 71296763919.13268],
#   [1620176694001, 71010885376.61975],
#   [1620181720146, 71823520035.60689],
#   [1620183654837, 69858000891.66919],
#   [1620187361205, 71879857020.36972],
#   [1620191138648, 72177917137.16295],
#   [1620194546418, 71621532225.75423],
#   [1620198347231, 73346809839.76619],
#   [1620201818491, 72780154120.81352],
#   [1620205402835, 67500831823.44165],
#   [1620209036458, 72526898989.10173],
#   [1620212619283, 73199607651.46623],
#   [1620216362923, 72588054717.56865],
#   [1620219736609, 73904570328.44218],
#   [1620223550300, 71444658912.42801],
#   [1620227037713, 72866693475.19855],
#   [1620230686572, 72112463940.55205],
#   [1620234128874, 70897064713.0737],
#   [1620237794727, 70275843782.96439],
#   [1620241460301, 69848786004.86807],
#   [1620245630505, 69657858135.92912],
#   [1620248472539, 69934582931.46048],
#   [1620252051815, 69780805646.59764],
#   [1620255724922, 72179629880.42348],
#   [1620259378716, 72158368257.54709],
#   [1620263134916, 69382728950.01294],
#   [1620266517694, 70619170832.47285],
#   [1620270174826, 90067411663.16301],
#   [1620273936743, 87893124129.02573],
#   [1620277376272, 89416039169.91447],
#   [1620281000989, 87054967262.0817],
#   [1620284747302, 87576515183.14641],
#   [1620288165127, 86853428450.69218],
#   [1620291729669, 87737076924.96112],
#   [1620295247574, 88012455119.16032],
#   [1620299104298, 88354975821.71317],
#   [1620302725628, 87593176280.46347],
#   [1620306149413, 89622896515.59937],
#   [1620309690336, 87380764258.24208],
#   [1620313240996, 84769073484.18774],
#   [1620316897885, 85048653131.14633],
#   [1620320579898, 81342192108.39488],
#   [1620324255129, 82681699046.36272],
#   [1620328001049, 83979963085.36024],
#   [1620331257346, 88056939832.42482],
#   [1620334937754, 85874664804.99408],
#   [1620338824963, 86478355714.19777],
#   [1620342290199, 85911259949.59088],
#   [1620345794398, 87510802710.77629],
#   [1620349247280, 85257488426.59454],
#   [1620353003716, 85577000566.8202],
#   [1620356499781, 66123990064.05568],
#   [1620360262856, 67275417791.8712],
#   [1620363914498, 69229036374.35107],
#   [1620367558592, 67901907624.42974],
#   [1620370993912, 68781765534.62404],
#   [1620371435000, 69912417374.21951]]}

# %%
cg.get_coin_market_chart_range_by_id(id='bitcoin',vs_currency='usd',from_timestamp='1605096000',to_timestamp='1605099600')
# Out:
# {'prices': [[1605097140839, 15542.025002631644]],
#  'market_caps': [[1605097140839, 288154238228.85516]],
#  'total_volumes': [[1605097140839, 21415724096.16228]]}

# %% [markdown]
# ### Get Exchanges

# %%
cg.get_exchanges_list()
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 1297382.471147465,
#   'trade_volume_24h_btc_normalized': 1297382.471147465},
#  {'id': 'gdax',
#   'name': 'Coinbase Pro',
#   'year_established': 2012,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.coinbase.com',
#   'image': 'https://assets.coingecko.com/markets/images/23/small/fe290a14-ac8f-4c90-9aed-5e72abf271f0.jpeg?1527171545',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 170362.43350262428,
#   'trade_volume_24h_btc_normalized': 170362.43350262428},
#  {'id': 'kraken',
#   'name': 'Kraken',
#   'year_established': 2011,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://r.kraken.com/Q1m9x',
#   'image': 'https://assets.coingecko.com/markets/images/29/small/kraken.jpg?1584251255',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 3,
#   'trade_volume_24h_btc': 68644.58221273946,
#   'trade_volume_24h_btc_normalized': 68644.58221273946},
#  {'id': 'bitfinex',
#   'name': 'Bitfinex',
#   'year_established': 2014,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://www.bitfinex.com',
#   'image': 'https://assets.coingecko.com/markets/images/4/small/BItfinex.png?1615895883',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 4,
#   'trade_volume_24h_btc': 42701.365083970064,
#   'trade_volume_24h_btc_normalized': 42701.365083970064},
#  {'id': 'binance_us',
#   'name': 'Binance US',
#   'year_established': 2019,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.binance.us/en',
#   'image': 'https://assets.coingecko.com/markets/images/469/small/Binance.png?1568875842',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 5,
#   'trade_volume_24h_btc': 40817.824235126594,
#   'trade_volume_24h_btc_normalized': 40817.824235126594},
#  {'id': 'crypto_com',
#   'name': 'Crypto.com',
#   'year_established': 2019,
#   'country': 'Cayman Islands',
#   'description': 'Crypto.com Exchange is the best place to trade crypto, with deep liquidity, low fees and best execution prices, users can trade major cryptocurrencies like Bitcoin, Ethereum, and many more and receive great CRO-powered rewards',
#   'url': 'https://crypto.com/exchange',
#   'image': 'https://assets.coingecko.com/markets/images/589/small/crypto_com.jpg?1602499898',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 6,
#   'trade_volume_24h_btc': 8838.401286316985,
#   'trade_volume_24h_btc_normalized': 8838.401286316985},
#  {'id': 'huobi',
#   'name': 'Huobi Global',
#   'year_established': 2013,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.huobi.com',
#   'image': 'https://assets.coingecko.com/markets/images/25/small/1481589873352_.pic_hd.jpg?1589962155',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 7,
#   'trade_volume_24h_btc': 500084.4137709369,
#   'trade_volume_24h_btc_normalized': 500084.4137709369},
#  {'id': 'okex',
#   'name': 'OKEx',
#   'year_established': 2013,
#   'country': 'Belize',
#   'description': '',
#   'url': 'https://www.okex.com',
#   'image': 'https://assets.coingecko.com/markets/images/96/small/okEX.jpg?1519349636',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 8,
#   'trade_volume_24h_btc': 404858.6254609674,
#   'trade_volume_24h_btc_normalized': 404858.6254609674},
#  {'id': 'kucoin',
#   'name': 'KuCoin',
#   'year_established': 2014,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.kucoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/61/small/kucoin.jpg?1591610627',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 9,
#   'trade_volume_24h_btc': 59002.5206450229,
#   'trade_volume_24h_btc_normalized': 59002.5206450229},
#  {'id': 'gate',
#   'name': 'Gate.io',
#   'year_established': None,
#   'country': 'Hong Kong',
#   'description': '',
#   'url': 'https://gate.io/',
#   'image': 'https://assets.coingecko.com/markets/images/60/small/gateio.jpg?1519793974',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 10,
#   'trade_volume_24h_btc': 42509.39785291005,
#   'trade_volume_24h_btc_normalized': 42509.39785291005},
#  {'id': 'ftx_spot',
#   'name': 'FTX',
#   'year_established': 2019,
#   'country': 'Antigua and Barbuda',
#   'description': '',
#   'url': 'https://ftx.com/',
#   'image': 'https://assets.coingecko.com/markets/images/451/small/F.png?1609051590',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 11,
#   'trade_volume_24h_btc': 33191.370502537065,
#   'trade_volume_24h_btc_normalized': 33191.370502537065},
#  {'id': 'bitstamp',
#   'name': 'Bitstamp',
#   'year_established': 2013,
#   'country': 'United Kingdom',
#   'description': None,
#   'url': 'https://www.bitstamp.net/',
#   'image': 'https://assets.coingecko.com/markets/images/9/small/bitstamp.jpg?1519627979',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 12,
#   'trade_volume_24h_btc': 25287.15874390611,
#   'trade_volume_24h_btc_normalized': 25287.15874390611},
#  {'id': 'bittrex',
#   'name': 'Bittrex',
#   'year_established': 2014,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://bittrex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/10/small/BG-color-250x250_icon.png?1596167574',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 13,
#   'trade_volume_24h_btc': 12411.11722854366,
#   'trade_volume_24h_btc_normalized': 12411.11722854366},
#  {'id': 'bithumb_global',
#   'name': 'Bithumb Global',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://bithumb.pro/',
#   'image': 'https://assets.coingecko.com/markets/images/405/small/bithumbglobal.jpg?1599652253',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 14,
#   'trade_volume_24h_btc': 7382.98550502936,
#   'trade_volume_24h_btc_normalized': 7382.98550502936},
#  {'id': 'gemini',
#   'name': 'Gemini',
#   'year_established': 2014,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://gemini.sjv.io/bZ49k',
#   'image': 'https://assets.coingecko.com/markets/images/50/small/gemini.png?1605704107',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 15,
#   'trade_volume_24h_btc': 5732.328490628383,
#   'trade_volume_24h_btc_normalized': 5732.328490628383},
#  {'id': 'cex',
#   'name': 'CEX.IO',
#   'year_established': 2013,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://cex.io/',
#   'image': 'https://assets.coingecko.com/markets/images/56/small/main-icon.png?1617267530',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 16,
#   'trade_volume_24h_btc': 1973.9913435826882,
#   'trade_volume_24h_btc_normalized': 1973.9913435826882},
#  {'id': 'bitso',
#   'name': 'Bitso',
#   'year_established': 2014,
#   'country': 'Mexico',
#   'description': '',
#   'url': 'https://bitso.com',
#   'image': 'https://assets.coingecko.com/markets/images/8/small/Bitso-icon-dark.png?1581909156',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 17,
#   'trade_volume_24h_btc': 716.9181103773442,
#   'trade_volume_24h_btc_normalized': 716.9181103773442},
#  {'id': 'nice_hash',
#   'name': 'NiceHash',
#   'year_established': None,
#   'country': 'Slovenia',
#   'description': '',
#   'url': 'https://www.nicehash.com',
#   'image': 'https://assets.coingecko.com/markets/images/546/small/nicehash.png?1594379914',
#   'has_trading_incentive': False,
#   'trust_score': 9,
#   'trust_score_rank': 18,
#   'trade_volume_24h_btc': 59.67480057884488,
#   'trade_volume_24h_btc_normalized': 59.67480057884488},
#  {'id': 'digifinex',
#   'name': 'Digifinex',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.digifinex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/225/small/DF_logo.png?1594264355',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 19,
#   'trade_volume_24h_btc': 159923.21236838793,
#   'trade_volume_24h_btc_normalized': 159923.21236838793},
#  {'id': 'coinbene',
#   'name': 'CoinBene',
#   'year_established': 2017,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'http://www.coinbene.com/#/',
#   'image': 'https://assets.coingecko.com/markets/images/109/small/CoinBene_logo.png?1607418278',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 20,
#   'trade_volume_24h_btc': 124788.82202952426,
#   'trade_volume_24h_btc_normalized': 124788.82202952426},
#  {'id': 'bitrue',
#   'name': 'Bitrue',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.bitrue.com/',
#   'image': 'https://assets.coingecko.com/markets/images/254/small/bitrue-exchange.jpg?1537878894',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 21,
#   'trade_volume_24h_btc': 112795.28509932886,
#   'trade_volume_24h_btc_normalized': 112795.28509932886},
#  {'id': 'zb',
#   'name': 'ZB',
#   'year_established': 2017,
#   'country': 'China',
#   'description': '',
#   'url': 'https://www.zb.com/',
#   'image': 'https://assets.coingecko.com/markets/images/115/small/zb.jpg?1519996151',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 22,
#   'trade_volume_24h_btc': 108212.01450572195,
#   'trade_volume_24h_btc_normalized': 108212.01450572195},
#  {'id': 'bithumb',
#   'name': 'Bithumb',
#   'year_established': 2014,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://www.bithumb.com/',
#   'image': 'https://assets.coingecko.com/markets/images/6/small/bithumb_BI.png?1573104549',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 23,
#   'trade_volume_24h_btc': 98745.91645030539,
#   'trade_volume_24h_btc_normalized': 98745.91645030539},
#  {'id': 'bitcoin_com',
#   'name': 'Bitcoin.com Exchange',
#   'year_established': 2019,
#   'country': 'Bahamas',
#   'description': 'The mission of Bitcoin.com Exchange is to empower people from all over the world to trade cryptocurrencies with ease and confidence, from first-time traders to advanced trading professionals. With high liquidity, 24/7 multilingual support and dozens of trading pairs, complemented with a high level of security, we offer an attractive platform for trading any cryptocurrency. Within one year since launch, on average, our exchange has been visited by more than 500K active traders per month, and this number continues to grow as you read this sentence. \r\n\r\nKey Features:\r\n\r\n- Enjoy more than 130 available trading pairs\r\n- Cutting-edge matching engine technologies\r\n- Up 5x and 10x leverage for more than 29 markets\r\n- Deep liquidity\r\n- User-friendly trading terminal\r\n- Tight spreads\r\n- Consistent trading competitions and giveaways',
#   'url': 'https://exchange.bitcoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/467/small/logomark.png?1568799194',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 24,
#   'trade_volume_24h_btc': 61736.4524548186,
#   'trade_volume_24h_btc_normalized': 61736.4524548186},
#  {'id': 'changelly',
#   'name': 'Changelly PRO',
#   'year_established': 2020,
#   'country': 'Seychelles',
#   'description': 'Launched on 06/07/2020, Changelly PRO is a centralized exchange located at 306 Victoria House, Victoria Mahe, Seychelles. It is a professional version of the instant swap platform Changelly. Changelly PRO aims to serve the fast growing Changelly community that has been requesting professional trading features as well as foster the onboarding of beginners to advanced trading. The PRO version has spot and margin trading as well as fiat on-ramp solution.\r\nPRO offers:\r\n• Multi-currency wallet to store a variety of coins\r\n• Interactive and customizable terminal\r\n• Access to 50+ markets\r\n• Competitive trading fees starting from 0.1% both for makers and takers\r\n• Lowest withdrawal fees on the most popular coins and tokens such as BTC, ETH, XRP\r\n• Simple registration process with several verification levels',
#   'url': 'https://pro.changelly.com/',
#   'image': 'https://assets.coingecko.com/markets/images/580/small/pro_logo_cmc.png?1600833621',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 25,
#   'trade_volume_24h_btc': 58417.69443844975,
#   'trade_volume_24h_btc_normalized': 58417.69443844975},
#  {'id': 'biki',
#   'name': 'BiKi',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': 'BiKi is a centralized cryptocurrency exchange located in Singapore. There are 470 coins and 515 trading pairs on the exchange. BiKi volume in the last 24 hours is reported to be at ₿20,541.23. The most active trading pair on BiKi exchange is ETH/USDT. BiKi is established in year 2018.\r\n\r\nMore information about BiKi exchange can be found at https://www.biki.cc/register?inviteCode=WWAETAA. ',
#   'url': 'https://www.biki.cc/',
#   'image': 'https://assets.coingecko.com/markets/images/384/small/BiKi_icon.png?1573632986',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 26,
#   'trade_volume_24h_btc': 56662.961573471504,
#   'trade_volume_24h_btc_normalized': 56662.961573471504},
#  {'id': 'cointiger',
#   'name': 'CoinTiger',
#   'year_established': 2017,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.cointiger.com/',
#   'image': 'https://assets.coingecko.com/markets/images/204/small/cointiger.png?1588935091',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 27,
#   'trade_volume_24h_btc': 51482.92185497222,
#   'trade_volume_24h_btc_normalized': 51482.92185497222},
#  {'id': 'hoo',
#   'name': 'Hoo.com',
#   'year_established': 2019,
#   'country': 'Hong Kong',
#   'description': 'Hoo.com is a world’s leading blockchain assets service platform, aiming to provide safe and reliable assets management and blockchain services to users worldwide. ',
#   'url': 'https://www.hoo.com',
#   'image': 'https://assets.coingecko.com/markets/images/526/small/Hoo_Logo2.jpg?1602237762',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 28,
#   'trade_volume_24h_btc': 28318.5662072976,
#   'trade_volume_24h_btc_normalized': 28318.5662072976},
#  {'id': 'coinsbit',
#   'name': 'Coinsbit',
#   'year_established': None,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://coinsbit.io/',
#   'image': 'https://assets.coingecko.com/markets/images/267/small/Coinsbit.png?1605153697',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 29,
#   'trade_volume_24h_btc': 25388.94402155361,
#   'trade_volume_24h_btc_normalized': 25388.94402155361},
#  {'id': 'lbank',
#   'name': 'LBank',
#   'year_established': 2017,
#   'country': 'China',
#   'description': "Founded in October 2016, LBank is a centralized digital asset trading platform for international users. It aims to provide professional asset management solutions. At present, LBank offers hundreds of digital currency pairs. LBank also claims to have one of the highest staking rewards on any exchange.\r\n\r\nLBank's claims that its core team comes from the traditional financial industry, IT, and top 500 universities. The team aims to build the most professional integrated service platform for digital assets while ensuring security.",
#   'url': 'https://www.lbank.info/',
#   'image': 'https://assets.coingecko.com/markets/images/118/small/LBank%E5%9C%86%E6%A0%87.png?1572923264',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 30,
#   'trade_volume_24h_btc': 24929.574321829423,
#   'trade_volume_24h_btc_normalized': 24929.574321829423},
#  {'id': 'bigone',
#   'name': 'BigONE',
#   'year_established': 2017,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://bigone.com',
#   'image': 'https://assets.coingecko.com/markets/images/100/small/qcFFufEY_400x400.jpg?1561103345',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 31,
#   'trade_volume_24h_btc': 22556.50679190873,
#   'trade_volume_24h_btc_normalized': 22556.50679190873},
#  {'id': 'bitforex',
#   'name': 'Bitforex',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.bitforex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/214/small/BitForex-Logo.png?1573808227',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 32,
#   'trade_volume_24h_btc': 16992.68618178517,
#   'trade_volume_24h_btc_normalized': 16992.68618178517},
#  {'id': 'latoken',
#   'name': 'LATOKEN',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://latoken.com/',
#   'image': 'https://assets.coingecko.com/markets/images/124/small/LA_token.png?1605773251',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 33,
#   'trade_volume_24h_btc': 15266.838761608165,
#   'trade_volume_24h_btc_normalized': 15266.838761608165},
#  {'id': 'bitmart',
#   'name': 'BitMart',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.bitmart.com/en',
#   'image': 'https://assets.coingecko.com/markets/images/239/small/BitMart_logo.png?1611891118',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 34,
#   'trade_volume_24h_btc': 13462.167130540609,
#   'trade_volume_24h_btc_normalized': 13462.167130540609},
#  {'id': 'bitflyer',
#   'name': 'bitFlyer',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://bitflyereuropesa.pxf.io/c/2223866/858437/11990',
#   'image': 'https://assets.coingecko.com/markets/images/5/small/bitflyer.jpg?1519611556',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 35,
#   'trade_volume_24h_btc': 7385.354218210614,
#   'trade_volume_24h_btc_normalized': 7385.354218210614},
#  {'id': 'poloniex',
#   'name': 'Poloniex',
#   'year_established': 2014,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://poloniex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/37/small/poloniex.jpg?1519639007',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 36,
#   'trade_volume_24h_btc': 6262.549004341357,
#   'trade_volume_24h_btc_normalized': 6262.549004341357},
#  {'id': 'bitmax',
#   'name': 'AscendEX (BitMax)',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': 'AscendEX (formerly BitMax) is a leading global digital asset financial platform founded by a group of Wall Street quantitative trading veterans in 2018, building on core value of “Efficiency, Resilience and Transparency.” \r\n \r\nDriven by its continuous innovative product development and early-mover advantage in strategic alignment with the leading projects from DeFi ecosystem, AscendEX offers trading services across over 200 trading pairs across cash, margin, and futures products, in particular margin trading of over 50 tokens in cross-asset collateral mode and futures trading in both cross-asset and isolated margin modes.',
#   'url': 'https://ascendex.com/en/global-digital-asset-platform',
#   'image': 'https://assets.coingecko.com/markets/images/277/small/AscendEX.png?1616471675',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 37,
#   'trade_volume_24h_btc': 5448.28524795948,
#   'trade_volume_24h_btc_normalized': 5448.28524795948},
#  {'id': 'etorox',
#   'name': 'eToroX',
#   'year_established': 2019,
#   'country': 'Gibraltar',
#   'description': 'eToroX is eToro’s professional crypto exchange. Designed exclusively for the corporate and institutional-grade crypto trading community, the eToroX exchange is a highly effective, trusted and secure crypto trading solution, which is licensed and regulated by the Gibraltar Financial Services Commission under the Investments and Financial Fiduciary Services Act (licence number FSC1333B). eToroX currently has more than 30 digital assets, including 17 tokenized fiat and commodity stablecoins, and more than 100 trading pairs.',
#   'url': 'https://www.etorox.com/',
#   'image': 'https://assets.coingecko.com/markets/images/503/small/eToroX_Logo_400x400.jpg?1580209571',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 38,
#   'trade_volume_24h_btc': 5376.119768004374,
#   'trade_volume_24h_btc_normalized': 5376.119768004374},
#  {'id': 'indodax',
#   'name': 'Indodax',
#   'year_established': 2014,
#   'country': 'Indonesia',
#   'description': '',
#   'url': 'https://indodax.com',
#   'image': 'https://assets.coingecko.com/markets/images/3/small/logogram-Indodax-new-_JPG_format.jpg?1580974378',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 39,
#   'trade_volume_24h_btc': 4364.32152091782,
#   'trade_volume_24h_btc_normalized': 4364.32152091782},
#  {'id': 'bitkub',
#   'name': 'Bitkub',
#   'year_established': 2018,
#   'country': 'Thailand',
#   'description': '',
#   'url': 'https://www.bitkub.com',
#   'image': 'https://assets.coingecko.com/markets/images/249/small/bitkub.png?1537180687',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 40,
#   'trade_volume_24h_btc': 4346.734758089014,
#   'trade_volume_24h_btc_normalized': 4346.734758089014},
#  {'id': 'bitget',
#   'name': 'Bitget',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.bitget.com/',
#   'image': 'https://assets.coingecko.com/markets/images/540/small/bitget-logo-1.png?1591831975',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 41,
#   'trade_volume_24h_btc': 3944.725029472252,
#   'trade_volume_24h_btc_normalized': 3944.725029472252},
#  {'id': 'dextrade',
#   'name': 'Dex-Trade',
#   'year_established': 2019,
#   'country': 'United Kingdom',
#   'description': 'Dex-Trade is young but the most technical equiped crypto exchange, it offers traders easy-to-use interface and transactions safity. Since 2018, Dex-Trade team has the most fully range of security measures and security risk control measures in the industry. Dex-Trade welcomes global users and continues to expands digital currency in various countries to provide users with global trading opportunities. High-quality currencies are listed on Dex-Trade to offer traders comprehensive range of digital assets. By your side 24 hours a day, our support team will assist you with any issue or question you may have.',
#   'url': 'https://dex-trade.com/',
#   'image': 'https://assets.coingecko.com/markets/images/380/small/Dex-Trade_logo_new.png?1599629803',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 42,
#   'trade_volume_24h_btc': 871.2000361960156,
#   'trade_volume_24h_btc_normalized': 871.2000361960156},
#  {'id': 'aax',
#   'name': 'AAX',
#   'year_established': 2019,
#   'country': None,
#   'description': 'AAX is the world’s first cryptocurrency exchange to be powered by LSEG Technology’s Millennium Exchange, the same matching engine at the heart of tier-one capital markets. AAX is a member of London Stock Exchange Group’s global ‘Partner Platform’. Offering OTC, Spot, and Futures trading, quoting more than 50 cryptocurrency pairs and listing 5 perpetual futures contracts for Bitcoin, Ether, Litecoin, Ripple, and EOS, which can be traded with high leverage, AAX provides a secure, deeply liquid, ultra-low latency and fully compliant trading platform. It offers an institutional-grade platform, for everyone. ',
#   'url': 'https://www.aax.com',
#   'image': 'https://assets.coingecko.com/markets/images/527/small/aax_app_logo.png?1586779427',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 43,
#   'trade_volume_24h_btc': 588.8283104327132,
#   'trade_volume_24h_btc_normalized': 588.8283104327132},
#  {'id': 'max_maicoin',
#   'name': 'Max Maicoin',
#   'year_established': None,
#   'country': 'Taiwan',
#   'description': '',
#   'url': 'https://max.maicoin.com',
#   'image': 'https://assets.coingecko.com/markets/images/218/small/max.jpg?1533888641',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 44,
#   'trade_volume_24h_btc': 566.1717919064754,
#   'trade_volume_24h_btc_normalized': 566.1717919064754},
#  {'id': 'bitopro',
#   'name': 'BitoPro',
#   'year_established': 2018,
#   'country': 'Taiwan',
#   'description': '',
#   'url': 'https://www.bitopro.com/',
#   'image': 'https://assets.coingecko.com/markets/images/358/small/bitopro_coingecko_250x250_%281%29.png?1575884378',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 45,
#   'trade_volume_24h_btc': 483.70560418992545,
#   'trade_volume_24h_btc_normalized': 483.70560418992545},
#  {'id': 'narkasa',
#   'name': 'Narkasa',
#   'year_established': 2020,
#   'country': 'Turkey',
#   'description': '',
#   'url': 'https://narkasa.com/',
#   'image': 'https://assets.coingecko.com/markets/images/573/small/narkasa.jpg?1599029564',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 46,
#   'trade_volume_24h_btc': 110.50165552844268,
#   'trade_volume_24h_btc_normalized': 110.50165552844268},
#  {'id': 'kuna',
#   'name': 'Kuna Exchange',
#   'year_established': None,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://kuna.io/',
#   'image': 'https://assets.coingecko.com/markets/images/97/small/kuna_exchange.png?1545126178',
#   'has_trading_incentive': False,
#   'trust_score': 8,
#   'trust_score_rank': 47,
#   'trade_volume_24h_btc': 54.0062126277343,
#   'trade_volume_24h_btc_normalized': 54.0062126277343},
#  {'id': 'upbit',
#   'name': 'Upbit',
#   'year_established': 2017,
#   'country': 'South Korea',
#   'description': None,
#   'url': 'https://upbit.com',
#   'image': 'https://assets.coingecko.com/markets/images/117/small/upbit.png?1520388800',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 48,
#   'trade_volume_24h_btc': 604546.52773782,
#   'trade_volume_24h_btc_normalized': 604546.52773782},
#  {'id': 'xt',
#   'name': 'XT.COM',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.xt.com/',
#   'image': 'https://assets.coingecko.com/markets/images/404/small/logo400x400.png?1575881839',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 49,
#   'trade_volume_24h_btc': 80905.23858563448,
#   'trade_volume_24h_btc_normalized': 80905.23858563448},
#  {'id': 'coinhe',
#   'name': 'CoinHe',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://coinhe.io/',
#   'image': 'https://assets.coingecko.com/markets/images/458/small/coinhe.png?1565866997',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 50,
#   'trade_volume_24h_btc': 34740.81888245552,
#   'trade_volume_24h_btc_normalized': 34740.81888245552},
#  {'id': 'whitebit',
#   'name': 'WhiteBIT',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://whitebit.com',
#   'image': 'https://assets.coingecko.com/markets/images/418/small/wb_3_avatar-02.png?1611212424',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 51,
#   'trade_volume_24h_btc': 32055.628174908226,
#   'trade_volume_24h_btc_normalized': 32055.628174908226},
#  {'id': 'coinone',
#   'name': 'Coinone',
#   'year_established': 2016,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://coinone.co.kr/',
#   'image': 'https://assets.coingecko.com/markets/images/20/small/coinone_circle_500x500.png?1606460853',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 52,
#   'trade_volume_24h_btc': 31404.83163756595,
#   'trade_volume_24h_btc_normalized': 31404.83163756595},
#  {'id': 'mxc',
#   'name': 'MXC',
#   'year_established': 2018,
#   'country': None,
#   'description': 'Launched in Apr 2018, MXC is a centralized cryptocurrency exchange registered in Seychelles. It supports CNY, VND, USD, GBP, EUR, AUD deposit, and CNY, VND withdrawal.',
#   'url': 'https://www.mxc.com/',
#   'image': 'https://assets.coingecko.com/markets/images/409/small/MXC.png?1558593762',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 53,
#   'trade_volume_24h_btc': 31573.263824345493,
#   'trade_volume_24h_btc_normalized': 31573.263824345493},
#  {'id': 'paribu',
#   'name': 'Paribu',
#   'year_established': None,
#   'country': 'Turkey',
#   'description': None,
#   'url': 'https://www.paribu.com/',
#   'image': 'https://assets.coingecko.com/markets/images/136/small/paribu.jpg?1527734779',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 54,
#   'trade_volume_24h_btc': 25782.061613116624,
#   'trade_volume_24h_btc_normalized': 25782.061613116624},
#  {'id': 'btcturk',
#   'name': 'BtcTurk PRO',
#   'year_established': None,
#   'country': 'Turkey',
#   'description': '',
#   'url': 'https://pro.btcturk.com/',
#   'image': 'https://assets.coingecko.com/markets/images/223/small/BTCTurk-exchange.jpg?1536726120',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 55,
#   'trade_volume_24h_btc': 20033.566915647327,
#   'trade_volume_24h_btc_normalized': 20033.566915647327},
#  {'id': 'omgfin',
#   'name': 'Omgfin',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://omgfin.com/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/396/small/Screenshot_11.png?1556858288',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 56,
#   'trade_volume_24h_btc': 19217.489712985967,
#   'trade_volume_24h_btc_normalized': 19217.489712985967},
#  {'id': 'bitbank',
#   'name': 'Bitbank',
#   'year_established': 2016,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://bitbank.cc/',
#   'image': 'https://assets.coingecko.com/markets/images/122/small/bitbank.jpg?1521186278',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 57,
#   'trade_volume_24h_btc': 15653.76522437179,
#   'trade_volume_24h_btc_normalized': 15653.76522437179},
#  {'id': 'cbx',
#   'name': 'CBX',
#   'year_established': 2018,
#   'country': 'United Arab Emirates',
#   'description': '',
#   'url': 'https://www.cbx.one',
#   'image': 'https://assets.coingecko.com/markets/images/355/small/cbx.jpg?1581414643',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 58,
#   'trade_volume_24h_btc': 15793.607309456957,
#   'trade_volume_24h_btc_normalized': 15793.607309456957},
#  {'id': 'coineal',
#   'name': 'Coineal',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': None,
#   'url': 'https://www.coineal.com/',
#   'image': 'https://assets.coingecko.com/markets/images/289/small/1537958245x-1566680256.png?1539679939',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 59,
#   'trade_volume_24h_btc': 12487.12909879646,
#   'trade_volume_24h_btc_normalized': 12487.12909879646},
#  {'id': 'oceanex',
#   'name': 'Oceanex',
#   'year_established': 2018,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://oceanex.pro',
#   'image': 'https://assets.coingecko.com/markets/images/341/small/Oceanex.png?1548153658',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 60,
#   'trade_volume_24h_btc': 11551.215352034154,
#   'trade_volume_24h_btc_normalized': 11551.215352034154},
#  {'id': 'probit',
#   'name': 'ProBit',
#   'year_established': 2017,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.probit.com/',
#   'image': 'https://assets.coingecko.com/markets/images/370/small/probit.png?1594886584',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 61,
#   'trade_volume_24h_btc': 8469.30608929051,
#   'trade_volume_24h_btc_normalized': 8469.30608929051},
#  {'id': 'aex',
#   'name': 'AEX',
#   'year_established': 2013,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.aex.cool/',
#   'image': 'https://assets.coingecko.com/markets/images/449/small/aex.png?1596082957',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 62,
#   'trade_volume_24h_btc': 6822.856967074442,
#   'trade_volume_24h_btc_normalized': 6822.856967074442},
#  {'id': 'ftx_us',
#   'name': 'FTX.US',
#   'year_established': 2020,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://ftx.us/',
#   'image': 'https://assets.coingecko.com/markets/images/532/small/FTX-US.jpg?1609051756',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 63,
#   'trade_volume_24h_btc': 3823.9398425816835,
#   'trade_volume_24h_btc_normalized': 3823.9398425816835},
#  {'id': 'coincheck',
#   'name': 'Coincheck',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://coincheck.com/',
#   'image': 'https://assets.coingecko.com/markets/images/18/small/Coincheck.jpg?1519703836',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 64,
#   'trade_volume_24h_btc': 3119.165555003249,
#   'trade_volume_24h_btc_normalized': 3119.165555003249},
#  {'id': 'gopax',
#   'name': 'GoPax',
#   'year_established': 2016,
#   'country': 'South Korea',
#   'description': None,
#   'url': 'https://www.gopax.co.kr/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/144/small/gopax.jpg?1523527412',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 65,
#   'trade_volume_24h_btc': 2936.8485424153628,
#   'trade_volume_24h_btc_normalized': 2936.8485424153628},
#  {'id': 'korbit',
#   'name': 'Korbit',
#   'year_established': 2013,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://www.korbit.co.kr/',
#   'image': 'https://assets.coingecko.com/markets/images/28/small/korbit-logo.png?1584091827',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 66,
#   'trade_volume_24h_btc': 2895.327772685544,
#   'trade_volume_24h_btc_normalized': 2895.327772685544},
#  {'id': 'alterdice',
#   'name': 'AlterDice',
#   'year_established': 2018,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://alterdice.com/',
#   'image': 'https://assets.coingecko.com/markets/images/327/small/alterdice_%281%29.png?1604294926',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 67,
#   'trade_volume_24h_btc': 2001.7403034546526,
#   'trade_volume_24h_btc_normalized': 2001.7403034546526},
#  {'id': 'nominex',
#   'name': 'Nominex',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': 'New trading platform for convenient trading experience with low fees and numerous instruments. \r\n\r\nAbsolutely unique affiliate program that allows to earn from an infinite number of referral levels, compared to 2-3 levels at all other exchanges. \r\n\r\nA unique model for the free 2 phases distribution of the native NMX token.\r\n\r\nAdvanced Trading Instruments – using Stop, Stop Limit, Trailing Stop, Scaled and other types of orders brings some kind of trading automation without the need to develop a trading bot, which allows to easily get more profit while trading.',
#   'url': 'https://www.nominex.io',
#   'image': 'https://assets.coingecko.com/markets/images/530/small/logo-200x200.png?1587543672',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 68,
#   'trade_volume_24h_btc': 1764.5905033325037,
#   'trade_volume_24h_btc_normalized': 1764.5905033325037},
#  {'id': 'luno',
#   'name': 'Luno',
#   'year_established': 2013,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://www.luno.com',
#   'image': 'https://assets.coingecko.com/markets/images/33/small/luno.jpg?1519996997',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 69,
#   'trade_volume_24h_btc': 1616.0603675374516,
#   'trade_volume_24h_btc_normalized': 1616.0603675374516},
#  {'id': 'okcoin',
#   'name': 'Okcoin',
#   'year_established': 2013,
#   'country': 'United States',
#   'description': 'About OKCoin:\r\nOKCoin is one of the largest and most trusted fiat-to-crypto trading platforms in the world. Founded in 2013, OKCoin offers advanced features for crypto beginners and high-volume traders alike, enabling users in 184 countries worldwide to exchange US dollars and the euro for Bitcoin, Tethers, USDK, Bitcoin Cash, Ethereum, Ethereum Classic, Decred, EOS, Litecoin, XRP, Cardano, 0x, Stellar, Zcash, TRX, and other digital assets. As a registered Money Services Business (MSB) with the Financial Crimes Enforcement Network (FinCEN) and a Virtual Financial Asset Act (VFAA) exchange with a transitory provision permissioned by the Malta Financial Services Authority, OKCoin is on a mission to make digital assets accessible to the world while complying with the highest of regulatory standards. For more information, visit www.okcoin.com. ',
#   'url': 'https://www.okcoin.com/',
#   'image': 'https://assets.coingecko.com/markets/images/415/small/okcoin_Logomark_SatoshiBlack.png?1619574335',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 70,
#   'trade_volume_24h_btc': 1186.8482401598574,
#   'trade_volume_24h_btc_normalized': 1186.8482401598574},
#  {'id': 'atomars',
#   'name': 'Atomars',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://atomars.com',
#   'image': 'https://assets.coingecko.com/markets/images/457/small/logo-ATOMARS-black.png?1565004325',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 71,
#   'trade_volume_24h_btc': 983.748556472161,
#   'trade_volume_24h_btc_normalized': 983.748556472161},
#  {'id': 'cryptology',
#   'name': 'Cryptology',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': '',
#   'url': 'https://cryptology.com/',
#   'image': 'https://assets.coingecko.com/markets/images/287/small/cryptology.png?1541390904',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 72,
#   'trade_volume_24h_btc': 751.0022263074003,
#   'trade_volume_24h_btc_normalized': 751.0022263074003},
#  {'id': 'blockchain_com',
#   'name': 'Blockchain.com',
#   'year_established': 2012,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://www.blockchain.com/',
#   'image': 'https://assets.coingecko.com/markets/images/613/small/unnamedddd.png?1610503741',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 73,
#   'trade_volume_24h_btc': 715.4663172738501,
#   'trade_volume_24h_btc_normalized': 715.4663172738501},
#  {'id': 'btcmarkets',
#   'name': 'BTCMarkets',
#   'year_established': None,
#   'country': 'Australia',
#   'description': '',
#   'url': 'https://www.btcmarkets.net/',
#   'image': 'https://assets.coingecko.com/markets/images/237/small/btcmarkets-exchange.jpg?1536726060',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 74,
#   'trade_volume_24h_btc': 656.9843422762073,
#   'trade_volume_24h_btc_normalized': 656.9843422762073},
#  {'id': 'zaif',
#   'name': 'Zaif',
#   'year_established': 2015,
#   'country': 'Japan',
#   'description': None,
#   'url': 'https://zaif.jp/',
#   'image': 'https://assets.coingecko.com/markets/images/99/small/zaif.png?1519627467',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 75,
#   'trade_volume_24h_btc': 453.0668798303408,
#   'trade_volume_24h_btc_normalized': 453.0668798303408},
#  {'id': 'mercado_bitcoin',
#   'name': 'Mercado Bitcoin',
#   'year_established': 2016,
#   'country': 'Brazil',
#   'description': None,
#   'url': 'https://www.mercadobitcoin.com.br/',
#   'image': 'https://assets.coingecko.com/markets/images/34/small/mercado.png?1520923694',
#   'has_trading_incentive': None,
#   'trust_score': 7,
#   'trust_score_rank': 76,
#   'trade_volume_24h_btc': 421.73140893911693,
#   'trade_volume_24h_btc_normalized': 421.73140893911693},
#  {'id': 'independent_reserve',
#   'name': 'Independent Reserve',
#   'year_established': 2013,
#   'country': 'Australia',
#   'description': '',
#   'url': 'https://www.independentreserve.com/',
#   'image': 'https://assets.coingecko.com/markets/images/389/small/x_V5Jquo_400x400.png?1556071437',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 77,
#   'trade_volume_24h_btc': 409.5469786145286,
#   'trade_volume_24h_btc_normalized': 409.5469786145286},
#  {'id': 'bitpanda',
#   'name': 'Bitpanda Pro',
#   'year_established': 2014,
#   'country': 'Austria',
#   'description': '',
#   'url': 'https://exchange.bitpanda.com',
#   'image': 'https://assets.coingecko.com/markets/images/474/small/bitpanda-pro.png?1619079941',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 78,
#   'trade_volume_24h_btc': 374.3659559712916,
#   'trade_volume_24h_btc_normalized': 374.3659559712916},
#  {'id': 'itbit',
#   'name': 'itBit',
#   'year_established': 2013,
#   'country': 'United States',
#   'description': None,
#   'url': 'https://www.itbit.com/',
#   'image': 'https://assets.coingecko.com/markets/images/26/small/itbit.png?1519810172',
#   'has_trading_incentive': False,
#   'trust_score': 7,
#   'trust_score_rank': 79,
#   'trade_volume_24h_btc': 907.0224563362907,
#   'trade_volume_24h_btc_normalized': 0.0},
#  {'id': 'vcc',
#   'name': 'VCC Exchange',
#   'year_established': 2019,
#   'country': 'Vietnam',
#   'description': 'Launched on May 19, 2019, VCC Exchange is an exchange based in Singapore, operates in Vietnam. It has worked with the government in few initiatives including Dialogue on blockchain-based applications’ legal framework (https://bit.ly/32SJVl2) and Vietnam Blockchain Startup (https://bit.ly/341Iv7Q).\r\n\r\nVCC supports trading crypto-crypto, VND-crypto in web, iOS and Android applications. VCC Exchange is backed by Signum Capital and Axiom Associates Capital. It currently supports trading fee of 0%.',
#   'url': 'https://vcc.exchange',
#   'image': 'https://assets.coingecko.com/markets/images/500/small/VCC_Logo_200x200.jpg?1576147069',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 80,
#   'trade_volume_24h_btc': 383722.5020125994,
#   'trade_volume_24h_btc_normalized': 383722.5020125994},
#  {'id': 'bidesk',
#   'name': 'Bidesk',
#   'year_established': 2019,
#   'country': 'British Virgin Islands',
#   'description': 'Bidesk exchange is a digital asset trading platform aiming to provide a secure and safe platform for trading liquidity of in demand and quality tokens with a class user experience. Its advanced fast matching engine, 24/7 customer support and high-grade financial support services are expected to maximize the wealth growth opportunities to its users. ',
#   'url': 'https://www.bidesk.com/',
#   'image': 'https://assets.coingecko.com/markets/images/545/small/bidesk.png?1593787873',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 81,
#   'trade_volume_24h_btc': 132586.80856516704,
#   'trade_volume_24h_btc_normalized': 132586.80856516704},
#  {'id': 'bitoffer',
#   'name': 'Bitoffer',
#   'year_established': 2019,
#   'country': 'Hong Kong',
#   'description': '',
#   'url': 'https://www.bitoffer.com/en',
#   'image': 'https://assets.coingecko.com/markets/images/456/small/S1naTFE.png?1565005583',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 82,
#   'trade_volume_24h_btc': 78999.54193807759,
#   'trade_volume_24h_btc_normalized': 78999.54193807759},
#  {'id': 'hitbtc',
#   'name': 'HitBTC',
#   'year_established': 2013,
#   'country': None,
#   'description': 'HitBTC is the world’s most advanced cryptocurrency exchange. Since 2013, HitBTC has been providing markets for Bitcoin, Ethereum, Litecoin, Dogecoin, Monero, USDT, and more than 300 cryptocurrencies in total.\r\n\r\nCreated by outstanding technical minds, high-level finance professionals and experienced traders, HitBTC delivers the most reliable, fast and powerful platform solution on the market.\r\n\r\nThe platform has earned its reputation for fault-tolerance, flawless uptime and high availability. Its core matching engine is among the best technological products in its class, offering traders a wide range of features such as real-time clearing and cutting-edge order matching algorithms.\r\n\r\nKey Features:\r\nRebate system - attractive to the most powerful market makers, creating high liquidity\r\nNo limits on the deposit or withdrawal of digital assets\r\nCutting-edge matching engine technologies\r\nWide range of available instruments (more than 500)\r\nThe most advanced API on the market (REST API and FIX API)\r\nAccess to the crypto assets exchange platform technology under the registered trademark “HitBTC” is provided in accordance with the Terms of Service.',
#   'url': 'https://hitbtc.com/',
#   'image': 'https://assets.coingecko.com/markets/images/24/small/hitbtc.png?1603975458',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 83,
#   'trade_volume_24h_btc': 72951.3522465502,
#   'trade_volume_24h_btc_normalized': 72951.3522465502},
#  {'id': 'bkex',
#   'name': 'BKEX',
#   'year_established': 2018,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://www.bkex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/293/small/logo.png?1588125944',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 84,
#   'trade_volume_24h_btc': 67623.627440604,
#   'trade_volume_24h_btc_normalized': 67623.627440604},
#  {'id': 'bibox',
#   'name': 'Bibox',
#   'year_established': 2017,
#   'country': 'China',
#   'description': '',
#   'url': 'https://www.bibox.com/',
#   'image': 'https://assets.coingecko.com/markets/images/114/small/bibox.jpg?1520752603',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 85,
#   'trade_volume_24h_btc': 30678.846045142567,
#   'trade_volume_24h_btc_normalized': 30678.846045142567},
#  {'id': 'uniswap_v2',
#   'name': 'Uniswap (v2)',
#   'year_established': 2018,
#   'country': None,
#   'description': '',
#   'url': 'https://app.uniswap.org/#/swap?use=V2',
#   'image': 'https://assets.coingecko.com/markets/images/535/small/256x256_Black-1.png?1590893262',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 86,
#   'trade_volume_24h_btc': 19850.937034016948,
#   'trade_volume_24h_btc_normalized': 19850.937034016948},
#  {'id': 'pancakeswap',
#   'name': 'PancakeSwap (v2)',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://pancakeswap.finance',
#   'image': 'https://assets.coingecko.com/markets/images/657/small/pancakeswap.png?1619272176',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 87,
#   'trade_volume_24h_btc': 19610.499611519885,
#   'trade_volume_24h_btc_normalized': 19610.499611519885},
#  {'id': 'phemex',
#   'name': 'Phemex',
#   'year_established': 2019,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://phemex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/564/small/phemex_logo.jpg?1596681293',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 88,
#   'trade_volume_24h_btc': 14915.860961986731,
#   'trade_volume_24h_btc_normalized': 14915.860961986731},
#  {'id': 'flybit',
#   'name': 'Flybit',
#   'year_established': 2018,
#   'country': 'South Korea',
#   'description': '',
#   'url': 'https://flybit.com',
#   'image': 'https://assets.coingecko.com/markets/images/655/small/flybit_logo_%EA%B0%80%EB%A1%9C%ED%98%95.png?1619148627',
#   'has_trading_incentive': True,
#   'trust_score': 6,
#   'trust_score_rank': 89,
#   'trade_volume_24h_btc': 13710.60697657055,
#   'trade_volume_24h_btc_normalized': 13710.60697657055},
#  {'id': 'btc_alpha',
#   'name': 'BTC-Alpha',
#   'year_established': 2016,
#   'country': None,
#   'description': None,
#   'url': 'https://btc-alpha.com/exchange/',
#   'image': 'https://assets.coingecko.com/markets/images/155/small/btc_alpha.jpg?1526356352',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 90,
#   'trade_volume_24h_btc': 13205.117190316947,
#   'trade_volume_24h_btc_normalized': 13205.117190316947},
#  {'id': 'p2pb2b',
#   'name': 'P2PB2B',
#   'year_established': 2018,
#   'country': 'Estonia',
#   'description': "P2PB2B Exchange is not just a cryptocurrency exchange platform but also a trusted partner for crypto projects. Our Crypto Startup Partner initiative provides trading consulting and helps our clients develop their community, support liquidity, create growth strategies.\r\n\r\nP2PB2B runs token sales of the promising crypto assets, enabling users to easily invest in new currencies. There are also available services for users such as the earning deposit program, regular gamification events - airdrop, trading competitions, referral program games.\r\n\r\nThe platform is compliant with OWASP TOP 10 security requirements and is recognized as the world's 12th most Trust Core secure crypto exchanges according to CER rating.\r\n\r\nP2PB2B utilizes the high processing speed with the ability to handle up to 10,000 trades per second, scaling to 1,000,000 TCP connections. Our KYC identity verification process leverages AI-powered technology which speeds up the authentication process. 24/7 live support is an essential advantage for users.",
#   'url': 'https://p2pb2b.io',
#   'image': 'https://assets.coingecko.com/markets/images/251/small/p2pb2b.jpg?1536307348',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 91,
#   'trade_volume_24h_btc': 10912.087382331862,
#   'trade_volume_24h_btc_normalized': 10912.087382331862},
#  {'id': 'sushiswap',
#   'name': 'Sushiswap',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://app.sushi.com/swap',
#   'image': 'https://assets.coingecko.com/markets/images/576/small/2048x2048_Logo.png?1609208464',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 92,
#   'trade_volume_24h_btc': 10666.050232416928,
#   'trade_volume_24h_btc_normalized': 10666.050232416928},
#  {'id': 'exmarkets',
#   'name': 'ExMarkets',
#   'year_established': 2018,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://exmarkets.com',
#   'image': 'https://assets.coingecko.com/markets/images/363/small/42200149_2115011248752220_3911078373144657920_n.jpg?1551247813',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 93,
#   'trade_volume_24h_btc': 7708.665012858611,
#   'trade_volume_24h_btc_normalized': 7708.665012858611},
#  {'id': 'wazirx',
#   'name': 'WazirX',
#   'year_established': 2018,
#   'country': 'India',
#   'description': '',
#   'url': 'https://wazirx.com/',
#   'image': 'https://assets.coingecko.com/markets/images/274/small/wazirx.jpg?1540450020',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 94,
#   'trade_volume_24h_btc': 6358.943291638811,
#   'trade_volume_24h_btc_normalized': 6358.943291638811},
#  {'id': 'quoine',
#   'name': 'Liquid',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://liquid.com',
#   'image': 'https://assets.coingecko.com/markets/images/40/small/liquid.png?1536133472',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 95,
#   'trade_volume_24h_btc': 5470.851540231065,
#   'trade_volume_24h_btc_normalized': 5470.851540231065},
#  {'id': 'pancakeswap_v1',
#   'name': 'PancakeSwap (v1)',
#   'year_established': 2020,
#   'country': None,
#   'description': '',
#   'url': 'https://v1exchange.pancakeswap.finance',
#   'image': 'https://assets.coingecko.com/markets/images/595/small/pancakeswap.png?1618240659',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 96,
#   'trade_volume_24h_btc': 5115.80734475675,
#   'trade_volume_24h_btc_normalized': 5115.80734475675},
#  {'id': 'exmo',
#   'name': 'EXMO',
#   'year_established': 2013,
#   'country': 'United Kingdom',
#   'description': '',
#   'url': 'https://exmo.com/',
#   'image': 'https://assets.coingecko.com/markets/images/59/small/exmo.png?1584091923',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 97,
#   'trade_volume_24h_btc': 3084.1356860291967,
#   'trade_volume_24h_btc_normalized': 3084.1356860291967},
#  {'id': 'emirex',
#   'name': 'Emirex',
#   'year_established': 2019,
#   'country': 'Estonia',
#   'description': 'Launched on 10/09/2019, Emirex is a centralized exchange located at 405, Al Saaha Offices C, Dubai, UAE. It supports USD, EUR, AED fiat pairs/OTC/IEOs',
#   'url': 'https://www.emirex.com/',
#   'image': 'https://assets.coingecko.com/markets/images/592/small/Emirex.png?1602067691',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 98,
#   'trade_volume_24h_btc': 2601.319634770163,
#   'trade_volume_24h_btc_normalized': 2601.319634770163},
#  {'id': 'bancor',
#   'name': 'Bancor Network',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://www.bancor.network/discover',
#   'image': 'https://assets.coingecko.com/markets/images/108/small/Bancor.jpg?1520913420',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 99,
#   'trade_volume_24h_btc': 2117.9110648315136,
#   'trade_volume_24h_btc_normalized': 2117.9110648315136},
#  {'id': 'bitbay',
#   'name': 'BitBay',
#   'year_established': 2014,
#   'country': 'Malta',
#   'description': '',
#   'url': 'https://bitbay.net/en',
#   'image': 'https://assets.coingecko.com/markets/images/2/small/BitBay-exchange.jpg?1537765063',
#   'has_trading_incentive': False,
#   'trust_score': 6,
#   'trust_score_rank': 100,
#   'trade_volume_24h_btc': 1931.5448388937734,
#   'trade_volume_24h_btc_normalized': 1931.5448388937734}]

# %%
data_id = cg.get_exchanges_list()

columns = ['id', 'name', 'year_established', 'country', 'description', 'url', 'has_trading_incentive', 
           'trust_score', 'trust_score_rank', 'trade_volume_24h_btc', 'trade_volume_24h_btc_normalized']
df_id = pd.DataFrame(data_id, columns=columns)
df_id['updated_date'] = datetime.today()
df_id.set_index('id', inplace=True)
df_id.sort_values('trust_score', ascending=False).head(10)
# Out:
#                     name  year_established                 country  \
# id
# binance          Binance            2017.0          Cayman Islands
# kraken            Kraken            2011.0           United States
# bitfinex        Bitfinex            2014.0  British Virgin Islands
# binance_us    Binance US            2019.0           United States
# crypto_com    Crypto.com            2019.0          Cayman Islands
# gdax        Coinbase Pro            2012.0           United States
# bittrex          Bittrex            2014.0           United States
# nice_hash       NiceHash               NaN                Slovenia
# cex               CEX.IO            2013.0          United Kingdom
# gemini            Gemini            2014.0           United States
#
#                                                   description  \
# id
# binance
# kraken
# bitfinex
# binance_us
# crypto_com  Crypto.com Exchange is the best place to trade...
# gdax
# bittrex
# nice_hash
# cex
# gemini
#
#                                     url has_trading_incentive  trust_score  \
# id
# binance        https://www.binance.com/                 False           10
# kraken       https://r.kraken.com/Q1m9x                 False           10
# bitfinex       https://www.bitfinex.com                 False           10
# binance_us    https://www.binance.us/en                 False           10
# crypto_com  https://crypto.com/exchange                 False           10
# gdax           https://www.coinbase.com                 False           10
# bittrex            https://bittrex.com/                 False            9
# nice_hash      https://www.nicehash.com                 False            9
# cex                     https://cex.io/                 False            9
# gemini      https://gemini.sjv.io/bZ49k                 False            9
#
#             trust_score_rank  trade_volume_24h_btc  \
# id
# binance                    1          1.297236e+06
# kraken                     3          6.864458e+04
# bitfinex                   4          4.297568e+04
# binance_us                 5          4.109532e+04
# crypto_com                 6          8.825898e+03
# gdax                       2          1.725085e+05
# bittrex                   13          1.244948e+04
# nice_hash                 18          5.998446e+01
# cex                       16          1.974928e+03
# gemini                    15          5.752762e+03
#
#             trade_volume_24h_btc_normalized               updated_date
# id
# binance                        1.297236e+06 2021-05-07 00:15:15.825043
# kraken                         6.864458e+04 2021-05-07 00:15:15.825043
# bitfinex                       4.297568e+04 2021-05-07 00:15:15.825043
# binance_us                     4.109532e+04 2021-05-07 00:15:15.825043
# crypto_com                     8.825898e+03 2021-05-07 00:15:15.825043
# gdax                           1.725085e+05 2021-05-07 00:15:15.825043
# bittrex                        1.244948e+04 2021-05-07 00:15:15.825043
# nice_hash                      5.998446e+01 2021-05-07 00:15:15.825043
# cex                            1.974928e+03 2021-05-07 00:15:15.825043
# gemini                         5.752762e+03 2021-05-07 00:15:15.825043

# %% [markdown]
# ### Top 100 Tickers

# %%
data_binance=cg.get_exchanges_by_id('binance')
df_binance =pd.DataFrame(data_binance['tickers'], columns=['base','target','volume'])
df_binance.head()
#df_binance.tail()
# Out:
#    base target        volume
# 0  BUSD   USDT  2.070766e+09
# 1   BTC   USDT  7.360370e+04
# 2  DOGE   USDT  9.530235e+09
# 3  BETH    ETH  6.812300e+03
# 4   ETH   USDT  9.873696e+05

# %%
data_coinbase_pro=cg.get_exchanges_tickers_by_id(id='gdax')

# %%
data_coinbase_pro
# Out:
# {'name': 'Coinbase Pro',
#  'tickers': [{'base': 'BTC',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 56175.77,
#    'volume': 18735.93740556,
#    'converted_last': {'btc': 1.000367, 'eth': 16.189715, 'usd': 56176},
#    'converted_volume': {'btc': 18743, 'eth': 303329, 'usd': 1052505710},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010018,
#    'timestamp': '2021-05-07T07:23:29+00:00',
#    'last_traded_at': '2021-05-07T07:23:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BTC-USD',
#    'token_info_url': None,
#    'coin_id': 'bitcoin'},
#   {'base': 'ETH',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3468.7,
#    'volume': 377260.95105798,
#    'converted_last': {'btc': 0.06177807, 'eth': 0.99948752, 'usd': 3468.7},
#    'converted_volume': {'btc': 23306, 'eth': 377068, 'usd': 1308605061},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.017298,
#    'timestamp': '2021-05-07T07:24:13+00:00',
#    'last_traded_at': '2021-05-07T07:24:13+00:00',
#    'last_fetch_at': '2021-05-07T07:24:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-USD',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'LTC',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 370.22,
#    'volume': 991888.11803478,
#    'converted_last': {'btc': 0.00659359, 'eth': 0.10667558, 'usd': 370.22},
#    'converted_volume': {'btc': 6540, 'eth': 105810, 'usd': 367216819},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.035122,
#    'timestamp': '2021-05-07T07:25:04+00:00',
#    'last_traded_at': '2021-05-07T07:25:04+00:00',
#    'last_fetch_at': '2021-05-07T07:25:04+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LTC-USD',
#    'token_info_url': None,
#    'coin_id': 'litecoin'},
#   {'base': 'BCH',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1402.1,
#    'volume': 264672.59904146,
#    'converted_last': {'btc': 0.02496833, 'eth': 0.40408167, 'usd': 1402.1},
#    'converted_volume': {'btc': 6608, 'eth': 106949, 'usd': 371097451},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.049939,
#    'timestamp': '2021-05-07T07:23:14+00:00',
#    'last_traded_at': '2021-05-07T07:23:14+00:00',
#    'last_fetch_at': '2021-05-07T07:24:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BCH-USD',
#    'token_info_url': None,
#    'coin_id': 'bitcoin-cash'},
#   {'base': 'ADA',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.6476,
#    'volume': 234776101.05,
#    'converted_last': {'btc': 2.934e-05, 'eth': 0.00047475, 'usd': 1.65},
#    'converted_volume': {'btc': 6889, 'eth': 111459, 'usd': 386817104},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.036401,
#    'timestamp': '2021-05-07T07:24:51+00:00',
#    'last_traded_at': '2021-05-07T07:24:51+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ADA-USD',
#    'token_info_url': None,
#    'coin_id': 'cardano'},
#   {'base': 'EOS',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 11.819,
#    'volume': 34642184.2,
#    'converted_last': {'btc': 0.00021047, 'eth': 0.00340621, 'usd': 11.82},
#    'converted_volume': {'btc': 7291, 'eth': 117998, 'usd': 409435975},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.059252,
#    'timestamp': '2021-05-07T07:23:28+00:00',
#    'last_traded_at': '2021-05-07T07:23:28+00:00',
#    'last_fetch_at': '2021-05-07T07:24:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/EOS-USD',
#    'token_info_url': None,
#    'coin_id': 'eos'},
#   {'base': 'ETH',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2877.59,
#    'volume': 32450.10534026,
#    'converted_last': {'btc': 0.06189584, 'eth': 1.001708, 'usd': 3475.77},
#    'converted_volume': {'btc': 2009, 'eth': 32506, 'usd': 112789103},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010348,
#    'timestamp': '2021-05-07T07:23:29+00:00',
#    'last_traded_at': '2021-05-07T07:23:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:36+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-EUR',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'ETH',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.06173,
#    'volume': 40834.66538123,
#    'converted_last': {'btc': 0.06173, 'eth': 0.9990242, 'usd': 3466.46},
#    'converted_volume': {'btc': 2521, 'eth': 40795, 'usd': 141551621},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.0162,
#    'timestamp': '2021-05-07T07:23:26+00:00',
#    'last_traded_at': '2021-05-07T07:23:26+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-BTC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'XLM',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.645384,
#    'volume': 441128872.0,
#    'converted_last': {'btc': 1.149e-05, 'eth': 0.000186, 'usd': 0.645384},
#    'converted_volume': {'btc': 5070, 'eth': 82049, 'usd': 284697516},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.031598,
#    'timestamp': '2021-05-07T07:23:16+00:00',
#    'last_traded_at': '2021-05-07T07:23:16+00:00',
#    'last_fetch_at': '2021-05-07T07:24:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/XLM-USD',
#    'token_info_url': None,
#    'coin_id': 'stellar'},
#   {'base': 'LINK',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 47.34566,
#    'volume': 4376359.25,
#    'converted_last': {'btc': 0.00084312, 'eth': 0.0136449, 'usd': 47.35},
#    'converted_volume': {'btc': 3690, 'eth': 59715, 'usd': 207201617},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.034092,
#    'timestamp': '2021-05-07T07:23:28+00:00',
#    'last_traded_at': '2021-05-07T07:23:28+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LINK-USD',
#    'token_info_url': None,
#    'coin_id': 'chainlink'},
#   {'base': 'BTC',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 46594.48,
#    'volume': 1745.29962988,
#    'converted_last': {'btc': 1.002361, 'eth': 16.216877, 'usd': 56280},
#    'converted_volume': {'btc': 1749, 'eth': 28303, 'usd': 98226028},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.030261,
#    'timestamp': '2021-05-07T07:24:58+00:00',
#    'last_traded_at': '2021-05-07T07:24:58+00:00',
#    'last_fetch_at': '2021-05-07T07:24:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BTC-EUR',
#    'token_info_url': None,
#    'coin_id': 'bitcoin'},
#   {'base': 'BTC',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 56170.83,
#    'volume': 1118.92609,
#    'converted_last': {'btc': 1.000094, 'eth': 16.185293, 'usd': 56160},
#    'converted_volume': {'btc': 1119, 'eth': 18110, 'usd': 62839366},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.023849,
#    'timestamp': '2021-05-07T07:23:15+00:00',
#    'last_traded_at': '2021-05-07T07:23:15+00:00',
#    'last_fetch_at': '2021-05-07T07:24:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BTC-USDC',
#    'token_info_url': None,
#    'coin_id': 'bitcoin',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'WBTC',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.0015,
#    'volume': 45.68864232,
#    'converted_last': {'btc': 1.0015, 'eth': 16.322976, 'usd': 56133},
#    'converted_volume': {'btc': 45.757175, 'eth': 745.775, 'usd': 2564662},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.019985,
#    'timestamp': '2021-05-07T07:11:29+00:00',
#    'last_traded_at': '2021-05-07T07:11:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:53+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/WBTC-BTC',
#    'token_info_url': None,
#    'coin_id': 'wrapped-bitcoin',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'DAI',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.000939,
#    'volume': 36438556.66936,
#    'converted_last': {'btc': 1.783e-05, 'eth': 0.00028841, 'usd': 1.0},
#    'converted_volume': {'btc': 649.577, 'eth': 10509, 'usd': 36472772},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.0101,
#    'timestamp': '2021-05-07T07:25:04+00:00',
#    'last_traded_at': '2021-05-07T07:25:04+00:00',
#    'last_fetch_at': '2021-05-07T07:25:04+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/DAI-USD',
#    'token_info_url': None,
#    'coin_id': 'dai'},
#   {'base': 'BTC',
#    'target': 'USDT',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 56103.43,
#    'volume': 432.08209109,
#    'converted_last': {'btc': 0.99962013, 'eth': 16.177623, 'usd': 56134},
#    'converted_volume': {'btc': 431.918, 'eth': 6990, 'usd': 24254416},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.05822,
#    'timestamp': '2021-05-07T07:23:33+00:00',
#    'last_traded_at': '2021-05-07T07:23:33+00:00',
#    'last_fetch_at': '2021-05-07T07:24:55+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BTC-USDT',
#    'token_info_url': None,
#    'coin_id': 'bitcoin',
#    'target_coin_id': 'tether'},
#   {'base': 'ETH',
#    'target': 'GBP',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2496.24,
#    'volume': 17369.43968219,
#    'converted_last': {'btc': 0.06189204, 'eth': 1.001331, 'usd': 3475.1},
#    'converted_volume': {'btc': 1075, 'eth': 17393, 'usd': 60360521},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014422,
#    'timestamp': '2021-05-07T07:24:58+00:00',
#    'last_traded_at': '2021-05-07T07:24:58+00:00',
#    'last_fetch_at': '2021-05-07T07:24:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-GBP',
#    'token_info_url': None,
#    'coin_id': 'ethereum'},
#   {'base': 'OMG',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 13.2659,
#    'volume': 11602542.4,
#    'converted_last': {'btc': 0.00023624, 'eth': 0.0038232, 'usd': 13.27},
#    'converted_volume': {'btc': 2741, 'eth': 44359, 'usd': 153918167},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.058063,
#    'timestamp': '2021-05-07T07:23:31+00:00',
#    'last_traded_at': '2021-05-07T07:23:31+00:00',
#    'last_fetch_at': '2021-05-07T07:24:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/OMG-USD',
#    'token_info_url': None,
#    'coin_id': 'omisego'},
#   {'base': 'ETH',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3467.28,
#    'volume': 19422.81926264,
#    'converted_last': {'btc': 0.06173322, 'eth': 0.99907623, 'usd': 3466.64},
#    'converted_volume': {'btc': 1199, 'eth': 19405, 'usd': 67331879},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.046117,
#    'timestamp': '2021-05-07T07:23:28+00:00',
#    'last_traded_at': '2021-05-07T07:23:28+00:00',
#    'last_fetch_at': '2021-05-07T07:24:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-USDC',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'ETH',
#    'target': 'USDT',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3465.5,
#    'volume': 8798.53374946,
#    'converted_last': {'btc': 0.06174638, 'eth': 0.99928925, 'usd': 3467.38},
#    'converted_volume': {'btc': 543.278, 'eth': 8792, 'usd': 30507833},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.036911,
#    'timestamp': '2021-05-07T07:23:16+00:00',
#    'last_traded_at': '2021-05-07T07:23:16+00:00',
#    'last_fetch_at': '2021-05-07T07:24:39+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-USDT',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'tether'},
#   {'base': 'GRT',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.6251,
#    'volume': 30821110.46,
#    'converted_last': {'btc': 2.894e-05, 'eth': 0.00046826, 'usd': 1.63},
#    'converted_volume': {'btc': 892.064, 'eth': 14432, 'usd': 50087387},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.049228,
#    'timestamp': '2021-05-07T07:24:08+00:00',
#    'last_traded_at': '2021-05-07T07:24:08+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/GRT-USD',
#    'token_info_url': None,
#    'coin_id': 'the-graph'},
#   {'base': 'BTC',
#    'target': 'GBP',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 40419.78,
#    'volume': 1008.51683648,
#    'converted_last': {'btc': 1.00204, 'eth': 16.216792, 'usd': 56270},
#    'converted_volume': {'btc': 1011, 'eth': 16355, 'usd': 56748963},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.029911,
#    'timestamp': '2021-05-07T07:23:30+00:00',
#    'last_traded_at': '2021-05-07T07:23:30+00:00',
#    'last_fetch_at': '2021-05-07T07:24:45+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BTC-GBP',
#    'token_info_url': None,
#    'coin_id': 'bitcoin'},
#   {'base': 'FIL',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 153.0075,
#    'volume': 206313.644,
#    'converted_last': {'btc': 0.00272473, 'eth': 0.04409637, 'usd': 153.01},
#    'converted_volume': {'btc': 562.149, 'eth': 9098, 'usd': 31567535},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.037515,
#    'timestamp': '2021-05-07T07:23:18+00:00',
#    'last_traded_at': '2021-05-07T07:23:18+00:00',
#    'last_fetch_at': '2021-05-07T07:24:45+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/FIL-USD',
#    'token_info_url': None,
#    'coin_id': 'filecoin'},
#   {'base': 'MATIC',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.7612,
#    'volume': 124970405.5,
#    'converted_last': {'btc': 1.356e-05, 'eth': 0.00021938, 'usd': 0.7612},
#    'converted_volume': {'btc': 1694, 'eth': 27415, 'usd': 95127473},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.052583,
#    'timestamp': '2021-05-07T07:23:24+00:00',
#    'last_traded_at': '2021-05-07T07:23:24+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MATIC-USD',
#    'token_info_url': None,
#    'coin_id': 'matic-network'},
#   {'base': 'UNI',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 40.2125,
#    'volume': 1559333.318847,
#    'converted_last': {'btc': 0.00071618, 'eth': 0.01158687, 'usd': 40.21},
#    'converted_volume': {'btc': 1117, 'eth': 18068, 'usd': 62704691},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.035053,
#    'timestamp': '2021-05-07T07:25:02+00:00',
#    'last_traded_at': '2021-05-07T07:25:02+00:00',
#    'last_fetch_at': '2021-05-07T07:25:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/UNI-USD',
#    'token_info_url': None,
#    'coin_id': 'uniswap'},
#   {'base': 'XTZ',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 7.8023,
#    'volume': 13265927.07,
#    'converted_last': {'btc': 0.00013896, 'eth': 0.00224819, 'usd': 7.8},
#    'converted_volume': {'btc': 1843, 'eth': 29824, 'usd': 103504743},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.062799,
#    'timestamp': '2021-05-07T07:24:59+00:00',
#    'last_traded_at': '2021-05-07T07:24:59+00:00',
#    'last_fetch_at': '2021-05-07T07:24:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/XTZ-USD',
#    'token_info_url': None,
#    'coin_id': 'tezos'},
#   {'base': 'ALGO',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.5552,
#    'volume': 43491448.0,
#    'converted_last': {'btc': 2.769e-05, 'eth': 0.0004482, 'usd': 1.56},
#    'converted_volume': {'btc': 1204, 'eth': 19493, 'usd': 67637900},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.03859,
#    'timestamp': '2021-05-07T07:23:20+00:00',
#    'last_traded_at': '2021-05-07T07:23:20+00:00',
#    'last_fetch_at': '2021-05-07T07:24:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ALGO-USD',
#    'token_info_url': None,
#    'coin_id': 'algorand'},
#   {'base': 'LTC',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.006592,
#    'volume': 157750.7551926,
#    'converted_last': {'btc': 0.006592, 'eth': 0.10664984, 'usd': 370.13},
#    'converted_volume': {'btc': 1040, 'eth': 16824, 'usd': 58387653},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.015156,
#    'timestamp': '2021-05-07T07:25:00+00:00',
#    'last_traded_at': '2021-05-07T07:25:00+00:00',
#    'last_fetch_at': '2021-05-07T07:25:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LTC-BTC',
#    'token_info_url': None,
#    'coin_id': 'litecoin',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ATOM',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 25.525,
#    'volume': 2685241.8,
#    'converted_last': {'btc': 0.0004546, 'eth': 0.00735489, 'usd': 25.53},
#    'converted_volume': {'btc': 1221, 'eth': 19750, 'usd': 68540797},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.070494,
#    'timestamp': '2021-05-07T07:24:26+00:00',
#    'last_traded_at': '2021-05-07T07:24:26+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ATOM-USD',
#    'token_info_url': None,
#    'coin_id': 'cosmos'},
#   {'base': 'FIL',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.00272531,
#    'volume': 41256.587,
#    'converted_last': {'btc': 0.00272531, 'eth': 0.04410579, 'usd': 153.04},
#    'converted_volume': {'btc': 112.437, 'eth': 1820, 'usd': 6313916},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.068256,
#    'timestamp': '2021-05-07T07:23:29+00:00',
#    'last_traded_at': '2021-05-07T07:23:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/FIL-BTC',
#    'token_info_url': None,
#    'coin_id': 'filecoin',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'LTC',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 305.83,
#    'volume': 113410.91237176,
#    'converted_last': {'btc': 0.00657828, 'eth': 0.10646145, 'usd': 369.4},
#    'converted_volume': {'btc': 746.049, 'eth': 12074, 'usd': 41894503},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.075178,
#    'timestamp': '2021-05-07T07:23:15+00:00',
#    'last_traded_at': '2021-05-07T07:23:15+00:00',
#    'last_fetch_at': '2021-05-07T07:24:44+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LTC-EUR',
#    'token_info_url': None,
#    'coin_id': 'litecoin'},
#   {'base': 'SUSHI',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 16.706,
#    'volume': 4021291.94,
#    'converted_last': {'btc': 0.0002975, 'eth': 0.00481463, 'usd': 16.71},
#    'converted_volume': {'btc': 1196, 'eth': 19361, 'usd': 67179703},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.047867,
#    'timestamp': '2021-05-07T07:23:29+00:00',
#    'last_traded_at': '2021-05-07T07:23:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/SUSHI-USD',
#    'token_info_url': None,
#    'coin_id': 'sushi'},
#   {'base': 'USDT',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.0,
#    'volume': 2031236.89,
#    'converted_last': {'btc': 1.78e-05, 'eth': 0.00028805, 'usd': 0.999696},
#    'converted_volume': {'btc': 36.165174, 'eth': 585.105, 'usd': 2030619},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.059958,
#    'timestamp': '2021-05-07T07:25:01+00:00',
#    'last_traded_at': '2021-05-07T07:25:01+00:00',
#    'last_fetch_at': '2021-05-07T07:25:01+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/USDT-USDC',
#    'token_info_url': None,
#    'coin_id': 'tether',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'BCH',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.02492,
#    'volume': 50078.95752834,
#    'converted_last': {'btc': 0.02492, 'eth': 0.40329958, 'usd': 1399.39},
#    'converted_volume': {'btc': 1248, 'eth': 20197, 'usd': 70079805},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.08016,
#    'timestamp': '2021-05-07T07:23:30+00:00',
#    'last_traded_at': '2021-05-07T07:23:30+00:00',
#    'last_fetch_at': '2021-05-07T07:24:56+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BCH-BTC',
#    'token_info_url': None,
#    'coin_id': 'bitcoin-cash',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'AAVE',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 447.482,
#    'volume': 68859.497,
#    'converted_last': {'btc': 0.00796962, 'eth': 0.12893793, 'usd': 447.48},
#    'converted_volume': {'btc': 548.784, 'eth': 8879, 'usd': 30813385},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.055174,
#    'timestamp': '2021-05-07T07:25:01+00:00',
#    'last_traded_at': '2021-05-07T07:25:01+00:00',
#    'last_fetch_at': '2021-05-07T07:25:01+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/AAVE-USD',
#    'token_info_url': None,
#    'coin_id': 'aave'},
#   {'base': 'ZRX',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2.133262,
#    'volume': 24484411.65854,
#    'converted_last': {'btc': 3.799e-05, 'eth': 0.00061469, 'usd': 2.13},
#    'converted_volume': {'btc': 930.254, 'eth': 15050, 'usd': 52231665},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.055434,
#    'timestamp': '2021-05-07T07:25:00+00:00',
#    'last_traded_at': '2021-05-07T07:25:00+00:00',
#    'last_fetch_at': '2021-05-07T07:25:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ZRX-USD',
#    'token_info_url': None,
#    'coin_id': '0x'},
#   {'base': 'ANKR',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.161,
#    'volume': 304886993.0,
#    'converted_last': {'btc': 2.87e-06, 'eth': 4.639e-05, 'usd': 0.161},
#    'converted_volume': {'btc': 874.243, 'eth': 14144, 'usd': 49086806},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.016211,
#    'timestamp': '2021-05-07T07:24:10+00:00',
#    'last_traded_at': '2021-05-07T07:24:10+00:00',
#    'last_fetch_at': '2021-05-07T07:25:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ANKR-USD',
#    'token_info_url': None,
#    'coin_id': 'ankr'},
#   {'base': 'DAI',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.000834,
#    'volume': 700953.70005,
#    'converted_last': {'btc': 1.785e-05, 'eth': 0.00028895, 'usd': 1.0},
#    'converted_volume': {'btc': 12.513363, 'eth': 202.537, 'usd': 703323},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.0101,
#    'timestamp': '2021-05-07T07:21:29+00:00',
#    'last_traded_at': '2021-05-07T07:21:29+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/DAI-USDC',
#    'token_info_url': None,
#    'coin_id': 'dai',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'MKR',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 5055.1729,
#    'volume': 8620.728528,
#    'converted_last': {'btc': 0.0900334, 'eth': 1.456621, 'usd': 5055.17},
#    'converted_volume': {'btc': 776.153, 'eth': 12557, 'usd': 43579273},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.114542,
#    'timestamp': '2021-05-07T07:24:06+00:00',
#    'last_traded_at': '2021-05-07T07:24:06+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MKR-USD',
#    'token_info_url': None,
#    'coin_id': 'maker'},
#   {'base': 'BCH',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1161.74,
#    'volume': 29851.28967948,
#    'converted_last': {'btc': 0.02498858, 'eth': 0.40440938, 'usd': 1403.24},
#    'converted_volume': {'btc': 745.941, 'eth': 12072, 'usd': 41888437},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.067142,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BCH-EUR',
#    'token_info_url': None,
#    'coin_id': 'bitcoin-cash'},
#   {'base': 'YFI',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 51874.13,
#    'volume': 994.035856,
#    'converted_last': {'btc': 0.92376448, 'eth': 14.949993, 'usd': 51874},
#    'converted_volume': {'btc': 918.255, 'eth': 14861, 'usd': 51564745},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.044042,
#    'timestamp': '2021-05-07T07:23:25+00:00',
#    'last_traded_at': '2021-05-07T07:23:25+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/YFI-USD',
#    'token_info_url': None,
#    'coin_id': 'yearn-finance'},
#   {'base': 'COMP',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 726.1,
#    'volume': 32219.1,
#    'converted_last': {'btc': 0.01293195, 'eth': 0.20922187, 'usd': 726.1},
#    'converted_volume': {'btc': 416.656, 'eth': 6741, 'usd': 23394289},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.057811,
#    'timestamp': '2021-05-07T07:24:55+00:00',
#    'last_traded_at': '2021-05-07T07:24:55+00:00',
#    'last_fetch_at': '2021-05-07T07:24:55+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/COMP-USD',
#    'token_info_url': None,
#    'coin_id': 'compound-governance-token'},
#   {'base': 'DASH',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 451.007,
#    'volume': 116147.82192881,
#    'converted_last': {'btc': 0.00803145, 'eth': 0.12997908, 'usd': 451.01},
#    'converted_volume': {'btc': 932.835, 'eth': 15097, 'usd': 52383481},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.143502,
#    'timestamp': '2021-05-07T07:23:15+00:00',
#    'last_traded_at': '2021-05-07T07:23:15+00:00',
#    'last_fetch_at': '2021-05-07T07:24:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/DASH-USD',
#    'token_info_url': None,
#    'coin_id': 'dash'},
#   {'base': 'ETH',
#    'target': 'DAI',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3464.45,
#    'volume': 1622.78878036,
#    'converted_last': {'btc': 0.06173427, 'eth': 0.99909334, 'usd': 3466.7},
#    'converted_volume': {'btc': 100.182, 'eth': 1621, 'usd': 5625717},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.157218,
#    'timestamp': '2021-05-07T07:23:23+00:00',
#    'last_traded_at': '2021-05-07T07:23:23+00:00',
#    'last_fetch_at': '2021-05-07T07:24:53+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ETH-DAI',
#    'token_info_url': None,
#    'coin_id': 'ethereum',
#    'target_coin_id': 'dai'},
#   {'base': 'ZEC',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 311.43,
#    'volume': 97412.48738744,
#    'converted_last': {'btc': 0.00554662, 'eth': 0.0897369, 'usd': 311.43},
#    'converted_volume': {'btc': 540.31, 'eth': 8741, 'usd': 30337171},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.125213,
#    'timestamp': '2021-05-07T07:24:16+00:00',
#    'last_traded_at': '2021-05-07T07:24:16+00:00',
#    'last_fetch_at': '2021-05-07T07:24:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ZEC-USD',
#    'token_info_url': None,
#    'coin_id': 'zcash'},
#   {'base': '1INCH',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 6.657,
#    'volume': 6510500.17,
#    'converted_last': {'btc': 0.00011856, 'eth': 0.00191818, 'usd': 6.66},
#    'converted_volume': {'btc': 771.899, 'eth': 12488, 'usd': 43340400},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.17991,
#    'timestamp': '2021-05-07T07:24:59+00:00',
#    'last_traded_at': '2021-05-07T07:24:59+00:00',
#    'last_fetch_at': '2021-05-07T07:24:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/1INCH-USD',
#    'token_info_url': None,
#    'coin_id': '1inch'},
#   {'base': 'MANA',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.501553,
#    'volume': 10712418.0,
#    'converted_last': {'btc': 2.673e-05, 'eth': 0.00043266, 'usd': 1.5},
#    'converted_volume': {'btc': 286.39, 'eth': 4635, 'usd': 16082284},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.013398,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:39+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MANA-USDC',
#    'token_info_url': None,
#    'coin_id': 'decentraland',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'USDC',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.829,
#    'volume': 39000373.11,
#    'converted_last': {'btc': 1.783e-05, 'eth': 0.00028853, 'usd': 1.0},
#    'converted_volume': {'btc': 695.525, 'eth': 11253, 'usd': 39052191},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.120482,
#    'timestamp': '2021-05-07T07:24:19+00:00',
#    'last_traded_at': '2021-05-07T07:24:19+00:00',
#    'last_fetch_at': '2021-05-07T07:24:43+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/USDC-EUR',
#    'token_info_url': None,
#    'coin_id': 'usd-coin'},
#   {'base': 'BAND',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 18.2555,
#    'volume': 1279939.49,
#    'converted_last': {'btc': 0.00032513, 'eth': 0.00526023, 'usd': 18.26},
#    'converted_volume': {'btc': 416.151, 'eth': 6733, 'usd': 23365935},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.014233,
#    'timestamp': '2021-05-07T07:24:57+00:00',
#    'last_traded_at': '2021-05-07T07:24:57+00:00',
#    'last_fetch_at': '2021-05-07T07:24:57+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BAND-USD',
#    'token_info_url': None,
#    'coin_id': 'band-protocol'},
#   {'base': 'LINK',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 39.28758,
#    'volume': 270214.17,
#    'converted_last': {'btc': 0.00084517, 'eth': 0.01367376, 'usd': 47.45},
#    'converted_volume': {'btc': 228.377, 'eth': 3695, 'usd': 12822878},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.126765,
#    'timestamp': '2021-05-07T07:24:59+00:00',
#    'last_traded_at': '2021-05-07T07:24:59+00:00',
#    'last_fetch_at': '2021-05-07T07:24:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LINK-EUR',
#    'token_info_url': None,
#    'coin_id': 'chainlink'},
#   {'base': 'MANA',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.503,
#    'volume': 20434373.24,
#    'converted_last': {'btc': 2.677e-05, 'eth': 0.00043316, 'usd': 1.5},
#    'converted_volume': {'btc': 546.929, 'eth': 8851, 'usd': 30712863},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.199468,
#    'timestamp': '2021-05-07T07:23:12+00:00',
#    'last_traded_at': '2021-05-07T07:23:12+00:00',
#    'last_fetch_at': '2021-05-07T07:24:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MANA-USD',
#    'token_info_url': None,
#    'coin_id': 'decentraland'},
#   {'base': 'SNX',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 18.4601,
#    'volume': 1408146.527,
#    'converted_last': {'btc': 0.00032873, 'eth': 0.00532015, 'usd': 18.46},
#    'converted_volume': {'btc': 462.905, 'eth': 7492, 'usd': 25994526},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.040637,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:57+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/SNX-USD',
#    'token_info_url': None,
#    'coin_id': 'havven'},
#   {'base': 'ADA',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.3685,
#    'volume': 23509983.46,
#    'converted_last': {'btc': 2.944e-05, 'eth': 0.0004763, 'usd': 1.65},
#    'converted_volume': {'btc': 692.129, 'eth': 11198, 'usd': 38861472},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.16076,
#    'timestamp': '2021-05-07T07:24:25+00:00',
#    'last_traded_at': '2021-05-07T07:24:25+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ADA-EUR',
#    'token_info_url': None,
#    'coin_id': 'cardano'},
#   {'base': 'BAT',
#    'target': 'USDC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.526193,
#    'volume': 10776259.0,
#    'converted_last': {'btc': 2.717e-05, 'eth': 0.00043963, 'usd': 1.53},
#    'converted_volume': {'btc': 292.825, 'eth': 4738, 'usd': 16441439},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.129252,
#    'timestamp': '2021-05-07T07:24:12+00:00',
#    'last_traded_at': '2021-05-07T07:24:12+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BAT-USDC',
#    'token_info_url': None,
#    'coin_id': 'basic-attention-token',
#    'target_coin_id': 'usd-coin'},
#   {'base': 'ADA',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2.934e-05,
#    'volume': 22174641.36,
#    'converted_last': {'btc': 2.934e-05, 'eth': 0.00047483, 'usd': 1.65},
#    'converted_volume': {'btc': 650.604, 'eth': 10529, 'usd': 36534762},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.102145,
#    'timestamp': '2021-05-07T07:23:33+00:00',
#    'last_traded_at': '2021-05-07T07:23:33+00:00',
#    'last_fetch_at': '2021-05-07T07:24:39+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ADA-BTC',
#    'token_info_url': None,
#    'coin_id': 'cardano',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'MATIC',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.356e-05,
#    'volume': 11023107.3,
#    'converted_last': {'btc': 1.356e-05, 'eth': 0.00021938, 'usd': 0.761373},
#    'converted_volume': {'btc': 149.473, 'eth': 2418, 'usd': 8392698},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.073692,
#    'timestamp': '2021-05-07T07:25:03+00:00',
#    'last_traded_at': '2021-05-07T07:25:03+00:00',
#    'last_fetch_at': '2021-05-07T07:25:03+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MATIC-BTC',
#    'token_info_url': None,
#    'coin_id': 'matic-network',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'BAT',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.522,
#    'volume': 13228558.31,
#    'converted_last': {'btc': 2.71e-05, 'eth': 0.00043864, 'usd': 1.52},
#    'converted_volume': {'btc': 358.54, 'eth': 5803, 'usd': 20133866},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.196592,
#    'timestamp': '2021-05-07T07:23:31+00:00',
#    'last_traded_at': '2021-05-07T07:23:31+00:00',
#    'last_fetch_at': '2021-05-07T07:24:39+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BAT-USD',
#    'token_info_url': None,
#    'coin_id': 'basic-attention-token'},
#   {'base': 'LTC',
#    'target': 'GBP',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 264.85,
#    'volume': 42150.48985023,
#    'converted_last': {'btc': 0.00656585, 'eth': 0.10626028, 'usd': 368.71},
#    'converted_volume': {'btc': 276.754, 'eth': 4479, 'usd': 15541160},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.022654,
#    'timestamp': '2021-05-07T07:23:24+00:00',
#    'last_traded_at': '2021-05-07T07:23:24+00:00',
#    'last_fetch_at': '2021-05-07T07:24:51+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LTC-GBP',
#    'token_info_url': None,
#    'coin_id': 'litecoin'},
#   {'base': 'SKL',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.617,
#    'volume': 41741824.3,
#    'converted_last': {'btc': 1.099e-05, 'eth': 0.00017782, 'usd': 0.617},
#    'converted_volume': {'btc': 458.635, 'eth': 7422, 'usd': 25754706},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.080985,
#    'timestamp': '2021-05-07T07:23:23+00:00',
#    'last_traded_at': '2021-05-07T07:23:23+00:00',
#    'last_fetch_at': '2021-05-07T07:24:44+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/SKL-USD',
#    'token_info_url': None,
#    'coin_id': 'skale'},
#   {'base': 'KNC',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3.5674,
#    'volume': 3454837.4,
#    'converted_last': {'btc': 6.353e-05, 'eth': 0.00102812, 'usd': 3.57},
#    'converted_volume': {'btc': 219.477, 'eth': 3552, 'usd': 12324787},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.042058,
#    'timestamp': '2021-05-07T07:23:22+00:00',
#    'last_traded_at': '2021-05-07T07:23:22+00:00',
#    'last_fetch_at': '2021-05-07T07:24:46+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/KNC-USD',
#    'token_info_url': None,
#    'coin_id': 'kyber-network'},
#   {'base': 'REN',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.9757,
#    'volume': 15765324.80808,
#    'converted_last': {'btc': 1.738e-05, 'eth': 0.00028119, 'usd': 0.9757},
#    'converted_volume': {'btc': 273.924, 'eth': 4433, 'usd': 15382227},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010257,
#    'timestamp': '2021-05-07T07:23:31+00:00',
#    'last_traded_at': '2021-05-07T07:23:31+00:00',
#    'last_fetch_at': '2021-05-07T07:24:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/REN-USD',
#    'token_info_url': None,
#    'coin_id': 'republic-protocol'},
#   {'base': 'EOS',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 9.805,
#    'volume': 3802932.6,
#    'converted_last': {'btc': 0.0002109, 'eth': 0.00341319, 'usd': 11.84},
#    'converted_volume': {'btc': 802.045, 'eth': 12980, 'usd': 45038959},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.193779,
#    'timestamp': '2021-05-07T07:23:31+00:00',
#    'last_traded_at': '2021-05-07T07:23:31+00:00',
#    'last_fetch_at': '2021-05-07T07:24:45+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/EOS-EUR',
#    'token_info_url': None,
#    'coin_id': 'eos'},
#   {'base': 'CRV',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 3.2436,
#    'volume': 4406562.59,
#    'converted_last': {'btc': 5.776e-05, 'eth': 0.0009348, 'usd': 3.24},
#    'converted_volume': {'btc': 254.529, 'eth': 4119, 'usd': 14293126},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.157039,
#    'timestamp': '2021-05-07T07:23:27+00:00',
#    'last_traded_at': '2021-05-07T07:23:27+00:00',
#    'last_fetch_at': '2021-05-07T07:24:41+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/CRV-USD',
#    'token_info_url': None,
#    'coin_id': 'curve-dao-token'},
#   {'base': 'XLM',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.534315,
#    'volume': 27624635.0,
#    'converted_last': {'btc': 1.149e-05, 'eth': 0.000186, 'usd': 0.645386},
#    'converted_volume': {'btc': 317.487, 'eth': 5138, 'usd': 17828550},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.117325,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:57+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/XLM-EUR',
#    'token_info_url': None,
#    'coin_id': 'stellar'},
#   {'base': 'GRT',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2.89e-05,
#    'volume': 4396577.12,
#    'converted_last': {'btc': 2.89e-05, 'eth': 0.00046756, 'usd': 1.62},
#    'converted_volume': {'btc': 127.061, 'eth': 2056, 'usd': 7134194},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.068942,
#    'timestamp': '2021-05-07T07:24:45+00:00',
#    'last_traded_at': '2021-05-07T07:24:45+00:00',
#    'last_fetch_at': '2021-05-07T07:24:45+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/GRT-BTC',
#    'token_info_url': None,
#    'coin_id': 'the-graph',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'STORJ',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.8808,
#    'volume': 8686700.56,
#    'converted_last': {'btc': 3.349e-05, 'eth': 0.00054204, 'usd': 1.88},
#    'converted_volume': {'btc': 290.943, 'eth': 4709, 'usd': 16337946},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.074397,
#    'timestamp': '2021-05-07T07:23:33+00:00',
#    'last_traded_at': '2021-05-07T07:23:33+00:00',
#    'last_fetch_at': '2021-05-07T07:25:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/STORJ-USD',
#    'token_info_url': None,
#    'coin_id': 'storj'},
#   {'base': 'LINK',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.00084324,
#    'volume': 332214.62,
#    'converted_last': {'btc': 0.00084324, 'eth': 0.01364251, 'usd': 47.35},
#    'converted_volume': {'btc': 280.137, 'eth': 4532, 'usd': 15729243},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.056901,
#    'timestamp': '2021-05-07T07:25:02+00:00',
#    'last_traded_at': '2021-05-07T07:25:02+00:00',
#    'last_fetch_at': '2021-05-07T07:25:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LINK-BTC',
#    'token_info_url': None,
#    'coin_id': 'chainlink',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ENJ',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2.474,
#    'volume': 3902462.67,
#    'converted_last': {'btc': 4.406e-05, 'eth': 0.00071287, 'usd': 2.47},
#    'converted_volume': {'btc': 171.952, 'eth': 2782, 'usd': 9654693},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.121261,
#    'timestamp': '2021-05-07T07:24:04+00:00',
#    'last_traded_at': '2021-05-07T07:24:04+00:00',
#    'last_fetch_at': '2021-05-07T07:24:37+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ENJ-USD',
#    'token_info_url': None,
#    'coin_id': 'enjincoin'},
#   {'base': 'UNI',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.0007157,
#    'volume': 168656.605244,
#    'converted_last': {'btc': 0.0007157, 'eth': 0.01157908, 'usd': 40.18},
# ...
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.1514,
#    'timestamp': '2021-05-07T07:24:10+00:00',
#    'last_traded_at': '2021-05-07T07:24:10+00:00',
#    'last_fetch_at': '2021-05-07T07:24:53+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ADA-GBP',
#    'token_info_url': None,
#    'coin_id': 'cardano'},
#   {'base': 'XLM',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.148e-05,
#    'volume': 34657251.0,
#    'converted_last': {'btc': 1.148e-05, 'eth': 0.00018579, 'usd': 0.644661},
#    'converted_volume': {'btc': 397.865, 'eth': 6439, 'usd': 22342181},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.087184,
#    'timestamp': '2021-05-07T07:23:23+00:00',
#    'last_traded_at': '2021-05-07T07:23:23+00:00',
#    'last_fetch_at': '2021-05-07T07:24:35+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/XLM-BTC',
#    'token_info_url': None,
#    'coin_id': 'stellar',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'LINK',
#    'target': 'GBP',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 34.03951,
#    'volume': 178061.82,
#    'converted_last': {'btc': 0.00084387, 'eth': 0.01365697, 'usd': 47.39},
#    'converted_volume': {'btc': 150.261, 'eth': 2432, 'usd': 8437911},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.152112,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LINK-GBP',
#    'token_info_url': None,
#    'coin_id': 'chainlink'},
#   {'base': 'FIL',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 126.9592,
#    'volume': 24072.566,
#    'converted_last': {'btc': 0.00273084, 'eth': 0.04419534, 'usd': 153.35},
#    'converted_volume': {'btc': 65.738, 'eth': 1064, 'usd': 3691549},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.053489,
#    'timestamp': '2021-05-07T07:23:28+00:00',
#    'last_traded_at': '2021-05-07T07:23:28+00:00',
#    'last_fetch_at': '2021-05-07T07:24:58+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/FIL-EUR',
#    'token_info_url': None,
#    'coin_id': 'filecoin'},
#   {'base': 'NU',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.4566,
#    'volume': 25930279.358012,
#    'converted_last': {'btc': 8.13e-06, 'eth': 0.00013157, 'usd': 0.4566},
#    'converted_volume': {'btc': 210.868, 'eth': 3412, 'usd': 11839766},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.021901,
#    'timestamp': '2021-05-07T07:24:52+00:00',
#    'last_traded_at': '2021-05-07T07:24:52+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/NU-USD',
#    'token_info_url': None,
#    'coin_id': 'nucypher'},
#   {'base': 'BNT',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 7.5337,
#    'volume': 1092939.50674,
#    'converted_last': {'btc': 0.00013416, 'eth': 0.00217119, 'usd': 7.53},
#    'converted_volume': {'btc': 146.627, 'eth': 2373, 'usd': 8233878},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.083644,
#    'timestamp': '2021-05-07T07:23:19+00:00',
#    'last_traded_at': '2021-05-07T07:23:19+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BNT-USD',
#    'token_info_url': None,
#    'coin_id': 'bancor'},
#   {'base': 'UMA',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 24.821,
#    'volume': 310880.526,
#    'converted_last': {'btc': 0.00044207, 'eth': 0.00715204, 'usd': 24.82},
#    'converted_volume': {'btc': 137.43, 'eth': 2223, 'usd': 7716366},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.144811,
#    'timestamp': '2021-05-07T07:24:59+00:00',
#    'last_traded_at': '2021-05-07T07:24:59+00:00',
#    'last_fetch_at': '2021-05-07T07:24:59+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/UMA-USD',
#    'token_info_url': None,
#    'coin_id': 'uma'},
#   {'base': 'BAL',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 65.3,
#    'volume': 88207.556,
#    'converted_last': {'btc': 0.00116285, 'eth': 0.01881929, 'usd': 65.3},
#    'converted_volume': {'btc': 102.572, 'eth': 1660, 'usd': 5759953},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.115,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:25:00+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/BAL-USD',
#    'token_info_url': None,
#    'coin_id': 'balancer'},
#   {'base': 'OMG',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 10.9839,
#    'volume': 1161472.4,
#    'converted_last': {'btc': 0.00023626, 'eth': 0.00382357, 'usd': 13.27},
#    'converted_volume': {'btc': 274.409, 'eth': 4441, 'usd': 15409466},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.237452,
#    'timestamp': '2021-05-07T07:23:26+00:00',
#    'last_traded_at': '2021-05-07T07:23:26+00:00',
#    'last_fetch_at': '2021-05-07T07:24:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/OMG-EUR',
#    'token_info_url': None,
#    'coin_id': 'omisego'},
#   {'base': 'GRT',
#    'target': 'GBP',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.169,
#    'volume': 2511564.63,
#    'converted_last': {'btc': 2.898e-05, 'eth': 0.00046893, 'usd': 1.63},
#    'converted_volume': {'btc': 72.796, 'eth': 1178, 'usd': 4087330},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.162699,
#    'timestamp': '2021-05-07T07:24:52+00:00',
#    'last_traded_at': '2021-05-07T07:24:52+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/GRT-GBP',
#    'token_info_url': None,
#    'coin_id': 'the-graph'},
#   {'base': 'AAVE',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.00797285,
#    'volume': 5724.92,
#    'converted_last': {'btc': 0.00797285, 'eth': 0.12904604, 'usd': 448.12},
#    'converted_volume': {'btc': 45.643928, 'eth': 738.778, 'usd': 2565452},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.091731,
#    'timestamp': '2021-05-07T07:21:08+00:00',
#    'last_traded_at': '2021-05-07T07:21:08+00:00',
#    'last_fetch_at': '2021-05-07T07:24:36+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/AAVE-BTC',
#    'token_info_url': None,
#    'coin_id': 'aave',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'MATIC',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.6324,
#    'volume': 9389687.1,
#    'converted_last': {'btc': 1.36e-05, 'eth': 0.0002201, 'usd': 0.76386},
#    'converted_volume': {'btc': 127.742, 'eth': 2067, 'usd': 7172410},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.110707,
#    'timestamp': '2021-05-07T07:24:54+00:00',
#    'last_traded_at': '2021-05-07T07:24:54+00:00',
#    'last_fetch_at': '2021-05-07T07:24:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/MATIC-EUR',
#    'token_info_url': None,
#    'coin_id': 'matic-network'},
#   {'base': 'CGLD',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 5.6013,
#    'volume': 3080466.36,
#    'converted_last': {'btc': 9.976e-05, 'eth': 0.00161396, 'usd': 5.6},
#    'converted_volume': {'btc': 307.303, 'eth': 4972, 'usd': 17254616},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.048176,
#    'timestamp': '2021-05-07T07:25:01+00:00',
#    'last_traded_at': '2021-05-07T07:25:01+00:00',
#    'last_fetch_at': '2021-05-07T07:25:01+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/CGLD-USD',
#    'token_info_url': None,
#    'coin_id': 'celo'},
#   {'base': 'GRT',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.3485,
#    'volume': 3580457.37,
#    'converted_last': {'btc': 2.901e-05, 'eth': 0.00046942, 'usd': 1.63},
#    'converted_volume': {'btc': 103.854, 'eth': 1681, 'usd': 5831920},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.126085,
#    'timestamp': '2021-05-07T07:23:32+00:00',
#    'last_traded_at': '2021-05-07T07:23:32+00:00',
#    'last_fetch_at': '2021-05-07T07:24:44+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/GRT-EUR',
#    'token_info_url': None,
#    'coin_id': 'the-graph'},
#   {'base': 'ALGO',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.2888,
#    'volume': 4210323.0,
#    'converted_last': {'btc': 2.773e-05, 'eth': 0.00044856, 'usd': 1.56},
#    'converted_volume': {'btc': 116.732, 'eth': 1889, 'usd': 6554251},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.170741,
#    'timestamp': '2021-05-07T07:24:21+00:00',
#    'last_traded_at': '2021-05-07T07:24:21+00:00',
#    'last_fetch_at': '2021-05-07T07:24:42+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ALGO-EUR',
#    'token_info_url': None,
#    'coin_id': 'algorand'},
#   {'base': 'XTZ',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 6.49871,
#    'volume': 1718127.5,
#    'converted_last': {'btc': 0.00013978, 'eth': 0.00226224, 'usd': 7.85},
#    'converted_volume': {'btc': 240.168, 'eth': 3887, 'usd': 13486668},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.165727,
#    'timestamp': '2021-05-07T07:23:33+00:00',
#    'last_traded_at': '2021-05-07T07:23:33+00:00',
#    'last_fetch_at': '2021-05-07T07:24:40+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/XTZ-EUR',
#    'token_info_url': None,
#    'coin_id': 'tezos'},
#   {'base': 'EOS',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.00021,
#    'volume': 2765316.8,
#    'converted_last': {'btc': 0.00021, 'eth': 0.00339859, 'usd': 11.79},
#    'converted_volume': {'btc': 580.717, 'eth': 9398, 'usd': 32610222},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.473934,
#    'timestamp': '2021-05-07T07:23:17+00:00',
#    'last_traded_at': '2021-05-07T07:23:17+00:00',
#    'last_fetch_at': '2021-05-07T07:24:45+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/EOS-BTC',
#    'token_info_url': None,
#    'coin_id': 'eos',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ALGO',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 2.766e-05,
#    'volume': 4609621.0,
#    'converted_last': {'btc': 2.766e-05, 'eth': 0.00044764, 'usd': 1.55},
#    'converted_volume': {'btc': 127.502, 'eth': 2063, 'usd': 7159900},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.108382,
#    'timestamp': '2021-05-07T07:23:20+00:00',
#    'last_traded_at': '2021-05-07T07:23:20+00:00',
#    'last_fetch_at': '2021-05-07T07:24:38+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ALGO-BTC',
#    'token_info_url': None,
#    'coin_id': 'algorand',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'ADA',
#    'target': 'ETH',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.000475,
#    'volume': 13708279.5,
#    'converted_last': {'btc': 2.932e-05, 'eth': 0.00047439, 'usd': 1.65},
#    'converted_volume': {'btc': 401.951, 'eth': 6503, 'usd': 22568631},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.210084,
#    'timestamp': '2021-05-07T07:24:23+00:00',
#    'last_traded_at': '2021-05-07T07:24:23+00:00',
#    'last_fetch_at': '2021-05-07T07:24:54+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ADA-ETH',
#    'token_info_url': None,
#    'coin_id': 'cardano',
#    'target_coin_id': 'ethereum'},
#   {'base': 'LRC',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.075e-05,
#    'volume': 1858906.0,
#    'converted_last': {'btc': 1.075e-05, 'eth': 0.00017392, 'usd': 0.603588},
#    'converted_volume': {'btc': 19.98324, 'eth': 323.302, 'usd': 1122014},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.185701,
#    'timestamp': '2021-05-07T07:24:52+00:00',
#    'last_traded_at': '2021-05-07T07:24:52+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/LRC-BTC',
#    'token_info_url': None,
#    'coin_id': 'loopring',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'SNX',
#    'target': 'BTC',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.0003289,
#    'volume': 189155.79,
#    'converted_last': {'btc': 0.0003289, 'eth': 0.00532117, 'usd': 18.47},
#    'converted_volume': {'btc': 62.213, 'eth': 1007, 'usd': 3493139},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.091213,
#    'timestamp': '2021-05-07T07:24:53+00:00',
#    'last_traded_at': '2021-05-07T07:24:53+00:00',
#    'last_fetch_at': '2021-05-07T07:24:53+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/SNX-BTC',
#    'token_info_url': None,
#    'coin_id': 'havven',
#    'target_coin_id': 'bitcoin'},
#   {'base': 'OGN',
#    'target': 'USD',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 1.574,
#    'volume': 6900278.21,
#    'converted_last': {'btc': 2.803e-05, 'eth': 0.00045353, 'usd': 1.57},
#    'converted_volume': {'btc': 193.434, 'eth': 3130, 'usd': 10861038},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.063573,
#    'timestamp': '2021-05-07T07:25:02+00:00',
#    'last_traded_at': '2021-05-07T07:25:02+00:00',
#    'last_fetch_at': '2021-05-07T07:25:02+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/OGN-USD',
#    'token_info_url': None,
#    'coin_id': 'origin-protocol'},
#   {'base': 'ANKR',
#    'target': 'EUR',
#    'market': {'name': 'Coinbase Pro',
#     'identifier': 'gdax',
#     'has_trading_incentive': False},
#    'last': 0.13378,
#    'volume': 33403285.0,
#    'converted_last': {'btc': 2.88e-06, 'eth': 4.656e-05, 'usd': 0.16159},
#    'converted_volume': {'btc': 96.132, 'eth': 1555, 'usd': 5397622},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.179426,
#    'timestamp': '2021-05-07T07:24:52+00:00',
#    'last_traded_at': '2021-05-07T07:24:52+00:00',
#    'last_fetch_at': '2021-05-07T07:24:52+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://pro.coinbase.com/trade/ANKR-EUR',
#    'token_info_url': None,
#    'coin_id': 'ankr'}]}

# %%
df_coinbase_pro = pd.DataFrame(data_coinbase_pro['tickers'], columns=['base', 'coin_id', 'target', 'last', 'volume', 'converted_last', 'timestamp', 'market'])
df_coinbase_pro.set_index('base',inplace=True)
df_coinbase_pro
# Out:
#               coin_id target          last        volume  \
# base
# BTC           bitcoin    USD  56175.770000  1.873594e+04
# ETH          ethereum    USD   3468.700000  3.772610e+05
# LTC          litecoin    USD    370.220000  9.918881e+05
# BCH      bitcoin-cash    USD   1402.100000  2.646726e+05
# ADA           cardano    USD      1.647600  2.347761e+08
# ...               ...    ...           ...           ...
# ADA           cardano    ETH      0.000475  1.370828e+07
# LRC          loopring    BTC      0.000011  1.858906e+06
# SNX            havven    BTC      0.000329  1.891558e+05
# OGN   origin-protocol    USD      1.574000  6.900278e+06
# ANKR             ankr    EUR      0.133780  3.340328e+07
#
#                                          converted_last  \
# base
# BTC   {'btc': 1.000367, 'eth': 16.189715, 'usd': 56176}
# ETH   {'btc': 0.06177807, 'eth': 0.99948752, 'usd': ...
# LTC   {'btc': 0.00659359, 'eth': 0.10667558, 'usd': ...
# BCH   {'btc': 0.02496833, 'eth': 0.40408167, 'usd': ...
# ADA   {'btc': 2.934e-05, 'eth': 0.00047475, 'usd': 1...
# ...                                                 ...
# ADA   {'btc': 2.932e-05, 'eth': 0.00047439, 'usd': 1...
# LRC   {'btc': 1.075e-05, 'eth': 0.00017392, 'usd': 0...
# SNX   {'btc': 0.0003289, 'eth': 0.00532117, 'usd': 1...
# OGN   {'btc': 2.803e-05, 'eth': 0.00045353, 'usd': 1...
# ANKR  {'btc': 2.88e-06, 'eth': 4.656e-05, 'usd': 0.1...
#
#                       timestamp  \
# base
# BTC   2021-05-07T07:23:29+00:00
# ETH   2021-05-07T07:24:13+00:00
# LTC   2021-05-07T07:25:04+00:00
# BCH   2021-05-07T07:23:14+00:00
# ADA   2021-05-07T07:24:51+00:00
# ...                         ...
# ADA   2021-05-07T07:24:23+00:00
# LRC   2021-05-07T07:24:52+00:00
# SNX   2021-05-07T07:24:53+00:00
# OGN   2021-05-07T07:25:02+00:00
# ANKR  2021-05-07T07:24:52+00:00
#
#                                                  market
# base
# BTC   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# ETH   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# LTC   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# BCH   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# ADA   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# ...                                                 ...
# ADA   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# LRC   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# SNX   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# OGN   {'name': 'Coinbase Pro', 'identifier': 'gdax',...
# ANKR  {'name': 'Coinbase Pro', 'identifier': 'gdax',...
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Crypto Derivatives Markets

# %%
cg.get_derivatives()
# Out:
# [{'market': 'Huobi Futures',
#   'symbol': 'TRX-USDT',
#   'index_id': 'TRX',
#   'price': '0.16',
#   'price_percentage_change_24h': 13.0166379,
#   'contract_type': 'perpetual',
#   'index': 0.158375511286,
#   'basis': -0.1050123714851585,
#   'spread': 0.03,
#   'funding_rate': 0.132459311872666,
#   'open_interest': 3301714459.25,
#   'volume_24h': 464434000.01496255,
#   'last_traded_at': 1620371363,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'BTCUSD',
#   'index_id': 'BTC',
#   'price': '56154.0',
#   'price_percentage_change_24h': -1.0937912813738442,
#   'contract_type': 'perpetual',
#   'index': 56103.77,
#   'basis': -0.0894504398618086,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 2135788413.0,
#   'volume_24h': 5317663068.9,
#   'last_traded_at': 1620371167,
#   'expired_at': None},
#  {'market': 'MXC (Futures)',
#   'symbol': 'ETH_USDT',
#   'index_id': 'ETH',
#   'price': '3442.42',
#   'price_percentage_change_24h': 0.43850673838687987,
#   'contract_type': 'perpetual',
#   'index': 3434.8118,
#   'basis': -0.025852082545041767,
#   'spread': 0.01,
#   'funding_rate': 0.0032,
#   'open_interest': 2009916090.38,
#   'volume_24h': 423331924.9534474,
#   'last_traded_at': 1620371190,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'BTCUSDT',
#   'index_id': 'BTC',
#   'price': '56233.26',
#   'price_percentage_change_24h': -1.145305529911699,
#   'contract_type': 'perpetual',
#   'index': 56059.42500383,
#   'basis': -0.09070523242426705,
#   'spread': 0.01,
#   'funding_rate': 0.048931,
#   'open_interest': 1863017195.46,
#   'volume_24h': 15532591521.020409,
#   'last_traded_at': 1620371049,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'BTC-PERP',
#   'index_id': 'BTC',
#   'price': '56088.0',
#   'price_percentage_change_24h': -1.126447723306362,
#   'contract_type': 'perpetual',
#   'index': 56010.84943193637,
#   'basis': -0.13755271727219726,
#   'spread': 0.01,
#   'funding_rate': 0.036,
#   'open_interest': 1657074438.98,
#   'volume_24h': 2937245307.6282,
#   'last_traded_at': 1620371342,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'ETH-PERP',
#   'index_id': 'ETH',
#   'price': '3437.9',
#   'price_percentage_change_24h': 0.46170480114549545,
#   'contract_type': 'perpetual',
#   'index': 3434.756001003,
#   'basis': -0.09145114741557346,
#   'spread': 0.01,
#   'funding_rate': 0.0264,
#   'open_interest': 1224298354.11,
#   'volume_24h': 4351723793.0269,
#   'last_traded_at': 1620371085,
#   'expired_at': None},
#  {'market': 'Bitfinex (Futures)',
#   'symbol': 'ETHF0:USTF0',
#   'index_id': 'ETH',
#   'price': '3429.2',
#   'price_percentage_change_24h': 0.35116469624253777,
#   'contract_type': 'perpetual',
#   'index': 3425.2675,
#   'basis': -0.11467689256969556,
#   'spread': 0.06,
#   'funding_rate': -0.064879,
#   'open_interest': 1159049902.62,
#   'volume_24h': 107984210.44798765,
#   'last_traded_at': 1620371358,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'BTCUSD_PERP',
#   'index_id': 'BTC',
#   'price': '56139.3',
#   'price_percentage_change_24h': -1.16807622159471,
#   'contract_type': 'perpetual',
#   'index': 56109.79818182,
#   'basis': -0.05255109732397803,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 1070593100.0,
#   'volume_24h': 7003445229.992554,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'ETHUSDT',
#   'index_id': 'ETH',
#   'price': '3440.86',
#   'price_percentage_change_24h': 0.5446974000948828,
#   'contract_type': 'perpetual',
#   'index': 3429.9374302,
#   'basis': -0.09910378232275277,
#   'spread': 0.01,
#   'funding_rate': 0.053879,
#   'open_interest': 1065364962.04,
#   'volume_24h': 10304946770.08407,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'ETHUSD',
#   'index_id': 'ETH',
#   'price': '3438.55',
#   'price_percentage_change_24h': 0.3780359645025689,
#   'contract_type': 'perpetual',
#   'index': 3438.4,
#   'basis': -0.004362303878088148,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 906846867.0,
#   'volume_24h': 4415964405.1305,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Hopex',
#   'symbol': 'ETHUSDT',
#   'index_id': 'ETH',
#   'price': '3445.05',
#   'price_percentage_change_24h': 0.8009270804300949,
#   'contract_type': 'perpetual',
#   'index': 3435.87,
#   'basis': 0.0005820975886607389,
#   'spread': None,
#   'funding_rate': 0.0,
#   'open_interest': 873174064.79,
#   'volume_24h': 2721029870.8077464,
#   'last_traded_at': 1620370870,
#   'expired_at': None},
#  {'market': 'BTSE (Futures)',
#   'symbol': 'BTCPFC',
#   'index_id': 'BTCPFC',
#   'price': '56132.0',
#   'price_percentage_change_24h': -1.0043826001075808,
#   'contract_type': 'perpetual',
#   'index': 56057.367694547,
#   'basis': -0.132958571675693,
#   'spread': 0.01,
#   'funding_rate': 0.0,
#   'open_interest': 777812401.33,
#   'volume_24h': 968767203.8425,
#   'last_traded_at': 1620371388,
#   'expired_at': None},
#  {'market': 'BitMEX',
#   'symbol': 'XBTUSD',
#   'index_id': 'BXBT',
#   'price': '56173.5',
#   'price_percentage_change_24h': -0.7693123001642849,
#   'contract_type': 'perpetual',
#   'index': 56167.8,
#   'basis': -0.010147133434804667,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 764783357.0,
#   'volume_24h': 2025144743.7741232,
#   'last_traded_at': 1620370692,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'BTC-USD',
#   'index_id': 'BTC',
#   'price': '56127.0',
#   'price_percentage_change_24h': -1.3073561864235412,
#   'contract_type': 'perpetual',
#   'index': 56078.3825,
#   'basis': -0.08662052131772587,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 752901900.0,
#   'volume_24h': 2499964331.042974,
#   'last_traded_at': 1620371255,
#   'expired_at': None},
#  {'market': 'Bitfinex (Futures)',
#   'symbol': 'BTCF0:USTF0',
#   'index_id': 'BTC',
#   'price': '56006.0',
#   'price_percentage_change_24h': -1.1647195849362935,
#   'contract_type': 'perpetual',
#   'index': 56001.3725,
#   'basis': -0.008262507588472663,
#   'spread': 0.01,
#   'funding_rate': 0.0,
#   'open_interest': 690406546.06,
#   'volume_24h': 79934429.0827997,
#   'last_traded_at': 1620371358,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'ETHUSD_PERP',
#   'index_id': 'ETH',
#   'price': '3435.29',
#   'price_percentage_change_24h': 0.6118205248359887,
#   'contract_type': 'perpetual',
#   'index': 3434.08857296,
#   'basis': -0.034973089317059114,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 689729520.0,
#   'volume_24h': 4863219858.646233,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Deribit',
#   'symbol': 'BTC-PERPETUAL',
#   'index_id': 'BTC',
#   'price': '56098.5',
#   'price_percentage_change_24h': -1.1915455746367238,
#   'contract_type': 'perpetual',
#   'index': 56067.94,
#   'basis': -0.05447560986479139,
#   'spread': 0.01,
#   'funding_rate': 0.005302,
#   'open_interest': 645944900.0,
#   'volume_24h': 821489124.4089646,
#   'last_traded_at': 1620371397,
#   'expired_at': None},
#  {'market': 'Gate.io (Futures)',
#   'symbol': 'DOGE_USDT',
#   'index_id': 'DOGE',
#   'price': '0.65',
#   'price_percentage_change_24h': 7.4568875,
#   'contract_type': 'perpetual',
#   'index': 0.646572,
#   'basis': -0.0927111,
#   'spread': None,
#   'funding_rate': 0.1027,
#   'open_interest': 613524116.46,
#   'volume_24h': 307113487.8381752,
#   'last_traded_at': 1620371301,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'XRPUSDT',
#   'index_id': 'XRP',
#   'price': '1.59',
#   'price_percentage_change_24h': -3.1790670660879132,
#   'contract_type': 'perpetual',
#   'index': 1.580848,
#   'basis': -0.18008461198459305,
#   'spread': 0.02,
#   'funding_rate': 0.052351,
#   'open_interest': 575525258.45,
#   'volume_24h': 4506154428.083573,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'XRP-USDT',
#   'index_id': 'XRP',
#   'price': '1.58',
#   'price_percentage_change_24h': -3.078518482156006,
#   'contract_type': 'perpetual',
#   'index': 1.5776466666666666,
#   'basis': -0.11796907479743718,
#   'spread': 0.01,
#   'funding_rate': 0.0174715760223317,
#   'open_interest': 553550148.69,
#   'volume_24h': 1312140070.1436007,
#   'last_traded_at': 1620371252,
#   'expired_at': None},
#  {'market': 'Bitget Futures',
#   'symbol': 'SBTCUSD',
#   'index_id': 'SBTC',
#   'price': '56169.0',
#   'price_percentage_change_24h': -0.9723115980994526,
#   'contract_type': 'perpetual',
#   'index': 56172.68,
#   'basis': 0.006551656607737364,
#   'spread': 0.01,
#   'funding_rate': 0.0147810974,
#   'open_interest': 549914908.0,
#   'volume_24h': 375708223.0917,
#   'last_traded_at': 1620371513,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'BNBUSDT',
#   'index_id': 'BNB',
#   'price': '623.63',
#   'price_percentage_change_24h': -2.4667376263970198,
#   'contract_type': 'perpetual',
#   'index': 621.59954475,
#   'basis': -0.2409649880196148,
#   'spread': 0.01,
#   'funding_rate': 0.119345,
#   'open_interest': 513469755.63,
#   'volume_24h': 1566664915.5969582,
#   'last_traded_at': 1620371414,
#   'expired_at': None},
#  {'market': 'Hopex',
#   'symbol': 'BCHUSDT',
#   'index_id': 'BCH',
#   'price': '1411.94',
#   'price_percentage_change_24h': 10.719760996894532,
#   'contract_type': 'perpetual',
#   'index': 1409.82,
#   'basis': 0.1079315486757083,
#   'spread': None,
#   'funding_rate': 0.0,
#   'open_interest': 466354437.65,
#   'volume_24h': 2371371237.7777586,
#   'last_traded_at': 1620370535,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'BTC-USD-SWAP',
#   'index_id': 'OkexSwap-BTC',
#   'price': '56200.3',
#   'price_percentage_change_24h': -0.8395073055485469,
#   'contract_type': 'perpetual',
#   'index': 56160.65,
#   'basis': -0.032485506124185416,
#   'spread': 0.01,
#   'funding_rate': 0.016757,
#   'open_interest': 442234800.0,
#   'volume_24h': 1241911115.90338,
#   'last_traded_at': 1620370738,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'ETH-USD',
#   'index_id': 'ETH',
#   'price': '3433.96',
#   'price_percentage_change_24h': 0.39879309538288815,
#   'contract_type': 'perpetual',
#   'index': 3434.8846027525,
#   'basis': 0.026925262743305107,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 421825360.0,
#   'volume_24h': 2497652286.06238,
#   'last_traded_at': 1620371252,
#   'expired_at': None},
#  {'market': 'Hopex',
#   'symbol': 'ETCUSDT',
#   'index_id': 'ETC',
#   'price': '135.6',
#   'price_percentage_change_24h': 47.8819490005686,
#   'contract_type': 'perpetual',
#   'index': 135.182,
#   'basis': -0.043625823529846716,
#   'spread': None,
#   'funding_rate': 0.0,
#   'open_interest': 370499231.1,
#   'volume_24h': 3038123123.8427515,
#   'last_traded_at': 1620370870,
#   'expired_at': None},
#  {'market': 'Bitforex (Futures)',
#   'symbol': 'SWAP-USD-BTC',
#   'index_id': 'BTC',
#   'price': '56060.5',
#   'price_percentage_change_24h': -1.2167186481295484,
#   'contract_type': 'perpetual',
#   'index': 56035.34,
#   'basis': -0.044880084908268746,
#   'spread': 0.01,
#   'funding_rate': 0.034,
#   'open_interest': 369242680.0,
#   'volume_24h': 5894723865.0,
#   'last_traded_at': 1620371331,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'DOTUSDM',
#   'index_id': 'KDOTUSD',
#   'price': '40.34',
#   'price_percentage_change_24h': 4.825758166367818,
#   'contract_type': 'perpetual',
#   'index': 40.346,
#   'basis': 0.019832416084089446,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 326147856.75,
#   'volume_24h': 4459201.0,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'Hopex',
#   'symbol': 'EOSUSDT',
#   'index_id': 'EOS',
#   'price': '11.9',
#   'price_percentage_change_24h': 36.93745672744057,
#   'contract_type': 'perpetual',
#   'index': 11.8568,
#   'basis': -0.0859526417797253,
#   'spread': None,
#   'funding_rate': 0.0,
#   'open_interest': 322203437.62,
#   'volume_24h': 4673931915.393578,
#   'last_traded_at': 1620370870,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'VET-USDT',
#   'index_id': 'VET',
#   'price': '0.23',
#   'price_percentage_change_24h': 14.0837107,
#   'contract_type': 'perpetual',
#   'index': 0.233557655392,
#   'basis': -0.2116377948584295,
#   'spread': 0.07,
#   'funding_rate': 0.153731214301392,
#   'open_interest': 314356479.38,
#   'volume_24h': 34033420.57502143,
#   'last_traded_at': 1620371256,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'ADA-USDT',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 11.515713288913819,
#   'contract_type': 'perpetual',
#   'index': 1.6232813210066666,
#   'basis': -0.42190234163250334,
#   'spread': 0.01,
#   'funding_rate': 0.0888918876246933,
#   'open_interest': 304738643.08,
#   'volume_24h': 550138830.1165627,
#   'last_traded_at': 1620371254,
#   'expired_at': None},
#  {'market': 'BitZ (Futures)',
#   'symbol': 'BTC_USDT',
#   'index_id': 'BTC',
#   'price': '56222.26',
#   'price_percentage_change_24h': -1.1764602284234904,
#   'contract_type': 'perpetual',
#   'index': 56056.9,
#   'basis': -0.09908665627088438,
#   'spread': 0.01,
#   'funding_rate': 0.0,
#   'open_interest': 294366212.01,
#   'volume_24h': 2452989950.911854,
#   'last_traded_at': 1620371175,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'BTCUSDT',
#   'index_id': 'BTC',
#   'price': '56202.72',
#   'price_percentage_change_24h': -1.1402890377158972,
#   'contract_type': 'perpetual',
#   'index': 56057.76,
#   'basis': -0.06282423831850677,
#   'spread': 0.01,
#   'funding_rate': 0.0836,
#   'open_interest': 293925736.58,
#   'volume_24h': 826868470.512139,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'ZBG Futures',
#   'symbol': 'BTC_USDT',
#   'index_id': 'BTC',
#   'price': '56168.15',
#   'price_percentage_change_24h': -1.1226739571390776,
#   'contract_type': 'perpetual',
#   'index': 56060.80173418,
#   'basis': 0.004105950355432272,
#   'spread': 0.02,
#   'funding_rate': 0.01,
#   'open_interest': 285907100.25,
#   'volume_24h': 1351299.0364313016,
#   'last_traded_at': 1620371167,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'XRP-PERP',
#   'index_id': 'XRP',
#   'price': '1.58',
#   'price_percentage_change_24h': -3.304379796865665,
#   'contract_type': 'perpetual',
#   'index': 1.575896,
#   'basis': -0.13333333333333333,
#   'spread': 0.03,
#   'funding_rate': 0.0744,
#   'open_interest': 284299008.19,
#   'volume_24h': 771269998.8605,
#   'last_traded_at': 1620371342,
#   'expired_at': None},
#  {'market': 'BitZ (Futures)',
#   'symbol': 'BTC_USDT_BZ',
#   'index_id': 'BTC',
#   'price': '56177.67',
#   'price_percentage_change_24h': -1.1782538577458954,
#   'contract_type': 'perpetual',
#   'index': 56056.9,
#   'basis': -0.019797388884925448,
#   'spread': 0.03,
#   'funding_rate': 0.0,
#   'open_interest': 284050742.55,
#   'volume_24h': 2369459910.722995,
#   'last_traded_at': 1620371176,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'DOTUSDT',
#   'index_id': 'DOT',
#   'price': '40.38',
#   'price_percentage_change_24h': 4.207888822876036,
#   'contract_type': 'perpetual',
#   'index': 40.25550617,
#   'basis': -0.21440144266521244,
#   'spread': 0.01,
#   'funding_rate': 0.09213,
#   'open_interest': 262525314.43,
#   'volume_24h': 1245764135.8203065,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'LTCUSDT',
#   'index_id': 'LTC',
#   'price': '361.97',
#   'price_percentage_change_24h': 8.75312396495137,
#   'contract_type': 'perpetual',
#   'index': 360.48973684,
#   'basis': -0.19111333960905919,
#   'spread': 0.02,
#   'funding_rate': 0.058244,
#   'open_interest': 258893466.08,
#   'volume_24h': 2889932141.9380255,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'DOGEUSDT',
#   'index_id': 'DOGE',
#   'price': '0.64',
#   'price_percentage_change_24h': 5.4610235,
#   'contract_type': 'perpetual',
#   'index': 0.63724346,
#   'basis': -0.0515299,
#   'spread': 0.02,
#   'funding_rate': 0.037695,
#   'open_interest': 254348736.93,
#   'volume_24h': 6735570382.1171875,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'XRPUSD',
#   'index_id': 'XRP',
#   'price': '1.58',
#   'price_percentage_change_24h': -3.179455823907062,
#   'contract_type': 'perpetual',
#   'index': 1.583,
#   'basis': -0.031575623618566466,
#   'spread': 0.02,
#   'funding_rate': 0.01,
#   'open_interest': 253571196.0,
#   'volume_24h': 3092722307.8767343,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'ETCUSDT',
#   'index_id': 'ETC',
#   'price': '132.24',
#   'price_percentage_change_24h': 43.05838277967864,
#   'contract_type': 'perpetual',
#   'index': 131.79725143,
#   'basis': -0.24654948040840732,
#   'spread': 0.03,
#   'funding_rate': 0.035244,
#   'open_interest': 252683246.36,
#   'volume_24h': 17248692376.252518,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Deribit',
#   'symbol': 'ETH-PERPETUAL',
#   'index_id': 'ETH',
#   'price': '3434.1',
#   'price_percentage_change_24h': 0.2510582396730404,
#   'contract_type': 'perpetual',
#   'index': 3433.7,
#   'basis': -0.011647884452986226,
#   'spread': 0.02,
#   'funding_rate': 0.0018,
#   'open_interest': 252521061.0,
#   'volume_24h': 570381236.6114528,
#   'last_traded_at': 1620371397,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'EOSUSDT',
#   'index_id': 'EOS',
#   'price': '11.69',
#   'price_percentage_change_24h': 33.08270676691729,
#   'contract_type': 'perpetual',
#   'index': 11.65643684,
#   'basis': -0.21882520116418422,
#   'spread': 0.02,
#   'funding_rate': 0.087379,
#   'open_interest': 247756363.9,
#   'volume_24h': 6953556799.356526,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'ZBG Futures',
#   'symbol': 'ETH_USDT',
#   'index_id': 'ETH',
#   'price': '3440.87',
#   'price_percentage_change_24h': 0.6300089373360878,
#   'contract_type': 'perpetual',
#   'index': 3432.75330731,
#   'basis': -0.040670695514173814,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 242893296.94,
#   'volume_24h': 1865532.9354375284,
#   'last_traded_at': 1620371167,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'ADAUSDT',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 10.896094958401187,
#   'contract_type': 'perpetual',
#   'index': 1.62588081,
#   'basis': -0.09948940092165899,
#   'spread': 0.01,
#   'funding_rate': 0.049272,
#   'open_interest': 239689678.91,
#   'volume_24h': 3271010473.380722,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'BitMEX',
#   'symbol': 'ETHUSD',
#   'index_id': 'BETH',
#   'price': '3448.1',
#   'price_percentage_change_24h': 1.5042684721813364,
#   'contract_type': 'perpetual',
#   'index': 3445.57,
#   'basis': -0.0733737420608451,
#   'spread': 0.01,
#   'funding_rate': 0.0989,
#   'open_interest': 234587762.62,
#   'volume_24h': 882587034.239659,
#   'last_traded_at': 1620370692,
#   'expired_at': None},
#  {'market': 'MXC (Futures)',
#   'symbol': 'BTC_USDT',
#   'index_id': 'BTC',
#   'price': '56180.18',
#   'price_percentage_change_24h': -1.15729723059566,
#   'contract_type': 'perpetual',
#   'index': 56079.4,
#   'basis': 0.01587287432785511,
#   'spread': 0.01,
#   'funding_rate': 0.0203,
#   'open_interest': 234362704.35,
#   'volume_24h': 83891664.35530627,
#   'last_traded_at': 1620371190,
#   'expired_at': None},
#  {'market': 'BitZ (Futures)',
#   'symbol': 'ETH_USDT',
#   'index_id': 'ETH',
#   'price': '3441.47',
#   'price_percentage_change_24h': 0.6298981908738006,
#   'contract_type': 'perpetual',
#   'index': 3432.13,
#   'basis': -0.07627920518232768,
#   'spread': 0.02,
#   'funding_rate': 0.0,
#   'open_interest': 234190488.5,
#   'volume_24h': 700798106.243438,
#   'last_traded_at': 1620371175,
#   'expired_at': None},
#  {'market': 'MXC (Futures)',
#   'symbol': 'LTC_USDT',
#   'index_id': 'LTC',
#   'price': '361.59',
#   'price_percentage_change_24h': 8.232612542362714,
#   'contract_type': 'perpetual',
#   'index': 360.772,
#   'basis': -0.029926845488805143,
#   'spread': 0.02,
#   'funding_rate': -0.0083,
#   'open_interest': 234030786.9,
#   'volume_24h': 80290259.44999017,
#   'last_traded_at': 1620371206,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'EOS-PERP',
#   'index_id': 'EOS',
#   'price': '11.59',
#   'price_percentage_change_24h': 32.05865603644647,
#   'contract_type': 'perpetual',
#   'index': 11.5903,
#   'basis': -0.03837943897022359,
#   'spread': 0.02,
#   'funding_rate': -0.0264,
#   'open_interest': 232725202.65,
#   'volume_24h': 830077141.06025,
#   'last_traded_at': 1620371341,
#   'expired_at': None},
#  {'market': 'MyCoinStory',
#   'symbol': 'ETHUSDT_QUANTO_PERP',
#   'index_id': 'ETH',
#   'price': '3447.99',
#   'price_percentage_change_24h': 0.5384345998949396,
#   'contract_type': 'perpetual',
#   'index': 3429.72355150417,
#   'basis': -0.44488319460762543,
#   'spread': None,
#   'funding_rate': 0.176504868204,
#   'open_interest': 227830332.9,
#   'volume_24h': 1288927.655377705,
#   'last_traded_at': 1620371411,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'SOL-PERP',
#   'index_id': 'SOL',
#   'price': '42.6',
#   'price_percentage_change_24h': -2.0240354206198607,
#   'contract_type': 'perpetual',
#   'index': 42.53433010248184,
#   'basis': -0.14829484715807265,
#   'spread': 0.07,
#   'funding_rate': 0.0696,
#   'open_interest': 224586841.85,
#   'volume_24h': 116263683.63,
#   'last_traded_at': 1620371086,
#   'expired_at': None},
#  {'market': 'Prime XBT',
#   'symbol': 'BTC/USD',
#   'index_id': 'BTC',
#   'price': '56016.5',
#   'price_percentage_change_24h': -1.1215863898651237,
#   'contract_type': 'perpetual',
#   'index': None,
#   'basis': 0.0,
#   'spread': 0.02,
#   'funding_rate': 0.0,
#   'open_interest': 224330855.0,
#   'volume_24h': 565966670.917375,
#   'last_traded_at': 1620371274,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'BNBUSD_PERP',
#   'index_id': 'BNB',
#   'price': '622.91',
#   'price_percentage_change_24h': -2.5172143974960877,
#   'contract_type': 'perpetual',
#   'index': 622.18297504,
#   'basis': -0.11751602706629316,
#   'spread': 0.01,
#   'funding_rate': 0.06652,
#   'open_interest': 214707680.0,
#   'volume_24h': 737639330.563074,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'DOGE-PERP',
#   'index_id': 'DOGE',
#   'price': '0.64',
#   'price_percentage_change_24h': 6.967942,
#   'contract_type': 'perpetual',
#   'index': 0.6430992426728154,
#   'basis': 0.1118094515272712,
#   'spread': 0.04,
#   'funding_rate': 0.0336,
#   'open_interest': 212710389.73,
#   'volume_24h': 1479795735.093302,
#   'last_traded_at': 1620371342,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'ETH-USD-SWAP',
#   'index_id': 'OkexSwap-ETH',
#   'price': '3446.57',
#   'price_percentage_change_24h': 0.7000505462205744,
#   'contract_type': 'perpetual',
#   'index': 3448.31521768,
#   'basis': 0.0030513710011861226,
#   'spread': 0.01,
#   'funding_rate': -0.000587,
#   'open_interest': 200020900.0,
#   'volume_24h': 808906403.528282,
#   'last_traded_at': 1620370398,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'XRPUSDM',
#   'index_id': 'KXRPUSD',
#   'price': '1.59',
#   'price_percentage_change_24h': -2.608642278418856,
#   'contract_type': 'perpetual',
#   'index': 1.5855,
#   'basis': -0.07562866326337682,
#   'spread': 0.02,
#   'funding_rate': 0.01,
#   'open_interest': 197467639.33,
#   'volume_24h': 11702475.0,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'BTCMEX',
#   'symbol': 'BTCUSD',
#   'index_id': 'BTC',
#   'price': '56063.5',
#   'price_percentage_change_24h': -1.292310400985959,
#   'contract_type': 'perpetual',
#   'index': 56058.96,
#   'basis': -0.00809796034853336,
#   'spread': None,
#   'funding_rate': 0.04,
#   'open_interest': 195415382.0,
#   'volume_24h': 2117831078.8735063,
#   'last_traded_at': 1620371359,
#   'expired_at': None},
#  {'market': 'Kraken (Futures)',
#   'symbol': 'PI_XBTUSD',
#   'index_id': 'KrakenFutures-rr_xbtusd',
#   'price': '56194.0',
#   'price_percentage_change_24h': -1.123476883825276,
#   'contract_type': 'perpetual',
#   'index': 56206.8,
#   'basis': 0.022778232551517955,
#   'spread': 0.03,
#   'funding_rate': 0.000671340083,
#   'open_interest': 194135691.0,
#   'volume_24h': 534799522.0,
#   'last_traded_at': 1620370807,
#   'expired_at': None},
#  {'market': 'Hopex',
#   'symbol': 'BTCUSDT',
#   'index_id': 'BTC',
#   'price': '56231.71',
#   'price_percentage_change_24h': -1.0044041976681584,
#   'contract_type': 'perpetual',
#   'index': 56078.59,
#   'basis': -0.005188876902365308,
#   'spread': None,
#   'funding_rate': 0.0,
#   'open_interest': 184825315.62,
#   'volume_24h': 3373752490.8042803,
#   'last_traded_at': 1620370870,
#   'expired_at': None},
#  {'market': 'Phemex (Futures)',
#   'symbol': 'BTCUSD',
#   'index_id': 'BTC',
#   'price': '56133.5',
#   'price_percentage_change_24h': -1.283776060214373,
#   'contract_type': 'perpetual',
#   'index': 56102.3257,
#   'basis': -0.05553599900237826,
#   'spread': 0.01,
#   'funding_rate': 0.018845,
#   'open_interest': 184276879.0,
#   'volume_24h': 1275881525.0,
#   'last_traded_at': 1620371167,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'BCHUSDT',
#   'index_id': 'BCH',
#   'price': '1399.27',
#   'price_percentage_change_24h': 7.089386246145822,
#   'contract_type': 'perpetual',
#   'index': 1394.56331593,
#   'basis': -0.11793956997872813,
#   'spread': 0.02,
#   'funding_rate': 0.055672,
#   'open_interest': 181487278.22,
#   'volume_24h': 3393076548.9467225,
#   'last_traded_at': 1620371049,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'TRXUSDT',
#   'index_id': 'TRX',
#   'price': '0.16',
#   'price_percentage_change_24h': 13.4264538,
#   'contract_type': 'perpetual',
#   'index': 0.15876974,
#   'basis': -0.2451998,
#   'spread': 0.02,
#   'funding_rate': 0.131887,
#   'open_interest': 174553196.93,
#   'volume_24h': 1593172918.7536533,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'Bitforex (Futures)',
#   'symbol': 'SWAP-USD-ETH',
#   'index_id': 'ETH',
#   'price': '3427.1',
#   'price_percentage_change_24h': 0.11685314481025971,
#   'contract_type': 'perpetual',
#   'index': 3428.01,
#   'basis': 0.02655306235592775,
#   'spread': 0.01,
#   'funding_rate': 0.015,
#   'open_interest': 168241333.0,
#   'volume_24h': 5594402369.0,
#   'last_traded_at': 1620371331,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'LTC-PERP',
#   'index_id': 'LTC',
#   'price': '358.2',
#   'price_percentage_change_24h': 7.142857142857143,
#   'contract_type': 'perpetual',
#   'index': 358.049,
#   'basis': -0.04215522054718034,
#   'spread': 0.02,
#   'funding_rate': 0.0312,
#   'open_interest': 159766588.42,
#   'volume_24h': 559137270.7335,
#   'last_traded_at': 1620371341,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'XBTUSDTM',
#   'index_id': 'KXBTUSDT',
#   'price': '56238.96',
#   'price_percentage_change_24h': -1.1972674131981125,
#   'contract_type': 'perpetual',
#   'index': 56075.73,
#   'basis': -0.07176206429538813,
#   'spread': 0.01,
#   'funding_rate': 0.01,
#   'open_interest': 159217941.19,
#   'volume_24h': 204793428.0138918,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'MyCoinStory',
#   'symbol': 'BCHUSDT_QUANTO_PERP',
#   'index_id': 'BCH',
#   'price': '1390.24',
#   'price_percentage_change_24h': 5.063913470993117,
#   'contract_type': 'perpetual',
#   'index': 1385.345,
#   'basis': -0.26672905942910624,
#   'spread': None,
#   'funding_rate': 0.271073448806,
#   'open_interest': 156731579.37,
#   'volume_24h': 1028298.3593644978,
#   'last_traded_at': 1620371411,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'FIL-USD',
#   'index_id': 'FIL',
#   'price': '152.5',
#   'price_percentage_change_24h': -3.1752179351242216,
#   'contract_type': 'perpetual',
#   'index': 152.35242511690655,
#   'basis': -0.09677041514327869,
#   'spread': 0.01,
#   'funding_rate': 0.0901419587993521,
#   'open_interest': 156613750.0,
#   'volume_24h': 344112093.72434634,
#   'last_traded_at': 1620371258,
#   'expired_at': None},
#  {'market': 'Bitget Futures',
#   'symbol': 'CMT_ETHUSDT',
#   'index_id': 'ETH',
#   'price': '3466.36',
#   'price_percentage_change_24h': 1.2537709595191882,
#   'contract_type': 'perpetual',
#   'index': 3465.71,
#   'basis': 0.0560083377360506,
#   'spread': 0.02,
#   'funding_rate': 0.0007183065,
#   'open_interest': 144288766.46,
#   'volume_24h': 553634243.5031177,
#   'last_traded_at': 1620371514,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'ETHUSDT',
#   'index_id': 'ETH',
#   'price': '3441.57',
#   'price_percentage_change_24h': 0.35644895037470964,
#   'contract_type': 'perpetual',
#   'index': 3432.56,
#   'basis': -0.0666695780019506,
#   'spread': 0.01,
#   'funding_rate': 0.0356,
#   'open_interest': 141048717.36,
#   'volume_24h': 469453030.2801345,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'LINKUSDT',
#   'index_id': 'LINK',
#   'price': '46.99',
#   'price_percentage_change_24h': 0.9864099416338222,
#   'contract_type': 'perpetual',
#   'index': 46.87755083,
#   'basis': -0.024417603275821622,
#   'spread': 0.02,
#   'funding_rate': 0.038206,
#   'open_interest': 138822636.79,
#   'volume_24h': 1122827895.2489357,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'ETHUSDTM',
#   'index_id': 'KETHUSDT',
#   'price': '3440.72',
#   'price_percentage_change_24h': 0.47998126902364785,
#   'contract_type': 'perpetual',
#   'index': 3430.88,
#   'basis': -0.06757543982290574,
#   'spread': 0.01,
#   'funding_rate': 0.1201,
#   'open_interest': 134400012.85,
#   'volume_24h': 184550411.90696698,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'BNB-PERP',
#   'index_id': 'BNB',
#   'price': '623.47',
#   'price_percentage_change_24h': -2.424643170151496,
#   'contract_type': 'perpetual',
#   'index': 623.2519861568123,
#   'basis': -0.034566973128142206,
#   'spread': 0.03,
#   'funding_rate': 0.0816,
#   'open_interest': 126664405.46,
#   'volume_24h': 288673480.3405,
#   'last_traded_at': 1620371106,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'FTT-PERP',
#   'index_id': 'FTT',
#   'price': '57.15',
#   'price_percentage_change_24h': 0.2025019066737966,
#   'contract_type': 'perpetual',
#   'index': 57.16421688464393,
#   'basis': 0.021376127946406077,
#   'spread': 0.05,
#   'funding_rate': 0.0216,
#   'open_interest': 119989892.45,
#   'volume_24h': 132176285.9524,
#   'last_traded_at': 1620371140,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'XLMUSDT',
#   'index_id': 'XLM',
#   'price': '0.64',
#   'price_percentage_change_24h': 3.4193044,
#   'contract_type': 'perpetual',
#   'index': 0.63477725,
#   'basis': -0.0602604,
#   'spread': 0.02,
#   'funding_rate': 0.049505,
#   'open_interest': 117868415.46,
#   'volume_24h': 735483153.8653387,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'ZBG Futures',
#   'symbol': 'DOT_USDT',
#   'index_id': 'DOT',
#   'price': '40.29',
#   'price_percentage_change_24h': 4.259456096233117,
#   'contract_type': 'perpetual',
#   'index': 40.21362734,
#   'basis': -0.00589979112790929,
#   'spread': 0.13,
#   'funding_rate': 0.01,
#   'open_interest': 114888884.66,
#   'volume_24h': 4086236.242478491,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'ADA-PERP',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 11.384339824509231,
#   'contract_type': 'perpetual',
#   'index': 1.6264910214072126,
#   'basis': -0.17117859378295935,
#   'spread': 0.02,
#   'funding_rate': 0.1776,
#   'open_interest': 108832124.07,
#   'volume_24h': 458577810.236775,
#   'last_traded_at': 1620371132,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'DOGEUSD_PERP',
#   'index_id': 'DOGE',
#   'price': '0.64',
#   'price_percentage_change_24h': 5.4824652,
#   'contract_type': 'perpetual',
#   'index': 0.6375515,
#   'basis': -0.1902885,
#   'spread': 0.01,
#   'funding_rate': 0.041318,
#   'open_interest': 107891380.0,
#   'volume_24h': 2511798668.9792504,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'BCH-PERP',
#   'index_id': 'BCH',
#   'price': '1382.05',
#   'price_percentage_change_24h': 4.971137779128057,
#   'contract_type': 'perpetual',
#   'index': 1379.5236,
#   'basis': -0.1828009116891574,
#   'spread': 0.05,
#   'funding_rate': 0.0288,
#   'open_interest': 107015948.72,
#   'volume_24h': 670171914.1759,
#   'last_traded_at': 1620371339,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'ADAUSDT',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 10.573257080610022,
#   'contract_type': 'perpetual',
#   'index': 1.625,
#   'basis': 0.05541530693922788,
#   'spread': 0.02,
#   'funding_rate': 0.3095,
#   'open_interest': 106193760.72,
#   'volume_24h': 201534987.68928573,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Bitget Futures',
#   'symbol': 'CMT_BTCUSDT',
#   'index_id': 'BTC',
#   'price': '56207.97',
#   'price_percentage_change_24h': -0.9732360097323601,
#   'contract_type': 'perpetual',
#   'index': 56187.07,
#   'basis': 0.0375137983833636,
#   'spread': 0.01,
#   'funding_rate': 0.0302747658,
#   'open_interest': 104157857.69,
#   'volume_24h': 4756988934.621982,
#   'last_traded_at': 1620371513,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'LINK-PERP',
#   'index_id': 'LINK',
#   'price': '46.58',
#   'price_percentage_change_24h': -0.12541940463301424,
#   'contract_type': 'perpetual',
#   'index': 46.61530865768598,
#   'basis': 0.06506098032838897,
#   'spread': 0.06,
#   'funding_rate': 0.0336,
#   'open_interest': 101028856.89,
#   'volume_24h': 375832790.4874,
#   'last_traded_at': 1620371341,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'UNIUSDT',
#   'index_id': 'UNI',
#   'price': '39.67',
#   'price_percentage_change_24h': -4.4314097046932295,
#   'contract_type': 'perpetual',
#   'index': 39.56439851,
#   'basis': -0.1927344806361123,
#   'spread': 0.03,
#   'funding_rate': 0.067169,
#   'open_interest': 101020074.19,
#   'volume_24h': 492200763.9741517,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'FILUSDT',
#   'index_id': 'FIL',
#   'price': '152.74',
#   'price_percentage_change_24h': -3.2558463869360432,
#   'contract_type': 'perpetual',
#   'index': 152.31450174,
#   'basis': -0.1942836754886607,
#   'spread': 0.02,
#   'funding_rate': 0.076377,
#   'open_interest': 99635418.52,
#   'volume_24h': 447327319.23273796,
#   'last_traded_at': 1620371413,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'DOTUSD_PERP',
#   'index_id': 'DOT',
#   'price': '40.33',
#   'price_percentage_change_24h': 4.131057808990215,
#   'contract_type': 'perpetual',
#   'index': 40.29475406,
#   'basis': -0.08987116610051821,
#   'spread': 0.01,
#   'funding_rate': 0.024071,
#   'open_interest': 97486890.0,
#   'volume_24h': 718195753.8376108,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Kraken (Futures)',
#   'symbol': 'PI_ETHUSD',
#   'index_id': 'KrakenFutures-rr_ethusd',
#   'price': '3446.45',
#   'price_percentage_change_24h': 0.8603912731742293,
#   'contract_type': 'perpetual',
#   'index': 3444.85,
#   'basis': -0.04642458181607161,
#   'spread': 0.04,
#   'funding_rate': 0.001597118691,
#   'open_interest': 97287428.0,
#   'volume_24h': 395288949.0,
#   'last_traded_at': 1620370807,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'DOT-PERP',
#   'index_id': 'DOT',
#   'price': '40.33',
#   'price_percentage_change_24h': 4.1745240370953995,
#   'contract_type': 'perpetual',
#   'index': 40.27515181758657,
#   'basis': -0.1285694011789372,
#   'spread': 0.04,
#   'funding_rate': 0.1128,
#   'open_interest': 90996669.72,
#   'volume_24h': 250144726.6045,
#   'last_traded_at': 1620371141,
#   'expired_at': None},
#  {'market': 'Bitforex (Futures)',
#   'symbol': 'SWAP-USD-LTC',
#   'index_id': 'LTC',
#   'price': '358.15',
#   'price_percentage_change_24h': 7.294787297783103,
#   'contract_type': 'perpetual',
#   'index': 357.927,
#   'basis': -0.06226441435152869,
#   'spread': 0.04,
#   'funding_rate': 0.042,
#   'open_interest': 88829694.0,
#   'volume_24h': 103983369.0,
#   'last_traded_at': 1620371331,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'XTZUSDT',
#   'index_id': 'XTZ',
#   'price': '7.71',
#   'price_percentage_change_24h': 16.96767339505236,
#   'contract_type': 'perpetual',
#   'index': 7.69448857,
#   'basis': -0.16233852342026728,
#   'spread': 0.05,
#   'funding_rate': 0.082993,
#   'open_interest': 86560397.55,
#   'volume_24h': 526374149.5580629,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'XRPUSD_PERP',
#   'index_id': 'XRP',
#   'price': '1.58',
#   'price_percentage_change_24h': -3.20786997433704,
#   'contract_type': 'perpetual',
#   'index': 1.58154618,
#   'basis': -0.1612158323338173,
#   'spread': 0.02,
#   'funding_rate': 0.01,
#   'open_interest': 85413640.0,
#   'volume_24h': 1065737362.2158114,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'SUSHI-PERP',
#   'index_id': 'SUSHI',
#   'price': '16.52',
#   'price_percentage_change_24h': 15.437446725263055,
#   'contract_type': 'perpetual',
#   'index': 16.48732032548733,
#   'basis': -0.21050395841127945,
#   'spread': 0.01,
#   'funding_rate': 0.1488,
#   'open_interest': 79560850.78,
#   'volume_24h': 240955083.91845,
#   'last_traded_at': 1620371082,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'DOT-USD',
#   'index_id': 'DOT',
#   'price': '40.22',
#   'price_percentage_change_24h': 3.976043446455759,
#   'contract_type': 'perpetual',
#   'index': 40.21032098816458,
#   'basis': -0.03624374910918361,
#   'spread': 0.02,
#   'funding_rate': 0.0459735592657581,
#   'open_interest': 77069650.0,
#   'volume_24h': 370915643.933672,
#   'last_traded_at': 1620371256,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'SXPUSDT',
#   'index_id': 'SXP',
#   'price': '4.79',
#   'price_percentage_change_24h': -6.102926733451189,
#   'contract_type': 'perpetual',
#   'index': 4.77157352,
#   'basis': -0.18255088592766144,
#   'spread': 0.02,
#   'funding_rate': 0.041286,
#   'open_interest': 75307373.36,
#   'volume_24h': 315876364.3169664,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Bitforex (Futures)',
#   'symbol': 'SWAP-USD-XRP',
#   'index_id': 'XRP',
#   'price': '1.58',
#   'price_percentage_change_24h': -3.610771113831089,
#   'contract_type': 'perpetual',
#   'index': 1.576,
#   'basis': 0.06349206349206349,
#   'spread': 0.13,
#   'funding_rate': 0.028,
#   'open_interest': 74869211.0,
#   'volume_24h': 19104372.0,
#   'last_traded_at': 1620371331,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'LTC-USD',
#   'index_id': 'LTC',
#   'price': '359.38',
#   'price_percentage_change_24h': 7.773046242427878,
#   'contract_type': 'perpetual',
#   'index': 359.5834480875,
#   'basis': 0.05661085410985586,
#   'spread': 0.01,
#   'funding_rate': 0.0102630554648726,
#   'open_interest': 74813030.0,
#   'volume_24h': 637240241.2638508,
#   'last_traded_at': 1620371252,
#   'expired_at': None},
#  {'market': 'Bybit',
#   'symbol': 'EOSUSD',
#   'index_id': 'EOS',
#   'price': '11.72',
#   'price_percentage_change_24h': 32.804532577903686,
#   'contract_type': 'perpetual',
#   'index': 11.69,
#   'basis': -0.25597269624573377,
#   'spread': 0.02,
#   'funding_rate': 0.0297,
#   'open_interest': 74667380.0,
#   'volume_24h': 2220538595.67248,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'DOGE-USD',
#   'index_id': 'DOGE',
#   'price': '0.64',
#   'price_percentage_change_24h': 6.5223424,
#   'contract_type': 'perpetual',
#   'index': 0.6410305536124986,
#   'basis': 0.0055466286786324,
#   'spread': 0.01,
#   'funding_rate': 0.019951471136647,
#   'open_interest': 73302090.0,
#   'volume_24h': 1455417105.991743,
#   'last_traded_at': 1620371360,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'TRX-PERP',
#   'index_id': 'TRX',
#   'price': '0.16',
#   'price_percentage_change_24h': 12.6831176,
#   'contract_type': 'perpetual',
#   'index': 0.1580028587806202,
#   'basis': -0.2853436113595658,
#   'spread': 0.01,
#   'funding_rate': 0.1104,
#   'open_interest': 72497267.12,
#   'volume_24h': 402950094.2118125,
#   'last_traded_at': 1620371344,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'XBTUSDM',
#   'index_id': 'BXBT',
#   'price': '56136.0',
#   'price_percentage_change_24h': -1.238564391273751,
#   'contract_type': 'perpetual',
#   'index': 56112.39,
#   'basis': -0.042058572039333046,
#   'spread': 0.03,
#   'funding_rate': 0.01,
#   'open_interest': 72024154.0,
#   'volume_24h': 38035246.0,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'SUSHIUSDT',
#   'index_id': 'SUSHI',
#   'price': '16.53',
#   'price_percentage_change_24h': 15.798824462967774,
#   'contract_type': 'perpetual',
#   'index': 16.47687976,
#   'basis': -0.08017076912814355,
#   'spread': 0.05,
#   'funding_rate': 0.081441,
#   'open_interest': 70551695.21,
#   'volume_24h': 515113103.17110616,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Prime XBT',
#   'symbol': 'ETH/USD',
#   'index_id': 'ETH',
#   'price': '3431.66',
#   'price_percentage_change_24h': 0.2978252037866765,
#   'contract_type': 'perpetual',
#   'index': None,
#   'basis': 0.0,
#   'spread': 0.03,
#   'funding_rate': 0.0,
#   'open_interest': 68144705.0,
#   'volume_24h': 349312909.5001,
#   'last_traded_at': 1620371274,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'LTCUSD_PERP',
#   'index_id': 'LTC',
#   'price': '360.89',
#   'price_percentage_change_24h': 7.96039248534163,
#   'contract_type': 'perpetual',
#   'index': 360.39051571,
#   'basis': -0.13840347197206906,
#   'spread': 0.02,
#   'funding_rate': 0.058466,
#   'open_interest': 67893360.0,
#   'volume_24h': 787000605.449934,
#   'last_traded_at': 1620371414,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'ETC-USDT',
#   'index_id': 'ETC',
#   'price': '131.45',
#   'price_percentage_change_24h': 42.45886114055176,
#   'contract_type': 'perpetual',
#   'index': 131.20235200825,
#   'basis': -0.09034959507618735,
#   'spread': 0.02,
#   'funding_rate': 0.245189343407026,
#   'open_interest': 66226017.25,
#   'volume_24h': 6683994841.351311,
#   'last_traded_at': 1620371359,
#   'expired_at': None},
#  {'market': 'Phemex (Futures)',
#   'symbol': 'DOTUSD',
#   'index_id': 'DOT',
#   'price': '40.24',
#   'price_percentage_change_24h': 4.03857589782041,
#   'contract_type': 'perpetual',
#   'index': 40.2342,
#   'basis': -0.011928725862968762,
#   'spread': 0.1,
#   'funding_rate': 0.190817,
#   'open_interest': 64435998.35,
#   'volume_24h': 1838649.0,
#   'last_traded_at': 1620371167,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'VETUSDT',
#   'index_id': 'VET',
#   'price': '0.23',
#   'price_percentage_change_24h': 14.1608656,
#   'contract_type': 'perpetual',
#   'index': 0.2338979,
#   'basis': -0.191213,
#   'spread': 0.02,
#   'funding_rate': 0.094871,
#   'open_interest': 64064793.01,
#   'volume_24h': 965048621.4447436,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'AAVEUSDT',
#   'index_id': 'AAVE',
#   'price': '443.45',
#   'price_percentage_change_24h': -3.7034461174670517,
#   'contract_type': 'perpetual',
#   'index': 442.40253209,
#   'basis': -0.15109686687490972,
#   'spread': 0.01,
#   'funding_rate': 0.079398,
#   'open_interest': 60117394.37,
#   'volume_24h': 222450664.21874985,
#   'last_traded_at': 1620371412,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'MATIC-PERP',
#   'index_id': 'MATIC',
#   'price': '0.77',
#   'price_percentage_change_24h': -0.165406,
#   'contract_type': 'perpetual',
#   'index': 0.7653299667404534,
#   'basis': -0.1575308787302122,
#   'spread': 0.04,
#   'funding_rate': 0.1416,
#   'open_interest': 60084434.84,
#   'volume_24h': 97230934.74246,
#   'last_traded_at': 1620371083,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'FILUSD_PERP',
#   'index_id': 'FIL',
#   'price': '152.67',
#   'price_percentage_change_24h': -3.3182618387223424,
#   'contract_type': 'perpetual',
#   'index': 152.40721193,
#   'basis': -0.17474361711882835,
#   'spread': 0.01,
#   'funding_rate': 0.057435,
#   'open_interest': 59217150.0,
#   'volume_24h': 254527966.2958708,
#   'last_traded_at': 1620371414,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'COMP-PERP',
#   'index_id': 'COMP',
#   'price': '719.22',
#   'price_percentage_change_24h': -4.4467177722568385,
#   'contract_type': 'perpetual',
#   'index': 717.3609487213238,
#   'basis': -0.2584815882033592,
#   'spread': 0.02,
#   'funding_rate': 0.1776,
#   'open_interest': 59208570.01,
#   'volume_24h': 22750520.322241,
#   'last_traded_at': 1620371340,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'FIL-PERP',
#   'index_id': 'FIL',
#   'price': '152.19',
#   'price_percentage_change_24h': -3.4664298626748278,
#   'contract_type': 'perpetual',
#   'index': 152.02830502942956,
#   'basis': -0.10624546328300151,
#   'spread': 0.03,
#   'funding_rate': 0.0264,
#   'open_interest': 58191414.06,
#   'volume_24h': 37697608.847,
#   'last_traded_at': 1620371345,
#   'expired_at': None},
#  {'market': 'BitMEX',
#   'symbol': 'XRPUSD',
#   'index_id': 'BXRP',
#   'price': '1.59',
#   'price_percentage_change_24h': -1.1100086816321468,
#   'contract_type': 'perpetual',
#   'index': 1.59525,
#   'basis': 0.034489245626136575,
#   'spread': 0.03,
#   'funding_rate': 0.1425,
#   'open_interest': 57245233.53,
#   'volume_24h': 235355804.63403666,
#   'last_traded_at': 1620370692,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'EOS-USDT',
#   'index_id': 'EOS',
#   'price': '11.65',
#   'price_percentage_change_24h': 32.943422978412,
#   'contract_type': 'perpetual',
#   'index': 11.59010932872,
#   'basis': -0.3147124401592885,
#   'spread': 0.03,
#   'funding_rate': 0.0926593224263624,
#   'open_interest': 54556092.81,
#   'volume_24h': 2574834388.776396,
#   'last_traded_at': 1620371252,
#   'expired_at': None},
#  {'market': 'ZBG Futures',
#   'symbol': 'EOS_USDT',
#   'index_id': 'EOS',
#   'price': '11.71',
#   'price_percentage_change_24h': 34.48037748877891,
#   'contract_type': 'perpetual',
#   'index': 11.685560530000002,
#   'basis': 0.0047970047068891745,
#   'spread': 0.1,
#   'funding_rate': 0.01,
#   'open_interest': 54525215.65,
#   'volume_24h': 1605157.6248885521,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'XLM-USDT',
#   'index_id': 'XLM',
#   'price': '0.64',
#   'price_percentage_change_24h': 3.8196808,
#   'contract_type': 'perpetual',
#   'index': 0.6334306908416667,
#   'basis': -0.1548374888807922,
#   'spread': 0.06,
#   'funding_rate': 0.064432509452531,
#   'open_interest': 53656357.06,
#   'volume_24h': 83691805.00225236,
#   'last_traded_at': 1620371253,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'XRPUSDTM',
#   'index_id': 'KXRPUSDT',
#   'price': '1.59',
#   'price_percentage_change_24h': -2.658072437077962,
#   'contract_type': 'perpetual',
#   'index': 1.5845,
#   'basis': -0.07567635744466167,
#   'spread': 0.04,
#   'funding_rate': 0.0386,
#   'open_interest': 53354766.5,
#   'volume_24h': 54651518.304574475,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'ZBG Futures',
#   'symbol': 'LTC_USDT',
#   'index_id': 'LTC',
#   'price': '361.07',
#   'price_percentage_change_24h': 8.476566027512717,
#   'contract_type': 'perpetual',
#   'index': 360.13131579,
#   'basis': -0.06623309653966757,
#   'spread': 0.05,
#   'funding_rate': 0.011496219478923,
#   'open_interest': 52325753.74,
#   'volume_24h': 2711778.9960677824,
#   'last_traded_at': 1620371166,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'AAVE-PERP',
#   'index_id': 'AAVE',
#   'price': '445.59',
#   'price_percentage_change_24h': -3.191535587033979,
#   'contract_type': 'perpetual',
#   'index': 444.274974085071,
#   'basis': -0.2951201586501044,
#   'spread': 0.01,
#   'funding_rate': 0.1752,
#   'open_interest': 52042309.75,
#   'volume_24h': 69067780.0255,
#   'last_traded_at': 1620371082,
#   'expired_at': None},
#  {'market': 'Binance (Futures)',
#   'symbol': 'ADAUSD_PERP',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 10.934671040988851,
#   'contract_type': 'perpetual',
#   'index': 1.62694985,
#   'basis': -0.1767147493910408,
#   'spread': 0.01,
#   'funding_rate': 0.038923,
#   'open_interest': 51994760.0,
#   'volume_24h': 1035565925.8157394,
#   'last_traded_at': 1620371414,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'LTC-USD-SWAP',
#   'index_id': 'OkexSwap-LTC',
#   'price': '361.33',
#   'price_percentage_change_24h': 8.758992264395149,
#   'contract_type': 'perpetual',
#   'index': 361.24381895,
#   'basis': -0.023851064124207788,
#   'spread': 0.01,
#   'funding_rate': 0.007296,
#   'open_interest': 51936380.0,
# ...
#   'index': 466.15041407071504,
#   'basis': -0.11776000198950075,
#   'spread': 0.53,
#   'funding_rate': -0.0216,
#   'open_interest': None,
#   'volume_24h': 4592657.63675,
#   'last_traded_at': 1620371344,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'ONTUSDTM',
#   'index_id': 'KONTUSDT',
#   'price': '2.73',
#   'price_percentage_change_24h': 28.909728142464715,
#   'contract_type': 'perpetual',
#   'index': 2.7182,
#   'basis': -0.1322654125946065,
#   'spread': 0.16,
#   'funding_rate': 0.0553,
#   'open_interest': None,
#   'volume_24h': 4498794.3841482885,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'PERP-PERP',
#   'index_id': 'PERP',
#   'price': '7.91',
#   'price_percentage_change_24h': -6.757872390612101,
#   'contract_type': 'perpetual',
#   'index': 7.895,
#   'basis': -0.13913483430306098,
#   'spread': 0.24,
#   'funding_rate': 0.06,
#   'open_interest': None,
#   'volume_24h': 4481730.4246,
#   'last_traded_at': 1620371083,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'ONE-USDT',
#   'index_id': 'ONE',
#   'price': '0.13',
#   'price_percentage_change_24h': 0.9405562,
#   'contract_type': 'perpetual',
#   'index': 0.129239940544,
#   'basis': -0.145300441944556,
#   'spread': 0.03,
#   'funding_rate': 0.0266798848103404,
#   'open_interest': None,
#   'volume_24h': 4467484.986297817,
#   'last_traded_at': 1620371258,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'FLM-USDT-SWAP',
#   'index_id': 'OkexSwap-FLM',
#   'price': '1.09',
#   'price_percentage_change_24h': 10.977719,
#   'contract_type': 'perpetual',
#   'index': 1.08153333,
#   'basis': 0.04933672525439408,
#   'spread': 0.19,
#   'funding_rate': 0.015782,
#   'open_interest': None,
#   'volume_24h': 4452534.624262142,
#   'last_traded_at': 1620370397,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'AAVEUSDTM',
#   'index_id': 'KAAVEUSDT',
#   'price': '445.83',
#   'price_percentage_change_24h': -3.183964830573027,
#   'contract_type': 'perpetual',
#   'index': 444.16,
#   'basis': -0.1573528750618172,
#   'spread': 0.18,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 4317583.962974593,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'Gate.io (Futures)',
#   'symbol': 'ADA_USDT',
#   'index_id': 'ADA',
#   'price': '1.63',
#   'price_percentage_change_24h': 10.938647803019997,
#   'contract_type': 'perpetual',
#   'index': 1.6241,
#   'basis': -0.42427438044904414,
#   'spread': None,
#   'funding_rate': 0.11,
#   'open_interest': None,
#   'volume_24h': 4136811.987371843,
#   'last_traded_at': 1620371301,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'MANAUSDTM',
#   'index_id': 'KMANAUSDT',
#   'price': '1.51',
#   'price_percentage_change_24h': 8.028673835125447,
#   'contract_type': 'perpetual',
#   'index': 1.503,
#   'basis': -0.26542800265428,
#   'spread': 0.26,
#   'funding_rate': 0.0181,
#   'open_interest': None,
#   'volume_24h': 4093499.886764715,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'CRVUSDTM',
#   'index_id': 'KCRVUSDT',
#   'price': '3.22',
#   'price_percentage_change_24h': 2.096569250317662,
#   'contract_type': 'perpetual',
#   'index': 3.206,
#   'basis': -0.24891101431238333,
#   'spread': 0.09,
#   'funding_rate': 0.0169,
#   'open_interest': None,
#   'volume_24h': 3993815.3456757613,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'SAND-USDT',
#   'index_id': 'SAND',
#   'price': '0.54',
#   'price_percentage_change_24h': -6.1189206,
#   'contract_type': 'perpetual',
#   'index': 0.5395588648416667,
#   'basis': -0.1362468944434614,
#   'spread': 0.11,
#   'funding_rate': 0.194162529569874,
#   'open_interest': None,
#   'volume_24h': 3982463.5920818006,
#   'last_traded_at': 1620371258,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'LUNA-USDT',
#   'index_id': 'LUNA',
#   'price': '16.52',
#   'price_percentage_change_24h': -3.732049036777583,
#   'contract_type': 'perpetual',
#   'index': 16.4587887839,
#   'basis': -0.19351037918341854,
#   'spread': 0.08,
#   'funding_rate': 0.0965758834974457,
#   'open_interest': None,
#   'volume_24h': 3935343.9992875536,
#   'last_traded_at': 1620371256,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'MASK-USDT',
#   'index_id': 'MASK',
#   'price': '13.3',
#   'price_percentage_change_24h': -0.5842259006815969,
#   'contract_type': 'perpetual',
#   'index': 13.2441,
#   'basis': -0.21773525201536956,
#   'spread': 0.09,
#   'funding_rate': 0.170742764177575,
#   'open_interest': None,
#   'volume_24h': 3897182.664005913,
#   'last_traded_at': 1620371254,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'SXPUSDTM',
#   'index_id': 'KSXPUSDT',
#   'price': '4.78',
#   'price_percentage_change_24h': -6.0236220472440944,
#   'contract_type': 'perpetual',
#   'index': 4.766,
#   'basis': -0.16757436112274823,
#   'spread': 0.08,
#   'funding_rate': 0.1073,
#   'open_interest': None,
#   'volume_24h': 3878393.6030626167,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'FILUSDTM',
#   'index_id': 'KFILUSDT',
#   'price': '153.09',
#   'price_percentage_change_24h': -2.7563816920236808,
#   'contract_type': 'perpetual',
#   'index': 152.46,
#   'basis': -0.19638648860958366,
#   'spread': 0.02,
#   'funding_rate': 0.0734,
#   'open_interest': None,
#   'volume_24h': 3867937.9416637393,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'IOSTUSDTM',
#   'index_id': 'KIOSTUSDT',
#   'price': '0.07',
#   'price_percentage_change_24h': 9.7840314,
#   'contract_type': 'perpetual',
#   'index': 0.06697,
#   'basis': -0.1937407,
#   'spread': 0.03,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 3833356.0446459036,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'BAND-USDT',
#   'index_id': 'BAND',
#   'price': '18.22',
#   'price_percentage_change_24h': -3.4710647288015033,
#   'contract_type': 'perpetual',
#   'index': 18.1294415439,
#   'basis': -0.303873344624877,
#   'spread': 0.12,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 3828961.7328026025,
#   'last_traded_at': 1620371257,
#   'expired_at': None},
#  {'market': 'Delta Exchange (Futures)',
#   'symbol': 'ETHUSDT',
#   'index_id': 'DEETHUSDT',
#   'price': '3454.69',
#   'price_percentage_change_24h': 1.3892976982398304,
#   'contract_type': 'perpetual',
#   'index': 3441.3,
#   'basis': -0.09580212506531963,
#   'spread': 0.01,
#   'funding_rate': 0.0175,
#   'open_interest': None,
#   'volume_24h': 3782537.5791937876,
#   'last_traded_at': 1620370722,
#   'expired_at': None},
#  {'market': 'MXC (Futures)',
#   'symbol': 'KAVA_USDT',
#   'index_id': 'KAVA',
#   'price': '6.36',
#   'price_percentage_change_24h': -1.5932056289132726,
#   'contract_type': 'perpetual',
#   'index': 6.3686,
#   'basis': 0.2992314476502457,
#   'spread': 0.84,
#   'funding_rate': 0.06,
#   'open_interest': None,
#   'volume_24h': 3730602.4731195155,
#   'last_traded_at': 1620371190,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'KNC-USDT',
#   'index_id': 'KNC',
#   'price': '3.53',
#   'price_percentage_change_24h': 9.858584600049838,
#   'contract_type': 'perpetual',
#   'index': 3.5178107569333332,
#   'basis': -0.25771195856607787,
#   'spread': 0.14,
#   'funding_rate': 0.0660176881198132,
#   'open_interest': None,
#   'volume_24h': 3651176.622251806,
#   'last_traded_at': 1620371253,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'SC-USDT-SWAP',
#   'index_id': 'OkexSwap-SC',
#   'price': '0.04',
#   'price_percentage_change_24h': -1.4139444,
#   'contract_type': 'perpetual',
#   'index': 0.04037211,
#   'basis': -0.1678783,
#   'spread': 0.12,
#   'funding_rate': 0.000583,
#   'open_interest': None,
#   'volume_24h': 3598578.4619697044,
#   'last_traded_at': 1620371176,
#   'expired_at': None},
#  {'market': 'BitMEX',
#   'symbol': 'UNIUSDT',
#   'index_id': 'BUNIT',
#   'price': '40.14',
#   'price_percentage_change_24h': -3.318840579710145,
#   'contract_type': 'perpetual',
#   'index': 39.902,
#   'basis': -0.30979863088992154,
#   'spread': 0.02,
#   'funding_rate': 0.1318,
#   'open_interest': None,
#   'volume_24h': 3597107.090539241,
#   'last_traded_at': 1620370692,
#   'expired_at': None},
#  {'market': 'OKEx (Futures)',
#   'symbol': 'SRM-USDT-SWAP',
#   'index_id': 'OkexSwap-SRM',
#   'price': '10.21',
#   'price_percentage_change_24h': -2.3875731134336946,
#   'contract_type': 'perpetual',
#   'index': 10.18396666,
#   'basis': 0.23589232283464567,
#   'spread': 0.13,
#   'funding_rate': 0.091516,
#   'open_interest': None,
#   'volume_24h': 3584913.375534626,
#   'last_traded_at': 1620370742,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'WAVESUSDTM',
#   'index_id': 'KWAVESUSDT',
#   'price': '34.02',
#   'price_percentage_change_24h': 1.2014429240079898,
#   'contract_type': 'perpetual',
#   'index': 33.657,
#   'basis': -0.8513521475284275,
#   'spread': 0.12,
#   'funding_rate': 0.0166,
#   'open_interest': None,
#   'volume_24h': 3489317.219430208,
#   'last_traded_at': 1620371047,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'KSMUSDTM',
#   'index_id': 'KKSMUSDT',
#   'price': '438.16',
#   'price_percentage_change_24h': 4.638361016705758,
#   'contract_type': 'perpetual',
#   'index': 435.459,
#   'basis': -0.3982159194876487,
#   'spread': 0.11,
#   'funding_rate': 0.049,
#   'open_interest': None,
#   'volume_24h': 3410936.976307625,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'BNT-PERP',
#   'index_id': 'BNT',
#   'price': '7.49',
#   'price_percentage_change_24h': 0.590564391651567,
#   'contract_type': 'perpetual',
#   'index': 7.488263404131424,
#   'basis': -0.08321563638102608,
#   'spread': 0.1,
#   'funding_rate': -0.036,
#   'open_interest': None,
#   'volume_24h': 3376292.05345,
#   'last_traded_at': 1620371137,
#   'expired_at': None},
#  {'market': 'Stormgain Futures',
#   'symbol': 'NEO-PERPUSDT',
#   'index_id': 'NEO',
#   'price': '128.08',
#   'price_percentage_change_24h': 13.092050024305095,
#   'contract_type': 'perpetual',
#   'index': 127.958,
#   'basis': 0.0,
#   'spread': 0.2,
#   'funding_rate': 0.004,
#   'open_interest': None,
#   'volume_24h': 3367060.751111118,
#   'last_traded_at': 1620371357,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'HBAR-PERP',
#   'index_id': 'HBAR',
#   'price': '0.3',
#   'price_percentage_change_24h': -0.5574684,
#   'contract_type': 'perpetual',
#   'index': 0.30329871521916085,
#   'basis': 0.0160643756507502,
#   'spread': 0.3,
#   'funding_rate': 0.2664,
#   'open_interest': None,
#   'volume_24h': 3343597.47385,
#   'last_traded_at': 1620371085,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'SKL-PERP',
#   'index_id': 'SKL',
#   'price': '0.61',
#   'price_percentage_change_24h': -5.5401235,
#   'contract_type': 'perpetual',
#   'index': 0.6110492681231485,
#   'basis': -0.1716601661250613,
#   'spread': 0.47,
#   'funding_rate': 0.4104,
#   'open_interest': None,
#   'volume_24h': 3307845.4401,
#   'last_traded_at': 1620371344,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'REEF-PERP',
#   'index_id': 'REEF',
#   'price': '0.04',
#   'price_percentage_change_24h': -1.6276704,
#   'contract_type': 'perpetual',
#   'index': 0.038646300530464764,
#   'basis': -0.0871237578470527,
#   'spread': 0.22,
#   'funding_rate': 0.1344,
#   'open_interest': None,
#   'volume_24h': 3302966.63895,
#   'last_traded_at': 1620371339,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'DENT-PERP',
#   'index_id': 'DENT',
#   'price': '0.01',
#   'price_percentage_change_24h': 0.1131687,
#   'contract_type': 'perpetual',
#   'index': 0.009674761007099845,
#   'basis': -0.5779364186636009,
#   'spread': 0.26,
#   'funding_rate': 0.4416,
#   'open_interest': None,
#   'volume_24h': 3269501.7805,
#   'last_traded_at': 1620371141,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'RSR-USD',
#   'index_id': 'RSR',
#   'price': '0.08',
#   'price_percentage_change_24h': -3.0214011,
#   'contract_type': 'perpetual',
#   'index': 0.010489096971477038,
#   'basis': -0.4451692152900532,
#   'spread': 0.24,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 3238943.5842341813,
#   'last_traded_at': 1620371255,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'AKRO-USDT',
#   'index_id': 'AKRO',
#   'price': '0.05',
#   'price_percentage_change_24h': -1.7094017,
#   'contract_type': 'perpetual',
#   'index': 0.05020901687333333,
#   'basis': -0.7726939262187154,
#   'spread': 0.12,
#   'funding_rate': 0.0657268443699469,
#   'open_interest': None,
#   'volume_24h': 3235611.802965499,
#   'last_traded_at': 1620371256,
#   'expired_at': None},
#  {'market': 'BigONE Futures',
#   'symbol': 'FILUSDT',
#   'index_id': 'FIL',
#   'price': '152.91',
#   'price_percentage_change_24h': -2.9692268565615465,
#   'contract_type': 'perpetual',
#   'index': 152.3133,
#   'basis': -0.19441714173383134,
#   'spread': 0.33,
#   'funding_rate': 0.01,
#   'open_interest': None,
#   'volume_24h': 3215762.884772909,
#   'last_traded_at': 1620371175,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'LRC-PERP',
#   'index_id': 'LRC',
#   'price': '0.6',
#   'price_percentage_change_24h': 5.4726807,
#   'contract_type': 'perpetual',
#   'index': 0.5971051012499856,
#   'basis': -0.0577284710041677,
#   'spread': 0.32,
#   'funding_rate': 0.1032,
#   'open_interest': None,
#   'volume_24h': 3214448.28765,
#   'last_traded_at': 1620371339,
#   'expired_at': None},
#  {'market': 'Gate.io (Futures)',
#   'symbol': 'MATIC_USDT',
#   'index_id': 'MATIC',
#   'price': '0.76',
#   'price_percentage_change_24h': -2.7997267,
#   'contract_type': 'perpetual',
#   'index': 0.752924,
#   'basis': -0.1519753,
#   'spread': None,
#   'funding_rate': 0.0267,
#   'open_interest': None,
#   'volume_24h': 3208961.3164621997,
#   'last_traded_at': 1620371301,
#   'expired_at': None},
#  {'market': 'Stormgain Futures',
#   'symbol': 'XLM-PERPUSDT',
#   'index_id': 'XLM',
#   'price': '0.63',
#   'price_percentage_change_24h': 3.3666345,
#   'contract_type': 'perpetual',
#   'index': 0.63218,
#   'basis': 0.0,
#   'spread': 0.31,
#   'funding_rate': 0.004,
#   'open_interest': None,
#   'volume_24h': 3140371.283782314,
#   'last_traded_at': 1620371357,
#   'expired_at': None},
#  {'market': 'Huobi Futures',
#   'symbol': 'LRC-USDT',
#   'index_id': 'LRC',
#   'price': '0.6',
#   'price_percentage_change_24h': 5.9078725,
#   'contract_type': 'perpetual',
#   'index': 0.5978655677611111,
#   'basis': -0.4453379023693509,
#   'spread': 0.13,
#   'funding_rate': 0.0661458542618858,
#   'open_interest': None,
#   'volume_24h': 3136648.55987283,
#   'last_traded_at': 1620371255,
#   'expired_at': None},
#  {'market': 'MXC (Futures)',
#   'symbol': 'BTS_USDT',
#   'index_id': 'BTS',
#   'price': '0.14',
#   'price_percentage_change_24h': 8.2972471,
#   'contract_type': 'perpetual',
#   'index': 0.14013,
#   'basis': 0.0571225,
#   'spread': 0.79,
#   'funding_rate': 0.09,
#   'open_interest': None,
#   'volume_24h': 3131775.995145763,
#   'last_traded_at': 1620371406,
#   'expired_at': None},
#  {'market': 'FTX (Derivatives)',
#   'symbol': 'PROM-PERP',
#   'index_id': 'PROM',
#   'price': '33.47',
#   'price_percentage_change_24h': -12.3592563498298,
#   'contract_type': 'perpetual',
#   'index': 33.34508688379153,
#   'basis': -0.37320919094254557,
#   'spread': 0.46,
#   'funding_rate': 0.204,
#   'open_interest': None,
#   'volume_24h': 3109696.22495,
#   'last_traded_at': 1620371119,
#   'expired_at': None},
#  {'market': 'KuCoin Futures',
#   'symbol': 'CHZUSDTM',
#   'index_id': 'KCHZUSDT',
#   'price': '0.51',
#   'price_percentage_change_24h': 0.0987362,
#   'contract_type': 'perpetual',
#   'index': 0.5064,
#   'basis': -0.0986388,
#   'spread': 0.08,
#   'funding_rate': 0.0503,
#   'open_interest': None,
#   'volume_24h': 3103465.1406529746,
#   'last_traded_at': 1620371048,
#   'expired_at': None},
#  {'market': 'Bitfinex (Futures)',
#   'symbol': 'LINKF0:USTF0',
#   'index_id': 'LINK',
#   'price': '46.62',
#   'price_percentage_change_24h': -0.038593481989708404,
#   'contract_type': 'perpetual',
#   'index': 46.608475,
#   'basis': -0.02900990948479259,
#   'spread': 0.11,
#   'funding_rate': 0.0,
#   'open_interest': None,
#   'volume_24h': 3067087.3357857084,
#   'last_traded_at': 1620371358,
#   'expired_at': None},
#  ...]

# %%
cg.get_derivatives_exchanges()
# Out:
# [{'name': 'Binance (Futures)',
#   'id': 'binance_futures',
#   'open_interest_btc': 213853.24,
#   'trade_volume_24h_btc': '2137542.37',
#   'number_of_perpetual_pairs': 130,
#   'number_of_futures_pairs': 32,
#   'image': 'https://assets.coingecko.com/markets/images/466/small/binance_futures.jpg?1568609512',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://www.binance.com/'},
#  {'name': 'Huobi Futures',
#   'id': 'huobi_dm',
#   'open_interest_btc': 159111.17,
#   'trade_volume_24h_btc': '974284.69',
#   'number_of_perpetual_pairs': 156,
#   'number_of_futures_pairs': 56,
#   'image': 'https://assets.coingecko.com/markets/images/433/small/huobifutures.png?1589963675',
#   'year_established': None,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.hbdm.com/en-us/'},
#  {'name': 'FTX (Derivatives)',
#   'id': 'ftx',
#   'open_interest_btc': 129094.05,
#   'trade_volume_24h_btc': '328932.81',
#   'number_of_perpetual_pairs': 139,
#   'number_of_futures_pairs': 445,
#   'image': 'https://assets.coingecko.com/markets/images/443/small/F.png?1609051598',
#   'year_established': 2019,
#   'country': 'Antigua and Barbuda',
#   'description': '',
#   'url': 'https://ftx.com/'},
#  {'name': 'Bybit',
#   'id': 'bybit',
#   'open_interest_btc': 79149.7,
#   'trade_volume_24h_btc': '317762.03',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 2,
#   'image': 'https://assets.coingecko.com/markets/images/460/small/bybit.png?1586533756',
#   'year_established': 2018,
#   'country': None,
#   'description': 'Established in March 2018, Bybit is one of the fastest growing cryptocurrency derivatives exchanges, with more than 1.6 million registered users. Built on customer-centric values, we endeavor to provide a professional, smart, intuitive and innovative trading experience for retail and professional clients around the world. Bybit is committed to creating a fair, transparent and efficient trading environment, and offer 24/7 multi-language customer support to provide assistance in a timely manner.\r\n\r\nDerivatives products currently offered on the Bybit platform are inverse perpetual contracts (BTCUSD, ETHUSD, XRPUSD, EOSUSD), linear perpetual contracts (BTCUSDT, ETHUSDT, BCHLINK, LINKUSDT, LTCUSDT, XTZUSDT, ADAUSDT, DOTUSDT, UNIUSDT) and inverse futures contracts (BTCUSD quarterly).',
#   'url': 'https://www.bybit.com/'},
#  {'name': 'OKEx (Futures)',
#   'id': 'okex_swap',
#   'open_interest_btc': 58318.72,
#   'trade_volume_24h_btc': '893051.36',
#   'number_of_perpetual_pairs': 132,
#   'number_of_futures_pairs': 1144,
#   'image': 'https://assets.coingecko.com/markets/images/379/small/okex_futures.jpg?1553504644',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://www.okex.com/futureTrade'},
#  {'name': 'MXC (Futures)',
#   'id': 'mxc_futures',
#   'open_interest_btc': 45274.1,
#   'trade_volume_24h_btc': '192379.59',
#   'number_of_perpetual_pairs': 115,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/551/small/MXC.png?1596090278',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': ''},
#  {'name': 'Hopex',
#   'id': 'hopex',
#   'open_interest_btc': 40518.18,
#   'trade_volume_24h_btc': '317361.38',
#   'number_of_perpetual_pairs': 11,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/515/small/hopexlogo.jpg?1584089974',
#   'year_established': 2020,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://web.hopex.com/home'},
#  {'name': 'BitMEX',
#   'id': 'bitmex',
#   'open_interest_btc': 39696.16,
#   'trade_volume_24h_btc': '64940.78',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 75,
#   'image': 'https://assets.coingecko.com/markets/images/378/small/BitMEX.png?1591671734',
#   'year_established': None,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.bitmex.com/'},
#  {'name': 'Deribit',
#   'id': 'deribit',
#   'open_interest_btc': 38068.07,
#   'trade_volume_24h_btc': '29921.65',
#   'number_of_perpetual_pairs': 2,
#   'number_of_futures_pairs': 43,
#   'image': 'https://assets.coingecko.com/markets/images/402/small/deribit_logo_on_light_bg.png?1557215233',
#   'year_established': 2014,
#   'country': 'Netherlands',
#   'description': '',
#   'url': 'https://www.deribit.com'},
#  {'name': 'Bitfinex (Futures)',
#   'id': 'bitfinex_futures',
#   'open_interest_btc': 33466.16,
#   'trade_volume_24h_btc': '4358.7',
#   'number_of_perpetual_pairs': 23,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/486/small/BItfinex.png?1615895876',
#   'year_established': 2019,
#   'country': 'British Virgin Islands',
#   'description': '',
#   'url': 'https://www.bitfinex.com/'},
#  {'name': 'KuCoin Futures',
#   'id': 'kumex',
#   'open_interest_btc': 21137.31,
#   'trade_volume_24h_btc': '21205.07',
#   'number_of_perpetual_pairs': 62,
#   'number_of_futures_pairs': 6,
#   'image': 'https://assets.coingecko.com/markets/images/471/small/kucoin_futures.jpg?1591611212',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://futures.kucoin.com/trade'},
#  {'name': 'Bitget Futures',
#   'id': 'bitget_futures',
#   'open_interest_btc': 18306.74,
#   'trade_volume_24h_btc': '146910.12',
#   'number_of_perpetual_pairs': 32,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/591/small/2_FuOREOGSIVp7ApVa506XTw.png?1604996661',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': ''},
#  {'name': 'BTSE (Futures)',
#   'id': 'btse_futures',
#   'open_interest_btc': 17867.01,
#   'trade_volume_24h_btc': '18929.0',
#   'number_of_perpetual_pairs': 12,
#   'number_of_futures_pairs': 120,
#   'image': 'https://assets.coingecko.com/markets/images/465/small/BTSE.jpg?1569554722',
#   'year_established': 2018,
#   'country': 'United Arab Emirates',
#   'description': 'BTSE is your Bitcoin futures exchange to trade with confidence and ease.\r\n\r\nBTSE‘s mission is to make institutional-grade security and stability available to every crypto trader.\r\n\r\nBTSE’s platform is built to facilitate reliable 24/7 trading. It uses an extremely powerful matching engine that eliminates the risk of system overloads, as well as horizontal scaling which enables BTSE to do hot upgrades with zero downtime. BTSE’s insurance fund, strict security protocols, and self-hosted servers allow for the highest level of security for our traders.',
#   'url': 'https://www.btse.com/en/futures/'},
#  {'name': 'BitZ (Futures)',
#   'id': 'bitz_futures',
#   'open_interest_btc': 17313.81,
#   'trade_volume_24h_btc': '288590.33',
#   'number_of_perpetual_pairs': 25,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/482/small/bit-z-new-blue.png?1595917661',
#   'year_established': 2019,
#   'country': None,
#   'description': '',
#   'url': 'https://swap.bitz.top/trade/101'},
#  {'name': 'ZBG Futures',
#   'id': 'zbg_futures',
#   'open_interest_btc': 13905.98,
#   'trade_volume_24h_btc': '1582.32',
#   'number_of_perpetual_pairs': 16,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/534/small/zbg-exchange.jpg?1590997937',
#   'year_established': 2020,
#   'country': 'China',
#   'description': '',
#   'url': 'https://futures.zbg.com/'},
#  {'name': 'Gate.io (Futures)',
#   'id': 'gate_futures',
#   'open_interest_btc': 12980.12,
#   'trade_volume_24h_btc': '28632.84',
#   'number_of_perpetual_pairs': 140,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/403/small/gateio_futures.jpg?1557221803',
#   'year_established': None,
#   'country': 'Hong Kong',
#   'description': '',
#   'url': 'https://www.gate.io/futures_trade/BTC_USD'},
#  {'name': 'Bitforex (Futures)',
#   'id': 'bitforex_futures',
#   'open_interest_btc': 12508.75,
#   'trade_volume_24h_btc': '252192.76',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/454/small/BitForex-Logo.png?1573808221',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.bitforex.com/en/perpetual/btc_usd'},
#  {'name': 'Phemex (Futures)',
#   'id': 'phemex_futures',
#   'open_interest_btc': 8633.24,
#   'trade_volume_24h_btc': '24015.95',
#   'number_of_perpetual_pairs': 25,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/519/small/Phemex_Logo.png?1585314912',
#   'year_established': 2019,
#   'country': 'British Virgin Islands',
#   'description': 'Phemex is a global cryptocurrency derivatives exchange offering perpetual contracts trading for bitcoin, ethereum, and more. It allows up to 100x leverage and settlements are in BTC and USD.',
#   'url': 'https://www.phemex.com'},
#  {'name': 'MyCoinStory',
#   'id': 'mycoinstory',
#   'open_interest_btc': 7827.55,
#   'trade_volume_24h_btc': '13138.43',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 6,
#   'image': 'https://assets.coingecko.com/markets/images/585/small/mcs_new_v2_200.png?1605069492',
#   'year_established': 2019,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://mycoinstory.com'},
#  {'name': 'Prime XBT',
#   'id': 'prime_xbt',
#   'open_interest_btc': 5704.04,
#   'trade_volume_24h_btc': '17094.41',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/481/small/156a13457e1b779d5d8cddc58e06db21.png?1570470959',
#   'year_established': None,
#   'country': 'Seychelles',
#   'description': 'PrimeXBT is a technologically advanced Bitcoin-based trading platform suitable for both beginners and professional traders. PrimeXBT allows its users to actively trade most popular cryptocurrencies such as Bitcoin, Ethereum, Ripple, and more with 100x leverage, profit from market rallies and declines, or hedge existing holdings. The company provides access to real-time market data and a wide range of trading tools, enabling a safe and efficient trading environment for everyone.',
#   'url': 'https://primexbt.com'},
#  {'name': 'Kraken (Futures)',
#   'id': 'kraken_futures',
#   'open_interest_btc': 5451.76,
#   'trade_volume_24h_btc': '18914.14',
#   'number_of_perpetual_pairs': 5,
#   'number_of_futures_pairs': 107,
#   'image': 'https://assets.coingecko.com/markets/images/426/small/NX0D_EiD_400x400.jpg?1560770269',
#   'year_established': 2019,
#   'country': 'United States',
#   'description': 'Kraken Futures was previously known as Crypto Facilities. Crypto Facilities Ltd is an FCA authorised cryptocurrency derivatives platform based in London. Crypto Facilities became a part of the Kraken group of companies and rebranded to Kraken Futures in February 2019. They offer up to 50x leverage on 5 trading pairs. The most popular trading pair is the XBTUSD pair. ',
#   'url': 'https://futures.kraken.com/'},
#  {'name': 'BTCMEX',
#   'id': 'btcmex',
#   'open_interest_btc': 3486.11,
#   'trade_volume_24h_btc': '37776.65',
#   'number_of_perpetual_pairs': 2,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/522/small/BTCMEX.png?1585319571',
#   'year_established': 219,
#   'country': 'Cayman Islands',
#   'description': 'BTCMEX.com is a cryptocurrency derivatives exchange offering Bitcoin perpetual contracts with 100x leverage. Our mission is to "Expand the possibilities of the crypto market by blending the best of traditional finance and innovations with a commitment to continuous improvement resulting in an exchange that offers our customers the best trading experience. "\r\n\r\nThe key advantages of BTCMEX that separate us from the competition are  100,000 TPS per trading pair  to ensure no overloads, customizable trading bots, the most order types within our Next Gen order system, an AI Research center and the most comprehensive educational materials.\r\n\r\nAdditionally BTCMEX upholds the highest crypto standards for security and trading such as separated cold and hot wallets, dual price mechanism, insurance fund,  auto deleveraging (ADL), funding mechanism, testnet accounts for demo purposes, Advanced Protocol Integration (API) for 3rd party integration and 24/7 multi-lingual and live customer support. \r\n\r\nOur platform is accessible online from desktop software, mobile application and mobile website. BTCMEX has offsite backups and  hot-fixes for no server downtime. The exchange was custom made by a team of international experts with a security cooperation with world renowned security teams that constantly audit the integrity of our platform.\r\n',
#   'url': 'https://www.btcmex.com'},
#  {'name': 'Perpetual Protocol',
#   'id': 'perpetual_protocol',
#   'open_interest_btc': 1196.38,
#   'trade_volume_24h_btc': '2371.58',
#   'number_of_perpetual_pairs': 13,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/628/small/token_2000x2000.png?1615791244',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://perp.exchange/'},
#  {'name': 'C-Trade',
#   'id': 'c_trade',
#   'open_interest_btc': 806.43,
#   'trade_volume_24h_btc': '1011.09',
#   'number_of_perpetual_pairs': 2,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/617/small/gFCKNM-r_400x400.jpg?1611287883',
#   'year_established': 2019,
#   'country': 'British Virgin Islands',
#   'description': 'C-Trade is a next-generation cryptocurrency derivatives trading platform established in 2019 and registered in the British Virgin Islands. At C-Trade, we have invented, and keep inventing, top-notch approaches for the best trading experience.\r\n',
#   'url': 'https://www.c-trade.com'},
#  {'name': 'BaseFEX',
#   'id': 'basefex',
#   'open_interest_btc': 803.12,
#   'trade_volume_24h_btc': '920.9',
#   'number_of_perpetual_pairs': 12,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/496/small/BaseFEX-normal.png?1573729624',
#   'year_established': 2018,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://basefex.com'},
#  {'name': 'CoinFLEX (Futures)',
#   'id': 'coinflex_futures',
#   'open_interest_btc': 700.4,
#   'trade_volume_24h_btc': '1584.33',
#   'number_of_perpetual_pairs': 23,
#   'number_of_futures_pairs': 29,
#   'image': 'https://assets.coingecko.com/markets/images/448/small/CoinFlex.png?1579227298',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://coinflex.com/'},
#  {'name': 'dYdX Perpetual',
#   'id': 'dydx_perpetual',
#   'open_interest_btc': 454.87,
#   'trade_volume_24h_btc': '414.12',
#   'number_of_perpetual_pairs': 10,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/646/small/dydx-exchange.jpeg?1617852136',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://dydx.exchange/'},
#  {'name': 'ACDX Futures',
#   'id': 'acdx_futures',
#   'open_interest_btc': 221.22,
#   'trade_volume_24h_btc': '1620.93',
#   'number_of_perpetual_pairs': 189,
#   'number_of_futures_pairs': 9,
#   'image': 'https://assets.coingecko.com/markets/images/604/small/Picture_1.png?1607005941',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://www.acdx.io/'},
#  {'name': 'Bit.com',
#   'id': 'bit_com_futures',
#   'open_interest_btc': 198.78,
#   'trade_volume_24h_btc': '846.19',
#   'number_of_perpetual_pairs': 3,
#   'number_of_futures_pairs': 3,
#   'image': 'https://assets.coingecko.com/markets/images/607/small/bit.jpg?1607319676',
#   'year_established': 2020,
#   'country': 'Seychelles',
#   'description': 'Bit.com is a centralized cryptocurrency exchange located in Seychelles. There are coins and 471 trading pairs on the exchange. Bit.com volume in the last 24 hours is reported to be at ₿866.25 and open interest of ₿780.42. The most active trading pair on Bit.com exchange is BTC/USD. Bit.com is established in year 2020. More information about Bit.com exchange can be found at https://www.bit.com.',
#   'url': 'https://www.bit.com'},
#  {'name': 'AAX Futures',
#   'id': 'aax_futures',
#   'open_interest_btc': 171.73,
#   'trade_volume_24h_btc': '1232.41',
#   'number_of_perpetual_pairs': 7,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/586/small/aax_app_logo.png?1601461630',
#   'year_established': 2019,
#   'country': 'Malta',
#   'description': 'AAX is the world’s first cryptocurrency exchange to be powered by LSEG Technology’s Millennium Exchange, the same matching engine at the heart of tier-one capital markets. AAX is a member of London Stock Exchange Group’s global ‘Partner Platform’. Offering OTC, Spot, and Futures trading, quoting more than 50 cryptocurrency pairs and listing 5 perpetual futures contracts for Bitcoin, Ether, Litecoin, Ripple, and EOS, which can be traded with high leverage, AAX provides a secure, deeply liquid, ultra-low latency and fully compliant trading platform. It offers an institutional-grade platform, for everyone.',
#   'url': 'https://www.aax.com/'},
#  {'name': 'AscendEX  (BitMax) (Futures)',
#   'id': 'bitmax_futures',
#   'open_interest_btc': 128.69,
#   'trade_volume_24h_btc': '372.16',
#   'number_of_perpetual_pairs': 7,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/524/small/AscendEX.png?1616471342',
#   'year_established': 2020,
#   'country': None,
#   'description': 'AscendEX (formerly BitMax) is a leading global digital asset financial platform founded by a group of Wall Street quantitative trading veterans in 2018, building on core value of “Efficiency, Resilience and Transparency.” \r\n \r\nDriven by its continuous innovative product development and early-mover advantage in strategic alignment with the leading projects from DeFi ecosystem, AscendEX offers trading services across over 200 trading pairs across cash, margin, and futures products, in particular margin trading of over 50 tokens in cross-asset collateral mode and futures trading in both cross-asset and isolated margin modes.',
#   'url': 'https://bitmax.io/#/futures/btc-perp'},
#  {'name': 'Futureswap',
#   'id': 'futureswap',
#   'open_interest_btc': 124.98,
#   'trade_volume_24h_btc': '614.31',
#   'number_of_perpetual_pairs': 1,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/619/small/fvcSZOF.png?1611564226',
#   'year_established': 2020,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://exchange.futureswap.com/'},
#  {'name': 'Poloniex Futures',
#   'id': 'poloniex_futures',
#   'open_interest_btc': 108.15,
#   'trade_volume_24h_btc': '329.77',
#   'number_of_perpetual_pairs': 15,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/593/small/poloniex.jpg?1602214536',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': ''},
#  {'name': 'BigONE Futures',
#   'id': 'bigone_futures',
#   'open_interest_btc': 75.59,
#   'trade_volume_24h_btc': '34362.82',
#   'number_of_perpetual_pairs': 8,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/584/small/54c25d1e746577c7ca5be760fac0cdee6d0a4477.jpg.png?1601461551',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': ''},
#  {'name': 'DueDEX',
#   'id': 'duedex',
#   'open_interest_btc': 60.71,
#   'trade_volume_24h_btc': '308.26',
#   'number_of_perpetual_pairs': 4,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/548/small/duedex.png?1594692950',
#   'year_established': 2019,
#   'country': 'Belize',
#   'description': 'DueDEX is a crypto derivatives trading platform registered in Belize. The exchange offers the trade of perpetual swap and futures contracts with up to 100x leverage.\r\n\r\nDueDEX = Due + Derivatives + Exchange\r\n\r\nPowered by unique risk management tools and promise of no internal trading desk, DueDEX strives to be the fairest crypto exchange. Built upon end-to-end multi-sig secure cold wallet storage and with no hot wallet involved, DueDEX aims to deliver the best crypto trading services by combining secure and robust platform, strong product innovation, and professional customer services.\r\n\r\nMore information is available at DueDEX.com',
#   'url': 'https://www.DueDEX.com/'},
#  {'name': 'Alpha5',
#   'id': 'alpha_five',
#   'open_interest_btc': 1.3,
#   'trade_volume_24h_btc': '3.93',
#   'number_of_perpetual_pairs': 2,
#   'number_of_futures_pairs': 5,
#   'image': 'https://assets.coingecko.com/markets/images/620/small/Fzkllkt3_400x400.jpg?1611655812',
#   'year_established': 2020,
#   'country': 'Seychelles',
#   'description': 'A new derivatives exchange aimed at enabling liquidity on futures curves and powered by implied orderbooks.',
#   'url': 'https://www.alpha5.io/trade/#/future/'},
#  {'name': 'CoinTiger (Futures)',
#   'id': 'cointiger_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '402238.28',
#   'number_of_perpetual_pairs': 62,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/577/small/cointiger.png?1599892737',
#   'year_established': None,
#   'country': 'Singapore',
#   'description': '',
#   'url': 'https://futures.cointiger.com/'},
#  {'name': 'Stormgain Futures',
#   'id': 'stormgain_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '12000.63',
#   'number_of_perpetual_pairs': 55,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/610/small/CpDGk9Hn_400x400.png?1607689678',
#   'year_established': None,
#   'country': None,
#   'description': 'StormGain is a crypto trading platform for everyone. It’s a convenient solution for those who want to profit from either the growth or decline of the cryptocurrency market and from long-term investments in crypto assets.\r\nAvailable on any device, StormGain allows you to start trading the most popular and most capitalised coins with a multiplier of up to 200x, or you can just buy and hodl crypto.',
#   'url': 'https://stormgain.com/?utm_id=1DSE&utm_source=coingecko_storm&utm_medium=media&utm_campaign=listing&utm_country=en'},
#  {'name': 'HBTC (Futures)',
#   'id': 'hbtc_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '11457.21',
#   'number_of_perpetual_pairs': 28,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/504/small/BHEX_Logo_1200x1000.jpg?1579863113',
#   'year_established': 2018,
#   'country': 'Malta',
#   'description': 'HBTC is the next generation digital asset trading platform, with top grade performance of matching system which designed for million level of concurrent transactions. It further evolves to a globally distributed multi-nodes system and provides decentralized custody and clearing services of digital assets to institutional and retail investors transparently.',
#   'url': 'https://www.hbtc.com'},
#  {'name': 'GMO Japan (Futures)',
#   'id': 'gmo_japan_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '6600.15',
#   'number_of_perpetual_pairs': 5,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/439/small/GMO.png?1562585771',
#   'year_established': 2016,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://coin.z.com/jp/'},
#  {'name': 'CME Bitcoin Futures',
#   'id': 'cme_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '5922.55',
#   'number_of_perpetual_pairs': 0,
#   'number_of_futures_pairs': 26,
#   'image': 'https://assets.coingecko.com/markets/images/452/small/cme_group.jpg?1564558467',
#   'year_established': 2017,
#   'country': 'United States',
#   'description': 'CME Group Inc provides the CME Globex trading platforms which is a derivatives, options, and futures exchanges based in Chicago and New York City.\r\nCME Group recently introduced Bitcoin Futures (BTC) to its trading platform allowing institutional traders to trade derivative products based on the cryptocurrency, Bitcoin.\r\n\r\nContract Unit: 5 bitcoin, as defined by the CME CF Bitcoin Reference Rate (BRR)\r\nMinimum Price Fluctuation:\r\nOutright: $5.00 per bitcoin = $25.00 per contract\r\nCalendar Spread: $1.00 per bitcoin = $5.00 per contract\r\n\r\n\r\n',
#   'url': 'https://www.cmegroup.com/trading/bitcoin-futures.html'},
#  {'name': 'Bitflyer (Futures)',
#   'id': 'bitflyer_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '2767.48',
#   'number_of_perpetual_pairs': 1,
#   'number_of_futures_pairs': 3,
#   'image': 'https://assets.coingecko.com/markets/images/434/small/WphG7pp0_400x400.jpg?1561623348',
#   'year_established': 2014,
#   'country': 'Japan',
#   'description': '',
#   'url': 'https://lightning.bitflyer.com/'},
#  {'name': 'Delta Exchange (Futures)',
#   'id': 'delta_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '1389.42',
#   'number_of_perpetual_pairs': 75,
#   'number_of_futures_pairs': 13,
#   'image': 'https://assets.coingecko.com/markets/images/480/small/Z31YpPwu_400x400.jpg?1570167324',
#   'year_established': 2018,
#   'country': 'Saint Vincent and the Grenadines',
#   'description': 'Delta Exchange is an crypto derivative exchange with focus on altcoins. Delta exchange offers futures and swaps on BTC and 13 leading altcoins such as BNB, LEO, LINK and ATOM with up to 100x leverage.\r\n\r\n\r\nImportant Features:\r\n\r\n(a) Innovative financial products such has stablecoin (USDC) settled derivatives\r\n\r\n(b) Tight spreads and deep order books in all market conditions\r\n\r\n(c) Enterprise-grade security\r\n\r\n\r\n\r\nDelta exchange offers a neat UI and easy to use trading terminal suitable for both institutional and individual traders. Quantitative and high-frequency traders benefit from reliable, well designed and documented APIs (REST and socket). \r\n\r\n\r\nThe founding team brings experience from Wall Street firms like Citi & UBS and have previously built companies backed by marquee VCs such as Sequoia.',
#   'url': 'https://www.delta.exchange/app/futures/markets'},
#  {'name': 'Equos.io (Perpetual)',
#   'id': 'equos_perpetual',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '713.93',
#   'number_of_perpetual_pairs': 0,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/645/small/EQUOS_logo_200x200.png?1617760229',
#   'year_established': 2020,
#   'country': 'Hong Kong',
#   'description': 'Launched on May 26th, 2020, EQUOS is a centralized spot exchange based in Hong Kong. It currently lists BTC, ETH and USDC as well as BTC/USDC, ETH/USDC and ETH/BTC trading pairs. EQUOS operates out of Singapore under a temporary exemption and has filed an application for a Major Payment Institution license.',
#   'url': 'https://equos.io/'},
#  {'name': 'Leverj',
#   'id': 'leverj',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '155.16',
#   'number_of_perpetual_pairs': 5,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/630/small/leverj-logo-simple.png?1614135892',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': 'High speed decentralized leveraged futures exchange on Plasma',
#   'url': 'https://live.leverj.io/'},
#  {'name': 'Bakkt',
#   'id': 'bakkt',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '130.32',
#   'number_of_perpetual_pairs': 0,
#   'number_of_futures_pairs': 30,
#   'image': 'https://assets.coingecko.com/markets/images/493/small/bakkt.jpg?1573039058',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://www.theice.com/products/72035464/Bakkt-Bitcoin-USD-Monthly-Futures/'},
#  {'name': 'Bibox (Futures)',
#   'id': 'bibox_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '68.81',
#   'number_of_perpetual_pairs': 12,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/490/small/0NRryWCr_400x400.png?1571912187',
#   'year_established': 2019,
#   'country': 'China',
#   'description': '',
#   'url': 'https://www.bibox.com/'},
#  {'name': 'Binance JEX (Futures)',
#   'id': 'jex_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '1.67',
#   'number_of_perpetual_pairs': 3,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/470/small/Jex.jpg?1568973375',
#   'year_established': 2019,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.jex.com/en'},
#  {'name': 'dYdX Perpetual (L1)',
#   'id': 'dydx_perpetual_l1',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '0.0',
#   'number_of_perpetual_pairs': 3,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/536/small/dydx-exchange.jpeg?1618450330',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': 'https://trade.dydx.exchange/perpetual'},
#  {'name': 'Biki (Futures)',
#   'id': 'biki_futures',
#   'open_interest_btc': None,
#   'trade_volume_24h_btc': '0.0',
#   'number_of_perpetual_pairs': 15,
#   'number_of_futures_pairs': 0,
#   'image': 'https://assets.coingecko.com/markets/images/531/small/BiKi_icon.png?1589105196',
#   'year_established': None,
#   'country': None,
#   'description': '',
#   'url': ''}]

# %%
cg.get_derivatives_exchanges_by_id(id='bitmex')
# Out:
# {'name': 'BitMEX',
#  'open_interest_btc': 39696.16,
#  'trade_volume_24h_btc': '64940.78',
#  'number_of_perpetual_pairs': 13,
#  'number_of_futures_pairs': 75,
#  'image': 'https://assets.coingecko.com/markets/images/378/small/BitMEX.png?1591671734',
#  'year_established': None,
#  'country': 'Seychelles',
#  'description': '',
#  'url': 'https://www.bitmex.com/'}

# %%
cg.get_derivatives_exchanges_list()
# Out:
# [{'id': 'binance_futures', 'name': 'Binance (Futures)'},
#  {'id': 'huobi_dm', 'name': 'Huobi Futures'},
#  {'id': 'ftx', 'name': 'FTX (Derivatives)'},
#  {'id': 'bybit', 'name': 'Bybit'},
#  {'id': 'okex_swap', 'name': 'OKEx (Futures)'},
#  {'id': 'mxc_futures', 'name': 'MXC (Futures)'},
#  {'id': 'hopex', 'name': 'Hopex'},
#  {'id': 'bitmex', 'name': 'BitMEX'},
#  {'id': 'deribit', 'name': 'Deribit'},
#  {'id': 'bitfinex_futures', 'name': 'Bitfinex (Futures)'},
#  {'id': 'kumex', 'name': 'KuCoin Futures'},
#  {'id': 'bitget_futures', 'name': 'Bitget Futures'},
#  {'id': 'btse_futures', 'name': 'BTSE (Futures)'},
#  {'id': 'bitz_futures', 'name': 'BitZ (Futures)'},
#  {'id': 'zbg_futures', 'name': 'ZBG Futures'},
#  {'id': 'gate_futures', 'name': 'Gate.io (Futures)'},
#  {'id': 'bitforex_futures', 'name': 'Bitforex (Futures)'},
#  {'id': 'phemex_futures', 'name': 'Phemex (Futures)'},
#  {'id': 'mycoinstory', 'name': 'MyCoinStory'},
#  {'id': 'prime_xbt', 'name': 'Prime XBT'},
#  {'id': 'kraken_futures', 'name': 'Kraken (Futures)'},
#  {'id': 'btcmex', 'name': 'BTCMEX'},
#  {'id': 'perpetual_protocol', 'name': 'Perpetual Protocol'},
#  {'id': 'c_trade', 'name': 'C-Trade'},
#  {'id': 'basefex', 'name': 'BaseFEX'},
#  {'id': 'coinflex_futures', 'name': 'CoinFLEX (Futures)'},
#  {'id': 'dydx_perpetual', 'name': 'dYdX Perpetual'},
#  {'id': 'acdx_futures', 'name': 'ACDX Futures'},
#  {'id': 'bit_com_futures', 'name': 'Bit.com'},
#  {'id': 'aax_futures', 'name': 'AAX Futures'},
#  {'id': 'bitmax_futures', 'name': 'AscendEX  (BitMax) (Futures)'},
#  {'id': 'futureswap', 'name': 'Futureswap'},
#  {'id': 'poloniex_futures', 'name': 'Poloniex Futures'},
#  {'id': 'bigone_futures', 'name': 'BigONE Futures'},
#  {'id': 'duedex', 'name': 'DueDEX'},
#  {'id': 'alpha_five', 'name': 'Alpha5'},
#  {'id': 'bitmart_futures', 'name': 'Bitmart Futures'},
#  {'id': 'hbtc_futures', 'name': 'HBTC (Futures)'},
#  {'id': 'bitflyer_futures', 'name': 'Bitflyer (Futures)'},
#  {'id': 'delta_futures', 'name': 'Delta Exchange (Futures)'},
#  {'id': 'liquid_derivatives', 'name': 'Liquid Perpetuals'},
#  {'id': 'stormgain_futures', 'name': 'Stormgain Futures'},
#  {'id': 'biki_futures', 'name': 'Biki (Futures)'},
#  {'id': 'jex_futures', 'name': 'Binance JEX (Futures)'},
#  {'id': 'cme_futures', 'name': 'CME Bitcoin Futures'},
#  {'id': 'bibox_futures', 'name': 'Bibox (Futures)'},
#  {'id': 'gmo_japan_futures', 'name': 'GMO Japan (Futures)'},
#  {'id': 'mcdex', 'name': 'MCDEX'},
#  {'id': 'leverj', 'name': 'Leverj'},
#  {'id': 'dydx_perpetual_l1', 'name': 'dYdX Perpetual (L1)'},
#  {'id': 'cointiger_futures', 'name': 'CoinTiger (Futures)'},
#  {'id': 'bithumb_futures', 'name': 'Bithumb (Futures)'},
#  {'id': 'fmex', 'name': 'FMex'},
#  {'id': 'bakkt', 'name': 'Bakkt'},
#  {'id': 'equos_perpetual', 'name': 'Equos.io (Perpetual)'}]

# %% [markdown]
# ### Downloading Historical Market Data

# %%
gecko_list = [
    "bitcoin",
    "ethereum",
    "ripple",  # xrp
    "tether",
    "bitcoin-cash",
    "cardano",
    "bitcoin-cash-sv",
    "litecoin",
    "chainlink",
    "binancecoin",
    "eos",
    "tron",
]

# %%
"""
We will get the historical market data up to the number of days indicated by timePeriod below.
As highlighted in the API, the API will return:

minutely data for duration within 1 day
hourly data will be used for duration between 1 day and 90 days
daily data will be used for duration above 90 days
"""

cg = CoinGeckoAPI()
timePeriod = 300

data = {}
for coin in gecko_list:
    try:
        nested_lists = cg.get_coin_market_chart_by_id(
            id=coin, vs_currency="usd", days=timePeriod
        )["prices"]
        data[coin] = {}
        data[coin]["timestamps"], data[coin]["values"] = zip(*nested_lists)

    except Exception as e:
        print(e)
        print("coin: " + coin)

frame_list = [
    pd.DataFrame(data[coin]["values"], index=data[coin]["timestamps"], columns=[coin])
    for coin in gecko_list
    if coin in data
]

# %%
df_cyptocurrency = pd.concat(frame_list, axis=1).sort_index()
df_cyptocurrency
# Out:
#                    bitcoin     ethereum    ripple    tether  bitcoin-cash  \
# 1594512000000  9234.314675   239.102026  0.201416  0.999884    236.537024
# 1594598400000  9297.479636   241.771523  0.200847  0.999738    237.292456
# 1594684800000  9240.762520   239.638787  0.198606  0.999954    231.955717
# 1594771200000  9247.060696   240.251471  0.198871  0.999647    230.211214
# 1594857600000  9203.371435   238.663597  0.197230  0.998742    227.346391
# ...                    ...          ...       ...       ...           ...
# 1620371370000          NaN          NaN       NaN       NaN           NaN
# 1620371379000          NaN          NaN  1.586451       NaN           NaN
# 1620371393000          NaN          NaN       NaN       NaN           NaN
# 1620371396000          NaN          NaN       NaN       NaN   1409.785982
# 1620371421000          NaN  3439.291358       NaN       NaN           NaN
#
#                 cardano  bitcoin-cash-sv   litecoin  chainlink  binancecoin  \
# 1594512000000  0.125425       181.314247  44.622098   6.117897    17.614558
# 1594598400000  0.126878       185.746189  44.707951   7.304026    18.282221
# 1594684800000  0.124288       181.645326  43.933225   7.168236    18.385027
# 1594771200000  0.132081       180.706832  43.855786   8.125226    18.090037
# 1594857600000  0.130447       180.519329  43.315161   8.661236    17.602997
# ...                 ...              ...        ...        ...          ...
# 1620371370000  1.623978              NaN        NaN        NaN          NaN
# 1620371379000       NaN              NaN        NaN        NaN          NaN
# 1620371393000       NaN              NaN        NaN        NaN          NaN
# 1620371396000       NaN              NaN        NaN        NaN          NaN
# 1620371421000       NaN              NaN        NaN        NaN          NaN
#
#                     eos      tron
# 1594512000000  2.619911  0.018356
# 1594598400000  2.615384  0.018162
# 1594684800000  2.553199  0.017539
# 1594771200000  2.557829  0.017632
# 1594857600000  2.535468  0.017580
# ...                 ...       ...
# 1620371370000       NaN       NaN
# 1620371379000       NaN       NaN
# 1620371393000       NaN  0.160178
# 1620371396000       NaN       NaN
# 1620371421000       NaN       NaN
#
# [312 rows x 12 columns]

# %%
df_cyptocurrency["datetime"] = pd.to_datetime(df_cyptocurrency.index, unit="ms")
df_cyptocurrency["date"] = df_cyptocurrency["datetime"].dt.date
df_cyptocurrency["hour"] = df_cyptocurrency["datetime"].dt.hour

# %%
df_cyptocurrency
# Out:
#                 datetime        date  hour currency_name        value
# 0    2020-07-12 00:00:00  2020-07-12     0       bitcoin  9234.314675
# 1    2020-07-13 00:00:00  2020-07-13     0       bitcoin  9297.479636
# 2    2020-07-14 00:00:00  2020-07-14     0       bitcoin  9240.762520
# 3    2020-07-15 00:00:00  2020-07-15     0       bitcoin  9247.060696
# 4    2020-07-16 00:00:00  2020-07-16     0       bitcoin  9203.371435
# ...                  ...         ...   ...           ...          ...
# 3739 2021-05-07 07:09:30  2021-05-07     7          tron          NaN
# 3740 2021-05-07 07:09:39  2021-05-07     7          tron          NaN
# 3741 2021-05-07 07:09:53  2021-05-07     7          tron     0.160178
# 3742 2021-05-07 07:09:56  2021-05-07     7          tron          NaN
# 3743 2021-05-07 07:10:21  2021-05-07     7          tron          NaN
#
# [3744 rows x 5 columns]

# %%
df_cyptocurrency = df_cyptocurrency.melt(
    id_vars=["datetime", "date", "hour"], var_name="currency_name", ignore_index=True
)
df_cyptocurrency.head(5)
# Out:
#     datetime        date  hour currency_name        value
# 0 2020-07-12  2020-07-12     0       bitcoin  9234.314675
# 1 2020-07-13  2020-07-13     0       bitcoin  9297.479636
# 2 2020-07-14  2020-07-14     0       bitcoin  9240.762520
# 3 2020-07-15  2020-07-15     0       bitcoin  9247.060696
# 4 2020-07-16  2020-07-16     0       bitcoin  9203.371435

# %% [markdown]
# ### Mapping

# %%
curr = dict(
    [
        ("bitcoin", "BTC"),
        ("ethereum", "ETH"),
        ("ripple", "XRP"),
        ("bitcoin-cash", "BCH"),
        ("cardano", "ADA"),
        ("bitcoin-cash-sv", "BSV"),
        ("litecoin", "LTC"),
        ("chainlink", "LINK"),
        ("binancecoin", "BNB"),
        ("tron", "TRON"),
        ("eos", "EOS"),
        ("tether", "USDT"),
    ]
)

df_cyptocurrency["coin_symbol"] = df_cyptocurrency["currency_name"].apply(
    lambda c: curr[c]
)

# %%
df_cyptocurrency
# Out:
#                 datetime        date  hour currency_name        value  \
# 0    2020-07-08 00:00:00  2020-07-08     0       bitcoin  9253.630980
# 1    2020-07-09 00:00:00  2020-07-09     0       bitcoin  9432.172516
# 2    2020-07-10 00:00:00  2020-07-10     0       bitcoin  9235.716302
# 3    2020-07-11 00:00:00  2020-07-11     0       bitcoin  9282.913639
# 4    2020-07-12 00:00:00  2020-07-12     0       bitcoin  9234.314675
# ...                  ...         ...   ...           ...          ...
# 3727 2021-05-03 21:21:56  2021-05-03    21          tron          NaN
# 3728 2021-05-03 21:22:09  2021-05-03    21          tron          NaN
# 3729 2021-05-03 21:22:21  2021-05-03    21          tron          NaN
# 3730 2021-05-03 21:22:23  2021-05-03    21          tron          NaN
# 3731 2021-05-03 21:23:05  2021-05-03    21          tron     0.130476
#
#      coin_symbol
# 0            BTC
# 1            BTC
# 2            BTC
# 3            BTC
# 4            BTC
# ...          ...
# 3727        TRON
# 3728        TRON
# 3729        TRON
# 3730        TRON
# 3731        TRON
#
# [3732 rows x 6 columns]
